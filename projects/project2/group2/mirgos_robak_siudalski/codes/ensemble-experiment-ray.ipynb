# %%
import pandas as pd

# Read x_train.txt
X = pd.read_csv('../data/x_train.txt', sep=' ', header=None)

# Read y_train.txt
y = pd.read_csv('../data/y_train.txt', sep=' ', header=None)


# Display the data
print("x:")
print(X.head())

print("\ny:")
print(y.head())
# Out:
# x:
#         0         1         2         3         4         5         6    \
# 0 -2.619773 -2.619533 -1.199350 -1.083335 -1.000910 -0.366967 -2.164037
# 1 -1.415579 -1.782544 -2.880270 -1.958863  1.159968  0.273030 -1.628728
# 2 -2.745092 -1.382945 -1.626015 -1.282560 -0.663146  0.052349 -2.403322
# 3  0.618998  0.455364 -0.115081  0.649040 -0.862207  2.308504  0.526114
# 4 -0.070694 -0.550509 -0.565556 -0.693065 -0.573089 -0.395862  0.003170
#
#         7         8         9    ...        490        491        492  \
# 0 -1.210001 -0.658311 -1.489539  ...  10.849925  10.343346  10.717519
# 1 -0.175813 -0.916857 -0.570166  ...  11.489417   5.195818   3.494627
# 2 -0.765073 -0.394354 -0.806624  ...  13.934934   9.267515   4.705604
# 3 -1.094852  1.088656 -0.481210  ...  12.021328   3.852231  11.059702
# 4 -0.981609 -0.505775 -0.758430  ...   7.537788  11.229665  11.318915
#
#         493        494        495        496        497        498        499
# 0  7.709295   5.894554  12.416573   6.765269  16.243907   7.209524   8.082021
# 1  5.529154  10.517576  15.697333  11.324938  12.187670  12.283861   5.032285
# 2  6.642557  14.658934   8.130767   7.194487  11.939354  11.653620   5.942778
# 3  7.527268   7.253120   9.791136   6.089743  10.752796   5.778888  10.366363
# 4  6.622256  12.557882   5.520360   5.397359  13.152269  10.684779   9.816471
#
# [5 rows x 500 columns]
#
# y:
#    0
# 0  0
# 1  0
# 2  1
# 3  1
# 4  1

# %%
import ray
from ray import tune
from ray.tune.schedulers.hb_bohb import HyperBandForBOHB
from ray.tune.search.bohb import TuneBOHB
from ray.train import report
from sklearn.model_selection import train_test_split
from sklearn.ensemble import ExtraTreesClassifier, VotingClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from xgboost import XGBClassifier
import pandas as pd
import numpy as np
import ConfigSpace as CS
import ConfigSpace.hyperparameters as CSH
import ast
# Assuming your data is in X and y dataframes

def train_ensemble(config):
    vars = ast.literal_eval(config['colset'])
    Xloc = X[vars]
    # Split data into training and validation sets
    X_train, X_val, y_train, y_val = train_test_split(Xloc, y, test_size=0.2)
   
    
    # Initialize the models with the given hyperparameters
    xgb_model = XGBClassifier(
        eta=config["xgb_eta"],
        max_depth=config["xgb_max_depth"],
        min_child_weight=config["xgb_min_child_weight"],
        subsample=config["xgb_subsample"],
        colsample_bytree=config["xgb_colsample_bytree"],
        reg_lambda=config["xgb_lambda"],
        reg_alpha=config["xgb_alpha"],
        objective="binary:logistic",
        eval_metric="logloss",
        use_label_encoder=False,
        verbosity=0
    )

    et_model = ExtraTreesClassifier(
        n_estimators=config["et_n_estimators"],
        max_depth=config["et_max_depth"],
        min_samples_split=config["et_min_samples_split"],
        min_samples_leaf=config["et_min_samples_leaf"],
        max_features=config["et_max_features"],
        bootstrap=config["et_bootstrap"]
    )
    
    svc_model = SVC(
        C=config["svc_C"],
        kernel=config["svc_kernel"],
        probability=True
    )

    lr_model = LogisticRegression(
        C=config["lr_C"],
        solver=config["lr_solver"],
        max_iter=1000
    )
    ensemble_model = VotingClassifier(
        estimators=[
            ('xgb', xgb_model),
            ('et', et_model),
            ('svc', svc_model),
            ('lr', lr_model)
        ],
        voting='soft',
        weights=[
            config["weight_xgb"],
            config["weight_et"],
            config["weight_svc"],
            config["weight_lr"]
        ]
    )
    # Train the models
    # xgb_model.fit(X_train, y_train)
    # et_model.fit(X_train, y_train)
    # svc_model.fit(X_train, y_train)
    # lr_model.fit(X_train, y_train)
    
    # Predict probabilities on the validation set
    # xgb_preds_proba = xgb_model.predict_proba(X_val)[:, 1]
    # et_preds_proba = et_model.predict_proba(X_val)[:, 1]
    # svc_preds_proba = svc_model.predict_proba(X_val)[:, 1]
    # lr_preds_proba = lr_model.predict_proba(X_val)[:, 1]

    ensemble_model.fit(X_train, y_train)
    
    # Ensemble the predictions by averaging
    #ensemble_preds_proba = (xgb_preds_proba + et_preds_proba + svc_preds_proba + lr_preds_proba) / 4
    ensemble_preds_proba = ensemble_model.predict_proba(X_val)[:, 1]
    
    # Get the indices of the top 20% predictions
    top_20_percent_indices = np.argsort(ensemble_preds_proba)[-int(0.2 * len(ensemble_preds_proba)):]

    # Select the corresponding true labels and predicted labels for top 20%
    top_20_true = y_val.iloc[top_20_percent_indices].values
    top_20_preds = (ensemble_preds_proba[top_20_percent_indices] >= 0.5).astype(int)
    
    # Calculate the number of correct class 1 predictions
    correct_class_1_predictions = sum(1 for true, pred in zip(top_20_true, top_20_preds) if true == 1 and pred == 1)
    
    # Calculate the number of features used
    num_features_used = Xloc.shape[1]

    #scaled score calculation
    customer_scaled = (correct_class_1_predictions / len(top_20_preds)) * 1000
    customer_gain = 10 * customer_scaled
    variable_cost = 200 * num_features_used
    custom_score = customer_gain - variable_cost
    
    # Compute the custom score
    #custom_score = (correct_class_1_predictions * 10) - (num_features_used * 200)
    
    report({"custom_score": custom_score})

# Define the search space using ConfigSpace
config_space = CS.ConfigurationSpace()

# Hyperparameters for XGBoost
config_space.add_hyperparameter(CSH.UniformFloatHyperparameter('xgb_eta', lower=0.01, upper=0.1, log=True))
config_space.add_hyperparameter(CSH.UniformIntegerHyperparameter('xgb_max_depth', lower=3, upper=10))
config_space.add_hyperparameter(CSH.UniformIntegerHyperparameter('xgb_min_child_weight', lower=1, upper=5))
config_space.add_hyperparameter(CSH.UniformFloatHyperparameter('xgb_subsample', lower=0.5, upper=1.0))
config_space.add_hyperparameter(CSH.UniformFloatHyperparameter('xgb_colsample_bytree', lower=0.5, upper=1.0))
config_space.add_hyperparameter(CSH.UniformFloatHyperparameter('xgb_lambda', lower=1e-3, upper=10.0, log=True))
config_space.add_hyperparameter(CSH.UniformFloatHyperparameter('xgb_alpha', lower=1e-3, upper=10.0, log=True))

# Hyperparameters for ExstraTrees
config_space.add_hyperparameter(CSH.UniformIntegerHyperparameter('et_n_estimators', lower=50, upper=200))
config_space.add_hyperparameter(CSH.UniformIntegerHyperparameter('et_max_depth', lower=3, upper=20))
config_space.add_hyperparameter(CSH.UniformIntegerHyperparameter('et_min_samples_split', lower=2, upper=10))
config_space.add_hyperparameter(CSH.UniformIntegerHyperparameter('et_min_samples_leaf', lower=1, upper=10))
config_space.add_hyperparameter(CSH.CategoricalHyperparameter('et_max_features', ['sqrt', 'log2']))
config_space.add_hyperparameter(CSH.CategoricalHyperparameter('et_bootstrap', [True, False]))

# Hyperparameters for SVC
config_space.add_hyperparameter(CSH.UniformFloatHyperparameter('svc_C', lower=0.1, upper=10.0, log=True))
config_space.add_hyperparameter(CSH.CategoricalHyperparameter('svc_kernel', ['linear', 'rbf', 'poly', 'sigmoid']))

# Hyperparameters for Logistic Regression
config_space.add_hyperparameter(CSH.UniformFloatHyperparameter('lr_C', lower=0.1, upper=10.0, log=True))
config_space.add_hyperparameter(CSH.CategoricalHyperparameter('lr_solver', ['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga']))

config_space.add_hyperparameter(CSH.UniformFloatHyperparameter('weight_xgb', lower=0.0, upper=1.0))
config_space.add_hyperparameter(CSH.UniformFloatHyperparameter('weight_et', lower=0.0, upper=1.0))
config_space.add_hyperparameter(CSH.UniformFloatHyperparameter('weight_svc', lower=0.0, upper=1.0))
config_space.add_hyperparameter(CSH.UniformFloatHyperparameter('weight_lr', lower=0.0, upper=1.0))


config_space.add_hyperparameter(CSH.CategoricalHyperparameter('colset', ['[101, 102, 103, 105]', '[101, 102, 103]', '[101, 102, 105]', '[101, 103, 105]', '[102, 103, 105]', '[104, 102, 103, 105]', '[100, 101, 102, 103, 105]', '[100, 101, 102, 103]', '[100, 101, 102, 105]', '[100, 101, 103, 105]', '[100, 102, 103, 105]', '[100, 104, 102, 103, 105]', '[100, 101, 102, 103, 104, 105]']))

# Set up the BOHB search algorithm
bohb_search = TuneBOHB(config_space, metric="custom_score", mode="max")

# Set up the HyperBandForBOHB scheduler
bohb_scheduler = HyperBandForBOHB(
    time_attr="training_iteration",
    metric="custom_score",
    mode="max"
)

# Function to create shorter directory names
def trial_dirname_creator(trial):
    return f"trial_{trial.trial_id}"

# Run the hyperparameter search
analysis = tune.run(
    train_ensemble,
    resources_per_trial={"cpu": 1, "gpu": 0},
    search_alg=bohb_search,
    scheduler=bohb_scheduler,
    num_samples=500,
    trial_dirname_creator=trial_dirname_creator,
    raise_on_failed_trial=False
)

# Get the best result
best_config = analysis.get_best_config(metric="custom_score", mode="max")
print("Best config: ", best_config)
# Out:
# 2024-05-29 13:32:16,193	INFO worker.py:1749 -- Started a local Ray instance.
# 2024-05-29 13:32:17,258	INFO tune.py:253 -- Initializing Ray automatically. For cluster usage or custom Ray initialization, call `ray.init(...)` before `tune.run(...)`.
# 2024-05-29 13:32:17,259	INFO tune.py:614 -- [output] This uses the legacy output and progress reporter, as Jupyter notebooks are not supported by the new engine, yet. For more information, please see https://github.com/ray-project/ray/issues/36949
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2024-05-29 13:48:30</td></tr>
# <tr><td>Running for: </td><td>00:16:12.85        </td></tr>
# <tr><td>Memory:      </td><td>28.8/63.8 GiB      </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using HyperBand: num_stopped=54 total_brackets=2<br>Round #0:<br>  Bracket(Max Size (n)=27, Milestone (r)=3, completed=20.0%): {TERMINATED: 81} <br>  Bracket(Max Size (n)=12, Milestone (r)=9, completed=88.4%): {TERMINATED: 419} <br>Logical resource usage: 1.0/28 CPUs, 0/1 GPUs (0.0/1.0 accelerator_type:G)
#     </div>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name             </th><th>status    </th><th>loc            </th><th>colset              </th><th>et_bootstrap  </th><th style="text-align: right;">  et_max_depth</th><th>et_max_features  </th><th style="text-align: right;">  et_min_samples_leaf</th><th style="text-align: right;">  et_min_samples_split</th><th style="text-align: right;">  et_n_estimators</th><th style="text-align: right;">    lr_C</th><th>lr_solver  </th><th style="text-align: right;">   svc_C</th><th>svc_kernel  </th><th style="text-align: right;">  weight_et</th><th style="text-align: right;">  weight_lr</th><th style="text-align: right;">  weight_svc</th><th style="text-align: right;">  weight_xgb</th><th style="text-align: right;">  xgb_alpha</th><th style="text-align: right;">  xgb_colsample_bytree</th><th style="text-align: right;">  xgb_eta</th><th style="text-align: right;">  xgb_lambda</th><th style="text-align: right;">  xgb_max_depth</th><th style="text-align: right;">  xgb_min_child_weight</th><th style="text-align: right;">  xgb_subsample</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  custom_score</th></tr>
# </thead>
# <tbody>
# <tr><td>train_ensemble_22c73578</td><td>TERMINATED</td><td>127.0.0.1:45528</td><td>[100, 101, 102,_ab50</td><td>True          </td><td style="text-align: right;">            20</td><td>sqrt             </td><td style="text-align: right;">                    9</td><td style="text-align: right;">                     8</td><td style="text-align: right;">               53</td><td style="text-align: right;">8.52415 </td><td>saga       </td><td style="text-align: right;">0.136305</td><td>poly        </td><td style="text-align: right;"> 0.30358   </td><td style="text-align: right;">0.101725   </td><td style="text-align: right;">  0.933142  </td><td style="text-align: right;"> 0.455196   </td><td style="text-align: right;"> 0.0307395 </td><td style="text-align: right;">              0.791668</td><td style="text-align: right;">0.036376 </td><td style="text-align: right;">  0.00757243</td><td style="text-align: right;">              4</td><td style="text-align: right;">                     4</td><td style="text-align: right;">       0.781699</td><td style="text-align: right;">     1</td><td style="text-align: right;">        1.18523 </td><td style="text-align: right;">          6350</td></tr>
# <tr><td>train_ensemble_78469c1b</td><td>TERMINATED</td><td>127.0.0.1:25896</td><td>[100, 104, 102,_b640</td><td>False         </td><td style="text-align: right;">             3</td><td>sqrt             </td><td style="text-align: right;">                    2</td><td style="text-align: right;">                     5</td><td style="text-align: right;">              125</td><td style="text-align: right;">0.813241</td><td>newton-cg  </td><td style="text-align: right;">0.795495</td><td>sigmoid     </td><td style="text-align: right;"> 0.295847  </td><td style="text-align: right;">0.816179   </td><td style="text-align: right;">  0.464023  </td><td style="text-align: right;"> 0.0970291  </td><td style="text-align: right;"> 2.79364   </td><td style="text-align: right;">              0.663552</td><td style="text-align: right;">0.0841544</td><td style="text-align: right;">  0.0149942 </td><td style="text-align: right;">              8</td><td style="text-align: right;">                     1</td><td style="text-align: right;">       0.641113</td><td style="text-align: right;">     1</td><td style="text-align: right;">        1.74932 </td><td style="text-align: right;">          6200</td></tr>
# <tr><td>train_ensemble_68f7ed2e</td><td>TERMINATED</td><td>127.0.0.1:58224</td><td>[101, 102, 103, 105]</td><td>True          </td><td style="text-align: right;">            14</td><td>sqrt             </td><td style="text-align: right;">                    4</td><td style="text-align: right;">                    10</td><td style="text-align: right;">              147</td><td style="text-align: right;">0.660762</td><td>saga       </td><td style="text-align: right;">2.53515 </td><td>sigmoid     </td><td style="text-align: right;"> 0.326389  </td><td style="text-align: right;">0.522018   </td><td style="text-align: right;">  0.220444  </td><td style="text-align: right;"> 0.177316   </td><td style="text-align: right;"> 0.321472  </td><td style="text-align: right;">              0.725514</td><td style="text-align: right;">0.0184404</td><td style="text-align: right;">  0.0191618 </td><td style="text-align: right;">              7</td><td style="text-align: right;">                     5</td><td style="text-align: right;">       0.546784</td><td style="text-align: right;">     1</td><td style="text-align: right;">        1.50565 </td><td style="text-align: right;">          6750</td></tr>
# <tr><td>train_ensemble_c959d932</td><td>TERMINATED</td><td>127.0.0.1:55096</td><td>[101, 103, 105]     </td><td>False         </td><td style="text-align: right;">            17</td><td>sqrt             </td><td style="text-align: right;">                    3</td><td style="text-align: right;">                     4</td><td style="text-align: right;">              186</td><td style="text-align: right;">4.06335 </td><td>saga       </td><td style="text-align: right;">7.45293 </td><td>poly        </td><td style="text-align: right;"> 0.328199  </td><td style="text-align: right;">0.810831   </td><td style="text-align: right;">  0.85698   </td><td style="text-align: right;"> 0.0530776  </td><td style="text-align: right;"> 0.501389  </td><td style="text-align: right;">              0.567672</td><td style="text-align: right;">0.0139128</td><td style="text-align: right;">  0.111816  </td><td style="text-align: right;">              3</td><td style="text-align: right;">                     4</td><td style="text-align: right;">       0.561262</td><td style="text-align: right;">     1</td><td style="text-align: right;">        2.57561 </td><td style="text-align: right;">          6250</td></tr>
# <tr><td>train_ensemble_b45ae11e</td><td>TERMINATED</td><td>127.0.0.1:60380</td><td>[100, 101, 102, 105]</td><td>True          </td><td style="text-align: right;">            14</td><td>sqrt             </td><td style="text-align: right;">                    4</td><td style="text-align: right;">                    10</td><td style="text-align: right;">              177</td><td style="text-align: right;">0.2716  </td><td>lbfgs      </td><td style="text-align: right;">0.149416</td><td>linear      </td><td style="text-align: right;"> 0.574648  </td><td style="text-align: right;">0.282162   </td><td style="text-align: right;">  0.631862  </td><td style="text-align: right;"> 0.290142   </td><td style="text-align: right;"> 0.023934  </td><td style="text-align: right;">              0.982069</td><td style="text-align: right;">0.0419023</td><td style="text-align: right;">  0.00379067</td><td style="text-align: right;">              4</td><td style="text-align: right;">                     3</td><td style="text-align: right;">       0.994315</td>
# (raylet) Warning: The actor ImplicitFunc is very large (19 MiB). Check that its definition is not implicitly capturing a large array or other object in scope. Tip: use ray.put() to put large objects in the Ray object store.
# (train_ensemble pid=45528) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:97: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# (train_ensemble pid=45528)   y = column_or_1d(y, warn=True)
# (train_ensemble pid=45528) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# (train_ensemble pid=45528)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# <div class="trialProgress">
#   <h3>Trial Progress</h3>
#   <table>
# <thead>
# <tr><th>Trial name             </th><th style="text-align: right;">  custom_score</th></tr>
# </thead>
# <tbody>
# <tr><td>train_ensemble_00fa124e</td><td style="text-align: right;">          6850</td></tr>
# <tr><td>train_ensemble_0127f3f9</td><td style="text-align: right;">          6850</td></tr>
# <tr><td>train_ensemble_012d3024</td><td style="text-align: right;">          6600</td></tr>
# <tr><td>train_ensemble_0194f48d</td><td style="text-align: right;">          6800</td></tr>
# <tr><td>train_ensemble_01b520b7</td><td style="text-align: right;">          6300</td></tr>
# <tr><td>train_ensemble_01fde203</td><td style="text-align: right;">          6900</td></tr>
# <tr><td>train_ensemble_0221e32e</td><td style="text-align: right;">          6550</td></tr>
# <tr><td>train_ensemble_0256ff27</td><td style="text-align: right;">          6950</td></tr>
# <tr><td>train_ensemble_02a437df</td><td style="text-align: right;">          6750</td></tr>
# <tr><td>train_ensemble_0317ea2c</td><td style="text-align: right;">          6550</td></tr>
# <tr><td>train_ensemble_0373a951</td><td style="text-align: right;">          6450</td></tr>
# <tr><td>train_ensemble_04b97853</td><td style="text-align: right;">          6950</td></tr>
# <tr><td>train_ensemble_04e0e6be</td><td style="text-align: right;">          6650</td></tr>
# <tr><td>train_ensemble_05e66b8d</td><td style="text-align: right;">          7100</td></tr>
# <tr><td>train_ensemble_0608809a</td><td style="text-align: right;">          6100</td></tr>
# <tr><td>train_ensemble_0640e0ea</td><td style="text-align: right;">          6200</td></tr>
# <tr><td>train_ensemble_0a0f5526</td><td style="text-align: right;">          6750</td></tr>
# <tr><td>train_ensemble_0a7984cb</td><td style="text-align: right;">          6700</td></tr>
# <tr><td>train_ensemble_0bcfb4d6</td><td style="text-align: right;">          6700</td></tr>
# <tr><td>train_ensemble_0da6dde4</td><td style="text-align: right;">          6850</td></tr>
# <tr><td>train_ensemble_0ec9ad80</td><td style="text-align: right;">          6000</td></tr>
# <tr><td>train_ensemble_0ef9114b</td><td style="text-align: right;">          6350</td></tr>
# <tr><td>train_ensemble_1093b4e0</td><td style="text-align: right;">          7000</td></tr>
# <tr><td>train_ensemble_10bc20d2</td><td style="text-align: right;">          6350</td></tr>
# <tr><td>train_ensemble_11a42491</td><td style="text-align: right;">          6600</td></tr>
# <tr><td>train_ensemble_13f742e8</td><td style="text-align: right;">          7050</td></tr>
# <tr><td>train_ensemble_145b23f9</td><td style="text-align: right;">          6200</td></tr>
# <tr><td>train_ensemble_156e1075</td><td style="text-align: right;">          6150</td></tr>
# <tr><td>train_ensemble_15b021b1</td><td style="text-align: right;">          7100</td></tr>
# <tr><td>train_ensemble_15cc71db</td><td style="text-align: right;">          6300</td></tr>
# <tr><td>train_ensemble_1607de6c</td><td style="text-align: right;">          6150</td></tr>
# <tr><td>train_ensemble_161026c2</td><td style="text-align: right;">          6650</td></tr>
# <tr><td>train_ensemble_1676484d</td><td style="text-align: right;">          5700</td></tr>
# <tr><td>train_ensemble_16b118e3</td><td style="text-align: right;">          7100</td></tr>
# <tr><td>train_ensemble_16d339ce</td><td style="text-align: right;">          5350</td></tr>
# <tr><td>train_ensemble_1748abde</td><td style="text-align: right;">          6100</td></tr>
# <tr><td>train_ensemble_17bda04f</td><td style="text-align: right;">          6300</td></tr>
# <tr><td>train_ensemble_1a8eba62</td><td style="text-align: right;">          6650</td></tr>
# <tr><td>train_ensemble_1a9de762</td><td style="text-align: right;">          6850</td></tr>
# <tr><td>train_ensemble_1aef05ba</td><td style="text-align: right;">          6650</td></tr>
# <tr><td>train_ensemble_1afacdc2</td><td style="text-align: right;">          6650</td></tr>
# <tr><td>train_ensemble_1b748a85</td><td style="text-align: right;">          6350</td></tr>
# <tr><td>train_ensemble_1caea1bc</td><td style="text-align: right;">          7100</td></tr>
# <tr><td>train_ensemble_1ce620a0</td><td style="text-align: right;">          7050</td></tr>
# <tr><td>train_ensemble_1d164f08</td><td style="text-align: right;">          6700</td></tr>
# <tr><td>train_ensemble_1d2653fb</td><td style="text-align: right;">          6750</td></tr>
# <tr><td>train_ensemble_1dae0dda</td><td style="text-align: right;">          6650</td></tr>
# <tr><td>train_ensemble_1dcaf151</td><td style="text-align: right;">          6650</td></tr>
# <tr><td>train_ensemble_1e1cf9b4</td><td style="text-align: right;">          6850</td></tr>
# <tr><td>train_ensemble_1e84f84e</td><td style="text-align: right;">          6350</td></tr>
# <tr><td>train_ensemble_1e98db6b</td><td style="text-align: right;">          6800</td></tr>
# <tr><td>train_ensemble_1ee9e958</td><td style="text-align: right;">          6750</td></tr>
# <tr><td>train_ensemble_1f21b901</td><td style="text-align: right;">          6800</td></tr>
# <tr><td>train_ensemble_1fa25cb6</td><td style="text-align: right;">          6700</td></tr>
# <tr><td>train_ensemble_1fd1c326</td><td style="text-align: right;">          6650</td></tr>
# <tr><td>train_ensemble_205643fe</td><td style="text-align: right;">          7100</td></tr>
# <tr><td>train_ensemble_2062d0f5</td><td style="text-align: right;">          6600</td></tr>
# <tr><td>train_ensemble_224b30f9</td><td style="text-align: right;">          6550</td></tr>
# <tr><td>train_ensemble_227323f6</td><td style="text-align: right;">          7150</td></tr>
# <tr><td>train_ensemble_22c73578</td><td style="text-align: right;">          6350</td></tr>
# <tr><td>train_ensemble_22dc45fb</td><td style="text-align: right;">          6800</td></tr>
# <tr><td>train_ensemble_241d2c3a</td><td style="text-align: right;">          6650</td></tr>
# <tr><td>train_ensemble_243330ad</td><td style="text-align: right;">          6800</td></tr>
# <tr><td>train_ensemble_248cca3a</td><td style="text-align: right;">          6750</td></tr>
# <tr><td>train_ensemble_2520c0df</td><td style="text-align: right;">          6000</td></tr>
# <tr><td>train_ensemble_25ed6e47</td><td style="text-align: right;">          6400</td></tr>
# <tr><td>train_ensemble_26720cc3</td><td style="text-align: right;">          6650</td></tr>
# <tr><td>train_ensemble_267cb339</td><td style="text-align: right;">          6650</td></tr>
# <tr><td>train_ensemble_274aa637</td><td style="text-align: right;">          6800</td></tr>
# <tr><td>train_ensemble_2750b53b</td><td style="text-align: right;">          7150</td></tr>
# <tr><td>train_ensemble_277da285</td><td style="text-align: right;">          6850</td></tr>
# <tr><td>train_ensemble_282a2ec0</td><td style="text-align: right;">          6650</td></tr>
# <tr><td>train_ensemble_284f768f</td><td style="text-align: right;">          6850</td></tr>
# <tr><td>train_ensemble_288ab09a</td><td style="text-align: right;">          6350</td></tr>
# <tr><td>train_ensemble_28ebfcbb</td><td style="text-align: right;">          6000</td></tr>
# <tr><td>train_ensemble_28efb497</td><td style="text-align: right;">          7150</td></tr>
# <tr><td>train_ensemble_28f4a1c3</td><td style="text-align: right;">          6600</td></tr>
# <tr><td>train_ensemble_2a93951f</td><td style="text-align: right;">          6350</td></tr>
# <tr><td>train_ensemble_2abae96b</td><td style="text-align: right;">          6650</td></tr>
# <tr><td>train_ensemble_2b51d7f3</td><td style="text-align: right;">          6900</td></tr>
# <tr><td>train_ensemble_2b5e116b</td><td style="text-align: right;">          6600</td></tr>
# <tr><td>train_ensemble_2c09122a</td><td style="text-align: right;">          6550</td></tr>
# <tr><td>train_ensemble_2da073aa</td><td style="text-align: right;">          6650</td></tr>
# <tr><td>train_ensemble_2e2c7c94</td><td style="text-align: right;">          6600</td></tr>
# <tr><td>train_ensemble_2e684c26</td><td style="text-align: right;">          7000</td></tr>
# (train_ensemble pid=55096) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/user-guides/configure-logging.html#log-deduplication for more options.)
# (train_ensemble pid=55096)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=55096)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=24112) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=24112)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=24112)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=56172) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=56172)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=56172)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=44184) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=44184)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=44184)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=54792) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=54792)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=54792)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=41100) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=41100)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=41100)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=51976) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=51976)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=51976)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=51396) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=51396)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=51396)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=14872) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=14872)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=14872)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=41832) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=41832)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=41832)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=32208) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=32208)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=32208)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=49868) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=49868)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=49868)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=28536) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=28536)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=28536)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=31644) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=31644)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=31644)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=44508) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=44508)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=44508)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=34116) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=34116)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=34116)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=60496) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=60496)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=60496)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=12988) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=12988)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=12988)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=7200) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=7200)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=7200)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=62392) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=62392)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=62392)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=46120) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=46120)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=46120)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=17368) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=17368)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=17368)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=2300) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=2300)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=2300)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=37232) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=37232)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=37232)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=30564) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=30564)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=30564)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=45268) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=45268)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=45268)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=8040) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=8040)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=8040)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# 2024-05-29 13:34:54,110	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# 2024-05-29 13:34:56,050	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# 2024-05-29 13:34:58,034	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# (train_ensemble pid=39508) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 10x across cluster]
# (train_ensemble pid=39508)   y = column_or_1d(y, warn=True) [repeated 5x across cluster]
# (train_ensemble pid=39508)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 5x across cluster]
# 2024-05-29 13:34:59,368	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# 2024-05-29 13:35:01,284	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# 2024-05-29 13:35:03,257	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# (train_ensemble pid=19064) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 10x across cluster]
# (train_ensemble pid=19064)   y = column_or_1d(y, warn=True) [repeated 5x across cluster]
# (train_ensemble pid=19064)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 5x across cluster]
# 2024-05-29 13:35:04,912	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# 2024-05-29 13:35:07,157	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# 2024-05-29 13:35:08,493	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# (train_ensemble pid=45300) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 8x across cluster]
# (train_ensemble pid=45300)   y = column_or_1d(y, warn=True) [repeated 4x across cluster]
# (train_ensemble pid=45300)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 4x across cluster]
# 2024-05-29 13:35:11,251	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# 2024-05-29 13:35:12,146	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# 2024-05-29 13:35:14,167	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# (train_ensemble pid=37620) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 10x across cluster]
# (train_ensemble pid=37620)   y = column_or_1d(y, warn=True) [repeated 5x across cluster]
# (train_ensemble pid=37620)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 5x across cluster]
# 2024-05-29 13:35:15,950	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# 2024-05-29 13:35:17,495	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# 2024-05-29 13:35:19,069	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# (train_ensemble pid=41928) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 8x across cluster]
# (train_ensemble pid=41928)   y = column_or_1d(y, warn=True) [repeated 4x across cluster]
# (train_ensemble pid=41928)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 4x across cluster]
# 2024-05-29 13:35:21,449	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# 2024-05-29 13:35:23,062	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# 2024-05-29 13:35:24,741	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# (train_ensemble pid=26936) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 10x across cluster]
# (train_ensemble pid=26936)   y = column_or_1d(y, warn=True) [repeated 5x across cluster]
# (train_ensemble pid=26936)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 5x across cluster]
# 2024-05-29 13:35:26,286	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# 2024-05-29 13:35:28,376	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# 2024-05-29 13:35:30,679	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# (train_ensemble pid=63752) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 8x across cluster]
# (train_ensemble pid=63752)   y = column_or_1d(y, warn=True) [repeated 4x across cluster]
# (train_ensemble pid=63752)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 4x across cluster]
# 2024-05-29 13:35:32,381	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# 2024-05-29 13:35:33,876	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# 2024-05-29 13:35:35,858	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# (train_ensemble pid=30996) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 10x across cluster]
# (train_ensemble pid=30996)   y = column_or_1d(y, warn=True) [repeated 5x across cluster]
# (train_ensemble pid=30996)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 5x across cluster]
# 2024-05-29 13:35:37,768	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# 2024-05-29 13:35:39,380	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# 2024-05-29 13:35:41,169	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# (train_ensemble pid=36096) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 8x across cluster]
# (train_ensemble pid=36096)   y = column_or_1d(y, warn=True) [repeated 4x across cluster]
# (train_ensemble pid=36096)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 4x across cluster]
# (train_ensemble pid=7600) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=7600)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=7600)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=9140) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=9140)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=9140)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=53008) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=53008)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=53008)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=40508) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=40508)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=40508)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=9800) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=9800)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=9800)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=24092) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=24092)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=24092)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=64216) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=64216)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=64216)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=6120) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=6120)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=6120)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=31768) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=31768)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=31768)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=4696) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=4696)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=4696)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=2876) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=2876)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=2876)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=28892) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=28892)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=28892)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=47332) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=47332)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=47332)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=27168) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=27168)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=27168)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=9036) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=9036)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=9036)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=43376) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=43376)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=43376)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=23580) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=23580)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=23580)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=10192) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=10192)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=10192)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=45108) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=45108)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=45108)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=21840) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=21840)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# ...
# (train_ensemble pid=15876) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=15876)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=15876)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=32092) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:97: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 5x across cluster]
# (train_ensemble pid=32092)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=37452)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 2x across cluster]
# (train_ensemble pid=22532) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 7x across cluster]
# (train_ensemble pid=22532)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=22532)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 4x across cluster]
# (train_ensemble pid=61324) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=61324)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=61324)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=24392) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=24392)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=24392)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=8148) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=8148)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=8148)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=14248) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=14248)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=14248)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=14288) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=14288)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=14288)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=10796) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=10796)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=10796)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=21260) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=21260)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=21260)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=14696) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=14696)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=14696)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# 2024-05-29 13:46:52,727	WARNING util.py:201 -- The `callbacks.on_trial_result` operation took 0.547 s, which may be a performance bottleneck.
# 2024-05-29 13:46:52,727	WARNING util.py:201 -- The `process_trial_result` operation took 0.547 s, which may be a performance bottleneck.
# 2024-05-29 13:46:52,728	WARNING util.py:201 -- Processing trial results took 0.548 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-05-29 13:46:52,729	WARNING util.py:201 -- The `process_trial_result` operation took 0.549 s, which may be a performance bottleneck.
# (train_ensemble pid=48760) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=48760)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=48760)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=43356) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=43356)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=43356)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=13996) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=13996)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=13996)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=60864) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=60864)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=60864)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=53932) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=53932)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=53932)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=38184) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=38184)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=38184)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=33832) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=33832)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=33832)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=47284) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=47284)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=47284)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=54752) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=54752)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=54752)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=58780) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=58780)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=58780)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=22964) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=22964)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=22964)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=31172) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=31172)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=31172)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=27376) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=27376)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=27376)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=59808) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=59808)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=59808)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=43100) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=43100)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=43100)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=51064) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=51064)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=51064)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=8040) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=8040)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=8040)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# 2024-05-29 13:48:30,117	WARNING experiment_state.py:205 -- Experiment state snapshotting has been triggered multiple times in the last 5.0 seconds. A snapshot is forced if `CheckpointConfig(num_to_keep)` is set, and a trial has checkpointed >= `num_to_keep` times since the last snapshot.
# You may want to consider increasing the `CheckpointConfig(num_to_keep)` or decreasing the frequency of saving checkpoints.
# You can suppress this error by setting the environment variable TUNE_WARN_EXCESSIVE_EXPERIMENT_CHECKPOINT_SYNC_THRESHOLD_S to a smaller value than the current threshold (5.0).
# 2024-05-29 13:48:30,390	INFO tune.py:1007 -- Wrote the latest version of all result files and experiment state to 'C:/Users/Mieszko/ray_results/train_ensemble_2024-05-29_13-32-17' in 0.3128s.
# 2024-05-29 13:48:30,507	INFO tune.py:1039 -- Total run time: 973.25 seconds (972.53 seconds for the tuning loop).
# Best config:  {'colset': '[100, 101, 102, 105]', 'et_bootstrap': True, 'et_max_depth': 7, 'et_max_features': 'sqrt', 'et_min_samples_leaf': 3, 'et_min_samples_split': 2, 'et_n_estimators': 191, 'lr_C': 0.2965858992012039, 'lr_solver': 'liblinear', 'svc_C': 0.14666802003882573, 'svc_kernel': 'linear', 'weight_et': 0.779258883724107, 'weight_lr': 0.5947871845865511, 'weight_svc': 0.2843918757107351, 'weight_xgb': 0.5108061358970724, 'xgb_alpha': 0.13534525357173383, 'xgb_colsample_bytree': 0.5327687947981937, 'xgb_eta': 0.025506248584380223, 'xgb_lambda': 0.06358084547274466, 'xgb_max_depth': 6, 'xgb_min_child_weight': 4, 'xgb_subsample': 0.6996535735845992}

# %%
df=analysis.dataframe()
df.to_csv('ensemble1-raytune-bohb.csv')

# %%
df.sort_values(by='custom_score', ascending=False, inplace=True)
print(df.head())
# Out:
#      custom_score   timestamp checkpoint_dir_name   done  training_iteration  \
# 435        7800.0  1716983186                None  False                   1
# 472        7600.0  1716983258                None  False                   1
# 225        7500.0  1716982786                None  False                   1
# 139        7400.0  1716982626                None  False                   1
# 311        7350.0  1716982949                None  False                   1
#
#      trial_id                 date  time_this_iter_s  time_total_s    pid  \
# 435  33c3d2ef  2024-05-29_13-46-26          1.002002      1.002002   9324
# 472  530c9293  2024-05-29_13-47-38          1.301511      1.301511  37732
# 225  81d84b57  2024-05-29_13-39-46          1.583009      1.583009  12976
# 139  60ceaa69  2024-05-29_13-37-06          1.776253      1.776253  39040
# 311  b242716a  2024-05-29_13-42-29          1.023832      1.023832  14988
#
#      ... config/weight_svc config/weight_xgb  config/xgb_alpha  \
# 435  ...          0.284392          0.510806          0.135345
# 472  ...          0.775695          0.417631          0.073119
# 225  ...          0.175602          0.014817          0.374858
# 139  ...          0.514773          0.828660          2.054831
# 311  ...          0.424070          0.259491          0.304805
#
#      config/xgb_colsample_bytree config/xgb_eta  config/xgb_lambda  \
# 435                     0.532769       0.025506           0.063581
# 472                     0.553140       0.029481           0.002169
# 225                     0.602731       0.054505           0.002853
# 139                     0.584385       0.010487           0.004494
# 311                     0.721159       0.010101           0.019823
#
#      config/xgb_max_depth config/xgb_min_child_weight  config/xgb_subsample  \
# 435                     6                           4              0.699654
# 472                     9                           4              0.580496
# 225                     7                           3              0.623434
# 139                    10                           4              0.746351
# 311                     4                           2              0.563118
#
#        logdir
# 435  33c3d2ef
# 472  530c9293
# 225  81d84b57
# 139  60ceaa69
# 311  b242716a
#
# [5 rows x 37 columns]
