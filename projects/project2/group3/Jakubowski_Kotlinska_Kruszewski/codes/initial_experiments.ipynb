# %% [markdown]
# # Initial experiments
#
# This notebook contains some initial experiments with the data. We evaluate several feature selection techniques and evaluate the features chosen by them in training a plethora of classifiers.

# %%
import warnings

import numpy as np
import pandas as pd
from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier
from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis, QuadraticDiscriminantAnalysis
from sklearn.ensemble import ExtraTreesClassifier, GradientBoostingClassifier, RandomForestClassifier
from sklearn.feature_selection import RFE, SelectFromModel, SelectKBest, f_classif
from sklearn.linear_model import ElasticNet, Lasso, LogisticRegression
from sklearn.model_selection import StratifiedKFold, cross_val_score, train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from xgboost import XGBClassifier

from evaluation import evaluate

warnings.filterwarnings("ignore")

# %%
# load data from txt files
X_train = pd.DataFrame(np.loadtxt('../data/x_train.txt'))
X_test = pd.DataFrame(np.loadtxt('../data/x_test.txt'))
y_train = pd.DataFrame(np.loadtxt('../data/y_train.txt'))
y_train = y_train.values.ravel()

# %%
# evaluate the feature selection methods on this dataset: SelectKBest, RFE, SFS, Random Forest, PCA, Lasso

max_features = 4

# SelectKBest
selector = SelectKBest(f_classif, k=max_features)
selector.fit(X_train, y_train)
X_train_kbest = selector.transform(X_train)
X_test_kbest = selector.transform(X_test)

# RFE
estimator = LogisticRegression()
selector = RFE(estimator, n_features_to_select=max_features)
selector.fit(X_train, y_train)
X_train_rfe = selector.transform(X_train)
X_test_rfe = selector.transform(X_test)

# Random Forest
estimator = RandomForestClassifier()
selector = SelectFromModel(estimator, max_features=max_features)
selector.fit(X_train, y_train)
X_train_rf = selector.transform(X_train)
X_test_rf = selector.transform(X_test)

# XGBoost
estimator = XGBClassifier()
selector = SelectFromModel(estimator, max_features=max_features)
selector.fit(X_train, y_train)
X_train_xgb = selector.transform(X_train)
X_test_xgb = selector.transform(X_test)

# Decision Tree
estimator = DecisionTreeClassifier()
selector = SelectFromModel(estimator, max_features=max_features)
selector.fit(X_train, y_train)
X_train_dt = selector.transform(X_train)
X_test_dt = selector.transform(X_test)

# Extra Trees Classifier
estimator = ExtraTreesClassifier()
selector = SelectFromModel(estimator, max_features=max_features)
selector.fit(X_train, y_train)
X_train_et = selector.transform(X_train)
X_test_et = selector.transform(X_test)




# PCA
estimator = PCA(n_components=max_features)
estimator.fit(X_train)
X_train_pca = estimator.transform(X_train)
X_test_pca = estimator.transform(X_test)

# Lasso
estimator = Lasso(alpha=0.1)
estimator.fit(X_train, y_train)
# filter out the features that are not important
important_features = estimator.coef_ != 0
X_train_lasso = X_train.loc[:, important_features]
X_test_lasso = X_test.loc[:, important_features]

# %%
# initialize classifiers
lr = LogisticRegression()
lda = LinearDiscriminantAnalysis()
qda = QuadraticDiscriminantAnalysis()
svm = SVC(probability=True)
elastic = LogisticRegression(penalty='elasticnet', solver='saga', l1_ratio=0.5) # ElasticNet()
dt = DecisionTreeClassifier()
rf = RandomForestClassifier()
gb = GradientBoostingClassifier()
nn = MLPClassifier()
xgb = XGBClassifier()
lgb = LGBMClassifier(verbose=-1)
cat = CatBoostClassifier(verbose=0)
et = ExtraTreesClassifier()

models = [lr, lda, qda, svm, elastic, dt, rf, gb, nn, xgb, lgb, cat, et]

# %%
# evaluate each model on each subset of features generated by the feature selection methods

data = {'SelectKBest': (X_train_kbest, X_test_kbest),
        'RFE': (X_train_rfe, X_test_rfe),
        'Random Forest': (X_train_rf, X_test_rf),
        'PCA': (X_train_pca, X_test_pca),
        'Lasso': (X_train_lasso, X_test_lasso),
        'XGBoost': (X_train_xgb, X_test_xgb),
        'Decision Tree': (X_train_dt, X_test_dt),
        'Extra Trees': (X_train_et, X_test_et)}


results = pd.DataFrame(index=[model.__class__.__name__ for model in models], columns=data.keys())

for model in models:
        for key, value in data.items():
                X_train, X_test = value
                cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
                model.fit(X_train, y_train)
                print(model.__class__.__name__, key, evaluate(model, X_train, y_train))
                results.loc[model.__class__.__name__, key] = cross_val_score(model, X_train, y_train, cv=cv, scoring=evaluate).mean() * 5

print(results)
# Out:
# Number of customers who took the offer:  566.0
# Number of variables used:  4
# LogisticRegression SelectKBest 4860.0
# Number of customers who took the offer:  113.0
# Number of variables used:  4
# Number of customers who took the offer:  107.0
# Number of variables used:  4
# Number of customers who took the offer:  108.0
# Number of variables used:  4
# Number of customers who took the offer:  110.0
# Number of variables used:  4
# Number of customers who took the offer:  115.0
# Number of variables used:  4
# Number of customers who took the offer:  552.0
# Number of variables used:  4
# LogisticRegression RFE 4720.0
# Number of customers who took the offer:  108.0
# Number of variables used:  4
# Number of customers who took the offer:  107.0
# Number of variables used:  4
# Number of customers who took the offer:  111.0
# Number of variables used:  4
# Number of customers who took the offer:  112.0
# Number of variables used:  4
# Number of customers who took the offer:  115.0
# Number of variables used:  4
# Number of customers who took the offer:  597.0
# Number of variables used:  4
# LogisticRegression Random Forest 5170.0
# Number of customers who took the offer:  111.0
# Number of variables used:  4
# Number of customers who took the offer:  120.0
# Number of variables used:  4
# Number of customers who took the offer:  115.0
# Number of variables used:  4
# Number of customers who took the offer:  124.0
# Number of variables used:  4
# Number of customers who took the offer:  112.0
# Number of variables used:  4
# Number of customers who took the offer:  514.0
# Number of variables used:  4
# LogisticRegression PCA 4340.0
# Number of customers who took the offer:  98.0
# Number of variables used:  4
# Number of customers who took the offer:  97.0
# Number of variables used:  4
# Number of customers who took the offer:  99.0
# Number of variables used:  4
# Number of customers who took the offer:  99.0
# Number of variables used:  4
# Number of customers who took the offer:  98.0
# Number of variables used:  4
# Number of customers who took the offer:  522.0
# Number of variables used:  1
# LogisticRegression Lasso 5020.0
# Number of customers who took the offer:  104.0
# Number of variables used:  1
# Number of customers who took the offer:  107.0
# Number of variables used:  1
# Number of customers who took the offer:  93.0
# Number of variables used:  1
# Number of customers who took the offer:  104.0
# Number of variables used:  1
# Number of customers who took the offer:  111.0
# Number of variables used:  1
# Number of customers who took the offer:  541.0
# Number of variables used:  4
# LogisticRegression XGBoost 4610.0
# Number of customers who took the offer:  114.0
# Number of variables used:  4
# Number of customers who took the offer:  109.0
# Number of variables used:  4
# Number of customers who took the offer:  102.0
# Number of variables used:  4
# Number of customers who took the offer:  102.0
# Number of variables used:  4
# Number of customers who took the offer:  107.0
# Number of variables used:  4
# Number of customers who took the offer:  590.0
# Number of variables used:  4
# LogisticRegression Decision Tree 5100.0
# Number of customers who took the offer:  113.0
# Number of variables used:  4
# Number of customers who took the offer:  118.0
# Number of variables used:  4
# Number of customers who took the offer:  112.0
# Number of variables used:  4
# Number of customers who took the offer:  123.0
# Number of variables used:  4
# Number of customers who took the offer:  120.0
# Number of variables used:  4
# Number of customers who took the offer:  590.0
# Number of variables used:  4
# LogisticRegression Extra Trees 5100.0
# Number of customers who took the offer:  113.0
# Number of variables used:  4
# Number of customers who took the offer:  118.0
# Number of variables used:  4
# Number of customers who took the offer:  112.0
# Number of variables used:  4
# Number of customers who took the offer:  123.0
# Number of variables used:  4
# Number of customers who took the offer:  120.0
# Number of variables used:  4
# Number of customers who took the offer:  568.0
# Number of variables used:  4
# LinearDiscriminantAnalysis SelectKBest 4880.0
# Number of customers who took the offer:  113.0
# Number of variables used:  4
# Number of customers who took the offer:  107.0
# Number of variables used:  4
# Number of customers who took the offer:  109.0
# Number of variables used:  4
# Number of customers who took the offer:  110.0
# Number of variables used:  4
# Number of customers who took the offer:  115.0
# Number of variables used:  4
# Number of customers who took the offer:  553.0
# Number of variables used:  4
# LinearDiscriminantAnalysis RFE 4730.0
# Number of customers who took the offer:  108.0
# Number of variables used:  4
# Number of customers who took the offer:  106.0
# Number of variables used:  4
# Number of customers who took the offer:  111.0
# Number of variables used:  4
# Number of customers who took the offer:  112.0
# Number of variables used:  4
# Number of customers who took the offer:  115.0
# Number of variables used:  4
# Number of customers who took the offer:  597.0
# Number of variables used:  4
# LinearDiscriminantAnalysis Random Forest 5170.0
# Number of customers who took the offer:  112.0
# Number of variables used:  4
# Number of customers who took the offer:  120.0
# Number of variables used:  4
# Number of customers who took the offer:  115.0
# Number of variables used:  4
# Number of customers who took the offer:  124.0
# Number of variables used:  4
# Number of customers who took the offer:  112.0
# Number of variables used:  4
# Number of customers who took the offer:  514.0
# Number of variables used:  4
# LinearDiscriminantAnalysis PCA 4340.0
# Number of customers who took the offer:  98.0
# Number of variables used:  4
# Number of customers who took the offer:  97.0
# Number of variables used:  4
# Number of customers who took the offer:  99.0
# Number of variables used:  4
# Number of customers who took the offer:  99.0
# Number of variables used:  4
# Number of customers who took the offer:  98.0
# Number of variables used:  4
# Number of customers who took the offer:  522.0
# Number of variables used:  1
# LinearDiscriminantAnalysis Lasso 5020.0
# Number of customers who took the offer:  104.0
# Number of variables used:  1
# Number of customers who took the offer:  107.0
# Number of variables used:  1
# Number of customers who took the offer:  93.0
# Number of variables used:  1
# Number of customers who took the offer:  104.0
# Number of variables used:  1
# Number of customers who took the offer:  111.0
# Number of variables used:  1
# Number of customers who took the offer:  541.0
# Number of variables used:  4
# LinearDiscriminantAnalysis XGBoost 4610.0
# Number of customers who took the offer:  114.0
# Number of variables used:  4
# Number of customers who took the offer:  108.0
# Number of variables used:  4
# Number of customers who took the offer:  101.0
# Number of variables used:  4
# Number of customers who took the offer:  103.0
# Number of variables used:  4
# Number of customers who took the offer:  106.0
# Number of variables used:  4
# Number of customers who took the offer:  590.0
# Number of variables used:  4
# LinearDiscriminantAnalysis Decision Tree 5100.0
# Number of customers who took the offer:  113.0
# Number of variables used:  4
# Number of customers who took the offer:  118.0
# Number of variables used:  4
# Number of customers who took the offer:  112.0
# Number of variables used:  4
# Number of customers who took the offer:  123.0
# Number of variables used:  4
# Number of customers who took the offer:  120.0
# Number of variables used:  4
# Number of customers who took the offer:  590.0
# Number of variables used:  4
# LinearDiscriminantAnalysis Extra Trees 5100.0
# Number of customers who took the offer:  113.0
# Number of variables used:  4
# Number of customers who took the offer:  118.0
# Number of variables used:  4
# Number of customers who took the offer:  112.0
# Number of variables used:  4
# Number of customers who took the offer:  123.0
# Number of variables used:  4
# Number of customers who took the offer:  120.0
# Number of variables used:  4
# Number of customers who took the offer:  565.0
# Number of variables used:  4
# QuadraticDiscriminantAnalysis SelectKBest 4850.0
# Number of customers who took the offer:  104.0
# Number of variables used:  4
# Number of customers who took the offer:  106.0
# Number of variables used:  4
# Number of customers who took the offer:  109.0
# Number of variables used:  4
# Number of customers who took the offer:  102.0
# Number of variables used:  4
# Number of customers who took the offer:  113.0
# Number of variables used:  4
# Number of customers who took the offer:  544.0
# Number of variables used:  4
# QuadraticDiscriminantAnalysis RFE 4640.0
# Number of customers who took the offer:  110.0
# Number of variables used:  4
# Number of customers who took the offer:  105.0
# Number of variables used:  4
# Number of customers who took the offer:  114.0
# Number of variables used:  4
# Number of customers who took the offer:  101.0
# Number of variables used:  4
# Number of customers who took the offer:  107.0
# Number of variables used:  4
# Number of customers who took the offer:  767.0
# Number of variables used:  4
# QuadraticDiscriminantAnalysis Random Forest 6870.0
# Number of customers who took the offer:  152.0
# Number of variables used:  4
# Number of customers who took the offer:  157.0
# Number of variables used:  4
# Number of customers who took the offer:  151.0
# Number of variables used:  4
# Number of customers who took the offer:  159.0
# Number of variables used:  4
# Number of customers who took the offer:  153.0
# Number of variables used:  4
# Number of customers who took the offer:  603.0
# Number of variables used:  4
# QuadraticDiscriminantAnalysis PCA 5230.0
# Number of customers who took the offer:  111.0
# Number of variables used:  4
# Number of customers who took the offer:  124.0
# Number of variables used:  4
# Number of customers who took the offer:  129.0
# Number of variables used:  4
# Number of customers who took the offer:  109.0
# Number of variables used:  4
# Number of customers who took the offer:  113.0
# Number of variables used:  4
# Number of customers who took the offer:  522.0
# Number of variables used:  1
# QuadraticDiscriminantAnalysis Lasso 5020.0
# Number of customers who took the offer:  104.0
# Number of variables used:  1
# Number of customers who took the offer:  107.0
# Number of variables used:  1
# Number of customers who took the offer:  93.0
# Number of variables used:  1
# Number of customers who took the offer:  104.0
# Number of variables used:  1
# Number of customers who took the offer:  111.0
# Number of variables used:  1
# Number of customers who took the offer:  756.0
# Number of variables used:  4
# QuadraticDiscriminantAnalysis XGBoost 6760.0
# Number of customers who took the offer:  153.0
# Number of variables used:  4
# Number of customers who took the offer:  149.0
# Number of variables used:  4
# Number of customers who took the offer:  150.0
# Number of variables used:  4
# Number of customers who took the offer:  149.0
# Number of variables used:  4
# Number of customers who took the offer:  151.0
# Number of variables used:  4
# Number of customers who took the offer:  774.0
# Number of variables used:  4
# QuadraticDiscriminantAnalysis Decision Tree 6940.0
# Number of customers who took the offer:  150.0
# Number of variables used:  4
# Number of customers who took the offer:  150.0
# Number of variables used:  4
# Number of customers who took the offer:  158.0
# Number of variables used:  4
# Number of customers who took the offer:  156.0
# Number of variables used:  4
# Number of customers who took the offer:  159.0
# Number of variables used:  4
# Number of customers who took the offer:  774.0
# Number of variables used:  4
# QuadraticDiscriminantAnalysis Extra Trees 6940.0
# Number of customers who took the offer:  150.0
# Number of variables used:  4
# Number of customers who took the offer:  150.0
# Number of variables used:  4
# Number of customers who took the offer:  158.0
# Number of variables used:  4
# Number of customers who took the offer:  156.0
# Number of variables used:  4
# Number of customers who took the offer:  159.0
# Number of variables used:  4
# Number of customers who took the offer:  545.0
# Number of variables used:  4
# SVC SelectKBest 4650.0
# Number of customers who took the offer:  99.0
# Number of variables used:  4
# Number of customers who took the offer:  112.0
# Number of variables used:  4
# Number of customers who took the offer:  105.0
# Number of variables used:  4
# Number of customers who took the offer:  109.0
# Number of variables used:  4
# Number of customers who took the offer:  116.0
# Number of variables used:  4
# Number of customers who took the offer:  570.0
# Number of variables used:  4
# SVC RFE 4900.0
# Number of customers who took the offer:  113.0
# Number of variables used:  4
# Number of customers who took the offer:  97.0
# Number of variables used:  4
# Number of customers who took the offer:  98.0
# Number of variables used:  4
# Number of customers who took the offer:  96.0
# Number of variables used:  4
# Number of customers who took the offer:  103.0
# Number of variables used:  4
# Number of customers who took the offer:  794.0
# Number of variables used:  4
# SVC Random Forest 7140.0
# Number of customers who took the offer:  151.0
# Number of variables used:  4
# Number of customers who took the offer:  153.0
# Number of variables used:  4
# Number of customers who took the offer:  153.0
# Number of variables used:  4
# Number of customers who took the offer:  157.0
# Number of variables used:  4
# Number of customers who took the offer:  156.0
# Number of variables used:  4
# Number of customers who took the offer:  636.0
# Number of variables used:  4
# SVC PCA 5560.0
# Number of customers who took the offer:  105.0
# Number of variables used:  4
# Number of customers who took the offer:  122.0
# Number of variables used:  4
# Number of customers who took the offer:  120.0
# Number of variables used:  4
# Number of customers who took the offer:  109.0
# Number of variables used:  4
# Number of customers who took the offer:  111.0
# Number of variables used:  4
# Number of customers who took the offer:  544.0
# Number of variables used:  1
# SVC Lasso 5240.0
# Number of customers who took the offer:  101.0
# Number of variables used:  1
# Number of customers who took the offer:  103.0
# Number of variables used:  1
# Number of customers who took the offer:  97.0
# Number of variables used:  1
# Number of customers who took the offer:  101.0
# Number of variables used:  1
# Number of customers who took the offer:  112.0
# Number of variables used:  1
# Number of customers who took the offer:  765.0
# Number of variables used:  4
# SVC XGBoost 6850.0
# Number of customers who took the offer:  152.0
# Number of variables used:  4
# Number of customers who took the offer:  146.0
# Number of variables used:  4
# Number of customers who took the offer:  147.0
# Number of variables used:  4
# Number of customers who took the offer:  149.0
# Number of variables used:  4
# Number of customers who took the offer:  151.0
# Number of variables used:  4
# Number of customers who took the offer:  798.0
# Number of variables used:  4
# SVC Decision Tree 7180.0
# Number of customers who took the offer:  142.0
# Number of variables used:  4
# Number of customers who took the offer:  143.0
# Number of variables used:  4
# Number of customers who took the offer:  160.0
# Number of variables used:  4
# Number of customers who took the offer:  157.0
# Number of variables used:  4
# Number of customers who took the offer:  159.0
# Number of variables used:  4
# Number of customers who took the offer:  798.0
# Number of variables used:  4
# SVC Extra Trees 7180.0
# Number of customers who took the offer:  142.0
# Number of variables used:  4
# Number of customers who took the offer:  143.0
# Number of variables used:  4
# Number of customers who took the offer:  160.0
# Number of variables used:  4
# Number of customers who took the offer:  157.0
# Number of variables used:  4
# Number of customers who took the offer:  159.0
# Number of variables used:  4
# Number of customers who took the offer:  568.0
# Number of variables used:  4
# LogisticRegression SelectKBest 4880.0
# Number of customers who took the offer:  111.0
# Number of variables used:  4
# Number of customers who took the offer:  107.0
# Number of variables used:  4
# Number of customers who took the offer:  108.0
# Number of variables used:  4
# Number of customers who took the offer:  109.0
# Number of variables used:  4
# Number of customers who took the offer:  114.0
# Number of variables used:  4
# Number of customers who took the offer:  552.0
# Number of variables used:  4
# LogisticRegression RFE 4720.0
# Number of customers who took the offer:  108.0
# Number of variables used:  4
# Number of customers who took the offer:  106.0
# Number of variables used:  4
# Number of customers who took the offer:  112.0
# Number of variables used:  4
# Number of customers who took the offer:  112.0
# Number of variables used:  4
# Number of customers who took the offer:  115.0
# Number of variables used:  4
# Number of customers who took the offer:  599.0
# Number of variables used:  4
# LogisticRegression Random Forest 5190.0
# Number of customers who took the offer:  111.0
# Number of variables used:  4
# Number of customers who took the offer:  119.0
# Number of variables used:  4
# Number of customers who took the offer:  115.0
# Number of variables used:  4
# Number of customers who took the offer:  123.0
# Number of variables used:  4
# Number of customers who took the offer:  112.0
# Number of variables used:  4
# Number of customers who took the offer:  513.0
# Number of variables used:  4
# LogisticRegression PCA 4330.0
# Number of customers who took the offer:  98.0
# Number of variables used:  4
# Number of customers who took the offer:  97.0
# Number of variables used:  4
# Number of customers who took the offer:  99.0
# Number of variables used:  4
# Number of customers who took the offer:  99.0
# Number of variables used:  4
# Number of customers who took the offer:  98.0
# Number of variables used:  4
# Number of customers who took the offer:  522.0
# Number of variables used:  1
# LogisticRegression Lasso 5020.0
# Number of customers who took the offer:  104.0
# Number of variables used:  1
# Number of customers who took the offer:  107.0
# Number of variables used:  1
# Number of customers who took the offer:  93.0
# Number of variables used:  1
# Number of customers who took the offer:  104.0
# Number of variables used:  1
# Number of customers who took the offer:  111.0
# Number of variables used:  1
# Number of customers who took the offer:  546.0
# Number of variables used:  4
# LogisticRegression XGBoost 4660.0
# Number of customers who took the offer:  114.0
# Number of variables used:  4
# Number of customers who took the offer:  109.0
# Number of variables used:  4
# Number of customers who took the offer:  102.0
# Number of variables used:  4
# Number of customers who took the offer:  103.0
# Number of variables used:  4
# Number of customers who took the offer:  107.0
# Number of variables used:  4
# Number of customers who took the offer:  590.0
# Number of variables used:  4
# LogisticRegression Decision Tree 5100.0
# Number of customers who took the offer:  114.0
# Number of variables used:  4
# Number of customers who took the offer:  118.0
# Number of variables used:  4
# Number of customers who took the offer:  112.0
# Number of variables used:  4
# Number of customers who took the offer:  122.0
# Number of variables used:  4
# Number of customers who took the offer:  120.0
# Number of variables used:  4
# Number of customers who took the offer:  590.0
# Number of variables used:  4
# LogisticRegression Extra Trees 5100.0
# Number of customers who took the offer:  114.0
# Number of variables used:  4
# Number of customers who took the offer:  118.0
# Number of variables used:  4
# Number of customers who took the offer:  112.0
# Number of variables used:  4
# Number of customers who took the offer:  122.0
# Number of variables used:  4
# Number of customers who took the offer:  120.0
# Number of variables used:  4
# Number of customers who took the offer:  1000.0
# Number of variables used:  4
# DecisionTreeClassifier SelectKBest 9200.0
# Number of customers who took the offer:  100.0
# Number of variables used:  4
# Number of customers who took the offer:  98.0
# Number of variables used:  4
# Number of customers who took the offer:  95.0
# Number of variables used:  4
# Number of customers who took the offer:  107.0
# Number of variables used:  4
# Number of customers who took the offer:  107.0
# Number of variables used:  4
# Number of customers who took the offer:  1000.0
# Number of variables used:  4
# DecisionTreeClassifier RFE 9200.0
# Number of customers who took the offer:  100.0
# Number of variables used:  4
# Number of customers who took the offer:  92.0
# Number of variables used:  4
# Number of customers who took the offer:  92.0
# Number of variables used:  4
# Number of customers who took the offer:  94.0
# Number of variables used:  4
# Number of customers who took the offer:  96.0
# Number of variables used:  4
# Number of customers who took the offer:  1000.0
# Number of variables used:  4
# DecisionTreeClassifier Random Forest 9200.0
# Number of customers who took the offer:  115.0
# Number of variables used:  4
# Number of customers who took the offer:  113.0
# Number of variables used:  4
# Number of customers who took the offer:  108.0
# Number of variables used:  4
# Number of customers who took the offer:  112.0
# Number of variables used:  4
# Number of customers who took the offer:  118.0
# Number of variables used:  4
# Number of customers who took the offer:  1000.0
# Number of variables used:  4
# DecisionTreeClassifier PCA 9200.0
# Number of customers who took the offer:  99.0
# Number of variables used:  4
# Number of customers who took the offer:  100.0
# Number of variables used:  4
# Number of customers who took the offer:  106.0
# Number of variables used:  4
# Number of customers who took the offer:  102.0
# Number of variables used:  4
# Number of customers who took the offer:  95.0
# Number of variables used:  4
# Number of customers who took the offer:  1000.0
# Number of variables used:  1
# DecisionTreeClassifier Lasso 9800.0
# Number of customers who took the offer:  103.0
# Number of variables used:  1
# Number of customers who took the offer:  101.0
# Number of variables used:  1
# Number of customers who took the offer:  98.0
# Number of variables used:  1
# Number of customers who took the offer:  103.0
# Number of variables used:  1
# Number of customers who took the offer:  100.0
# Number of variables used:  1
# Number of customers who took the offer:  1000.0
# Number of variables used:  4
# DecisionTreeClassifier XGBoost 9200.0
# Number of customers who took the offer:  112.0
# Number of variables used:  4
# Number of customers who took the offer:  113.0
# Number of variables used:  4
# Number of customers who took the offer:  98.0
# Number of variables used:  4
# Number of customers who took the offer:  104.0
# Number of variables used:  4
# Number of customers who took the offer:  115.0
# Number of variables used:  4
# Number of customers who took the offer:  1000.0
# Number of variables used:  4
# DecisionTreeClassifier Decision Tree 9200.0
# Number of customers who took the offer:  114.0
# Number of variables used:  4
# Number of customers who took the offer:  118.0
# Number of variables used:  4
# Number of customers who took the offer:  105.0
# Number of variables used:  4
# Number of customers who took the offer:  112.0
# Number of variables used:  4
# Number of customers who took the offer:  120.0
# Number of variables used:  4
# Number of customers who took the offer:  1000.0
# Number of variables used:  4
# DecisionTreeClassifier Extra Trees 9200.0
# Number of customers who took the offer:  119.0
# Number of variables used:  4
# Number of customers who took the offer:  116.0
# Number of variables used:  4
# Number of customers who took the offer:  106.0
# Number of variables used:  4
# Number of customers who took the offer:  110.0
# Number of variables used:  4
# Number of customers who took the offer:  119.0
# Number of variables used:  4
# Number of customers who took the offer:  1000.0
# Number of variables used:  4
# RandomForestClassifier SelectKBest 9200.0
# Number of customers who took the offer:  101.0
# Number of variables used:  4
# Number of customers who took the offer:  106.0
# Number of variables used:  4
# Number of customers who took the offer:  108.0
# Number of variables used:  4
# Number of customers who took the offer:  100.0
# Number of variables used:  4
# Number of customers who took the offer:  103.0
# Number of variables used:  4
# Number of customers who took the offer:  1000.0
# Number of variables used:  4
# RandomForestClassifier RFE 9200.0
# Number of customers who took the offer:  87.0
# Number of variables used:  4
# Number of customers who took the offer:  97.0
# Number of variables used:  4
# Number of customers who took the offer:  94.0
# Number of variables used:  4
# Number of customers who took the offer:  92.0
# Number of variables used:  4
# Number of customers who took the offer:  95.0
# Number of variables used:  4
# Number of customers who took the offer:  1000.0
# Number of variables used:  4
# RandomForestClassifier Random Forest 9200.0
# Number of customers who took the offer:  145.0
# Number of variables used:  4
# Number of customers who took the offer:  144.0
# Number of variables used:  4
# Number of customers who took the offer:  146.0
# Number of variables used:  4
# Number of customers who took the offer:  139.0
# Number of variables used:  4
# Number of customers who took the offer:  145.0
# Number of variables used:  4
# Number of customers who took the offer:  1000.0
# Number of variables used:  4
# RandomForestClassifier PCA 9200.0
# Number of customers who took the offer:  108.0
# Number of variables used:  4
# Number of customers who took the offer:  112.0
# Number of variables used:  4
# Number of customers who took the offer:  123.0
# Number of variables used:  4
# Number of customers who took the offer:  105.0
# Number of variables used:  4
# Number of customers who took the offer:  104.0
# Number of variables used:  4
# Number of customers who took the offer:  1000.0
# Number of variables used:  1
# RandomForestClassifier Lasso 9800.0
# Number of customers who took the offer:  112.0
# Number of variables used:  1
# Number of customers who took the offer:  103.0
# Number of variables used:  1
# Number of customers who took the offer:  109.0
# Number of variables used:  1
# Number of customers who took the offer:  103.0
# Number of variables used:  1
# Number of customers who took the offer:  100.0
# Number of variables used:  1
# Number of customers who took the offer:  1000.0
# Number of variables used:  4
# RandomForestClassifier XGBoost 9200.0
# Number of customers who took the offer:  147.0
# Number of variables used:  4
# Number of customers who took the offer:  129.0
# Number of variables used:  4
# Number of customers who took the offer:  136.0
# Number of variables used:  4
# Number of customers who took the offer:  137.0
# Number of variables used:  4
# Number of customers who took the offer:  133.0
# Number of variables used:  4
# Number of customers who took the offer:  1000.0
# Number of variables used:  4
# RandomForestClassifier Decision Tree 9200.0
# Number of customers who took the offer:  141.0
# Number of variables used:  4
# Number of customers who took the offer:  144.0
# Number of variables used:  4
# Number of customers who took the offer:  137.0
# Number of variables used:  4
# Number of customers who took the offer:  142.0
# Number of variables used:  4
# Number of customers who took the offer:  149.0
# Number of variables used:  4
# Number of customers who took the offer:  1000.0
# Number of variables used:  4
# RandomForestClassifier Extra Trees 9200.0
# Number of customers who took the offer:  138.0
# Number of variables used:  4
# Number of customers who took the offer:  142.0
# Number of variables used:  4
# Number of customers who took the offer:  134.0
# Number of variables used:  4
# Number of customers who took the offer:  135.0
# Number of variables used:  4
# Number of customers who took the offer:  148.0
# Number of variables used:  4
# Number of customers who took the offer:  779.0
# Number of variables used:  4
# GradientBoostingClassifier SelectKBest 6990.0
# Number of customers who took the offer:  101.0
# Number of variables used:  4
# Number of customers who took the offer:  111.0
# Number of variables used:  4
# Number of customers who took the offer:  106.0
# Number of variables used:  4
# Number of customers who took the offer:  101.0
# Number of variables used:  4
# Number of customers who took the offer:  106.0
# Number of variables used:  4
# Number of customers who took the offer:  753.0
# Number of variables used:  4
# GradientBoostingClassifier RFE 6730.0
# Number of customers who took the offer:  89.0
# Number of variables used:  4
# Number of customers who took the offer:  95.0
# Number of variables used:  4
# Number of customers who took the offer:  105.0
# Number of variables used:  4
# Number of customers who took the offer:  94.0
# Number of variables used:  4
# Number of customers who took the offer:  98.0
# Number of variables used:  4
# Number of customers who took the offer:  878.0
# Number of variables used:  4
# GradientBoostingClassifier Random Forest 7980.0
# Number of customers who took the offer:  150.0
# Number of variables used:  4
# Number of customers who took the offer:  146.0
# Number of variables used:  4
# Number of customers who took the offer:  152.0
# Number of variables used:  4
# Number of customers who took the offer:  150.0
# Number of variables used:  4
# Number of customers who took the offer:  152.0
# Number of variables used:  4
# Number of customers who took the offer:  768.0
# Number of variables used:  4
# GradientBoostingClassifier PCA 6880.0
# Number of customers who took the offer:  108.0
# Number of variables used:  4
# Number of customers who took the offer:  115.0
# Number of variables used:  4
# Number of customers who took the offer:  113.0
# Number of variables used:  4
# Number of customers who took the offer:  103.0
# Number of variables used:  4
# Number of customers who took the offer:  108.0
# Number of variables used:  4
# Number of customers who took the offer:  717.0
# Number of variables used:  1
# GradientBoostingClassifier Lasso 6970.0
# Number of customers who took the offer:  110.0
# Number of variables used:  1
# Number of customers who took the offer:  95.0
# Number of variables used:  1
# Number of customers who took the offer:  102.0
# Number of variables used:  1
# Number of customers who took the offer:  99.0
# Number of variables used:  1
# Number of customers who took the offer:  105.0
# Number of variables used:  1
# Number of customers who took the offer:  842.0
# Number of variables used:  4
# GradientBoostingClassifier XGBoost 7620.0
# Number of customers who took the offer:  148.0
# Number of variables used:  4
# Number of customers who took the offer:  141.0
# Number of variables used:  4
# Number of customers who took the offer:  142.0
# Number of variables used:  4
# Number of customers who took the offer:  146.0
# Number of variables used:  4
# Number of customers who took the offer:  146.0
# Number of variables used:  4
# Number of customers who took the offer:  887.0
# Number of variables used:  4
# GradientBoostingClassifier Decision Tree 8070.0
# Number of customers who took the offer:  148.0
# Number of variables used:  4
# Number of customers who took the offer:  147.0
# Number of variables used:  4
# Number of customers who took the offer:  155.0
# Number of variables used:  4
# Number of customers who took the offer:  152.0
# Number of variables used:  4
# Number of customers who took the offer:  153.0
# Number of variables used:  4
# Number of customers who took the offer:  887.0
# Number of variables used:  4
# GradientBoostingClassifier Extra Trees 8070.0
# Number of customers who took the offer:  148.0
# Number of variables used:  4
# Number of customers who took the offer:  147.0
# Number of variables used:  4
# Number of customers who took the offer:  155.0
# Number of variables used:  4
# Number of customers who took the offer:  152.0
# Number of variables used:  4
# Number of customers who took the offer:  153.0
# Number of variables used:  4
# Number of customers who took the offer:  564.0
# Number of variables used:  4
# MLPClassifier SelectKBest 4840.0
# Number of customers who took the offer:  107.0
# Number of variables used:  4
# Number of customers who took the offer:  108.0
# Number of variables used:  4
# Number of customers who took the offer:  105.0
# Number of variables used:  4
# Number of customers who took the offer:  107.0
# Number of variables used:  4
# Number of customers who took the offer:  115.0
# Number of variables used:  4
# Number of customers who took the offer:  555.0
# Number of variables used:  4
# MLPClassifier RFE 4750.0
# Number of customers who took the offer:  106.0
# Number of variables used:  4
# Number of customers who took the offer:  105.0
# Number of variables used:  4
# Number of customers who took the offer:  114.0
# Number of variables used:  4
# Number of customers who took the offer:  106.0
# Number of variables used:  4
# Number of customers who took the offer:  109.0
# Number of variables used:  4
# Number of customers who took the offer:  782.0
# Number of variables used:  4
# MLPClassifier Random Forest 7020.0
# Number of customers who took the offer:  151.0
# Number of variables used:  4
# Number of customers who took the offer:  151.0
# Number of variables used:  4
# Number of customers who took the offer:  149.0
# Number of variables used:  4
# Number of customers who took the offer:  157.0
# Number of variables used:  4
# Number of customers who took the offer:  155.0
# Number of variables used:  4
# Number of customers who took the offer:  641.0
# Number of variables used:  4
# MLPClassifier PCA 5610.0
# Number of customers who took the offer:  111.0
# Number of variables used:  4
# Number of customers who took the offer:  119.0
# Number of variables used:  4
# Number of customers who took the offer:  120.0
# Number of variables used:  4
# Number of customers who took the offer:  101.0
# Number of variables used:  4
# Number of customers who took the offer:  116.0
# Number of variables used:  4
# Number of customers who took the offer:  522.0
# Number of variables used:  1
# MLPClassifier Lasso 5020.0
# Number of customers who took the offer:  104.0
# Number of variables used:  1
# Number of customers who took the offer:  107.0
# Number of variables used:  1
# Number of customers who took the offer:  93.0
# Number of variables used:  1
# Number of customers who took the offer:  104.0
# Number of variables used:  1
# Number of customers who took the offer:  111.0
# Number of variables used:  1
# Number of customers who took the offer:  767.0
# Number of variables used:  4
# MLPClassifier XGBoost 6870.0
# Number of customers who took the offer:  156.0
# Number of variables used:  4
# Number of customers who took the offer:  144.0
# Number of variables used:  4
# Number of customers who took the offer:  145.0
# Number of variables used:  4
# Number of customers who took the offer:  148.0
# Number of variables used:  4
# Number of customers who took the offer:  150.0
# Number of variables used:  4
# Number of customers who took the offer:  806.0
# Number of variables used:  4
# MLPClassifier Decision Tree 7260.0
# Number of customers who took the offer:  146.0
# Number of variables used:  4
# Number of customers who took the offer:  148.0
# Number of variables used:  4
# Number of customers who took the offer:  153.0
# Number of variables used:  4
# Number of customers who took the offer:  160.0
# Number of variables used:  4
# Number of customers who took the offer:  161.0
# Number of variables used:  4
# Number of customers who took the offer:  797.0
# Number of variables used:  4
# MLPClassifier Extra Trees 7170.0
# Number of customers who took the offer:  147.0
# Number of variables used:  4
# Number of customers who took the offer:  145.0
# Number of variables used:  4
# Number of customers who took the offer:  150.0
# Number of variables used:  4
# Number of customers who took the offer:  160.0
# Number of variables used:  4
# Number of customers who took the offer:  160.0
# Number of variables used:  4
# Number of customers who took the offer:  1000.0
# Number of variables used:  4
# XGBClassifier SelectKBest 9200.0
# Number of customers who took the offer:  106.0
# Number of variables used:  4
# Number of customers who took the offer:  98.0
# Number of variables used:  4
# Number of customers who took the offer:  100.0
# Number of variables used:  4
# Number of customers who took the offer:  94.0
# Number of variables used:  4
# Number of customers who took the offer:  98.0
# Number of variables used:  4
# Number of customers who took the offer:  997.0
# Number of variables used:  4
# XGBClassifier RFE 9170.0
# Number of customers who took the offer:  82.0
# Number of variables used:  4
# Number of customers who took the offer:  97.0
# Number of variables used:  4
# Number of customers who took the offer:  98.0
# Number of variables used:  4
# Number of customers who took the offer:  83.0
# Number of variables used:  4
# Number of customers who took the offer:  93.0
# Number of variables used:  4
# Number of customers who took the offer:  1000.0
# Number of variables used:  4
# XGBClassifier Random Forest 9200.0
# Number of customers who took the offer:  155.0
# Number of variables used:  4
# Number of customers who took the offer:  148.0
# Number of variables used:  4
# Number of customers who took the offer:  148.0
# Number of variables used:  4
# Number of customers who took the offer:  145.0
# Number of variables used:  4
# Number of customers who took the offer:  147.0
# Number of variables used:  4
# Number of customers who took the offer:  1000.0
# Number of variables used:  4
# XGBClassifier PCA 9200.0
# Number of customers who took the offer:  102.0
# Number of variables used:  4
# Number of customers who took the offer:  104.0
# Number of variables used:  4
# Number of customers who took the offer:  110.0
# Number of variables used:  4
# Number of customers who took the offer:  89.0
# Number of variables used:  4
# Number of customers who took the offer:  102.0
# Number of variables used:  4
# Number of customers who took the offer:  657.0
# Number of variables used:  1
# XGBClassifier Lasso 6370.0
# Number of customers who took the offer:  103.0
# Number of variables used:  1
# Number of customers who took the offer:  103.0
# Number of variables used:  1
# Number of customers who took the offer:  99.0
# Number of variables used:  1
# Number of customers who took the offer:  95.0
# Number of variables used:  1
# Number of customers who took the offer:  100.0
# Number of variables used:  1
# Number of customers who took the offer:  999.0
# Number of variables used:  4
# XGBClassifier XGBoost 9190.0
# Number of customers who took the offer:  138.0
# Number of variables used:  4
# Number of customers who took the offer:  135.0
# Number of variables used:  4
# Number of customers who took the offer:  134.0
# Number of variables used:  4
# Number of customers who took the offer:  137.0
# Number of variables used:  4
# Number of customers who took the offer:  136.0
# Number of variables used:  4
# Number of customers who took the offer:  1000.0
# Number of variables used:  4
# XGBClassifier Decision Tree 9200.0
# Number of customers who took the offer:  142.0
# Number of variables used:  4
# Number of customers who took the offer:  142.0
# Number of variables used:  4
# Number of customers who took the offer:  141.0
# Number of variables used:  4
# Number of customers who took the offer:  140.0
# Number of variables used:  4
# Number of customers who took the offer:  146.0
# Number of variables used:  4
# Number of customers who took the offer:  1000.0
# Number of variables used:  4
# XGBClassifier Extra Trees 9200.0
# Number of customers who took the offer:  142.0
# Number of variables used:  4
# Number of customers who took the offer:  142.0
# Number of variables used:  4
# Number of customers who took the offer:  141.0
# Number of variables used:  4
# Number of customers who took the offer:  140.0
# Number of variables used:  4
# Number of customers who took the offer:  146.0
# Number of variables used:  4
# Number of customers who took the offer:  960.0
# Number of variables used:  4
# LGBMClassifier SelectKBest 8800.0
# Number of customers who took the offer:  95.0
# Number of variables used:  4
# Number of customers who took the offer:  97.0
# Number of variables used:  4
# Number of customers who took the offer:  108.0
# Number of variables used:  4
# Number of customers who took the offer:  104.0
# Number of variables used:  4
# Number of customers who took the offer:  103.0
# Number of variables used:  4
# Number of customers who took the offer:  967.0
# Number of variables used:  4
# LGBMClassifier RFE 8870.0
# Number of customers who took the offer:  88.0
# Number of variables used:  4
# Number of customers who took the offer:  100.0
# Number of variables used:  4
# Number of customers who took the offer:  92.0
# Number of variables used:  4
# Number of customers who took the offer:  93.0
# Number of variables used:  4
# Number of customers who took the offer:  101.0
# Number of variables used:  4
# Number of customers who took the offer:  983.0
# Number of variables used:  4
# LGBMClassifier Random Forest 9030.0
# Number of customers who took the offer:  148.0
# Number of variables used:  4
# Number of customers who took the offer:  142.0
# Number of variables used:  4
# Number of customers who took the offer:  146.0
# Number of variables used:  4
# Number of customers who took the offer:  151.0
# Number of variables used:  4
# Number of customers who took the offer:  148.0
# Number of variables used:  4
# Number of customers who took the offer:  959.0
# Number of variables used:  4
# LGBMClassifier PCA 8790.0
# Number of customers who took the offer:  100.0
# Number of variables used:  4
# Number of customers who took the offer:  108.0
# Number of variables used:  4
# Number of customers who took the offer:  127.0
# Number of variables used:  4
# Number of customers who took the offer:  96.0
# Number of variables used:  4
# Number of customers who took the offer:  107.0
# Number of variables used:  4
# Number of customers who took the offer:  660.0
# Number of variables used:  1
# LGBMClassifier Lasso 6400.0
# Number of customers who took the offer:  106.0
# Number of variables used:  1
# Number of customers who took the offer:  105.0
# Number of variables used:  1
# Number of customers who took the offer:  95.0
# Number of variables used:  1
# Number of customers who took the offer:  101.0
# Number of variables used:  1
# Number of customers who took the offer:  104.0
# Number of variables used:  1
# Number of customers who took the offer:  974.0
# Number of variables used:  4
# LGBMClassifier XGBoost 8940.0
# Number of customers who took the offer:  145.0
# Number of variables used:  4
# Number of customers who took the offer:  139.0
# Number of variables used:  4
# Number of customers who took the offer:  134.0
# Number of variables used:  4
# Number of customers who took the offer:  138.0
# Number of variables used:  4
# Number of customers who took the offer:  136.0
# Number of variables used:  4
# Number of customers who took the offer:  986.0
# Number of variables used:  4
# LGBMClassifier Decision Tree 9060.0
# Number of customers who took the offer:  138.0
# Number of variables used:  4
# Number of customers who took the offer:  143.0
# Number of variables used:  4
# Number of customers who took the offer:  147.0
# Number of variables used:  4
# Number of customers who took the offer:  141.0
# Number of variables used:  4
# Number of customers who took the offer:  154.0
# Number of variables used:  4
# Number of customers who took the offer:  986.0
# Number of variables used:  4
# LGBMClassifier Extra Trees 9060.0
# Number of customers who took the offer:  138.0
# Number of variables used:  4
# Number of customers who took the offer:  143.0
# Number of variables used:  4
# Number of customers who took the offer:  147.0
# Number of variables used:  4
# Number of customers who took the offer:  141.0
# Number of variables used:  4
# Number of customers who took the offer:  154.0
# Number of variables used:  4
# Number of customers who took the offer:  922.0
# Number of variables used:  4
# CatBoostClassifier SelectKBest 8420.0
# Number of customers who took the offer:  100.0
# Number of variables used:  4
# Number of customers who took the offer:  100.0
# Number of variables used:  4
# Number of customers who took the offer:  102.0
# Number of variables used:  4
# Number of customers who took the offer:  100.0
# Number of variables used:  4
# Number of customers who took the offer:  106.0
# Number of variables used:  4
# Number of customers who took the offer:  941.0
# Number of variables used:  4
# CatBoostClassifier RFE 8610.0
# Number of customers who took the offer:  87.0
# Number of variables used:  4
# Number of customers who took the offer:  101.0
# Number of variables used:  4
# Number of customers who took the offer:  96.0
# Number of variables used:  4
# Number of customers who took the offer:  91.0
# Number of variables used:  4
# Number of customers who took the offer:  102.0
# Number of variables used:  4
# Number of customers who took the offer:  977.0
# Number of variables used:  4
# CatBoostClassifier Random Forest 8970.0
# Number of customers who took the offer:  147.0
# Number of variables used:  4
# Number of customers who took the offer:  148.0
# Number of variables used:  4
# Number of customers who took the offer:  147.0
# Number of variables used:  4
# Number of customers who took the offer:  150.0
# Number of variables used:  4
# Number of customers who took the offer:  153.0
# Number of variables used:  4
# Number of customers who took the offer:  936.0
# Number of variables used:  4
# CatBoostClassifier PCA 8560.0
# Number of customers who took the offer:  98.0
# Number of variables used:  4
# Number of customers who took the offer:  108.0
# Number of variables used:  4
# Number of customers who took the offer:  121.0
# Number of variables used:  4
# Number of customers who took the offer:  106.0
# Number of variables used:  4
# Number of customers who took the offer:  102.0
# Number of variables used:  4
# Number of customers who took the offer:  632.0
# Number of variables used:  1
# CatBoostClassifier Lasso 6120.0
# Number of customers who took the offer:  111.0
# Number of variables used:  1
# Number of customers who took the offer:  95.0
# Number of variables used:  1
# Number of customers who took the offer:  103.0
# Number of variables used:  1
# Number of customers who took the offer:  95.0
# Number of variables used:  1
# Number of customers who took the offer:  107.0
# Number of variables used:  1
# Number of customers who took the offer:  951.0
# Number of variables used:  4
# CatBoostClassifier XGBoost 8710.0
# Number of customers who took the offer:  151.0
# Number of variables used:  4
# Number of customers who took the offer:  146.0
# Number of variables used:  4
# Number of customers who took the offer:  143.0
# Number of variables used:  4
# Number of customers who took the offer:  147.0
# Number of variables used:  4
# Number of customers who took the offer:  140.0
# Number of variables used:  4
# Number of customers who took the offer:  982.0
# Number of variables used:  4
# CatBoostClassifier Decision Tree 9020.0
# Number of customers who took the offer:  152.0
# Number of variables used:  4
# Number of customers who took the offer:  148.0
# Number of variables used:  4
# Number of customers who took the offer:  146.0
# Number of variables used:  4
# Number of customers who took the offer:  146.0
# Number of variables used:  4
# Number of customers who took the offer:  154.0
# Number of variables used:  4
# Number of customers who took the offer:  982.0
# Number of variables used:  4
# CatBoostClassifier Extra Trees 9020.0
# Number of customers who took the offer:  152.0
# Number of variables used:  4
# Number of customers who took the offer:  148.0
# Number of variables used:  4
# Number of customers who took the offer:  146.0
# Number of variables used:  4
# Number of customers who took the offer:  146.0
# Number of variables used:  4
# Number of customers who took the offer:  154.0
# Number of variables used:  4
# Number of customers who took the offer:  1000.0
# Number of variables used:  4
# ExtraTreesClassifier SelectKBest 9200.0
# Number of customers who took the offer:  97.0
# Number of variables used:  4
# Number of customers who took the offer:  97.0
# Number of variables used:  4
# Number of customers who took the offer:  100.0
# Number of variables used:  4
# Number of customers who took the offer:  103.0
# Number of variables used:  4
# Number of customers who took the offer:  106.0
# Number of variables used:  4
# Number of customers who took the offer:  1000.0
# Number of variables used:  4
# ExtraTreesClassifier RFE 9200.0
# Number of customers who took the offer:  86.0
# Number of variables used:  4
# Number of customers who took the offer:  95.0
# Number of variables used:  4
# Number of customers who took the offer:  104.0
# Number of variables used:  4
# Number of customers who took the offer:  100.0
# Number of variables used:  4
# Number of customers who took the offer:  100.0
# Number of variables used:  4
# Number of customers who took the offer:  1000.0
# Number of variables used:  4
# ExtraTreesClassifier Random Forest 9200.0
# Number of customers who took the offer:  144.0
# Number of variables used:  4
# Number of customers who took the offer:  141.0
# Number of variables used:  4
# Number of customers who took the offer:  144.0
# Number of variables used:  4
# Number of customers who took the offer:  144.0
# Number of variables used:  4
# Number of customers who took the offer:  141.0
# Number of variables used:  4
# Number of customers who took the offer:  1000.0
# Number of variables used:  4
# ExtraTreesClassifier PCA 9200.0
# Number of customers who took the offer:  103.0
# Number of variables used:  4
# Number of customers who took the offer:  114.0
# Number of variables used:  4
# Number of customers who took the offer:  118.0
# Number of variables used:  4
# Number of customers who took the offer:  103.0
# Number of variables used:  4
# Number of customers who took the offer:  108.0
# Number of variables used:  4
# Number of customers who took the offer:  1000.0
# Number of variables used:  1
# ExtraTreesClassifier Lasso 9800.0
# Number of customers who took the offer:  115.0
# Number of variables used:  1
# Number of customers who took the offer:  101.0
# Number of variables used:  1
# Number of customers who took the offer:  104.0
# Number of variables used:  1
# Number of customers who took the offer:  103.0
# Number of variables used:  1
# Number of customers who took the offer:  106.0
# Number of variables used:  1
# Number of customers who took the offer:  1000.0
# Number of variables used:  4
# ExtraTreesClassifier XGBoost 9200.0
# Number of customers who took the offer:  146.0
# Number of variables used:  4
# Number of customers who took the offer:  137.0
# Number of variables used:  4
# Number of customers who took the offer:  126.0
# Number of variables used:  4
# Number of customers who took the offer:  133.0
# Number of variables used:  4
# Number of customers who took the offer:  136.0
# Number of variables used:  4
# Number of customers who took the offer:  1000.0
# Number of variables used:  4
# ExtraTreesClassifier Decision Tree 9200.0
# Number of customers who took the offer:  138.0
# Number of variables used:  4
# Number of customers who took the offer:  138.0
# Number of variables used:  4
# Number of customers who took the offer:  143.0
# Number of variables used:  4
# Number of customers who took the offer:  132.0
# Number of variables used:  4
# Number of customers who took the offer:  147.0
# Number of variables used:  4
# Number of customers who took the offer:  1000.0
# Number of variables used:  4
# ExtraTreesClassifier Extra Trees 9200.0
# Number of customers who took the offer:  140.0
# Number of variables used:  4
# Number of customers who took the offer:  137.0
# Number of variables used:  4
# Number of customers who took the offer:  143.0
# Number of variables used:  4
# Number of customers who took the offer:  138.0
# Number of variables used:  4
# Number of customers who took the offer:  154.0
# Number of variables used:  4
#                               SelectKBest     RFE Random Forest     PCA  \
# LogisticRegression                 4690.0  4730.0        5000.0  4110.0
# LinearDiscriminantAnalysis         4740.0  4720.0        5030.0  4110.0
# QuadraticDiscriminantAnalysis      4540.0  4570.0        6920.0  5060.0
# SVC                                4610.0  4270.0        6900.0  4870.0
# LogisticRegression                 4690.0  4730.0        5000.0  4110.0
# DecisionTreeClassifier             4270.0  3940.0        4860.0  4220.0
# RandomForestClassifier             4380.0  3850.0        6390.0  4720.0
# GradientBoostingClassifier         4450.0  4010.0        6700.0  4670.0
# MLPClassifier                      4620.0  4600.0        6830.0  4870.0
# XGBClassifier                      4160.0  3730.0        6630.0  4270.0
# LGBMClassifier                     4270.0  3940.0        6550.0  4580.0
# CatBoostClassifier                 4280.0  3970.0        6650.0  4550.0
# ExtraTreesClassifier               4230.0  4050.0        6340.0  4660.0
#
#                                 Lasso XGBoost Decision Tree Extra Trees
# LogisticRegression             4990.0  4550.0        5060.0      5060.0
# LinearDiscriminantAnalysis     4990.0  4520.0        5060.0      5060.0
# QuadraticDiscriminantAnalysis  4990.0  6720.0        6930.0      6930.0
# SVC                            4940.0  6650.0        6810.0      6810.0
# LogisticRegression             4990.0  4550.0        5060.0      5060.0
# DecisionTreeClassifier         4850.0  4620.0        4890.0      4900.0
# RandomForestClassifier         5070.0  6020.0        6330.0      6170.0
# GradientBoostingClassifier     4910.0  6430.0        6750.0      6750.0
# MLPClassifier                  4990.0  6630.0        6880.0      6820.0
# XGBClassifier                  4800.0  6000.0        6310.0      6310.0
# LGBMClassifier                 4910.0  6120.0        6430.0      6430.0
# CatBoostClassifier             4910.0  6470.0        6660.0      6660.0
# ExtraTreesClassifier           5090.0  5980.0        6180.0      6320.0

# %%
results.to_csv('results_4.csv')

# %%
results.sum().sort_values(ascending=False)
# Out:
# Random Forest    79800.0
# Decision Tree    79350.0
# Extra Trees      79280.0
# XGBoost          75260.0
# Lasso            64430.0
# PCA              58800.0
# SelectKBest      57930.0
# RFE              55110.0
# dtype: object

# %%
results.sum(axis=1).sort_values(ascending=False)
# Out:
# QuadraticDiscriminantAnalysis    46660.0
# MLPClassifier                    46240.0
# SVC                              45860.0
# GradientBoostingClassifier       44670.0
# CatBoostClassifier               44150.0
# LGBMClassifier                   43230.0
# RandomForestClassifier           42930.0
# ExtraTreesClassifier             42850.0
# XGBClassifier                    42210.0
# LinearDiscriminantAnalysis       38230.0
# LogisticRegression               38190.0
# LogisticRegression               38190.0
# DecisionTreeClassifier           36550.0
# dtype: object

# %% [markdown]
# As we see, for feature selection, the best results are given for tree-based models feature importance methods, such as Random Forest, Extra Trees, and Decision tree.
# When it comes to classifiers, SVM, QDA and MLP (neural network) stood out from the rest.
# This is why we will investigate further the performance of combination of these methods in hyperparameter tuning.
