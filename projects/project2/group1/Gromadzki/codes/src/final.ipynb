# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.feature_selection import SelectFromModel
from sklearn.metrics import make_scorer
from tqdm import trange
from utils import *
# Out:
# 2024-06-03 01:47:51.944730: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-06-03 01:47:54.180712: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
SPLIT = 0.2
max_features = 5
th = 0.9

# %%
df, y = get_data()
X_train, X_test, y_train, y_test = train_test_split(
    df, y, test_size=SPLIT, random_state=SEED
)

# %%
to_drop = drop_colinear(X_train, th)
X_train = X_train.drop(columns=to_drop)
X_test = X_test.drop(columns=to_drop)
cols = X_train.columns
scaler = StandardScaler()
X_train_base = scaler.fit_transform(X_train)
X_test_base = scaler.transform(X_test)
y_train, y_test = y_train.values, y_test.values

# %%
C_values = [0.001, 0.01, 0.1, 1, 10]
kernel_values = ['linear', 'poly', 'rbf', 'sigmoid']
degree_values = [2, 3, 4, 5]  # Only used for 'poly' kernel
gamma_values = ['scale', 'auto']

# %%
results = []
for num in trange(1, max_features + 1):
    poly = PolynomialFeatures()
    model = RandomForestClassifier()
    selector = SelectFromModel(model, max_features=num, threshold=-np.inf)
    selector.fit(X_train_base, y_train)

    X_train = X_train_base[:, selector.get_support()]
    X_test = X_test_base[:, selector.get_support()]

    X_train = poly.fit_transform(X_train)
    X_test = poly.transform(X_test)

    for C in C_values:
        print(C)
        for kernel in kernel_values:
            for degree in degree_values if kernel == 'poly' else [3]:  # Default degree is 3
                for gamma in gamma_values:
                    model = SVC(C=C, kernel=kernel, degree=degree, gamma=gamma, probability=True, random_state=SEED)
                    model.fit(X_train, y_train)
                    y_pred = model.predict_proba(X_test)
                    acc, metric = eval_model(y_test, y_pred, num)
                    results.append([num, cols[selector.get_support()].tolist(), acc, metric, C, kernel, degree, gamma])
# Out:
# 0.001
# 0.01
# 0.1
# 1
# 10
# 0.001
# 0.01
# 0.1
# 1
# 10

# %%
results = pd.DataFrame(
    results, columns=["num_features", "columns", "accuracy", "metric", "C", "kernel", "degree", "gamma"]
)

# %%
results.sort_values("metric", ascending=False, inplace=True)
results
# Out:
#      num_features                    columns  accuracy  metric       C  \
# 0               4       [100, 102, 103, 105]     0.635    7400  10.000
# 2               4       [100, 102, 103, 105]     0.639    7400   0.100
# 3               4       [100, 102, 103, 105]     0.635    7400  10.000
# 1               4       [100, 102, 103, 105]     0.639    7400   0.100
# 4               4       [100, 102, 103, 105]     0.636    7350   1.000
# ..            ...                        ...       ...     ...     ...
# 345             5  [100, 102, 103, 104, 105]     0.491    3900   0.001
# 346             5  [100, 102, 103, 104, 105]     0.491    3900   0.001
# 347             5  [100, 102, 103, 104, 105]     0.491    3900   0.001
# 348             5  [100, 102, 103, 104, 105]     0.513    3850   1.000
# 349             5  [100, 102, 103, 104, 105]     0.513    3850   1.000
#
#      kernel  degree  gamma
# 0      poly       4   auto
# 2      poly       4   auto
# 3      poly       4  scale
# 1      poly       4  scale
# 4      poly       4  scale
# ..      ...     ...    ...
# 345    poly       3   auto
# 346  linear       3   auto
# 347  linear       3  scale
# 348    poly       5  scale
# 349    poly       5   auto
#
# [350 rows x 8 columns]

# %%
results.sort_values("accuracy", ascending=False, inplace=True)
results
# Out:
#      num_features                    columns  accuracy  metric      C  \
# 29              5  [100, 102, 103, 104, 105]     0.676    7150   0.01
# 24              5  [100, 102, 103, 104, 105]     0.676    7150   0.01
# 6               5  [100, 102, 103, 104, 105]     0.672    7300   0.01
# 7               5  [100, 102, 103, 104, 105]     0.672    7300   0.01
# 14              5  [100, 102, 103, 104, 105]     0.671    7250   0.01
# ..            ...                        ...       ...     ...    ...
# 251             1                      [100]     0.483    4600  10.00
# 252             1                      [100]     0.483    4600   1.00
# 253             1                      [100]     0.483    4600   1.00
# 250             1                      [100]     0.482    4600   0.10
# 255             1                      [100]     0.482    4600   0.10
#
#       kernel  degree  gamma
# 29      poly       4   auto
# 24      poly       4  scale
# 6        rbf       3   auto
# 7        rbf       3  scale
# 14      poly       2   auto
# ..       ...     ...    ...
# 251  sigmoid       3   auto
# 252  sigmoid       3  scale
# 253  sigmoid       3   auto
# 250  sigmoid       3  scale
# 255  sigmoid       3   auto
#
# [350 rows x 8 columns]

# %%
# results.to_csv("../results/final_interactions.csv", index=False)

# %%
results = []
for num in trange(5):
    model = RandomForestClassifier()
    selector = SelectFromModel(model, max_features=num, threshold=-np.inf)
    selector.fit(X_train_base, y_train)

    X_train = X_train_base[:, selector.get_support()]
    X_test = X_test_base[:, selector.get_support()]

    for C in C_values:
        print(C)
        for kernel in kernel_values:
            for degree in degree_values if kernel == 'poly' else [3]:  # Default degree is 3
                for gamma in gamma_values:
                    model = SVC(C=C, kernel=kernel, degree=degree, gamma=gamma, probability=True, random_state=SEED)
                    model.fit(X_train, y_train)
                    y_pred = model.predict_proba(X_test)
                    acc, metric = eval_model(y_test, y_pred, num)
                    results.append([num, cols[selector.get_support()].tolist(), acc, metric, C, kernel, degree, gamma])
# Out:
# 0.001
# 0.01
# 0.1
# 1
# 10
# 0.001
# 0.01
# 0.1
# 1
# 10

# %%
results = pd.DataFrame(
    results, columns=["num_features", "columns", "accuracy", "metric", "C", "kernel", "degree", "gamma"]
)

# %%
results.sort_values("metric", ascending=False, inplace=True)
results
# Out:
#      num_features                    columns  accuracy  metric       C  \
# 0               5  [100, 102, 103, 104, 105]     0.677    7300   0.010
# 4               5  [100, 102, 103, 104, 105]     0.679    7300   0.001
# 5               5  [100, 102, 103, 104, 105]     0.587    7300   0.001
# 1               5  [100, 102, 103, 104, 105]     0.671    7300   0.010
# 3               5  [100, 102, 103, 104, 105]     0.676    7300   0.010
# ..            ...                        ...       ...     ...     ...
# 345             3            [100, 102, 105]     0.495    4250   1.000
# 346             3            [100, 102, 105]     0.491    4250   1.000
# 347             3            [100, 102, 105]     0.491    4250   0.100
# 348             3            [100, 102, 105]     0.491    4150   1.000
# 349             5  [100, 102, 103, 104, 105]     0.500    3950  10.000
#
#       kernel  degree  gamma
# 0        rbf       3   auto
# 4     linear       3   auto
# 5       poly       2  scale
# 1       poly       2  scale
# 3        rbf       3  scale
# ..       ...     ...    ...
# 345     poly       5   auto
# 346     poly       5  scale
# 347     poly       5   auto
# 348  sigmoid       3   auto
# 349     poly       5   auto
#
# [350 rows x 8 columns]

# %%
results.sort_values("accuracy", ascending=False, inplace=True)
results
# Out:
#      num_features                    columns  accuracy  metric       C  \
# 55              5  [100, 102, 103, 104, 105]     0.679    7100   0.010
# 2               5  [100, 102, 103, 104, 105]     0.679    7300   0.001
# 4               5  [100, 102, 103, 104, 105]     0.679    7300   0.001
# 150             5  [100, 102, 103, 104, 105]     0.678    6800  10.000
# 0               5  [100, 102, 103, 104, 105]     0.677    7300   0.010
# ..            ...                        ...       ...     ...     ...
# 332             1                      [100]     0.484    4950  10.000
# 333             1                      [100]     0.482    4950   1.000
# 336             1                      [100]     0.478    4900  10.000
# 334             1                      [100]     0.478    4900   1.000
# 337             1                      [100]     0.477    4850   0.100
#
#       kernel  degree  gamma
# 55   sigmoid       3  scale
# 2     linear       3  scale
# 4     linear       3   auto
# 150     poly       2   auto
# 0        rbf       3   auto
# ..       ...     ...    ...
# 332  sigmoid       3  scale
# 333  sigmoid       3  scale
# 336  sigmoid       3   auto
# 334  sigmoid       3   auto
# 337  sigmoid       3  scale
#
# [350 rows x 8 columns]

# %%
# results.to_csv("../results/final.csv", index=False)

# %%
to_drop
# Out:
# [6, 7, 9, 8]

# %%
cols = [100, 102, 103, 104, 105]

# %%
df, y = get_data()
df = df.drop(columns=to_drop)[cols]
scaler = StandardScaler()
X_train_base = scaler.fit_transform(df)
y_train = y.values

# %%
X_test = pd.read_table("../data/x_test.txt", sep=" ", header=None)
X_test = X_test.drop(columns=to_drop)[cols]
X_test_base = scaler.transform(X_test)

# %%
poly = PolynomialFeatures()
X_train = poly.fit_transform(X_train_base)
X_test = poly.transform(X_test_base)

# %%
model = SVC(C=0.001, kernel="linear", degree=3, gamma="auto", probability=True, random_state=SEED)
model.fit(X_train, y_train)
# Out:
# SVC(C=0.001, gamma='auto', kernel='linear', probability=True, random_state=1337)

# %%
y_pred = model.predict_proba(X_test)

# %%
idx = np.argsort(y_pred[:, 1])[-1000:]
idx
# Out:
# array([ 367, 3657, 2641, 1007, 3852, 4279, 1689, 1324, 3683, 4353, 3001,
#        1787, 1068,  632, 1070, 3140,  428, 2222, 3675, 3847, 2075, 4710,
#        4624, 1734, 2409, 3327, 2303, 4159, 3165, 3637, 3623, 4260, 3506,
#        3120, 2049, 2490, 2876, 3159, 2482, 4252, 1236, 1234, 2874,   71,
#        2932, 4322,   65, 2057, 2391, 2179, 3916, 2212,  427,  284, 1521,
#        4286, 4899, 3192, 4859,  517, 2673, 4573, 1484, 1338, 1993, 3823,
#         357,  488, 3553, 1077, 4131, 3791, 2548, 1155, 1554, 4054, 2639,
#        3851, 1097, 1166, 3696, 3830, 3345, 1462, 4094, 3105, 1237, 4142,
#        4452, 2190, 3446, 1424, 4407, 1931, 3868, 1890, 4347, 4234, 1940,
#         605, 3354, 1897, 4232, 1963,   88, 4112, 1446, 3687, 2527, 1069,
#         518, 3334, 1048, 1143,  446, 3301, 4189, 1607, 3743, 2093,  712,
#        1255, 3566,  606, 3014, 2722,  703, 3169, 4474, 3908, 2547, 2735,
#        3434, 2743, 4477,  777, 3948, 3634, 3666, 3310, 1361, 3280, 1214,
#         571, 4643, 1749,  353,  165, 2839, 1022, 3412,  779,  737,  776,
#        4177, 1647, 3713,   81, 4253, 3902, 1099, 2130, 3356, 1347,  257,
#        3170, 4647, 4491, 3595, 3260, 2777, 1564, 1522, 3597, 4935,  311,
#         650, 1786, 4012, 4660, 2578,  791,  627, 2962, 3143, 2170,  236,
#        4861, 2770, 1965, 1061,  199, 2830, 3456, 1016, 2314, 1676, 3921,
#        1516, 1156,  441, 2515, 2231, 1908, 4071,  143, 1389, 3302, 1751,
#         879, 3060, 3917,  422, 1285,   77, 4916,  618,  114, 2081, 4722,
#         492, 1314, 1343, 3530,  245, 4058, 3686,  524, 1858, 3441, 3103,
#         669,  312, 3592, 2472, 1527, 1311,  581, 3435, 4093, 4571, 4467,
#        1189, 4648, 4855,  645,    1, 2312, 4531, 4773, 2091, 4535,  569,
#        1489, 4178, 2686,  662, 3247, 1093, 1393, 1818, 4037, 4941,  221,
#        2355,  871,  411, 2734, 4089, 1781, 1441, 3525, 3501, 2386,  133,
#        3807, 4501,   32, 1706, 2384, 3593, 1673,  631, 3900, 2848, 4980,
#         868, 1018, 2372, 1279, 4582,  921, 1997,  416, 4030, 2879, 1833,
#         470, 4956,  541,  248, 3967, 2914, 3541, 2917, 1141, 4265, 1684,
#         158, 4042, 1354, 1887, 3269, 2600, 4655, 3147, 4500,  124, 4144,
#        2882, 3241, 1192, 4536, 2992, 3836, 2728, 4371, 4409,  287, 3426,
#        1173, 2371, 1199, 2244, 1252, 4937, 3625,  459,  559, 2399, 1213,
#        1059, 2967, 4276,   96,  359, 4291, 1430, 4478, 2730, 4171, 3818,
#        3038, 3212, 2012, 2755, 3734, 3965,  694, 3035, 1045, 4376,  444,
#        1968, 2072, 4471,  842, 3738, 4450,  649, 4341, 1303, 3605, 1723,
#        2795,   84, 1248, 1530, 3773,  980, 3870, 4417,  825, 3571, 1942,
#        2880,  958, 3167, 4626,   60,  778, 1961, 4230, 1117,  908, 1984,
#        1981, 1154, 2690, 2351, 1435, 4114, 1448, 4802, 3589, 2085, 4377,
#        4646, 4137, 3532, 2520, 2544,  851, 4942,  120, 4846, 2295,   70,
#        2569, 4996, 4566, 2387, 1927, 1866,  692,  625, 3895, 1308, 2779,
#         301, 3750,  993, 3085, 2736, 2217, 3556, 4630,  431, 4062, 2015,
#        3993, 4870, 2794,  661, 4015, 4921, 3175, 4462,  596,  182, 4333,
#        2059, 2671, 4810, 1498,  543, 4690, 1039,  238, 2740,  614, 1685,
#        1754,  196, 4961,   75, 3596,  574, 4978,  161, 3983, 1356, 1722,
#        1991, 1550, 4369,  272,  667,  970, 2588, 3005, 4465, 2447, 2849,
#         839,  195, 3635, 3371, 3061, 2496,    5, 1432, 1335, 4886,  987,
#         774, 4602, 1138, 4051, 3516, 2239, 2975, 3020,   83,  822, 2266,
#        2628, 1454, 4284, 3950,  455, 1094, 2028, 3468, 3829, 4863, 3712,
#        3379, 2234, 1272, 3554, 1202, 4009, 2227,  550, 1205, 3156, 2612,
#        1805, 3997, 2288, 4468, 4922, 2206, 1986, 3304, 2633, 1024,   18,
#        1187, 1563, 2009,  462, 2753, 2509, 4522, 1664, 4208,  249, 1452,
#        3931, 3087, 4416, 2959, 4768, 4925, 1392, 4198, 4003,  364,  666,
#        1625,  954, 3329,  880, 3293,  672,  613, 4216, 2492, 3590, 1261,
#        4728, 2429, 3051,  443,  153, 4077, 4715, 4538,  320,  198, 4843,
#        2296,  489, 3932, 4883,  976, 4657,  640, 1329, 2256, 3040, 1260,
#        2787, 3463,  957, 1930, 1021,  159, 4986, 1004,  683, 1012, 2614,
#        4824, 4193,  111, 1359, 4995, 3616, 1513, 4580,  590, 3608, 3059,
#        3476, 1162, 3843, 2885, 3031, 4460,  325, 1380, 4503,  100, 1705,
#        3729, 2086, 3731, 4123, 1744, 4830, 1724,  183, 1980, 2759, 1870,
#        4965, 4313, 4413, 1399, 2315, 3180, 4993, 2766, 3971, 4285,  633,
#        2488,  337, 2033, 2638, 4053,  857,  905, 1372, 2654,  629, 3894,
#        2925, 3985, 1559, 1726, 4367, 1816, 4837,  264, 4708, 4578,  302,
#        4711, 1688, 4897, 4504,  500, 4036,  218, 4075, 3307, 2152, 1760,
#        1103,  565,  251,  142, 4735,  420, 1000, 3929, 2008, 1611,  648,
#         557, 3966, 4324, 2658, 1333, 4912, 2732, 3976, 1495, 4723, 2987,
#        2865,  894,  951, 4380, 2868, 4506, 1791, 2186, 1030, 4080,  138,
#        2679, 3512, 4791, 1926,  149, 4384, 2657, 1376, 2603, 3407, 1731,
#        1635, 2149, 1274, 3538, 4310, 3475, 1284, 1506, 3505, 3485, 2489,
#        4775, 2521,   89, 2498,  943,  677,  356,  448,  902,  370,  656,
#        4725,  926, 3172, 4616, 4797, 4757, 3082, 4342, 3274, 2554, 2936,
#        4906,  821, 1135, 3751, 2436, 1539,  368,  861,  351, 4968, 2035,
#         377, 1867, 4210, 1457, 1291, 4026, 3551, 1823, 2602, 1678, 4255,
#        1358,  982, 3081,  836,  372,  483, 1350,  696, 3579,  741, 4220,
#        3879, 1862, 1892, 3909, 3229,  828, 2747, 2411, 1271,  385, 4525,
#         231, 3101, 4699, 4066,   64,  934, 1450, 1428, 2703, 3534, 3022,
#        2756, 1556, 3127, 1492,  382,  681,  178, 3718,  523, 4705, 4268,
#        4240, 3680, 3074, 2560, 2282, 4836,  689, 3856, 3961, 1959, 3121,
#        2609, 4229, 1384, 4196,  136, 4926, 4164, 2505, 2898, 3080, 1438,
#         250, 1869,  784, 3181, 2525, 2650,  554, 3458, 2934,  586, 2931,
#         639, 4095,  200,  570,  425, 3761, 2583,  286, 2171,  621, 3552,
#        3191, 2478,  503, 1053, 4756, 2214,  188, 2973, 2894, 4217, 3099,
#        3043, 1752, 2416, 3228, 1582, 3768, 2568, 1096, 3368, 1509,  602,
#        3164, 3021, 4331, 3320,  773, 4370, 2204, 1113, 1844, 1547, 3185,
#        3018, 3726, 4939,  115, 3943,  588, 1312, 3714, 3846, 2192, 3708,
#        3941, 4601,  262, 1604, 3279, 1614, 2921,  754, 2499, 4783, 2866,
#        2786, 4652,   95, 2274, 4278, 4785, 4704,  780, 3197, 2713, 2901,
#        2173,  612, 1679, 4438,  616, 1600, 3821, 4201, 3764, 3342, 1110,
#        4311, 4479, 3003, 2533, 2205,  417,   25, 1859, 2079, 3799, 3811,
#        3812, 1650, 4737, 3135,  472, 4621, 3062, 3999,   99, 4335, 4209,
#        2800, 1955, 2260, 2591, 3114, 1641, 1716, 4877, 2873, 2642, 3884,
#        4392, 3863, 3333, 2937, 2922, 4894, 3859, 1871, 2813, 1515, 4121,
#        2285, 4698, 1109, 4052, 2319,  749, 3249, 4997, 4197, 4001])

# %%
# write cols list to file
with open("../../313356_vars.txt", "w") as f:
    for col in cols:
        f.write(f"{col+1}\n")

# %%
with open("../../313356_obs.txt", "w") as f:
    for i in idx:
        f.write(f"{i+1}\n")
