# %%
import pandas as pd

# Read x_train.txt
X = pd.read_csv('../data/x_train.txt', sep=' ', header=None)

# Read y_train.txt
y = pd.read_csv('../data/y_train.txt', sep=' ', header=None)


# Display the data
print("x:")
print(X.head())

print("\ny:")
print(y.head())
# Out:
# x:
#         0         1         2         3         4         5         6    \
# 0 -2.619773 -2.619533 -1.199350 -1.083335 -1.000910 -0.366967 -2.164037
# 1 -1.415579 -1.782544 -2.880270 -1.958863  1.159968  0.273030 -1.628728
# 2 -2.745092 -1.382945 -1.626015 -1.282560 -0.663146  0.052349 -2.403322
# 3  0.618998  0.455364 -0.115081  0.649040 -0.862207  2.308504  0.526114
# 4 -0.070694 -0.550509 -0.565556 -0.693065 -0.573089 -0.395862  0.003170
#
#         7         8         9    ...        490        491        492  \
# 0 -1.210001 -0.658311 -1.489539  ...  10.849925  10.343346  10.717519
# 1 -0.175813 -0.916857 -0.570166  ...  11.489417   5.195818   3.494627
# 2 -0.765073 -0.394354 -0.806624  ...  13.934934   9.267515   4.705604
# 3 -1.094852  1.088656 -0.481210  ...  12.021328   3.852231  11.059702
# 4 -0.981609 -0.505775 -0.758430  ...   7.537788  11.229665  11.318915
#
#         493        494        495        496        497        498        499
# 0  7.709295   5.894554  12.416573   6.765269  16.243907   7.209524   8.082021
# 1  5.529154  10.517576  15.697333  11.324938  12.187670  12.283861   5.032285
# 2  6.642557  14.658934   8.130767   7.194487  11.939354  11.653620   5.942778
# 3  7.527268   7.253120   9.791136   6.089743  10.752796   5.778888  10.366363
# 4  6.622256  12.557882   5.520360   5.397359  13.152269  10.684779   9.816471
#
# [5 rows x 500 columns]
#
# y:
#    0
# 0  0
# 1  0
# 2  1
# 3  1
# 4  1

# %%
import ray
from ray import tune
from ray.tune.schedulers.hb_bohb import HyperBandForBOHB
from ray.tune.search.bohb import TuneBOHB
from ray.train import report
from sklearn.model_selection import train_test_split
from sklearn.ensemble import ExtraTreesClassifier, VotingClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from xgboost import XGBClassifier
import pandas as pd
import numpy as np
import ConfigSpace as CS
import ConfigSpace.hyperparameters as CSH
import ast
# Assuming your data is in X and y dataframes

def train_ensemble(config):
    # Split data into training and validation sets
    vars = ast.literal_eval(config['colset'])
    Xloc = X[vars]

    X_train, X_val, y_train, y_val = train_test_split(Xloc, y, test_size=0.2)
    
    # Initialize the models with the given hyperparameters
    xgb_model = XGBClassifier(
        eta=config["xgb_eta"],
        max_depth=config["xgb_max_depth"],
        min_child_weight=config["xgb_min_child_weight"],
        subsample=config["xgb_subsample"],
        colsample_bytree=config["xgb_colsample_bytree"],
        reg_lambda=config["xgb_lambda"],
        reg_alpha=config["xgb_alpha"],
        objective="binary:logistic",
        eval_metric="logloss",
        use_label_encoder=False,
        verbosity=0
    )

    et_model = ExtraTreesClassifier(
        n_estimators=config["et_n_estimators"],
        max_depth=config["et_max_depth"],
        min_samples_split=config["et_min_samples_split"],
        min_samples_leaf=config["et_min_samples_leaf"],
        max_features=config["et_max_features"],
        bootstrap=config["et_bootstrap"]
    )
    
    svc_model = SVC(
        C=config["svc_C"],
        kernel=config["svc_kernel"],
        probability=True
    )

    lr_model = LogisticRegression(
        C=config["lr_C"],
        solver=config["lr_solver"],
        max_iter=1000
    )
    
    knn_model = KNeighborsClassifier(
        n_neighbors=config["knn_n_neighbors"],
        weights=config["knn_weights"],
        algorithm=config["knn_algorithm"]
    )

    # # Train the models
    # xgb_model.fit(X_train, y_train)
    # et_model.fit(X_train, y_train)
    # svc_model.fit(X_train, y_train)
    # lr_model.fit(X_train, y_train)
    # knn_model.fit(X_train, y_train)
    
    # # Predict probabilities on the validation set
    # xgb_preds_proba = xgb_model.predict_proba(X_val)[:, 1]
    # et_preds_proba = et_model.predict_proba(X_val)[:, 1]
    # svc_preds_proba = svc_model.predict_proba(X_val)[:, 1]
    # lr_preds_proba = lr_model.predict_proba(X_val)[:, 1]
    # knn_preds_proba = knn_model.predict_proba(X_val)[:, 1]
    # Create the ensemble model
    ensemble_model = VotingClassifier(
        estimators=[
            ('xgb', xgb_model),
            ('et', et_model),
            ('svc', svc_model),
            ('lr', lr_model),
            ('knn', knn_model)
        ],
        voting='soft',
        weights=[
            config["weight_xgb"],
            config["weight_et"],
            config["weight_svc"],
            config["weight_lr"],
            config["weight_knn"]
        ]
    )
    
    # Train the ensemble model
    ensemble_model.fit(X_train, y_train)
    
    # Predict probabilities on the validation set
    ensemble_preds_proba = ensemble_model.predict_proba(X_val)[:, 1]
    # Ensemble the predictions by averaging
    #ensemble_preds_proba = (xgb_preds_proba + et_preds_proba + svc_preds_proba + lr_preds_proba + knn_preds_proba) / 5
    
    # Get the indices of the top 20% predictions
    top_20_percent_indices = np.argsort(ensemble_preds_proba)[-int(0.2 * len(ensemble_preds_proba)):]

    # Select the corresponding true labels and predicted labels for top 20%
    top_20_true = y_val.iloc[top_20_percent_indices].values
    top_20_preds = (ensemble_preds_proba[top_20_percent_indices] >= 0.5).astype(int)
    
    # Calculate the number of correct class 1 predictions
    correct_class_1_predictions = sum(1 for true, pred in zip(top_20_true, top_20_preds) if true == 1 and pred == 1)
    
    # Calculate the number of features used
    num_features_used = Xloc.shape[1]
    
    #scaled score calculation
    customer_scaled = (correct_class_1_predictions / len(top_20_preds)) * 1000
    customer_gain = 10 * customer_scaled
    variable_cost = 200 * num_features_used
    custom_score = customer_gain - variable_cost
    # # Compute the custom score
    # custom_score = (correct_class_1_predictions * 10) - (num_features_used * 200)
    
    report({"custom_score": custom_score})

# Define the search space using ConfigSpace
config_space = CS.ConfigurationSpace()

# Hyperparameters for XGBoost
config_space.add_hyperparameter(CSH.UniformFloatHyperparameter('xgb_eta', lower=0.01, upper=0.1, log=True))
config_space.add_hyperparameter(CSH.UniformIntegerHyperparameter('xgb_max_depth', lower=3, upper=10))
config_space.add_hyperparameter(CSH.UniformIntegerHyperparameter('xgb_min_child_weight', lower=1, upper=5))
config_space.add_hyperparameter(CSH.UniformFloatHyperparameter('xgb_subsample', lower=0.5, upper=1.0))
config_space.add_hyperparameter(CSH.UniformFloatHyperparameter('xgb_colsample_bytree', lower=0.5, upper=1.0))
config_space.add_hyperparameter(CSH.UniformFloatHyperparameter('xgb_lambda', lower=1e-3, upper=10.0, log=True))
config_space.add_hyperparameter(CSH.UniformFloatHyperparameter('xgb_alpha', lower=1e-3, upper=10.0, log=True))

# Hyperparameters for ExstraTrees
config_space.add_hyperparameter(CSH.UniformIntegerHyperparameter('et_n_estimators', lower=50, upper=200))
config_space.add_hyperparameter(CSH.UniformIntegerHyperparameter('et_max_depth', lower=3, upper=20))
config_space.add_hyperparameter(CSH.UniformIntegerHyperparameter('et_min_samples_split', lower=2, upper=10))
config_space.add_hyperparameter(CSH.UniformIntegerHyperparameter('et_min_samples_leaf', lower=1, upper=10))
config_space.add_hyperparameter(CSH.CategoricalHyperparameter('et_max_features', ['sqrt', 'log2']))
config_space.add_hyperparameter(CSH.CategoricalHyperparameter('et_bootstrap', [True, False]))

# Hyperparameters for SVC
config_space.add_hyperparameter(CSH.UniformFloatHyperparameter('svc_C', lower=0.1, upper=10.0, log=True))
config_space.add_hyperparameter(CSH.CategoricalHyperparameter('svc_kernel', ['linear', 'rbf', 'poly', 'sigmoid']))

# Hyperparameters for Logistic Regression
config_space.add_hyperparameter(CSH.UniformFloatHyperparameter('lr_C', lower=0.1, upper=10.0, log=True))
config_space.add_hyperparameter(CSH.CategoricalHyperparameter('lr_solver', ['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga']))

# Hyperparameters for KNN
config_space.add_hyperparameter(CSH.UniformIntegerHyperparameter('knn_n_neighbors', lower=1, upper=30))
config_space.add_hyperparameter(CSH.CategoricalHyperparameter('knn_weights', ['uniform', 'distance']))
config_space.add_hyperparameter(CSH.CategoricalHyperparameter('knn_algorithm', ['auto', 'ball_tree', 'kd_tree', 'brute']))

# Hyperparameters for model weights
config_space.add_hyperparameter(CSH.UniformFloatHyperparameter('weight_xgb', lower=0.0, upper=1.0))
config_space.add_hyperparameter(CSH.UniformFloatHyperparameter('weight_et', lower=0.0, upper=1.0))
config_space.add_hyperparameter(CSH.UniformFloatHyperparameter('weight_svc', lower=0.0, upper=1.0))
config_space.add_hyperparameter(CSH.UniformFloatHyperparameter('weight_lr', lower=0.0, upper=1.0))
config_space.add_hyperparameter(CSH.UniformFloatHyperparameter('weight_knn', lower=0.0, upper=1.0))


config_space.add_hyperparameter(CSH.CategoricalHyperparameter('colset', ['[101, 102, 103, 105]', '[101, 102, 103]', '[101, 102, 105]', '[101, 103, 105]', '[102, 103, 105]', '[104, 102, 103, 105]', '[100, 101, 102, 103, 105]', '[100, 101, 102, 103]', '[100, 101, 102, 105]', '[100, 101, 103, 105]', '[100, 102, 103, 105]', '[100, 104, 102, 103, 105]', '[100, 101, 102, 103, 104, 105]', '[100, 101]', '[100, 102]', '[100, 103]', '[100, 104]', '[100, 105]','[101, 102]', '[101, 103]', '[101, 104]', '[101, 105]', '[102, 103]', '[102, 104]', '[102, 105]', '[103, 104]', '[103, 105]', '[104, 105]',]))


# Set up the BOHB search algorithm
bohb_search = TuneBOHB(config_space, metric="custom_score", mode="max")

# Set up the HyperBandForBOHB scheduler
bohb_scheduler = HyperBandForBOHB(
    time_attr="training_iteration",
    metric="custom_score",
    mode="max"
)

# Function to create shorter directory names
def trial_dirname_creator(trial):
    return f"trial_{trial.trial_id}"

# Run the hyperparameter search
analysis = tune.run(
    train_ensemble,
    resources_per_trial={"cpu": 1, "gpu": 0},
    search_alg=bohb_search,
    scheduler=bohb_scheduler,
    num_samples=600,
    trial_dirname_creator=trial_dirname_creator,
    raise_on_failed_trial=False
)

# Get the best result
best_config = analysis.get_best_config(metric="custom_score", mode="max")
print("Best config: ", best_config)
# Out:
# 2024-05-29 13:54:29,689	INFO worker.py:1749 -- Started a local Ray instance.
# 2024-05-29 13:54:31,262	INFO tune.py:253 -- Initializing Ray automatically. For cluster usage or custom Ray initialization, call `ray.init(...)` before `tune.run(...)`.
# 2024-05-29 13:54:31,264	INFO tune.py:614 -- [output] This uses the legacy output and progress reporter, as Jupyter notebooks are not supported by the new engine, yet. For more information, please see https://github.com/ray-project/ray/issues/36949
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2024-05-29 14:13:43</td></tr>
# <tr><td>Running for: </td><td>00:19:12.30        </td></tr>
# <tr><td>Memory:      </td><td>26.3/63.8 GiB      </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using HyperBand: num_stopped=54 total_brackets=2<br>Round #0:<br>  Bracket(Max Size (n)=27, Milestone (r)=3, completed=20.0%): {TERMINATED: 81} <br>  Bracket(Max Size (n)=12, Milestone (r)=9, completed=100.0%): {TERMINATED: 519} <br>Logical resource usage: 1.0/28 CPUs, 0/1 GPUs (0.0/1.0 accelerator_type:G)
#     </div>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name             </th><th>status    </th><th>loc            </th><th>colset              </th><th>et_bootstrap  </th><th style="text-align: right;">  et_max_depth</th><th>et_max_features  </th><th style="text-align: right;">  et_min_samples_leaf</th><th style="text-align: right;">  et_min_samples_split</th><th style="text-align: right;">  et_n_estimators</th><th>knn_algorithm  </th><th style="text-align: right;">  knn_n_neighbors</th><th>knn_weights  </th><th style="text-align: right;">    lr_C</th><th>lr_solver  </th><th style="text-align: right;">   svc_C</th><th>svc_kernel  </th><th style="text-align: right;">  weight_et</th><th style="text-align: right;">  weight_knn</th><th style="text-align: right;">  weight_lr</th><th style="text-align: right;">  weight_svc</th><th style="text-align: right;">  weight_xgb</th><th style="text-align: right;">  xgb_alpha</th><th style="text-align: right;">  xgb_colsample_bytree</th><th style="text-align: right;">  xgb_eta</th><th style="text-align: right;">  xgb_lambda</th><th style="text-align: right;">  xgb_max_depth</th><th style="text-align: right;">  xgb_min_child_weight</th><th style="text-align: right;">  xgb_subsample</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  custom_score</th></tr>
# </thead>
# <tbody>
# <tr><td>train_ensemble_580f61ef</td><td>TERMINATED</td><td>127.0.0.1:44456</td><td>[103, 105]          </td><td>False         </td><td style="text-align: right;">            16</td><td>log2             </td><td style="text-align: right;">                    8</td><td style="text-align: right;">                     9</td><td style="text-align: right;">              173</td><td>auto           </td><td style="text-align: right;">               12</td><td>uniform      </td><td style="text-align: right;">1.40943 </td><td>liblinear  </td><td style="text-align: right;">4.91158 </td><td>rbf         </td><td style="text-align: right;"> 0.124633  </td><td style="text-align: right;">  0.513567  </td><td style="text-align: right;">0.678996   </td><td style="text-align: right;">  0.782806  </td><td style="text-align: right;"> 0.436227   </td><td style="text-align: right;"> 0.0168649 </td><td style="text-align: right;">              0.731459</td><td style="text-align: right;">0.012894 </td><td style="text-align: right;">  9.98652   </td><td style="text-align: right;">              8</td><td style="text-align: right;">                     1</td><td style="text-align: right;">       0.745696</td><td style="text-align: right;">     1</td><td style="text-align: right;">        1.60162 </td><td style="text-align: right;">          7050</td></tr>
# <tr><td>train_ensemble_036cf302</td><td>TERMINATED</td><td>127.0.0.1:52832</td><td>[100, 104]          </td><td>True          </td><td style="text-align: right;">             3</td><td>sqrt             </td><td style="text-align: right;">                    3</td><td style="text-align: right;">                     5</td><td style="text-align: right;">               51</td><td>brute          </td><td style="text-align: right;">               15</td><td>uniform      </td><td style="text-align: right;">0.247422</td><td>sag        </td><td style="text-align: right;">7.90703 </td><td>poly        </td><td style="text-align: right;"> 0.877442  </td><td style="text-align: right;">  0.781652  </td><td style="text-align: right;">0.860577   </td><td style="text-align: right;">  0.241999  </td><td style="text-align: right;"> 0.448318   </td><td style="text-align: right;"> 1.59079   </td><td style="text-align: right;">              0.966791</td><td style="text-align: right;">0.0997166</td><td style="text-align: right;">  0.164308  </td><td style="text-align: right;">              9</td><td style="text-align: right;">                     4</td><td style="text-align: right;">       0.974796</td><td style="text-align: right;">     1</td><td style="text-align: right;">        3.27452 </td><td style="text-align: right;">          6100</td></tr>
# <tr><td>train_ensemble_d13fac4d</td><td>TERMINATED</td><td>127.0.0.1:3732 </td><td>[102, 104]          </td><td>False         </td><td style="text-align: right;">            13</td><td>log2             </td><td style="text-align: right;">                    6</td><td style="text-align: right;">                     8</td><td style="text-align: right;">              186</td><td>kd_tree        </td><td style="text-align: right;">               12</td><td>uniform      </td><td style="text-align: right;">0.941172</td><td>sag        </td><td style="text-align: right;">0.902339</td><td>rbf         </td><td style="text-align: right;"> 0.302062  </td><td style="text-align: right;">  0.489341  </td><td style="text-align: right;">0.0791242  </td><td style="text-align: right;">  0.234006  </td><td style="text-align: right;"> 0.349887   </td><td style="text-align: right;"> 0.0957057 </td><td style="text-align: right;">              0.604548</td><td style="text-align: right;">0.0123208</td><td style="text-align: right;">  0.00349171</td><td style="text-align: right;">              6</td><td style="text-align: right;">                     3</td><td style="text-align: right;">       0.541237</td><td style="text-align: right;">     1</td><td style="text-align: right;">        1.62876 </td><td style="text-align: right;">          6250</td></tr>
# <tr><td>train_ensemble_3a609c70</td><td>TERMINATED</td><td>127.0.0.1:58708</td><td>[101, 102, 103]     </td><td>False         </td><td style="text-align: right;">            16</td><td>log2             </td><td style="text-align: right;">                    7</td><td style="text-align: right;">                     4</td><td style="text-align: right;">              147</td><td>brute          </td><td style="text-align: right;">                4</td><td>uniform      </td><td style="text-align: right;">0.114854</td><td>newton-cg  </td><td style="text-align: right;">0.403742</td><td>rbf         </td><td style="text-align: right;"> 0.0614045 </td><td style="text-align: right;">  0.192684  </td><td style="text-align: right;">0.998469   </td><td style="text-align: right;">  0.369417  </td><td style="text-align: right;"> 0.0899971  </td><td style="text-align: right;"> 0.0114147 </td><td style="text-align: right;">              0.962211</td><td style="text-align: right;">0.054856 </td><td style="text-align: right;">  0.156678  </td><td style="text-align: right;">              8</td><td style="text-align: right;">                     4</td><td style="text-align: right;">       0.981118</td><td style="text-align: right;">     1</td><td style="text-align: right;">        1.41518 </td><td style="text-align: right;">          6650</td></tr>
# <tr><td>train_ensemble_febb5eb1</td><td>TERMINATED</td><td>127.0.0.1:33956</td><td>[101, 102]          </td><td>False         </td><td style="text-align: right;">             9</td><td>log2             </td><td style="text-align: right;">                    9</td><td style="text-align: right;">
# (raylet) Warning: The actor ImplicitFunc is very large (19 MiB). Check that its definition is not implicitly capturing a large array or other object in scope. Tip: use ray.put() to put large objects in the Ray object store.
# (train_ensemble pid=9036) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:97: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# (train_ensemble pid=9036)   y = column_or_1d(y, warn=True)
# (train_ensemble pid=9036) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# (train_ensemble pid=9036)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# <div class="trialProgress">
#   <h3>Trial Progress</h3>
#   <table>
# <thead>
# <tr><th>Trial name             </th><th style="text-align: right;">  custom_score</th></tr>
# </thead>
# <tbody>
# <tr><td>train_ensemble_0046cb65</td><td style="text-align: right;">          7050</td></tr>
# <tr><td>train_ensemble_004f7eeb</td><td style="text-align: right;">          6800</td></tr>
# <tr><td>train_ensemble_00a6f292</td><td style="text-align: right;">          6400</td></tr>
# <tr><td>train_ensemble_00f42c4a</td><td style="text-align: right;">          5450</td></tr>
# <tr><td>train_ensemble_01671cbc</td><td style="text-align: right;">          6250</td></tr>
# <tr><td>train_ensemble_01a50972</td><td style="text-align: right;">          6900</td></tr>
# <tr><td>train_ensemble_02451f4a</td><td style="text-align: right;">          5850</td></tr>
# <tr><td>train_ensemble_029cca57</td><td style="text-align: right;">          6250</td></tr>
# <tr><td>train_ensemble_02fb07a0</td><td style="text-align: right;">          6200</td></tr>
# <tr><td>train_ensemble_036cf302</td><td style="text-align: right;">          6100</td></tr>
# <tr><td>train_ensemble_03cbb19f</td><td style="text-align: right;">          6500</td></tr>
# <tr><td>train_ensemble_042d0aba</td><td style="text-align: right;">          6300</td></tr>
# <tr><td>train_ensemble_04effa32</td><td style="text-align: right;">          6100</td></tr>
# <tr><td>train_ensemble_050f6b6f</td><td style="text-align: right;">          6000</td></tr>
# <tr><td>train_ensemble_059bafd1</td><td style="text-align: right;">          5800</td></tr>
# <tr><td>train_ensemble_05b64a6e</td><td style="text-align: right;">          6100</td></tr>
# <tr><td>train_ensemble_067519cc</td><td style="text-align: right;">          6700</td></tr>
# <tr><td>train_ensemble_06be951b</td><td style="text-align: right;">          7050</td></tr>
# <tr><td>train_ensemble_07a5d555</td><td style="text-align: right;">          6250</td></tr>
# <tr><td>train_ensemble_08d72e69</td><td style="text-align: right;">          6450</td></tr>
# <tr><td>train_ensemble_08e3eb6a</td><td style="text-align: right;">          6300</td></tr>
# <tr><td>train_ensemble_09352732</td><td style="text-align: right;">          7100</td></tr>
# <tr><td>train_ensemble_09d2c527</td><td style="text-align: right;">          6350</td></tr>
# <tr><td>train_ensemble_09f9eaf2</td><td style="text-align: right;">          6550</td></tr>
# <tr><td>train_ensemble_0a5f7387</td><td style="text-align: right;">          6600</td></tr>
# <tr><td>train_ensemble_0b38403b</td><td style="text-align: right;">          6200</td></tr>
# <tr><td>train_ensemble_0b40f47e</td><td style="text-align: right;">          6000</td></tr>
# <tr><td>train_ensemble_0bede0cd</td><td style="text-align: right;">          6000</td></tr>
# <tr><td>train_ensemble_0c3976e8</td><td style="text-align: right;">          7000</td></tr>
# <tr><td>train_ensemble_0c43b756</td><td style="text-align: right;">          6600</td></tr>
# <tr><td>train_ensemble_0c9cbe59</td><td style="text-align: right;">          6350</td></tr>
# <tr><td>train_ensemble_0ccf4aac</td><td style="text-align: right;">          6550</td></tr>
# <tr><td>train_ensemble_0d2a650f</td><td style="text-align: right;">          6800</td></tr>
# <tr><td>train_ensemble_0d442acb</td><td style="text-align: right;">          6800</td></tr>
# <tr><td>train_ensemble_0d6f9c08</td><td style="text-align: right;">          6450</td></tr>
# <tr><td>train_ensemble_0daf76f5</td><td style="text-align: right;">          6000</td></tr>
# <tr><td>train_ensemble_0eb2a3e7</td><td style="text-align: right;">          6500</td></tr>
# <tr><td>train_ensemble_104d7165</td><td style="text-align: right;">          5900</td></tr>
# <tr><td>train_ensemble_10c2d4b3</td><td style="text-align: right;">          6300</td></tr>
# <tr><td>train_ensemble_11146e07</td><td style="text-align: right;">          6250</td></tr>
# <tr><td>train_ensemble_115aa537</td><td style="text-align: right;">          6650</td></tr>
# <tr><td>train_ensemble_1165303f</td><td style="text-align: right;">          6800</td></tr>
# <tr><td>train_ensemble_11839ca1</td><td style="text-align: right;">          6650</td></tr>
# <tr><td>train_ensemble_127574f8</td><td style="text-align: right;">          6950</td></tr>
# <tr><td>train_ensemble_12e04657</td><td style="text-align: right;">          6450</td></tr>
# <tr><td>train_ensemble_1314984c</td><td style="text-align: right;">          5950</td></tr>
# <tr><td>train_ensemble_1328697e</td><td style="text-align: right;">          6150</td></tr>
# <tr><td>train_ensemble_1398d6a1</td><td style="text-align: right;">          6200</td></tr>
# <tr><td>train_ensemble_13d7cc3c</td><td style="text-align: right;">          6700</td></tr>
# <tr><td>train_ensemble_144a1106</td><td style="text-align: right;">          6300</td></tr>
# <tr><td>train_ensemble_148fa09f</td><td style="text-align: right;">          5950</td></tr>
# <tr><td>train_ensemble_14a72a80</td><td style="text-align: right;">          6350</td></tr>
# <tr><td>train_ensemble_14b3f30d</td><td style="text-align: right;">          6800</td></tr>
# <tr><td>train_ensemble_15c5cdd7</td><td style="text-align: right;">          6650</td></tr>
# <tr><td>train_ensemble_1610ee24</td><td style="text-align: right;">          6650</td></tr>
# <tr><td>train_ensemble_165ce32b</td><td style="text-align: right;">          6250</td></tr>
# <tr><td>train_ensemble_175eb9a3</td><td style="text-align: right;">          6650</td></tr>
# <tr><td>train_ensemble_17fe6e77</td><td style="text-align: right;">          7650</td></tr>
# <tr><td>train_ensemble_18c46d4b</td><td style="text-align: right;">          6850</td></tr>
# <tr><td>train_ensemble_19884e60</td><td style="text-align: right;">          6450</td></tr>
# <tr><td>train_ensemble_19f3c058</td><td style="text-align: right;">          6800</td></tr>
# <tr><td>train_ensemble_1a071727</td><td style="text-align: right;">          6900</td></tr>
# <tr><td>train_ensemble_1a9ee9f3</td><td style="text-align: right;">          7050</td></tr>
# <tr><td>train_ensemble_1ab9e7e6</td><td style="text-align: right;">          6200</td></tr>
# <tr><td>train_ensemble_1bd631f4</td><td style="text-align: right;">          5450</td></tr>
# <tr><td>train_ensemble_1beb9fdb</td><td style="text-align: right;">          6750</td></tr>
# <tr><td>train_ensemble_1c0bfa60</td><td style="text-align: right;">          6500</td></tr>
# <tr><td>train_ensemble_1c6554fc</td><td style="text-align: right;">          6600</td></tr>
# <tr><td>train_ensemble_1c9bc05a</td><td style="text-align: right;">          6550</td></tr>
# <tr><td>train_ensemble_1cc62e59</td><td style="text-align: right;">          6150</td></tr>
# <tr><td>train_ensemble_1d6f9731</td><td style="text-align: right;">          7200</td></tr>
# <tr><td>train_ensemble_1d8ff22f</td><td style="text-align: right;">          5800</td></tr>
# <tr><td>train_ensemble_1d9cb810</td><td style="text-align: right;">          6850</td></tr>
# <tr><td>train_ensemble_1ec50876</td><td style="text-align: right;">          6650</td></tr>
# <tr><td>train_ensemble_1f0d12c7</td><td style="text-align: right;">          6650</td></tr>
# <tr><td>train_ensemble_1f358ecc</td><td style="text-align: right;">          6200</td></tr>
# <tr><td>train_ensemble_1f414310</td><td style="text-align: right;">          6450</td></tr>
# <tr><td>train_ensemble_1f8de0c1</td><td style="text-align: right;">          6250</td></tr>
# <tr><td>train_ensemble_1fee9856</td><td style="text-align: right;">          6050</td></tr>
# <tr><td>train_ensemble_2002f9dd</td><td style="text-align: right;">          6150</td></tr>
# <tr><td>train_ensemble_2039b2e5</td><td style="text-align: right;">          6300</td></tr>
# <tr><td>train_ensemble_20cf06e3</td><td style="text-align: right;">          6950</td></tr>
# <tr><td>train_ensemble_20e57f25</td><td style="text-align: right;">          6200</td></tr>
# <tr><td>train_ensemble_2102e39e</td><td style="text-align: right;">          6400</td></tr>
# <tr><td>train_ensemble_21765522</td><td style="text-align: right;">          6700</td></tr>
# (train_ensemble pid=58708) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/user-guides/configure-logging.html#log-deduplication for more options.)
# (train_ensemble pid=58708)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=58708)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=10144) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=10144)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=10144)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=34696) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=34696)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=34696)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=22560) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=22560)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=22560)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=9264) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=9264)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=9264)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=24184) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=24184)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=24184)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=8824) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=8824)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=8824)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=6780) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=6780)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=6780)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=13456) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=13456)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=13456)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=55568) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=55568)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=55568)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=39624) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=39624)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=39624)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=48532) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=48532)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=48532)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=43072) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=43072)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=43072)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=62252) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=62252)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=62252)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=39100) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=39100)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=39100)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=51000) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=51000)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=51000)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=15176) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=15176)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=15176)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=56236) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=56236)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=56236)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=62328) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=62328)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=62328)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=47540) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=47540)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=47540)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=42496) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=42496)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=42496)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=23348) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=23348)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=23348)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=29304) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=29304)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=29304)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=62076) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=62076)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=62076)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=40768) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=40768)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=40768)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=34956) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=34956)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=34956)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=13456) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=13456)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=13456)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# 2024-05-29 13:57:07,681	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# 2024-05-29 13:57:08,940	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# 2024-05-29 13:57:10,578	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# (train_ensemble pid=19476) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 10x across cluster]
# (train_ensemble pid=19476)   y = column_or_1d(y, warn=True) [repeated 5x across cluster]
# (train_ensemble pid=19476)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 5x across cluster]
# 2024-05-29 13:57:13,581	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# 2024-05-29 13:57:14,621	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# 2024-05-29 13:57:16,608	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# (train_ensemble pid=26044) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 10x across cluster]
# (train_ensemble pid=26044)   y = column_or_1d(y, warn=True) [repeated 5x across cluster]
# (train_ensemble pid=26044)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 5x across cluster]
# 2024-05-29 13:57:18,445	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# 2024-05-29 13:57:19,964	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# 2024-05-29 13:57:21,363	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# (train_ensemble pid=21836) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 8x across cluster]
# (train_ensemble pid=21836)   y = column_or_1d(y, warn=True) [repeated 4x across cluster]
# (train_ensemble pid=21836)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 4x across cluster]
# 2024-05-29 13:57:24,201	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# 2024-05-29 13:57:25,238	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# (train_ensemble pid=18344) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 10x across cluster]
# (train_ensemble pid=18344)   y = column_or_1d(y, warn=True) [repeated 5x across cluster]
# (train_ensemble pid=18344)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 5x across cluster]
# 2024-05-29 13:57:27,807	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# 2024-05-29 13:57:28,649	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# 2024-05-29 13:57:30,570	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# 2024-05-29 13:57:32,462	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# (train_ensemble pid=36900) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 8x across cluster]
# (train_ensemble pid=36900)   y = column_or_1d(y, warn=True) [repeated 4x across cluster]
# (train_ensemble pid=36900)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 4x across cluster]
# 2024-05-29 13:57:34,536	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# 2024-05-29 13:57:36,217	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# 2024-05-29 13:57:38,060	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# (train_ensemble pid=27176) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 10x across cluster]
# (train_ensemble pid=27176)   y = column_or_1d(y, warn=True) [repeated 5x across cluster]
# (train_ensemble pid=27176)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 5x across cluster]
# 2024-05-29 13:57:39,285	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# 2024-05-29 13:57:41,242	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# 2024-05-29 13:57:43,238	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# (train_ensemble pid=61524) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 8x across cluster]
# (train_ensemble pid=61524)   y = column_or_1d(y, warn=True) [repeated 4x across cluster]
# (train_ensemble pid=61524)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 4x across cluster]
# 2024-05-29 13:57:45,245	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# 2024-05-29 13:57:46,883	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# 2024-05-29 13:57:48,548	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# (train_ensemble pid=30440) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 10x across cluster]
# (train_ensemble pid=30440)   y = column_or_1d(y, warn=True) [repeated 5x across cluster]
# (train_ensemble pid=30440)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 5x across cluster]
# 2024-05-29 13:57:50,456	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# 2024-05-29 13:57:52,163	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# (train_ensemble pid=11076) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 8x across cluster]
# (train_ensemble pid=11076)   y = column_or_1d(y, warn=True) [repeated 4x across cluster]
# (train_ensemble pid=11076)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 4x across cluster]
# (train_ensemble pid=38424) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=38424)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=38424)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=33664) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=33664)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=33664)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=36340) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=36340)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=36340)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=11536) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=11536)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=11536)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=41768) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=41768)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=41768)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=33604) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=33604)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=33604)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=24276) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=24276)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=24276)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=27584) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=27584)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=27584)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=34792) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=34792)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=34792)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=6436) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=6436)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=6436)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=38408) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=38408)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=38408)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=19328) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=19328)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=19328)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=35624) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=35624)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=35624)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=44788) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=44788)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=44788)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=39960) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=39960)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=39960)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=27108) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=27108)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=27108)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=45208) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=45208)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=45208)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=2440) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=2440)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=2440)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=21960) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=21960)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=21960)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=36976) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=36976)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=36976)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# ...
# (train_ensemble pid=59184)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=33424) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=33424)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=33424)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=43504) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=43504)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=43504)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=22560) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=22560)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=22560)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=10236) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=10236)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=10236)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=25788) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=25788)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=25788)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=15084) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=15084)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=15084)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=51956) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=51956)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=51956)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=15680) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=15680)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=15680)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=6472) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=6472)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=6472)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=32036) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=32036)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=32036)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=54280) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=54280)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=54280)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=25500) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=25500)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=25500)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=17272) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=17272)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=17272)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=9080) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=9080)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=9080)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=3128) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=3128)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=3128)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=46760) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=46760)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=46760)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=18756) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=18756)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=18756)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=61008) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=61008)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=61008)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=44428) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=44428)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=44428)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=16828) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=16828)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=16828)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=51432) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=51432)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=51432)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=23852) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=23852)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=23852)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=12144) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=12144)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=12144)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=39960) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=39960)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=39960)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=51136) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=51136)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=51136)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=31304) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=31304)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=31304)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=48860) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=48860)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=48860)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=18344) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=18344)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=18344)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=42988) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=42988)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=42988)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=19168) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=19168)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=19168)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# 2024-05-29 14:13:43,827	INFO tune.py:1007 -- Wrote the latest version of all result files and experiment state to 'C:/Users/Mieszko/ray_results/train_ensemble_2024-05-29_13-54-31' in 0.3748s.
# 2024-05-29 14:13:43,986	INFO tune.py:1039 -- Total run time: 1152.72 seconds (1151.92 seconds for the tuning loop).
# Best config:  {'colset': '[101, 102, 105]', 'et_bootstrap': False, 'et_max_depth': 12, 'et_max_features': 'sqrt', 'et_min_samples_leaf': 10, 'et_min_samples_split': 3, 'et_n_estimators': 108, 'knn_algorithm': 'brute', 'knn_n_neighbors': 27, 'knn_weights': 'uniform', 'lr_C': 4.514984819282504, 'lr_solver': 'sag', 'svc_C': 0.1884652734305775, 'svc_kernel': 'rbf', 'weight_et': 0.7496984957246486, 'weight_knn': 0.6635888019981687, 'weight_lr': 0.011412155873019136, 'weight_svc': 0.4846194549815259, 'weight_xgb': 0.41604852070874554, 'xgb_alpha': 0.1331655591104277, 'xgb_colsample_bytree': 0.7382259102923003, 'xgb_eta': 0.027781866578049316, 'xgb_lambda': 0.052031232944512805, 'xgb_max_depth': 8, 'xgb_min_child_weight': 2, 'xgb_subsample': 0.8489255131045501}

# %%
df=analysis.dataframe()
df.to_csv('ensemble2-raytune-bohb.csv')

# %%
df.sort_values(by='custom_score', ascending=False, inplace=True)
print(df.head())
# Out:
#      custom_score   timestamp checkpoint_dir_name   done  training_iteration  \
# 20         7650.0  1716983836                None  False                   1
# 66         7400.0  1716983861                None  False                   1
# 424        7350.0  1716984493                None  False                   1
# 395        7250.0  1716984438                None  False                   1
# 61         7250.0  1716983858                None  False                   1
#
#      trial_id                 date  time_this_iter_s  time_total_s    pid  \
# 20   17fe6e77  2024-05-29_13-57-16          1.404000      1.404000  28064
# 66   798f3dcc  2024-05-29_13-57-41          1.047000      1.047000  58104
# 424  c4364fe3  2024-05-29_14-08-13          1.684004      1.684004  50052
# 395  da97b380  2024-05-29_14-07-18          1.364893      1.364893  56120
# 61   4c35c736  2024-05-29_13-57-38          1.458998      1.458998  32964
#
#      ... config/weight_svc config/weight_xgb  config/xgb_alpha  \
# 20   ...          0.484619          0.416049          0.133166
# 66   ...          0.516301          0.027791          0.005773
# 424  ...          0.330507          0.511787          0.001124
# 395  ...          0.418033          0.328082          0.087122
# 61   ...          0.727680          0.970354          0.121811
#
#      config/xgb_colsample_bytree config/xgb_eta  config/xgb_lambda  \
# 20                      0.738226       0.027782           0.052031
# 66                      0.931936       0.059937           4.083957
# 424                     0.885731       0.079288           0.013793
# 395                     0.549667       0.069529           0.839470
# 61                      0.696615       0.050425           1.424584
#
#      config/xgb_max_depth config/xgb_min_child_weight  config/xgb_subsample  \
# 20                      8                           2              0.848926
# 66                     10                           4              0.955350
# 424                     4                           2              0.733583
# 395                     9                           1              0.746399
# 61                      8                           1              0.571851
#
#        logdir
# 20   17fe6e77
# 66   798f3dcc
# 424  c4364fe3
# 395  da97b380
# 61   4c35c736
#
# [5 rows x 41 columns]
