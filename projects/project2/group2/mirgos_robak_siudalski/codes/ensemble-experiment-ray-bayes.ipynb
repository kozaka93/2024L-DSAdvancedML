# %%
import pandas as pd

# Read x_train.txt
X = pd.read_csv('../data/x_train.txt', sep=' ', header=None)

# Read y_train.txt
y = pd.read_csv('../data/y_train.txt', sep=' ', header=None)


# Display the data
print("x:")
print(X.head())

print("\ny:")
print(y.head())
# Out:
# x:
#         0         1         2         3         4         5         6    \
# 0 -2.619773 -2.619533 -1.199350 -1.083335 -1.000910 -0.366967 -2.164037
# 1 -1.415579 -1.782544 -2.880270 -1.958863  1.159968  0.273030 -1.628728
# 2 -2.745092 -1.382945 -1.626015 -1.282560 -0.663146  0.052349 -2.403322
# 3  0.618998  0.455364 -0.115081  0.649040 -0.862207  2.308504  0.526114
# 4 -0.070694 -0.550509 -0.565556 -0.693065 -0.573089 -0.395862  0.003170
#
#         7         8         9    ...        490        491        492  \
# 0 -1.210001 -0.658311 -1.489539  ...  10.849925  10.343346  10.717519
# 1 -0.175813 -0.916857 -0.570166  ...  11.489417   5.195818   3.494627
# 2 -0.765073 -0.394354 -0.806624  ...  13.934934   9.267515   4.705604
# 3 -1.094852  1.088656 -0.481210  ...  12.021328   3.852231  11.059702
# 4 -0.981609 -0.505775 -0.758430  ...   7.537788  11.229665  11.318915
#
#         493        494        495        496        497        498        499
# 0  7.709295   5.894554  12.416573   6.765269  16.243907   7.209524   8.082021
# 1  5.529154  10.517576  15.697333  11.324938  12.187670  12.283861   5.032285
# 2  6.642557  14.658934   8.130767   7.194487  11.939354  11.653620   5.942778
# 3  7.527268   7.253120   9.791136   6.089743  10.752796   5.778888  10.366363
# 4  6.622256  12.557882   5.520360   5.397359  13.152269  10.684779   9.816471
#
# [5 rows x 500 columns]
#
# y:
#    0
# 0  0
# 1  0
# 2  1
# 3  1
# 4  1

# %%
import ray
from ray import tune
from ray.tune.schedulers.hb_bohb import HyperBandForBOHB
from ray.tune.search.bohb import TuneBOHB
from ray.train import report
from sklearn.model_selection import train_test_split
from sklearn.ensemble import ExtraTreesClassifier, VotingClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from xgboost import XGBClassifier
from sklearn.naive_bayes import GaussianNB
import pandas as pd
import numpy as np
import ConfigSpace as CS
import ConfigSpace.hyperparameters as CSH
import ast

# Assuming your data is in X and y dataframes

def train_ensemble(config):
    vars = ast.literal_eval(config['colset'])
    Xloc = X[vars]
    # Split data into training and validation sets
    X_train, X_val, y_train, y_val = train_test_split(Xloc, y, test_size=0.2, random_state=42)
    
    # Initialize the models with the given hyperparameters
    xgb_model = XGBClassifier(
        eta=config["xgb_eta"],
        max_depth=config["xgb_max_depth"],
        min_child_weight=config["xgb_min_child_weight"],
        subsample=config["xgb_subsample"],
        colsample_bytree=config["xgb_colsample_bytree"],
        reg_lambda=config["xgb_lambda"],
        reg_alpha=config["xgb_alpha"],
        objective="binary:logistic",
        eval_metric="logloss",
        use_label_encoder=False,
        verbosity=0
    )

    # et_model = ExtraTreesClassifier(
    #     n_estimators=config["et_n_estimators"],
    #     max_depth=config["et_max_depth"],
    #     min_samples_split=config["et_min_samples_split"],
    #     min_samples_leaf=config["et_min_samples_leaf"],
    #     max_features=config["et_max_features"],
    #     bootstrap=config["et_bootstrap"]
    # )
    
    svc_model = SVC(
        C=config["svc_C"],
        kernel=config["svc_kernel"],
        probability=True
    )

    lr_model = LogisticRegression(
        C=config["lr_C"],
        solver=config["lr_solver"],
        max_iter=1000
    )

    nb_model = GaussianNB()
    
    ensemble_model = VotingClassifier(
        estimators=[
            ('xgb', xgb_model),
            # ('et', et_model),
            ('svc', svc_model),
            ('lr', lr_model),
            ('nb', nb_model)
        ],
        voting='soft',
        weights=[
            config["weight_xgb"],
            # config["weight_et"],
            config["weight_svc"],
            config["weight_lr"],
            config["weight_nb"]
        ]
    )
    
    # Train the ensemble model
    ensemble_model.fit(X_train, y_train)
    
    # Predict probabilities on the validation set
    ensemble_preds_proba = ensemble_model.predict_proba(X_val)[:, 1]
    
    # Get the indices of the top 20% predictions
    top_20_percent_indices = np.argsort(ensemble_preds_proba)[-int(0.2 * len(ensemble_preds_proba)):]

    # Select the corresponding true labels and predicted labels for top 20%
    top_20_true = y_val.iloc[top_20_percent_indices].values
    top_20_preds = (ensemble_preds_proba[top_20_percent_indices] >= 0.5).astype(int)
    
    # Calculate the number of correct class 1 predictions
    correct_class_1_predictions = sum(1 for true, pred in zip(top_20_true, top_20_preds) if true == 1 and pred == 1)
    
    # Calculate the number of features used
    num_features_used = Xloc.shape[1]

    # Scaled score calculation
    customer_scaled = (correct_class_1_predictions / len(top_20_preds)) * 1000
    customer_gain = 10 * customer_scaled
    variable_cost = 200 * num_features_used
    custom_score = customer_gain - variable_cost
    
    # Report the custom score
    report({"custom_score": custom_score})

# Define the search space using ConfigSpace
config_space = CS.ConfigurationSpace()

# Hyperparameters for XGBoost
config_space.add_hyperparameter(CSH.UniformFloatHyperparameter('xgb_eta', lower=0.01, upper=0.1, log=True))
config_space.add_hyperparameter(CSH.UniformIntegerHyperparameter('xgb_max_depth', lower=3, upper=10))
config_space.add_hyperparameter(CSH.UniformIntegerHyperparameter('xgb_min_child_weight', lower=1, upper=5))
config_space.add_hyperparameter(CSH.UniformFloatHyperparameter('xgb_subsample', lower=0.5, upper=1.0))
config_space.add_hyperparameter(CSH.UniformFloatHyperparameter('xgb_colsample_bytree', lower=0.5, upper=1.0))
config_space.add_hyperparameter(CSH.UniformFloatHyperparameter('xgb_lambda', lower=1e-3, upper=10.0, log=True))
config_space.add_hyperparameter(CSH.UniformFloatHyperparameter('xgb_alpha', lower=1e-3, upper=10.0, log=True))

# Hyperparameters for ExtraTrees
# config_space.add_hyperparameter(CSH.UniformIntegerHyperparameter('et_n_estimators', lower=50, upper=200))
# config_space.add_hyperparameter(CSH.UniformIntegerHyperparameter('et_max_depth', lower=3, upper=20))
# config_space.add_hyperparameter(CSH.UniformIntegerHyperparameter('et_min_samples_split', lower=2, upper=10))
# config_space.add_hyperparameter(CSH.UniformIntegerHyperparameter('et_min_samples_leaf', lower=1, upper=10))
# config_space.add_hyperparameter(CSH.CategoricalHyperparameter('et_max_features', ['sqrt', 'log2']))
# config_space.add_hyperparameter(CSH.CategoricalHyperparameter('et_bootstrap', [True, False]))

# Hyperparameters for SVC
config_space.add_hyperparameter(CSH.UniformFloatHyperparameter('svc_C', lower=0.1, upper=10.0, log=True))
config_space.add_hyperparameter(CSH.CategoricalHyperparameter('svc_kernel', ['linear', 'rbf', 'poly', 'sigmoid']))

# Hyperparameters for Logistic Regression
config_space.add_hyperparameter(CSH.UniformFloatHyperparameter('lr_C', lower=0.1, upper=10.0, log=True))
config_space.add_hyperparameter(CSH.CategoricalHyperparameter('lr_solver', ['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga']))

# Weights for the ensemble
config_space.add_hyperparameter(CSH.UniformFloatHyperparameter('weight_xgb', lower=0.0, upper=1.0))
#config_space.add_hyperparameter(CSH.UniformFloatHyperparameter('weight_et', lower=0.0, upper=1.0))
config_space.add_hyperparameter(CSH.UniformFloatHyperparameter('weight_svc', lower=0.0, upper=1.0))
config_space.add_hyperparameter(CSH.UniformFloatHyperparameter('weight_lr', lower=0.0, upper=1.0))
config_space.add_hyperparameter(CSH.UniformFloatHyperparameter('weight_nb', lower=0.0, upper=1.0))

# Hyperparameters for feature sets
config_space.add_hyperparameter(CSH.CategoricalHyperparameter('colset', [
    '[101, 102, 103, 105]', '[101, 102, 103]', '[101, 102, 105]', '[101, 103, 105]', 
    '[102, 103, 105]', '[104, 102, 103, 105]', '[100, 101, 102, 103, 105]', '[100, 101, 102, 103]', 
    '[100, 101, 102, 105]', '[100, 101, 103, 105]', '[100, 102, 103, 105]', '[100, 104, 102, 103, 105]', 
    '[100, 101, 102, 103, 104, 105]'
]))

# Set up the BOHB search algorithm
bohb_search = TuneBOHB(config_space, metric="custom_score", mode="max")

# Set up the HyperBandForBOHB scheduler
bohb_scheduler = HyperBandForBOHB(
    time_attr="training_iteration",
    metric="custom_score",
    mode="max"
)

# Function to create shorter directory names
def trial_dirname_creator(trial):
    return f"trial_{trial.trial_id}"

# Run the hyperparameter search
analysis = tune.run(
    train_ensemble,
    resources_per_trial={"cpu": 1, "gpu": 0},
    search_alg=bohb_search,
    scheduler=bohb_scheduler,
    num_samples=500,
    trial_dirname_creator=trial_dirname_creator,
    raise_on_failed_trial=False
)

# Get the best result
best_config = analysis.get_best_config(metric="custom_score", mode="max")
print("Best config: ", best_config)
# Out:
# 2024-06-02 22:00:44,606	INFO worker.py:1749 -- Started a local Ray instance.
# 2024-06-02 22:00:45,597	INFO tune.py:253 -- Initializing Ray automatically. For cluster usage or custom Ray initialization, call `ray.init(...)` before `tune.run(...)`.
# 2024-06-02 22:00:45,598	INFO tune.py:614 -- [output] This uses the legacy output and progress reporter, as Jupyter notebooks are not supported by the new engine, yet. For more information, please see https://github.com/ray-project/ray/issues/36949
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2024-06-02 22:16:41</td></tr>
# <tr><td>Running for: </td><td>00:15:55.24        </td></tr>
# <tr><td>Memory:      </td><td>24.9/63.8 GiB      </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using HyperBand: num_stopped=54 total_brackets=2<br>Round #0:<br>  Bracket(Max Size (n)=27, Milestone (r)=3, completed=20.0%): {TERMINATED: 81} <br>  Bracket(Max Size (n)=12, Milestone (r)=9, completed=88.4%): {TERMINATED: 419} <br>Logical resource usage: 1.0/28 CPUs, 0/1 GPUs (0.0/1.0 accelerator_type:G)
#     </div>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name             </th><th>status    </th><th>loc            </th><th>colset              </th><th style="text-align: right;">    lr_C</th><th>lr_solver  </th><th style="text-align: right;">   svc_C</th><th>svc_kernel  </th><th style="text-align: right;">  weight_lr</th><th style="text-align: right;">  weight_nb</th><th style="text-align: right;">  weight_svc</th><th style="text-align: right;">  weight_xgb</th><th style="text-align: right;">  xgb_alpha</th><th style="text-align: right;">  xgb_colsample_bytree</th><th style="text-align: right;">  xgb_eta</th><th style="text-align: right;">  xgb_lambda</th><th style="text-align: right;">  xgb_max_depth</th><th style="text-align: right;">  xgb_min_child_weight</th><th style="text-align: right;">  xgb_subsample</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  custom_score</th></tr>
# </thead>
# <tbody>
# <tr><td>train_ensemble_e0f49734</td><td>TERMINATED</td><td>127.0.0.1:14680</td><td>[100, 104, 102,_69c0</td><td style="text-align: right;">0.484938</td><td>lbfgs      </td><td style="text-align: right;">0.126215</td><td>linear      </td><td style="text-align: right;"> 0.112939  </td><td style="text-align: right;"> 0.732059  </td><td style="text-align: right;">  0.973503  </td><td style="text-align: right;">  0.09909   </td><td style="text-align: right;"> 0.830174  </td><td style="text-align: right;">              0.525952</td><td style="text-align: right;">0.0455705</td><td style="text-align: right;">  0.0547733 </td><td style="text-align: right;">              8</td><td style="text-align: right;">                     1</td><td style="text-align: right;">       0.595487</td><td style="text-align: right;">     1</td><td style="text-align: right;">        0.921642</td><td style="text-align: right;">          6850</td></tr>
# <tr><td>train_ensemble_57e1a450</td><td>TERMINATED</td><td>127.0.0.1:21328</td><td>[100, 101, 102,_2380</td><td style="text-align: right;">0.982341</td><td>saga       </td><td style="text-align: right;">0.392889</td><td>rbf         </td><td style="text-align: right;"> 0.945115  </td><td style="text-align: right;"> 0.366296  </td><td style="text-align: right;">  0.740207  </td><td style="text-align: right;">  0.64266   </td><td style="text-align: right;"> 0.341481  </td><td style="text-align: right;">              0.539108</td><td style="text-align: right;">0.0797305</td><td style="text-align: right;">  0.021864  </td><td style="text-align: right;">              3</td><td style="text-align: right;">                     2</td><td style="text-align: right;">       0.721785</td><td style="text-align: right;">     1</td><td style="text-align: right;">        1.19688 </td><td style="text-align: right;">          6850</td></tr>
# <tr><td>train_ensemble_7ea2a20b</td><td>TERMINATED</td><td>127.0.0.1:56116</td><td>[104, 102, 103, 105]</td><td style="text-align: right;">0.613769</td><td>sag        </td><td style="text-align: right;">4.148   </td><td>sigmoid     </td><td style="text-align: right;"> 0.738068  </td><td style="text-align: right;"> 0.766039  </td><td style="text-align: right;">  0.939035  </td><td style="text-align: right;">  0.285325  </td><td style="text-align: right;"> 0.00317232</td><td style="text-align: right;">              0.973114</td><td style="text-align: right;">0.0540553</td><td style="text-align: right;">  0.85506   </td><td style="text-align: right;">             10</td><td style="text-align: right;">                     3</td><td style="text-align: right;">       0.64    </td><td style="text-align: right;">     1</td><td style="text-align: right;">        1.29687 </td><td style="text-align: right;">          7000</td></tr>
# <tr><td>train_ensemble_a3e83ad6</td><td>TERMINATED</td><td>127.0.0.1:25484</td><td>[100, 101, 102,_2380</td><td style="text-align: right;">5.28949 </td><td>liblinear  </td><td style="text-align: right;">3.79535 </td><td>poly        </td><td style="text-align: right;"> 0.589578  </td><td style="text-align: right;"> 0.124927  </td><td style="text-align: right;">  0.504864  </td><td style="text-align: right;">  0.488574  </td><td style="text-align: right;"> 0.00247231</td><td style="text-align: right;">              0.742047</td><td style="text-align: right;">0.0852046</td><td style="text-align: right;">  0.00234956</td><td style="text-align: right;">              9</td><td style="text-align: right;">                     3</td><td style="text-align: right;">       0.53975 </td><td style="text-align: right;">     1</td><td style="text-align: right;">        1.83358 </td><td style="text-align: right;">          6950</td></tr>
# <tr><td>train_ensemble_ed134764</td><td>TERMINATED</td><td>127.0.0.1:25328</td><td>[100, 101, 103, 105]</td><td style="text-align: right;">5.66406 </td><td>newton-cg  </td><td style="text-align: right;">2.33487 </td><td>poly        </td><td style="text-align: right;"> 0.545024  </td><td style="text-align: right;"> 0.366589  </td><td style="text-align: right;">  0.361278  </td><td style="text-align: right;">  0.570056  </td><td style="text-align: right;"> 2.63743   </td><td style="text-align: right;">              0.532425</td><td style="text-align: right;">0.0100091</td><td style="text-align: right;">  0.0098339 </td><td style="text-align: right;">              5</td><td style="text-align: right;">                     4</td><td style="text-align: right;">       0.796597</td><td style="text-align: right;">     1</td><td style="text-align: right;">        1.49245 </td><td style="text-align: right;">          6900</td></tr>
# <tr><td>train_ensemble_6e30c5cd</td><td>TERMINATED</td><td>127.0.0.1:11848</td><td>[100, 101, 102, 105]</td><td style="text-align: right;">0.208937</td><td>newton-cg  </td><td style="text-align: right;">1.50309 </td><td>linear      </td><td style="text-align: right;"> 0.108499  </td><td style="text-align: right;"> 0.234078  </td><td style="text-align: right;">  0.387825  </td><td style="text-align: right;">  0.714539  </td><td style="text-align: right;"> 0.382134  </td><td style="text-align: right;">              0.746916</td><td style="text-align: right;">0.0234621</td><td style="text-align: right;">  0.489502  </td><td style="text-align: right;">              6</td><td style="text-align: right;">                     5</td><td style="text-align: right;">       0.82952 </td><td style="text-align: right;">     1</td><td style="text-align: right;">        1.06294 </td><td style="text-align: right;">          7000</td></tr>
# <tr><td>train_ensemble_0d6f8b39</td><td>TERMINATED</td><td>127.0.0.1:45156</td><td>[100, 101, 102,_2380</td><td style="text-align: right;">0.153801</td><td>saga       </td><td style="text-align: right;">3.65727 </td><td>rbf         </td><td style="text-align: right;"> 0.55875   </td><td style="text-align: right;"> 0.588381  </td><td style="text-align: right;">  0.93011   </td><td style="text-align: right;">  0.280332  </td><td style="text-align: right;"> 1.82316   </td><td style="text-align: right;">
# (raylet) Warning: The actor ImplicitFunc is very large (19 MiB). Check that its definition is not implicitly capturing a large array or other object in scope. Tip: use ray.put() to put large objects in the Ray object store.
# (train_ensemble pid=14680) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:97: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# (train_ensemble pid=14680)   y = column_or_1d(y, warn=True)
# (train_ensemble pid=14680) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# (train_ensemble pid=14680)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# <div class="trialProgress">
#   <h3>Trial Progress</h3>
#   <table>
# <thead>
# <tr><th>Trial name             </th><th style="text-align: right;">  custom_score</th></tr>
# </thead>
# <tbody>
# <tr><td>train_ensemble_01a5aca9</td><td style="text-align: right;">          6750</td></tr>
# <tr><td>train_ensemble_0235a1b9</td><td style="text-align: right;">          7200</td></tr>
# <tr><td>train_ensemble_025806d4</td><td style="text-align: right;">          7400</td></tr>
# <tr><td>train_ensemble_02a82daa</td><td style="text-align: right;">          6800</td></tr>
# <tr><td>train_ensemble_03848274</td><td style="text-align: right;">          6950</td></tr>
# <tr><td>train_ensemble_0445b470</td><td style="text-align: right;">          6750</td></tr>
# <tr><td>train_ensemble_04e56d35</td><td style="text-align: right;">          7300</td></tr>
# <tr><td>train_ensemble_0530be7b</td><td style="text-align: right;">          7250</td></tr>
# <tr><td>train_ensemble_05b43db1</td><td style="text-align: right;">          6650</td></tr>
# <tr><td>train_ensemble_0616a3cd</td><td style="text-align: right;">          6700</td></tr>
# <tr><td>train_ensemble_06a97492</td><td style="text-align: right;">          7050</td></tr>
# <tr><td>train_ensemble_073aa885</td><td style="text-align: right;">          6950</td></tr>
# <tr><td>train_ensemble_076ee574</td><td style="text-align: right;">          7250</td></tr>
# <tr><td>train_ensemble_07bc6b39</td><td style="text-align: right;">          7050</td></tr>
# <tr><td>train_ensemble_087579ee</td><td style="text-align: right;">          6400</td></tr>
# <tr><td>train_ensemble_0ba8fb88</td><td style="text-align: right;">          7150</td></tr>
# <tr><td>train_ensemble_0bbeabce</td><td style="text-align: right;">          6950</td></tr>
# <tr><td>train_ensemble_0bf09362</td><td style="text-align: right;">          7500</td></tr>
# <tr><td>train_ensemble_0bf22e69</td><td style="text-align: right;">          7200</td></tr>
# <tr><td>train_ensemble_0cd3cdd4</td><td style="text-align: right;">          6950</td></tr>
# <tr><td>train_ensemble_0d6f8b39</td><td style="text-align: right;">          6900</td></tr>
# <tr><td>train_ensemble_0d7f65e1</td><td style="text-align: right;">          6850</td></tr>
# <tr><td>train_ensemble_0da5e1ff</td><td style="text-align: right;">          6950</td></tr>
# <tr><td>train_ensemble_0df9fee6</td><td style="text-align: right;">          6900</td></tr>
# <tr><td>train_ensemble_0e981fe3</td><td style="text-align: right;">          6750</td></tr>
# <tr><td>train_ensemble_0f63c187</td><td style="text-align: right;">          6850</td></tr>
# <tr><td>train_ensemble_101ad461</td><td style="text-align: right;">          6850</td></tr>
# <tr><td>train_ensemble_1049af5e</td><td style="text-align: right;">          7100</td></tr>
# <tr><td>train_ensemble_10dbee3b</td><td style="text-align: right;">          7000</td></tr>
# <tr><td>train_ensemble_11561eb5</td><td style="text-align: right;">          7000</td></tr>
# <tr><td>train_ensemble_11e7d485</td><td style="text-align: right;">          7000</td></tr>
# <tr><td>train_ensemble_12455993</td><td style="text-align: right;">          7300</td></tr>
# <tr><td>train_ensemble_1298bf1b</td><td style="text-align: right;">          7050</td></tr>
# <tr><td>train_ensemble_12c12b9d</td><td style="text-align: right;">          6850</td></tr>
# <tr><td>train_ensemble_1376a31a</td><td style="text-align: right;">          7100</td></tr>
# <tr><td>train_ensemble_13cbc95f</td><td style="text-align: right;">          6850</td></tr>
# <tr><td>train_ensemble_13d24993</td><td style="text-align: right;">          7100</td></tr>
# <tr><td>train_ensemble_1822e912</td><td style="text-align: right;">          7050</td></tr>
# <tr><td>train_ensemble_1a2b58d7</td><td style="text-align: right;">          6700</td></tr>
# <tr><td>train_ensemble_1a9004cd</td><td style="text-align: right;">          7050</td></tr>
# <tr><td>train_ensemble_1c8e681a</td><td style="text-align: right;">          7100</td></tr>
# <tr><td>train_ensemble_1d19eb83</td><td style="text-align: right;">          6900</td></tr>
# <tr><td>train_ensemble_1d910045</td><td style="text-align: right;">          6800</td></tr>
# <tr><td>train_ensemble_1db7b2b2</td><td style="text-align: right;">          6650</td></tr>
# <tr><td>train_ensemble_1df296a8</td><td style="text-align: right;">          6800</td></tr>
# <tr><td>train_ensemble_1e5f7eb4</td><td style="text-align: right;">          7050</td></tr>
# <tr><td>train_ensemble_1e6fab56</td><td style="text-align: right;">          7350</td></tr>
# <tr><td>train_ensemble_1e70ff40</td><td style="text-align: right;">          6700</td></tr>
# <tr><td>train_ensemble_1ff3c95d</td><td style="text-align: right;">          7150</td></tr>
# <tr><td>train_ensemble_1ffc4899</td><td style="text-align: right;">          6900</td></tr>
# <tr><td>train_ensemble_21071ccf</td><td style="text-align: right;">          7500</td></tr>
# <tr><td>train_ensemble_213a70e6</td><td style="text-align: right;">          6600</td></tr>
# <tr><td>train_ensemble_217c925e</td><td style="text-align: right;">          6950</td></tr>
# <tr><td>train_ensemble_2209167e</td><td style="text-align: right;">          7200</td></tr>
# <tr><td>train_ensemble_23e7393d</td><td style="text-align: right;">          7050</td></tr>
# <tr><td>train_ensemble_2499219d</td><td style="text-align: right;">          7200</td></tr>
# <tr><td>train_ensemble_26c9604a</td><td style="text-align: right;">          7150</td></tr>
# <tr><td>train_ensemble_26e0bf80</td><td style="text-align: right;">          6600</td></tr>
# <tr><td>train_ensemble_26e8de8c</td><td style="text-align: right;">          7300</td></tr>
# <tr><td>train_ensemble_281c8f6e</td><td style="text-align: right;">          6400</td></tr>
# <tr><td>train_ensemble_2869886a</td><td style="text-align: right;">          7200</td></tr>
# <tr><td>train_ensemble_28e3b87e</td><td style="text-align: right;">          6650</td></tr>
# <tr><td>train_ensemble_2949ca4e</td><td style="text-align: right;">          7400</td></tr>
# <tr><td>train_ensemble_29d6cbdd</td><td style="text-align: right;">          7350</td></tr>
# <tr><td>train_ensemble_2ad206a0</td><td style="text-align: right;">          7000</td></tr>
# <tr><td>train_ensemble_2b2171c7</td><td style="text-align: right;">          6850</td></tr>
# <tr><td>train_ensemble_2b21ad97</td><td style="text-align: right;">          6650</td></tr>
# <tr><td>train_ensemble_2be75218</td><td style="text-align: right;">          7050</td></tr>
# <tr><td>train_ensemble_2ca279f9</td><td style="text-align: right;">          6950</td></tr>
# <tr><td>train_ensemble_2ca76a6e</td><td style="text-align: right;">          6800</td></tr>
# <tr><td>train_ensemble_2cc08e7c</td><td style="text-align: right;">          6750</td></tr>
# <tr><td>train_ensemble_2cd16db1</td><td style="text-align: right;">          7000</td></tr>
# <tr><td>train_ensemble_2cf46c0b</td><td style="text-align: right;">          6950</td></tr>
# <tr><td>train_ensemble_2d32f939</td><td style="text-align: right;">          6900</td></tr>
# <tr><td>train_ensemble_2d88ed68</td><td style="text-align: right;">          7000</td></tr>
# <tr><td>train_ensemble_2de01053</td><td style="text-align: right;">          6800</td></tr>
# <tr><td>train_ensemble_2e2a90aa</td><td style="text-align: right;">          7000</td></tr>
# <tr><td>train_ensemble_2e91adad</td><td style="text-align: right;">          6950</td></tr>
# <tr><td>train_ensemble_2ed42028</td><td style="text-align: right;">          6600</td></tr>
# <tr><td>train_ensemble_2eeac285</td><td style="text-align: right;">          7100</td></tr>
# <tr><td>train_ensemble_2fb0e9cf</td><td style="text-align: right;">          6750</td></tr>
# <tr><td>train_ensemble_3014e756</td><td style="text-align: right;">          7200</td></tr>
# <tr><td>train_ensemble_30a095ca</td><td style="text-align: right;">          7150</td></tr>
# <tr><td>train_ensemble_30a1608e</td><td style="text-align: right;">          6900</td></tr>
# <tr><td>train_ensemble_328828ef</td><td style="text-align: right;">          6900</td></tr>
# (train_ensemble pid=25484) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/user-guides/configure-logging.html#log-deduplication for more options.)
# (train_ensemble pid=25484)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=25484)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=45156) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=45156)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=45156)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=34692) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=34692)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=34692)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=40440) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=40440)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=40440)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=48880) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=48880)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=48880)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=59096) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=59096)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=59096)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=37208) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=37208)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=37208)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=57268) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=57268)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=57268)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=22664) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=22664)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=22664)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=48712) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=48712)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=48712)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=9112) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=9112)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=9112)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=33248) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=33248)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=33248)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=45188) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=45188)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=45188)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=29788) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=29788)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=29788)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=43496) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=43496)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=43496)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=39900) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:97: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 5x across cluster]
# (train_ensemble pid=39900)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=32820)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 2x across cluster]
# (train_ensemble pid=11008) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 7x across cluster]
# (train_ensemble pid=11008)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=11008)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 4x across cluster]
# (train_ensemble pid=48056) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=48056)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=48056)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=59576) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=59576)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=59576)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=7332) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=7332)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=7332)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=18660) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=18660)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=18660)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=60716) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=60716)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=60716)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=39016) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=39016)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=39016)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=29684) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=29684)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=29684)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=21752) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=21752)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=21752)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=11284) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=11284)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=11284)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=37992) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=37992)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=37992)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# 2024-06-02 22:03:18,766	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# 2024-06-02 22:03:21,032	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# 2024-06-02 22:03:22,515	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# (train_ensemble pid=23728) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 10x across cluster]
# (train_ensemble pid=23728)   y = column_or_1d(y, warn=True) [repeated 5x across cluster]
# (train_ensemble pid=23728)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 5x across cluster]
# 2024-06-02 22:03:24,448	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# 2024-06-02 22:03:26,424	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# 2024-06-02 22:03:27,994	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# (train_ensemble pid=27348) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 10x across cluster]
# (train_ensemble pid=27348)   y = column_or_1d(y, warn=True) [repeated 5x across cluster]
# (train_ensemble pid=27348)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 5x across cluster]
# 2024-06-02 22:03:29,432	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# 2024-06-02 22:03:31,521	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# 2024-06-02 22:03:33,240	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# (train_ensemble pid=36928) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 8x across cluster]
# (train_ensemble pid=36928)   y = column_or_1d(y, warn=True) [repeated 4x across cluster]
# (train_ensemble pid=36928)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 4x across cluster]
# 2024-06-02 22:03:34,736	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# 2024-06-02 22:03:37,140	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# 2024-06-02 22:03:38,866	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# (train_ensemble pid=60500) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 10x across cluster]
# (train_ensemble pid=60500)   y = column_or_1d(y, warn=True) [repeated 5x across cluster]
# (train_ensemble pid=60500)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 5x across cluster]
# 2024-06-02 22:03:40,313	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# 2024-06-02 22:03:41,740	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# 2024-06-02 22:03:44,064	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# (train_ensemble pid=9032) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 8x across cluster]
# (train_ensemble pid=9032)   y = column_or_1d(y, warn=True) [repeated 4x across cluster]
# (train_ensemble pid=9032)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 4x across cluster]
# 2024-06-02 22:03:45,290	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# 2024-06-02 22:03:47,169	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# 2024-06-02 22:03:49,091	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# (train_ensemble pid=59660) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 10x across cluster]
# (train_ensemble pid=59660)   y = column_or_1d(y, warn=True) [repeated 5x across cluster]
# (train_ensemble pid=59660)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 5x across cluster]
# 2024-06-02 22:03:50,955	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# 2024-06-02 22:03:52,742	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# 2024-06-02 22:03:53,914	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# (train_ensemble pid=37564) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 8x across cluster]
# (train_ensemble pid=37564)   y = column_or_1d(y, warn=True) [repeated 4x across cluster]
# (train_ensemble pid=37564)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 4x across cluster]
# 2024-06-02 22:03:56,212	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# 2024-06-02 22:03:57,622	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# 2024-06-02 22:03:59,206	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# (train_ensemble pid=36708) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 10x across cluster]
# (train_ensemble pid=36708)   y = column_or_1d(y, warn=True) [repeated 5x across cluster]
# (train_ensemble pid=36708)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 5x across cluster]
# 2024-06-02 22:04:01,060	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# 2024-06-02 22:04:02,870	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# 2024-06-02 22:04:04,132	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# (train_ensemble pid=44568) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 8x across cluster]
# (train_ensemble pid=44568)   y = column_or_1d(y, warn=True) [repeated 4x across cluster]
# (train_ensemble pid=44568)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 4x across cluster]
# (train_ensemble pid=34756) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=34756)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=34756)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=45756) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=45756)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=45756)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=23368) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=23368)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=23368)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=25348) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=25348)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=25348)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=9964) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=9964)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=9964)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=58648) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=58648)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=58648)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=60212) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=60212)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=60212)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=14540) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=14540)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=14540)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=65028) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=65028)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=65028)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=34736) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=34736)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=34736)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=31388) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=31388)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=31388)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=64228) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=64228)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=64228)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=22444) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=22444)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=22444)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=40628) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=40628)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=40628)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=24132) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=24132)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=24132)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=3952) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=3952)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=3952)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=10064) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=10064)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=10064)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=9664) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=9664)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=9664)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=4904) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=4904)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=4904)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=18316) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=18316)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# ...
# (train_ensemble pid=28280)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=28280)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=17868) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=17868)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=17868)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=41924) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=41924)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=41924)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=36076) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=36076)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=36076)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=28240) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=28240)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=28240)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=55612) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=55612)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=55612)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=13272) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=13272)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=13272)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=3480) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=3480)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=3480)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=61048) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=61048)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=61048)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=41212) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=41212)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=41212)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=47716) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=47716)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=47716)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=31676) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=31676)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=31676)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=28468) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=28468)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=28468)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=51552) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=51552)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=51552)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=13848) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=13848)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=13848)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=32468) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=32468)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=32468)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=33172) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=33172)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=33172)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=14628) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=14628)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=14628)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=1540) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=1540)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=1540)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=33112) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=33112)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=33112)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=48540) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=48540)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=48540)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=58612) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=58612)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=58612)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=27036) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=27036)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=27036)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=49844) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=49844)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=49844)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=26324) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=26324)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=26324)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=31968) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=31968)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=31968)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=41652) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=41652)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=41652)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=10296) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=10296)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=10296)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=13444) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=13444)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=13444)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=62956) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=62956)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=62956)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=19372) d:\mgr\aml\pr2\venv\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel(). [repeated 6x across cluster]
# (train_ensemble pid=19372)   y = column_or_1d(y, warn=True) [repeated 3x across cluster]
# (train_ensemble pid=19372)   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True) [repeated 3x across cluster]
# 2024-06-02 22:16:41,031	INFO tune.py:1007 -- Wrote the latest version of all result files and experiment state to 'C:/Users/Mieszko/ray_results/train_ensemble_2024-06-02_22-00-45' in 0.2861s.
# 2024-06-02 22:16:41,126	INFO tune.py:1039 -- Total run time: 955.53 seconds (954.95 seconds for the tuning loop).
# Best config:  {'colset': '[102, 103, 105]', 'lr_C': 0.11571707559506507, 'lr_solver': 'newton-cg', 'svc_C': 0.1696684360739591, 'svc_kernel': 'rbf', 'weight_lr': 0.06140413456556626, 'weight_nb': 0.07067428735903525, 'weight_svc': 0.9183199868143154, 'weight_xgb': 0.2553230191779601, 'xgb_alpha': 0.2791474323818901, 'xgb_colsample_bytree': 0.8182440566054697, 'xgb_eta': 0.0201501034795639, 'xgb_lambda': 0.027568612453583018, 'xgb_max_depth': 9, 'xgb_min_child_weight': 1, 'xgb_subsample': 0.566849382645442}

# %%
df=analysis.dataframe()
df.to_csv('ensemble4-raytune-bohb.csv')

# %%
df.sort_values(by='custom_score', ascending=False, inplace=True)
print(df.head())
# Out:
#      custom_score   timestamp checkpoint_dir_name   done  training_iteration  \
# 16         7500.0  1717358604                None  False                   1
# 191        7500.0  1717358817                None  False                   1
# 153        7500.0  1717358749                None  False                   1
# 235        7500.0  1717358895                None  False                   1
# 221        7500.0  1717358870                None  False                   1
#
#      trial_id                 date  time_this_iter_s  time_total_s    pid  \
# 16   21071ccf  2024-06-02_22-03-24          1.278706      1.278706  23728
# 191  b6084f18  2024-06-02_22-06-57          1.283568      1.283568  44072
# 153  f2b25af6  2024-06-02_22-05-49          1.242032      1.242032  64548
# 235  89f5eaa1  2024-06-02_22-08-15          0.923303      0.923303  24872
# 221  0bf09362  2024-06-02_22-07-50          0.932133      0.932133  52520
#
#      ... config/weight_svc config/weight_xgb  config/xgb_alpha  \
# 16   ...          0.918320          0.255323          0.279147
# 191  ...          0.942519          0.114298          0.013432
# 153  ...          0.448838          0.068574          0.015480
# 235  ...          0.572888          0.077030          0.001233
# 221  ...          0.354555          0.399804          0.089435
#
#      config/xgb_colsample_bytree config/xgb_eta  config/xgb_lambda  \
# 16                      0.818244       0.020150           0.027569
# 191                     0.549407       0.029869           0.001440
# 153                     0.516797       0.017611           0.119073
# 235                     0.840366       0.037595           8.715272
# 221                     0.820046       0.023342           0.006337
#
#     config/xgb_max_depth  config/xgb_min_child_weight config/xgb_subsample  \
# 16                     9                            1             0.566849
# 191                    4                            4             0.878506
# 153                    5                            4             0.921612
# 235                   10                            1             0.720220
# 221                    8                            2             0.609362
#
#        logdir
# 16   21071ccf
# 191  b6084f18
# 153  f2b25af6
# 235  89f5eaa1
# 221  0bf09362
#
# [5 rows x 31 columns]
