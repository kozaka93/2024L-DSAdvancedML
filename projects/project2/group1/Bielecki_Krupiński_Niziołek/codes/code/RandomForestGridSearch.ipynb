# %%
import time

import numpy as np
import pandas as pd
from sklearn.discriminant_analysis import (
    LinearDiscriminantAnalysis,
    QuadraticDiscriminantAnalysis,
)
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier
from sklearn.feature_selection import (
    RFE,
    SelectFromModel,
    SelectKBest,
    SequentialFeatureSelector,
    f_classif,
    mutual_info_classif,
)
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from utils import (
    experiment,
    get_data,
    get_param_combinations,
    get_params_json,
    save_results,
)

from xgboost import XGBClassifier

# %%
X, y = get_data()

# %%
def run_experiment(feature_selectors, classifiers, ks, results, train_test_seeds=[42]):
    for fs in feature_selectors:
        for clf in classifiers:
            for k in ks:
                # Generate parameter combinations
                fs_cls, fs_params, k_param_name, requires_estimator = fs
                clf_cls, clf_params = clf

                fs_param_combinations = get_param_combinations(fs_params)
                clf_param_combinations = get_param_combinations(clf_params)

                for fs_params in fs_param_combinations:
                    for clf_params in clf_param_combinations:
                        result = experiment(
                            X,
                            y,
                            fs_cls,
                            fs_params,
                            clf_cls,
                            clf_params,
                            k,
                            k_param_name,
                            requires_estimator,
                            train_test_seeds,
                        )

                        print(result)
                        print(f"Elapsed time: {result[-1]:.2f}s\n")
                        results.append(result)
                        save_results(results, filename)

# %%
results = []

filename = "piotrkowe_RF2"

feature_selectors = [
    (SelectFromModel, {"threshold": [-np.inf]}, "max_features", True)
]

classifiers = [
    (
        RandomForestClassifier,
        {
            "criterion": ['gini', 'entropy', 'log_loss'],
            "n_estimators": [10, 75, 150],
            "min_samples_split": [2, 4, 8],
            "max_depth": [2, 6, 10],
            "ccp_alpha" : [0, 0.001]
        },
    )
]

ks = np.arange(5, 7, 1)
train_test_seeds = list(range(42, 47))

run_experiment(feature_selectors, classifiers, ks, results, train_test_seeds)
# Out:
# 42 0.601
# 43 0.584
# 44 0.602
# 45 0.597
# 46 0.62
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'gini', 'n_estimators': 10, 'min_samples_split': 2, 'max_depth': 2, 'ccp_alpha': 0}", 5, 0.6008, 0.011548160026601651, 0.6809999999999999, 0.28538026809692385)
# Elapsed time: 0.29s
#
# 42 0.609
# 43 0.542
# 44 0.618
# 45 0.525
# 46 0.6
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'gini', 'n_estimators': 10, 'min_samples_split': 2, 'max_depth': 2, 'ccp_alpha': 0.001}", 5, 0.5788, 0.03780687768118386, 0.645, 0.30038881301879883)
# Elapsed time: 0.30s
#
# 42 0.638
# 43 0.616
# 44 0.582
# 45 0.65
# 46 0.64
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'gini', 'n_estimators': 10, 'min_samples_split': 2, 'max_depth': 6, 'ccp_alpha': 0}", 5, 0.6252, 0.024284974778656886, 0.696, 0.6303155422210693)
# Elapsed time: 0.63s
#
# 42 0.651
# 43 0.651
# 44 0.636
# 45 0.657
# 46 0.608
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'gini', 'n_estimators': 10, 'min_samples_split': 2, 'max_depth': 6, 'ccp_alpha': 0.001}", 5, 0.6406000000000001, 0.017715529910222853, 0.7230000000000001, 0.6606314659118653)
# Elapsed time: 0.66s
#
# 42 0.618
# 43 0.654
# 44 0.65
# 45 0.638
# 46 0.647
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'gini', 'n_estimators': 10, 'min_samples_split': 2, 'max_depth': 10, 'ccp_alpha': 0}", 5, 0.6414, 0.012831211945876364, 0.726, 0.9226210594177247)
# Elapsed time: 0.92s
#
# 42 0.631
# 43 0.652
# 44 0.67
# 45 0.616
# 46 0.639
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'gini', 'n_estimators': 10, 'min_samples_split': 2, 'max_depth': 10, 'ccp_alpha': 0.001}", 5, 0.6416000000000001, 0.018380424369420872, 0.7209999999999999, 1.0414913654327393)
# Elapsed time: 1.04s
#
# 42 0.603
# 43 0.616
# 44 0.624
# 45 0.589
# 46 0.582
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'gini', 'n_estimators': 10, 'min_samples_split': 4, 'max_depth': 2, 'ccp_alpha': 0}", 5, 0.6028, 0.01579113675452152, 0.6869999999999999, 0.3308448314666748)
# Elapsed time: 0.33s
#
# 42 0.578
# 43 0.609
# 44 0.607
# 45 0.579
# 46 0.609
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'gini', 'n_estimators': 10, 'min_samples_split': 4, 'max_depth': 2, 'ccp_alpha': 0.001}", 5, 0.5963999999999999, 0.014636939570825604, 0.6569999999999999, 0.2805631160736084)
# Elapsed time: 0.28s
#
# 42 0.656
# 43 0.649
# 44 0.616
# 45 0.646
# 46 0.638
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'gini', 'n_estimators': 10, 'min_samples_split': 4, 'max_depth': 6, 'ccp_alpha': 0}", 5, 0.641, 0.013769531582446816, 0.712, 0.6495596885681152)
# Elapsed time: 0.65s
#
# 42 0.632
# 43 0.653
# 44 0.642
# 45 0.638
# 46 0.648
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'gini', 'n_estimators': 10, 'min_samples_split': 4, 'max_depth': 6, 'ccp_alpha': 0.001}", 5, 0.6426000000000001, 0.007364781055808795, 0.7150000000000001, 0.6980465888977051)
# Elapsed time: 0.70s
#
# 42 0.618
# 43 0.656
# 44 0.614
# 45 0.63
# 46 0.651
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'gini', 'n_estimators': 10, 'min_samples_split': 4, 'max_depth': 10, 'ccp_alpha': 0}", 5, 0.6337999999999999, 0.016998823488700635, 0.7070000000000001, 0.960105037689209)
# Elapsed time: 0.96s
#
# 42 0.654
# 43 0.654
# 44 0.655
# 45 0.666
# 46 0.654
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'gini', 'n_estimators': 10, 'min_samples_split': 4, 'max_depth': 10, 'ccp_alpha': 0.001}", 5, 0.6566, 0.004715930449020643, 0.7189999999999999, 0.9740315437316894)
# Elapsed time: 0.97s
#
# 42 0.588
# 43 0.596
# 44 0.613
# 45 0.598
# 46 0.62
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'gini', 'n_estimators': 10, 'min_samples_split': 8, 'max_depth': 2, 'ccp_alpha': 0}", 5, 0.603, 0.011730302638892154, 0.666, 0.335130500793457)
# Elapsed time: 0.34s
#
# 42 0.588
# 43 0.596
# 44 0.598
# 45 0.561
# 46 0.614
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'gini', 'n_estimators': 10, 'min_samples_split': 8, 'max_depth': 2, 'ccp_alpha': 0.001}", 5, 0.5913999999999999, 0.01738505104968056, 0.674, 0.3243206024169922)
# Elapsed time: 0.32s
#
# 42 0.626
# 43 0.602
# 44 0.629
# 45 0.62
# 46 0.646
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'gini', 'n_estimators': 10, 'min_samples_split': 8, 'max_depth': 6, 'ccp_alpha': 0}", 5, 0.6245999999999999, 0.014221111067704954, 0.7190000000000001, 0.794731855392456)
# Elapsed time: 0.79s
#
# 42 0.623
# 43 0.642
# 44 0.65
# 45 0.643
# 46 0.627
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'gini', 'n_estimators': 10, 'min_samples_split': 8, 'max_depth': 6, 'ccp_alpha': 0.001}", 5, 0.6369999999999999, 0.010256705123966477, 0.7209999999999999, 0.780789852142334)
# Elapsed time: 0.78s
#
# 42 0.628
# 43 0.639
# 44 0.621
# 45 0.649
# 46 0.64
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'gini', 'n_estimators': 10, 'min_samples_split': 8, 'max_depth': 10, 'ccp_alpha': 0}", 5, 0.6354, 0.009810198774744585, 0.7229999999999999, 1.086582565307617)
# Elapsed time: 1.09s
#
# 42 0.632
# 43 0.661
# 44 0.663
# 45 0.689
# 46 0.655
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'gini', 'n_estimators': 10, 'min_samples_split': 8, 'max_depth': 10, 'ccp_alpha': 0.001}", 5, 0.6599999999999999, 0.01822086715828858, 0.738, 1.0864762783050537)
# Elapsed time: 1.09s
#
# 42 0.575
# 43 0.619
# 44 0.626
# 45 0.622
# 46 0.638
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'gini', 'n_estimators': 75, 'min_samples_split': 2, 'max_depth': 2, 'ccp_alpha': 0}", 5, 0.6159999999999999, 0.021494185260204697, 0.677, 2.16621470451355)
# Elapsed time: 2.17s
#
# 42 0.58
# 43 0.619
# 44 0.625
# 45 0.636
# 46 0.625
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'gini', 'n_estimators': 75, 'min_samples_split': 2, 'max_depth': 2, 'ccp_alpha': 0.001}", 5, 0.617, 0.019297668252926326, 0.6910000000000001, 1.875197410583496)
# Elapsed time: 1.88s
#
# 42 0.639
# 43 0.65
# 44 0.664
# 45 0.65
# 46 0.66
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'gini', 'n_estimators': 75, 'min_samples_split': 2, 'max_depth': 6, 'ccp_alpha': 0}", 5, 0.6526000000000001, 0.008754427451295723, 0.7329999999999999, 4.721545648574829)
# Elapsed time: 4.72s
#
# 42 0.665
# 43 0.669
# 44 0.651
# 45 0.667
# 46 0.651
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'gini', 'n_estimators': 75, 'min_samples_split': 2, 'max_depth': 6, 'ccp_alpha': 0.001}", 5, 0.6606, 0.00793977329651169, 0.726, 3.8848647594451906)
# Elapsed time: 3.88s
#
# 42 0.653
# 43 0.687
# 44 0.669
# 45 0.688
# 46 0.663
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'gini', 'n_estimators': 75, 'min_samples_split': 2, 'max_depth': 10, 'ccp_alpha': 0}", 5, 0.672, 0.013652838532700795, 0.745, 5.949125194549561)
# Elapsed time: 5.95s
#
# 42 0.657
# 43 0.678
# 44 0.679
# 45 0.677
# 46 0.67
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'gini', 'n_estimators': 75, 'min_samples_split': 2, 'max_depth': 10, 'ccp_alpha': 0.001}", 5, 0.6722, 0.00823164625090268, 0.743, 6.050041389465332)
# Elapsed time: 6.05s
#
# 42 0.603
# 43 0.617
# 44 0.63
# 45 0.611
# 46 0.632
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'gini', 'n_estimators': 75, 'min_samples_split': 4, 'max_depth': 2, 'ccp_alpha': 0}", 5, 0.6186, 0.01107429455992571, 0.681, 1.5899128437042236)
# Elapsed time: 1.59s
#
# 42 0.592
# 43 0.633
# 44 0.622
# 45 0.62
# 46 0.622
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'gini', 'n_estimators': 75, 'min_samples_split': 4, 'max_depth': 2, 'ccp_alpha': 0.001}", 5, 0.6178, 0.01368795090581495, 0.6990000000000001, 1.4219955444335937)
# Elapsed time: 1.42s
#
# 42 0.648
# 43 0.671
# 44 0.668
# 45 0.663
# 46 0.649
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'gini', 'n_estimators': 75, 'min_samples_split': 4, 'max_depth': 6, 'ccp_alpha': 0}", 5, 0.6598, 0.009579144011862446, 0.742, 3.6238475799560548)
# Elapsed time: 3.62s
#
# 42 0.648
# 43 0.665
# 44 0.666
# 45 0.66
# 46 0.655
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'gini', 'n_estimators': 75, 'min_samples_split': 4, 'max_depth': 6, 'ccp_alpha': 0.001}", 5, 0.6588, 0.00667532770731146, 0.747, 3.6745961189270018)
# Elapsed time: 3.67s
#
# 42 0.683
# 43 0.661
# 44 0.68
# 45 0.675
# 46 0.655
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'gini', 'n_estimators': 75, 'min_samples_split': 4, 'max_depth': 10, 'ccp_alpha': 0}", 5, 0.6708000000000001, 0.01092520022699814, 0.727, 5.861444568634033)
# Elapsed time: 5.86s
#
# 42 0.655
# 43 0.647
# 44 0.678
# 45 0.69
# 46 0.672
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'gini', 'n_estimators': 75, 'min_samples_split': 4, 'max_depth': 10, 'ccp_alpha': 0.001}", 5, 0.6684, 0.015551205741034985, 0.7550000000000001, 6.266212797164917)
# Elapsed time: 6.27s
#
# 42 0.591
# 43 0.622
# 44 0.627
# 45 0.625
# 46 0.626
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'gini', 'n_estimators': 75, 'min_samples_split': 8, 'max_depth': 2, 'ccp_alpha': 0}", 5, 0.6182, 0.013702554506368524, 0.6839999999999999, 1.6349116325378419)
# Elapsed time: 1.63s
#
# 42 0.581
# 43 0.614
# 44 0.63
# 45 0.61
# 46 0.625
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'gini', 'n_estimators': 75, 'min_samples_split': 8, 'max_depth': 2, 'ccp_alpha': 0.001}", 5, 0.6119999999999999, 0.017099707599839257, 0.6769999999999999, 1.5305211067199707)
# Elapsed time: 1.53s
#
# 42 0.646
# 43 0.67
# 44 0.676
# 45 0.655
# 46 0.654
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'gini', 'n_estimators': 75, 'min_samples_split': 8, 'max_depth': 6, 'ccp_alpha': 0}", 5, 0.6602, 0.011070682002478448, 0.74, 4.009701490402222)
# Elapsed time: 4.01s
#
# 42 0.636
# 43 0.66
# 44 0.663
# 45 0.649
# 46 0.663
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'gini', 'n_estimators': 75, 'min_samples_split': 8, 'max_depth': 6, 'ccp_alpha': 0.001}", 5, 0.6542, 0.010457533169921106, 0.7469999999999999, 3.9823680400848387)
# Elapsed time: 3.98s
#
# 42 0.676
# 43 0.691
# 44 0.649
# 45 0.698
# 46 0.67
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'gini', 'n_estimators': 75, 'min_samples_split': 8, 'max_depth': 10, 'ccp_alpha': 0}", 5, 0.6768, 0.017151093259614645, 0.735, 5.711364793777466)
# Elapsed time: 5.71s
#
# 42 0.657
# 43 0.679
# 44 0.652
# 45 0.695
# 46 0.669
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'gini', 'n_estimators': 75, 'min_samples_split': 8, 'max_depth': 10, 'ccp_alpha': 0.001}", 5, 0.6704, 0.01548676854608473, 0.7540000000000001, 5.880376195907592)
# Elapsed time: 5.88s
#
# 42 0.596
# 43 0.639
# 44 0.639
# 45 0.62
# 46 0.643
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'gini', 'n_estimators': 150, 'min_samples_split': 2, 'max_depth': 2, 'ccp_alpha': 0}", 5, 0.6274, 0.017624982269494646, 0.7230000000000001, 3.129724216461182)
# Elapsed time: 3.13s
#
# 42 0.6
# 43 0.618
# 44 0.63
# 45 0.641
# 46 0.629
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'gini', 'n_estimators': 150, 'min_samples_split': 2, 'max_depth': 2, 'ccp_alpha': 0.001}", 5, 0.6235999999999999, 0.013865064009949624, 0.7090000000000001, 3.2477688789367676)
# Elapsed time: 3.25s
#
# 42 0.667
# 43 0.664
# 44 0.672
# 45 0.646
# 46 0.653
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'gini', 'n_estimators': 150, 'min_samples_split': 2, 'max_depth': 6, 'ccp_alpha': 0}", 5, 0.6604, 0.009520504188329532, 0.728, 8.391477870941163)
# Elapsed time: 8.39s
#
# 42 0.651
# 43 0.668
# 44 0.67
# 45 0.674
# 46 0.66
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'gini', 'n_estimators': 150, 'min_samples_split': 2, 'max_depth': 6, 'ccp_alpha': 0.001}", 5, 0.6646, 0.008187795796183495, 0.747, 7.967313623428344)
# Elapsed time: 7.97s
#
# 42 0.653
# 43 0.688
# 44 0.679
# 45 0.677
# 46 0.669
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'gini', 'n_estimators': 150, 'min_samples_split': 2, 'max_depth': 10, 'ccp_alpha': 0}", 5, 0.6732, 0.011771151175649712, 0.74, 12.626762342453002)
# Elapsed time: 12.63s
#
# 42 0.666
# 43 0.682
# 44 0.689
# 45 0.671
# 46 0.667
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'gini', 'n_estimators': 150, 'min_samples_split': 2, 'max_depth': 10, 'ccp_alpha': 0.001}", 5, 0.675, 0.00901110426085502, 0.7540000000000001, 13.240027618408202)
# Elapsed time: 13.24s
#
# 42 0.602
# 43 0.624
# 44 0.634
# 45 0.625
# 46 0.625
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'gini', 'n_estimators': 150, 'min_samples_split': 4, 'max_depth': 2, 'ccp_alpha': 0}", 5, 0.622, 0.010639548862616319, 0.705, 3.557470607757568)
# Elapsed time: 3.56s
#
# 42 0.62
# 43 0.605
# 44 0.649
# 45 0.61
# 46 0.634
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'gini', 'n_estimators': 150, 'min_samples_split': 4, 'max_depth': 2, 'ccp_alpha': 0.001}", 5, 0.6235999999999999, 0.01610714127336072, 0.711, 3.4953308582305906)
# Elapsed time: 3.50s
#
# 42 0.652
# 43 0.656
# 44 0.669
# 45 0.679
# 46 0.654
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'gini', 'n_estimators': 150, 'min_samples_split': 4, 'max_depth': 6, 'ccp_alpha': 0}", 5, 0.662, 0.01037304198391196, 0.748, 8.233681917190552)
# Elapsed time: 8.23s
#
# 42 0.652
# 43 0.636
# 44 0.673
# 45 0.647
# 46 0.656
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'gini', 'n_estimators': 150, 'min_samples_split': 4, 'max_depth': 6, 'ccp_alpha': 0.001}", 5, 0.6528, 0.012122705968553402, 0.7409999999999999, 8.464881753921508)
# Elapsed time: 8.46s
#
# 42 0.672
# 43 0.674
# 44 0.675
# 45 0.695
# 46 0.677
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'gini', 'n_estimators': 150, 'min_samples_split': 4, 'max_depth': 10, 'ccp_alpha': 0}", 5, 0.6786, 0.008357032966310435, 0.7529999999999999, 12.299038171768188)
# Elapsed time: 12.30s
#
# 42 0.67
# 43 0.675
# 44 0.69
# 45 0.701
# 46 0.673
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'gini', 'n_estimators': 150, 'min_samples_split': 4, 'max_depth': 10, 'ccp_alpha': 0.001}", 5, 0.6818000000000001, 0.011822013364905279, 0.753, 14.12086591720581)
# Elapsed time: 14.12s
#
# 42 0.602
# 43 0.608
# 44 0.642
# 45 0.624
# 46 0.621
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'gini', 'n_estimators': 150, 'min_samples_split': 8, 'max_depth': 2, 'ccp_alpha': 0}", 5, 0.6194, 0.013908270920570981, 0.693, 3.959600257873535)
# Elapsed time: 3.96s
#
# 42 0.607
# 43 0.617
# 44 0.629
# 45 0.649
# 46 0.636
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'gini', 'n_estimators': 150, 'min_samples_split': 8, 'max_depth': 2, 'ccp_alpha': 0.001}", 5, 0.6275999999999999, 0.014609585894199752, 0.6849999999999999, 3.992992115020752)
# Elapsed time: 3.99s
#
# 42 0.653
# 43 0.65
# 44 0.659
# 45 0.652
# 46 0.656
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'gini', 'n_estimators': 150, 'min_samples_split': 8, 'max_depth': 6, 'ccp_alpha': 0}", 5, 0.654, 0.003162277660168382, 0.7489999999999999, 9.269404935836793)
# Elapsed time: 9.27s
#
# 42 0.643
# 43 0.68
# 44 0.67
# 45 0.679
# 46 0.653
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'gini', 'n_estimators': 150, 'min_samples_split': 8, 'max_depth': 6, 'ccp_alpha': 0.001}", 5, 0.6649999999999999, 0.014656056768449022, 0.744, 8.146974515914916)
# Elapsed time: 8.15s
#
# 42 0.673
# 43 0.691
# 44 0.677
# 45 0.698
# 46 0.67
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'gini', 'n_estimators': 150, 'min_samples_split': 8, 'max_depth': 10, 'ccp_alpha': 0}", 5, 0.6818, 0.010833282051160631, 0.742, 12.530601263046265)
# Elapsed time: 12.53s
#
# 42 0.661
# 43 0.683
# 44 0.683
# 45 0.674
# 46 0.672
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'gini', 'n_estimators': 150, 'min_samples_split': 8, 'max_depth': 10, 'ccp_alpha': 0.001}", 5, 0.6746000000000001, 0.008163332652783427, 0.748, 12.309050893783569)
# Elapsed time: 12.31s
#
# 42 0.569
# 43 0.604
# 44 0.584
# 45 0.599
# 46 0.623
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'entropy', 'n_estimators': 10, 'min_samples_split': 2, 'max_depth': 2, 'ccp_alpha': 0}", 5, 0.5958, 0.018301912468373368, 0.673, 0.33019313812255857)
# Elapsed time: 0.33s
#
# 42 0.586
# 43 0.618
# 44 0.606
# 45 0.612
# 46 0.608
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'entropy', 'n_estimators': 10, 'min_samples_split': 2, 'max_depth': 2, 'ccp_alpha': 0.001}", 5, 0.6060000000000001, 0.010807404868885047, 0.657, 0.32241067886352537)
# Elapsed time: 0.32s
#
# 42 0.637
# 43 0.647
# 44 0.628
# 45 0.613
# 46 0.624
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'entropy', 'n_estimators': 10, 'min_samples_split': 2, 'max_depth': 6, 'ccp_alpha': 0}", 5, 0.6298, 0.011548160026601651, 0.6880000000000001, 0.7816603183746338)
# Elapsed time: 0.78s
#
# 42 0.626
# 43 0.615
# 44 0.666
# 45 0.638
# 46 0.646
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'entropy', 'n_estimators': 10, 'min_samples_split': 2, 'max_depth': 6, 'ccp_alpha': 0.001}", 5, 0.6382, 0.017440183485273326, 0.718, 0.8078569412231446)
# Elapsed time: 0.81s
#
# 42 0.651
# 43 0.656
# 44 0.628
# 45 0.652
# 46 0.65
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'entropy', 'n_estimators': 10, 'min_samples_split': 2, 'max_depth': 10, 'ccp_alpha': 0}", 5, 0.6474, 0.009911609354691103, 0.717, 1.1855623722076416)
# Elapsed time: 1.19s
#
# 42 0.616
# 43 0.672
# 44 0.661
# 45 0.636
# 46 0.64
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'entropy', 'n_estimators': 10, 'min_samples_split': 2, 'max_depth': 10, 'ccp_alpha': 0.001}", 5, 0.645, 0.019657059800489003, 0.72, 1.2557006359100342)
# Elapsed time: 1.26s
#
# 42 0.576
# 43 0.572
# 44 0.581
# 45 0.603
# 46 0.607
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'entropy', 'n_estimators': 10, 'min_samples_split': 4, 'max_depth': 2, 'ccp_alpha': 0}", 5, 0.5878, 0.014386104406683567, 0.664, 0.32351183891296387)
# Elapsed time: 0.32s
#
# 42 0.587
# 43 0.613
# 44 0.59
# 45 0.56
# 46 0.59
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'entropy', 'n_estimators': 10, 'min_samples_split': 4, 'max_depth': 2, 'ccp_alpha': 0.001}", 5, 0.588, 0.016840427548016686, 0.663, 0.3415809631347656)
# Elapsed time: 0.34s
#
# 42 0.615
# 43 0.63
# 44 0.625
# 45 0.651
# 46 0.656
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'entropy', 'n_estimators': 10, 'min_samples_split': 4, 'max_depth': 6, 'ccp_alpha': 0}", 5, 0.6354, 0.015628179676469057, 0.7230000000000001, 0.8182421684265136)
# Elapsed time: 0.82s
#
# 42 0.636
# 43 0.648
# 44 0.625
# 45 0.656
# 46 0.64
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'entropy', 'n_estimators': 10, 'min_samples_split': 4, 'max_depth': 6, 'ccp_alpha': 0.001}", 5, 0.641, 0.010545141061171263, 0.716, 0.7852056980133056)
# Elapsed time: 0.79s
#
# 42 0.639
# 43 0.637
# 44 0.679
# 45 0.637
# 46 0.648
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'entropy', 'n_estimators': 10, 'min_samples_split': 4, 'max_depth': 10, 'ccp_alpha': 0}", 5, 0.648, 0.01602498049920812, 0.7190000000000001, 1.3160732746124268)
# Elapsed time: 1.32s
#
# 42 0.657
# 43 0.637
# 44 0.658
# 45 0.671
# 46 0.647
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'entropy', 'n_estimators': 10, 'min_samples_split': 4, 'max_depth': 10, 'ccp_alpha': 0.001}", 5, 0.6540000000000001, 0.011419281938896169, 0.726, 1.3079368591308593)
# Elapsed time: 1.31s
#
# 42 0.617
# 43 0.603
# 44 0.616
# 45 0.59
# 46 0.618
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'entropy', 'n_estimators': 10, 'min_samples_split': 8, 'max_depth': 2, 'ccp_alpha': 0}", 5, 0.6087999999999999, 0.010870142593360964, 0.679, 0.34902071952819824)
# Elapsed time: 0.35s
#
# 42 0.584
# 43 0.623
# 44 0.601
# 45 0.607
# 46 0.615
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'entropy', 'n_estimators': 10, 'min_samples_split': 8, 'max_depth': 2, 'ccp_alpha': 0.001}", 5, 0.6060000000000001, 0.013266499161421611, 0.682, 0.3268099308013916)
# Elapsed time: 0.33s
#
# 42 0.626
# 43 0.639
# 44 0.61
# 45 0.666
# 46 0.61
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'entropy', 'n_estimators': 10, 'min_samples_split': 8, 'max_depth': 6, 'ccp_alpha': 0}", 5, 0.6302, 0.020941824180333496, 0.6970000000000001, 0.9062149524688721)
# Elapsed time: 0.91s
#
# 42 0.612
# 43 0.644
# 44 0.661
# 45 0.632
# 46 0.616
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'entropy', 'n_estimators': 10, 'min_samples_split': 8, 'max_depth': 6, 'ccp_alpha': 0.001}", 5, 0.633, 0.01808867048735204, 0.697, 0.8533359050750733)
# Elapsed time: 0.85s
#
# 42 0.634
# 43 0.644
# 44 0.65
# 45 0.642
# 46 0.643
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'entropy', 'n_estimators': 10, 'min_samples_split': 8, 'max_depth': 10, 'ccp_alpha': 0}", 5, 0.6426000000000001, 0.005122499389946284, 0.733, 1.1798397064208985)
# Elapsed time: 1.18s
#
# 42 0.65
# 43 0.667
# 44 0.663
# 45 0.667
# 46 0.654
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'entropy', 'n_estimators': 10, 'min_samples_split': 8, 'max_depth': 10, 'ccp_alpha': 0.001}", 5, 0.6602, 0.006968500556073745, 0.734, 1.297179365158081)
# Elapsed time: 1.30s
#
# 42 0.603
# 43 0.625
# 44 0.632
# 45 0.64
# 46 0.612
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'entropy', 'n_estimators': 75, 'min_samples_split': 2, 'max_depth': 2, 'ccp_alpha': 0}", 5, 0.6224000000000001, 0.01336562755728291, 0.7050000000000001, 2.3290951251983643)
# Elapsed time: 2.33s
#
# 42 0.591
# 43 0.62
# 44 0.629
# 45 0.626
# 46 0.626
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'entropy', 'n_estimators': 75, 'min_samples_split': 2, 'max_depth': 2, 'ccp_alpha': 0.001}", 5, 0.6184, 0.01400856880626998, 0.687, 2.6158950328826904)
# Elapsed time: 2.62s
#
# 42 0.657
# 43 0.672
# 44 0.661
# 45 0.68
# 46 0.658
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'entropy', 'n_estimators': 75, 'min_samples_split': 2, 'max_depth': 6, 'ccp_alpha': 0}", 5, 0.6656000000000001, 0.008957678270623486, 0.734, 6.059567975997925)
# Elapsed time: 6.06s
#
# 42 0.648
# 43 0.664
# 44 0.665
# 45 0.662
# 46 0.652
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'entropy', 'n_estimators': 75, 'min_samples_split': 2, 'max_depth': 6, 'ccp_alpha': 0.001}", 5, 0.6582000000000001, 0.006881860213634108, 0.736, 6.359842109680176)
# Elapsed time: 6.36s
#
# 42 0.658
# 43 0.666
# 44 0.683
# 45 0.664
# 46 0.672
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'entropy', 'n_estimators': 75, 'min_samples_split': 2, 'max_depth': 10, 'ccp_alpha': 0}", 5, 0.6686000000000001, 0.008475848040166843, 0.75, 8.57918119430542)
# Elapsed time: 8.58s
#
# 42 0.675
# 43 0.678
# 44 0.687
# 45 0.668
# 46 0.67
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'entropy', 'n_estimators': 75, 'min_samples_split': 2, 'max_depth': 10, 'ccp_alpha': 0.001}", 5, 0.6756, 0.006711184694225013, 0.7420000000000001, 8.406990194320679)
# Elapsed time: 8.41s
#
# 42 0.607
# 43 0.615
# 44 0.614
# 45 0.597
# 46 0.625
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'entropy', 'n_estimators': 75, 'min_samples_split': 4, 'max_depth': 2, 'ccp_alpha': 0}", 5, 0.6115999999999999, 0.009286549412995128, 0.6809999999999999, 2.11178879737854)
# Elapsed time: 2.11s
#
# 42 0.603
# 43 0.624
# 44 0.622
# 45 0.63
# 46 0.609
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'entropy', 'n_estimators': 75, 'min_samples_split': 4, 'max_depth': 2, 'ccp_alpha': 0.001}", 5, 0.6175999999999999, 0.01001199280862707, 0.6900000000000001, 2.1053601264953614)
# Elapsed time: 2.11s
#
# 42 0.657
# 43 0.653
# 44 0.671
# 45 0.681
# 46 0.647
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'entropy', 'n_estimators': 75, 'min_samples_split': 4, 'max_depth': 6, 'ccp_alpha': 0}", 5, 0.6618, 0.012432216214336054, 0.742, 5.709877443313599)
# Elapsed time: 5.71s
#
# 42 0.652
# 43 0.669
# 44 0.656
# 45 0.662
# 46 0.659
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'entropy', 'n_estimators': 75, 'min_samples_split': 4, 'max_depth': 6, 'ccp_alpha': 0.001}", 5, 0.6596, 0.005748043145279971, 0.7409999999999999, 5.631753063201904)
# Elapsed time: 5.63s
#
# 42 0.673
# 43 0.685
# 44 0.655
# 45 0.666
# 46 0.668
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'entropy', 'n_estimators': 75, 'min_samples_split': 4, 'max_depth': 10, 'ccp_alpha': 0}", 5, 0.6694, 0.009769339793455858, 0.744, 8.679159498214721)
# Elapsed time: 8.68s
#
# 42 0.68
# 43 0.678
# 44 0.687
# 45 0.649
# 46 0.666
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'entropy', 'n_estimators': 75, 'min_samples_split': 4, 'max_depth': 10, 'ccp_alpha': 0.001}", 5, 0.6719999999999999, 0.013341664064126346, 0.748, 9.699166679382325)
# Elapsed time: 9.70s
#
# 42 0.601
# 43 0.645
# 44 0.624
# 45 0.628
# 46 0.648
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'entropy', 'n_estimators': 75, 'min_samples_split': 8, 'max_depth': 2, 'ccp_alpha': 0}", 5, 0.6292000000000001, 0.016892601931022953, 0.704, 2.2715409278869627)
# Elapsed time: 2.27s
#
# 42 0.609
# 43 0.611
# 44 0.634
# 45 0.616
# 46 0.625
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'entropy', 'n_estimators': 75, 'min_samples_split': 8, 'max_depth': 2, 'ccp_alpha': 0.001}", 5, 0.619, 0.0093166517590817, 0.673, 2.3789565563201904)
# Elapsed time: 2.38s
#
# 42 0.651
# 43 0.673
# 44 0.654
# 45 0.679
# 46 0.657
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'entropy', 'n_estimators': 75, 'min_samples_split': 8, 'max_depth': 6, 'ccp_alpha': 0}", 5, 0.6628000000000001, 0.011106754701531867, 0.7409999999999999, 5.730120325088501)
# Elapsed time: 5.73s
#
# 42 0.646
# 43 0.648
# 44 0.645
# 45 0.645
# 46 0.66
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'entropy', 'n_estimators': 75, 'min_samples_split': 8, 'max_depth': 6, 'ccp_alpha': 0.001}", 5, 0.6488, 0.005706137047074847, 0.741, 6.16446886062622)
# Elapsed time: 6.16s
#
# 42 0.675
# 43 0.687
# 44 0.679
# 45 0.697
# 46 0.654
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'entropy', 'n_estimators': 75, 'min_samples_split': 8, 'max_depth': 10, 'ccp_alpha': 0}", 5, 0.6784000000000001, 0.014333178293735116, 0.756, 9.880721044540405)
# Elapsed time: 9.88s
#
# 42 0.664
# 43 0.684
# 44 0.681
# 45 0.656
# 46 0.668
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'entropy', 'n_estimators': 75, 'min_samples_split': 8, 'max_depth': 10, 'ccp_alpha': 0.001}", 5, 0.6706000000000001, 0.010499523798725359, 0.7489999999999999, 9.5206458568573)
# Elapsed time: 9.52s
#
# 42 0.607
# 43 0.63
# 44 0.629
# 45 0.604
# 46 0.642
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'entropy', 'n_estimators': 150, 'min_samples_split': 2, 'max_depth': 2, 'ccp_alpha': 0}", 5, 0.6224000000000001, 0.014568459081179461, 0.6950000000000001, 4.810208320617676)
# Elapsed time: 4.81s
#
# 42 0.603
# 43 0.615
# 44 0.636
# 45 0.617
# 46 0.64
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'entropy', 'n_estimators': 150, 'min_samples_split': 2, 'max_depth': 2, 'ccp_alpha': 0.001}", 5, 0.6222000000000001, 0.013818827736099772, 0.704, 4.8905528545379635)
# Elapsed time: 4.89s
#
# 42 0.665
# 43 0.669
# 44 0.661
# 45 0.647
# 46 0.664
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'entropy', 'n_estimators': 150, 'min_samples_split': 2, 'max_depth': 6, 'ccp_alpha': 0}", 5, 0.6612000000000001, 0.00754718490564529, 0.7460000000000001, 12.213468933105469)
# Elapsed time: 12.21s
#
# 42 0.648
# 43 0.657
# 44 0.649
# 45 0.656
# 46 0.659
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'entropy', 'n_estimators': 150, 'min_samples_split': 2, 'max_depth': 6, 'ccp_alpha': 0.001}", 5, 0.6538, 0.004445222154178577, 0.746, 12.045153951644897)
# Elapsed time: 12.05s
#
# 42 0.674
# 43 0.673
# 44 0.678
# 45 0.691
# 46 0.673
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'entropy', 'n_estimators': 150, 'min_samples_split': 2, 'max_depth': 10, 'ccp_alpha': 0}", 5, 0.6778, 0.006852736679604689, 0.7529999999999999, 18.23071093559265)
# Elapsed time: 18.23s
#
# 42 0.663
# 43 0.679
# 44 0.675
# 45 0.696
# 46 0.671
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'entropy', 'n_estimators': 150, 'min_samples_split': 2, 'max_depth': 10, 'ccp_alpha': 0.001}", 5, 0.6768000000000001, 0.010961751684835748, 0.745, 17.750663423538207)
# Elapsed time: 17.75s
#
# 42 0.606
# 43 0.631
# 44 0.634
# 45 0.593
# 46 0.623
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'entropy', 'n_estimators': 150, 'min_samples_split': 4, 'max_depth': 2, 'ccp_alpha': 0}", 5, 0.6174, 0.015602563891873682, 0.696, 4.201184225082398)
# Elapsed time: 4.20s
#
# 42 0.602
# 43 0.599
# 44 0.619
# 45 0.659
# 46 0.645
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'entropy', 'n_estimators': 150, 'min_samples_split': 4, 'max_depth': 2, 'ccp_alpha': 0.001}", 5, 0.6248, 0.023650792798551194, 0.7, 4.2273355484008786)
# Elapsed time: 4.23s
#
# 42 0.649
# 43 0.663
# 44 0.662
# 45 0.666
# 46 0.659
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'entropy', 'n_estimators': 150, 'min_samples_split': 4, 'max_depth': 6, 'ccp_alpha': 0}", 5, 0.6598, 0.005844655678480989, 0.748, 11.305984401702881)
# Elapsed time: 11.31s
#
# 42 0.649
# 43 0.667
# 44 0.678
# 45 0.658
# 46 0.651
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'entropy', 'n_estimators': 150, 'min_samples_split': 4, 'max_depth': 6, 'ccp_alpha': 0.001}", 5, 0.6606, 0.010744300814850644, 0.743, 11.251554727554321)
# Elapsed time: 11.25s
#
# 42 0.669
# 43 0.68
# 44 0.68
# 45 0.667
# 46 0.668
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'entropy', 'n_estimators': 150, 'min_samples_split': 4, 'max_depth': 10, 'ccp_alpha': 0}", 5, 0.6728000000000002, 0.0059126981996377986, 0.743, 17.93367862701416)
# Elapsed time: 17.93s
#
# 42 0.662
# 43 0.673
# 44 0.654
# 45 0.689
# 46 0.667
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'entropy', 'n_estimators': 150, 'min_samples_split': 4, 'max_depth': 10, 'ccp_alpha': 0.001}", 5, 0.6689999999999999, 0.011781341180018485, 0.753, 17.651614236831666)
# Elapsed time: 17.65s
#
# 42 0.601
# 43 0.618
# 44 0.622
# 45 0.615
# 46 0.629
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'entropy', 'n_estimators': 150, 'min_samples_split': 8, 'max_depth': 2, 'ccp_alpha': 0}", 5, 0.6169999999999999, 0.009273618495495713, 0.702, 4.7039618492126465)
# Elapsed time: 4.70s
#
# 42 0.597
# 43 0.619
# 44 0.631
# 45 0.619
# 46 0.641
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'entropy', 'n_estimators': 150, 'min_samples_split': 8, 'max_depth': 2, 'ccp_alpha': 0.001}", 5, 0.6214000000000001, 0.014718695594379293, 0.7060000000000001, 4.9014105796813965)
# Elapsed time: 4.90s
#
# 42 0.652
# 43 0.664
# 44 0.667
# 45 0.666
# 46 0.66
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'entropy', 'n_estimators': 150, 'min_samples_split': 8, 'max_depth': 6, 'ccp_alpha': 0}", 5, 0.6618, 0.005455272678794347, 0.739, 11.30602126121521)
# Elapsed time: 11.31s
#
# 42 0.651
# 43 0.665
# 44 0.66
# 45 0.655
# 46 0.655
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'entropy', 'n_estimators': 150, 'min_samples_split': 8, 'max_depth': 6, 'ccp_alpha': 0.001}", 5, 0.6572000000000001, 0.004833218389437833, 0.752, 10.951890897750854)
# Elapsed time: 10.95s
#
# 42 0.668
# 43 0.676
# 44 0.687
# 45 0.689
# 46 0.68
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'entropy', 'n_estimators': 150, 'min_samples_split': 8, 'max_depth': 10, 'ccp_alpha': 0}", 5, 0.68, 0.007615773105863888, 0.741, 16.350153732299805)
# Elapsed time: 16.35s
#
# 42 0.661
# 43 0.682
# 44 0.685
# 45 0.665
# 46 0.667
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'entropy', 'n_estimators': 150, 'min_samples_split': 8, 'max_depth': 10, 'ccp_alpha': 0.001}", 5, 0.672, 0.009633275663033845, 0.754, 16.380961847305297)
# Elapsed time: 16.38s
#
# 42 0.567
# 43 0.592
# 44 0.628
# 45 0.584
# 46 0.609
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'log_loss', 'n_estimators': 10, 'min_samples_split': 2, 'max_depth': 2, 'ccp_alpha': 0}", 5, 0.596, 0.020947553556441876, 0.6679999999999999, 0.3107180595397949)
# Elapsed time: 0.31s
#
# 42 0.566
# 43 0.609
# 44 0.592
# 45 0.617
# 46 0.604
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'log_loss', 'n_estimators': 10, 'min_samples_split': 2, 'max_depth': 2, 'ccp_alpha': 0.001}", 5, 0.5976, 0.017760630619434677, 0.68, 0.3172261714935303)
# Elapsed time: 0.32s
#
# 42 0.639
# 43 0.614
# 44 0.667
# 45 0.615
# 46 0.65
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'log_loss', 'n_estimators': 10, 'min_samples_split': 2, 'max_depth': 6, 'ccp_alpha': 0}", 5, 0.637, 0.020425474290698874, 0.714, 0.7466128826141357)
# Elapsed time: 0.75s
#
# 42 0.638
# 43 0.642
# 44 0.662
# 45 0.625
# 46 0.662
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'log_loss', 'n_estimators': 10, 'min_samples_split': 2, 'max_depth': 6, 'ccp_alpha': 0.001}", 5, 0.6458, 0.014372195378577356, 0.726, 0.7467445373535156)
# Elapsed time: 0.75s
#
# 42 0.631
# 43 0.649
# 44 0.622
# 45 0.658
# 46 0.636
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'log_loss', 'n_estimators': 10, 'min_samples_split': 2, 'max_depth': 10, 'ccp_alpha': 0}", 5, 0.6392, 0.012828094168659671, 0.717, 1.1209080696105957)
# Elapsed time: 1.12s
#
# 42 0.675
# 43 0.647
# 44 0.665
# 45 0.664
# 46 0.643
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'log_loss', 'n_estimators': 10, 'min_samples_split': 2, 'max_depth': 10, 'ccp_alpha': 0.001}", 5, 0.6588, 0.011973303637676623, 0.731, 1.130481481552124)
# Elapsed time: 1.13s
#
# 42 0.598
# 43 0.595
# 44 0.64
# 45 0.607
# 46 0.563
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'log_loss', 'n_estimators': 10, 'min_samples_split': 4, 'max_depth': 2, 'ccp_alpha': 0}", 5, 0.6006, 0.024678735786097333, 0.683, 0.314409875869751)
# Elapsed time: 0.31s
#
# 42 0.583
# 43 0.604
# 44 0.608
# 45 0.58
# 46 0.577
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'log_loss', 'n_estimators': 10, 'min_samples_split': 4, 'max_depth': 2, 'ccp_alpha': 0.001}", 5, 0.5904, 0.012939860895697462, 0.673, 0.325701379776001)
# Elapsed time: 0.33s
#
# 42 0.626
# 43 0.638
# 44 0.64
# 45 0.625
# 46 0.608
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'log_loss', 'n_estimators': 10, 'min_samples_split': 4, 'max_depth': 6, 'ccp_alpha': 0}", 5, 0.6274, 0.011447270417003358, 0.6900000000000001, 0.7792975902557373)
# Elapsed time: 0.78s
#
# 42 0.631
# 43 0.651
# 44 0.612
# 45 0.664
# 46 0.646
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'log_loss', 'n_estimators': 10, 'min_samples_split': 4, 'max_depth': 6, 'ccp_alpha': 0.001}", 5, 0.6408, 0.01785945127936468, 0.71, 0.7476108074188232)
# Elapsed time: 0.75s
#
# 42 0.668
# 43 0.658
# 44 0.634
# 45 0.652
# 46 0.636
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'log_loss', 'n_estimators': 10, 'min_samples_split': 4, 'max_depth': 10, 'ccp_alpha': 0}", 5, 0.6496000000000001, 0.012986146464598355, 0.712, 1.1204044342041015)
# Elapsed time: 1.12s
#
# 42 0.665
# 43 0.658
# 44 0.653
# 45 0.61
# 46 0.66
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'log_loss', 'n_estimators': 10, 'min_samples_split': 4, 'max_depth': 10, 'ccp_alpha': 0.001}", 5, 0.6492, 0.01997398307799425, 0.721, 1.1333509922027587)
# Elapsed time: 1.13s
#
# 42 0.609
# 43 0.615
# 44 0.575
# 45 0.599
# 46 0.603
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'log_loss', 'n_estimators': 10, 'min_samples_split': 8, 'max_depth': 2, 'ccp_alpha': 0}", 5, 0.6001999999999998, 0.013717142559585808, 0.6809999999999999, 0.30795741081237793)
# Elapsed time: 0.31s
#
# 42 0.602
# 43 0.615
# 44 0.633
# 45 0.574
# 46 0.602
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'log_loss', 'n_estimators': 10, 'min_samples_split': 8, 'max_depth': 2, 'ccp_alpha': 0.001}", 5, 0.6052, 0.019301813386311678, 0.6679999999999999, 0.30981993675231934)
# Elapsed time: 0.31s
#
# 42 0.617
# 43 0.595
# 44 0.637
# 45 0.651
# 46 0.657
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'log_loss', 'n_estimators': 10, 'min_samples_split': 8, 'max_depth': 6, 'ccp_alpha': 0}", 5, 0.6314, 0.022817537115122674, 0.7110000000000001, 0.7482845783233643)
# Elapsed time: 0.75s
#
# 42 0.619
# 43 0.644
# 44 0.627
# 45 0.635
# 46 0.663
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'log_loss', 'n_estimators': 10, 'min_samples_split': 8, 'max_depth': 6, 'ccp_alpha': 0.001}", 5, 0.6376, 0.01517366139071254, 0.73, 0.7539205074310302)
# Elapsed time: 0.75s
#
# 42 0.661
# 43 0.656
# 44 0.658
# 45 0.66
# 46 0.643
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'log_loss', 'n_estimators': 10, 'min_samples_split': 8, 'max_depth': 10, 'ccp_alpha': 0}", 5, 0.6556000000000001, 0.0065299310869258095, 0.727, 1.159118890762329)
# Elapsed time: 1.16s
#
# 42 0.644
# 43 0.646
# 44 0.639
# 45 0.669
# 46 0.651
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'log_loss', 'n_estimators': 10, 'min_samples_split': 8, 'max_depth': 10, 'ccp_alpha': 0.001}", 5, 0.6497999999999999, 0.010342146779078326, 0.729, 1.1352700233459472)
# Elapsed time: 1.14s
#
# 42 0.597
# 43 0.626
# 44 0.636
# 45 0.626
# 46 0.635
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'log_loss', 'n_estimators': 75, 'min_samples_split': 2, 'max_depth': 2, 'ccp_alpha': 0}", 5, 0.624, 0.014156270695349124, 0.694, 2.017644262313843)
# Elapsed time: 2.02s
#
# 42 0.592
# 43 0.619
# 44 0.645
# 45 0.61
# 46 0.622
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'log_loss', 'n_estimators': 75, 'min_samples_split': 2, 'max_depth': 2, 'ccp_alpha': 0.001}", 5, 0.6175999999999999, 0.017234848418248433, 0.675, 2.0274188995361326)
# Elapsed time: 2.03s
#
# 42 0.651
# 43 0.672
# 44 0.667
# 45 0.673
# 46 0.648
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'log_loss', 'n_estimators': 75, 'min_samples_split': 2, 'max_depth': 6, 'ccp_alpha': 0}", 5, 0.6622000000000001, 0.010609429767899884, 0.742, 5.379918432235717)
# Elapsed time: 5.38s
#
# 42 0.654
# 43 0.676
# 44 0.667
# 45 0.676
# 46 0.64
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'log_loss', 'n_estimators': 75, 'min_samples_split': 2, 'max_depth': 6, 'ccp_alpha': 0.001}", 5, 0.6626000000000001, 0.013879481258317991, 0.729, 5.3948005676269535)
# Elapsed time: 5.39s
#
# 42 0.666
# 43 0.667
# 44 0.663
# 45 0.666
# 46 0.678
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'log_loss', 'n_estimators': 75, 'min_samples_split': 2, 'max_depth': 10, 'ccp_alpha': 0}", 5, 0.668, 0.005176871642217918, 0.75, 8.77320213317871)
# Elapsed time: 8.77s
#
# 42 0.664
# 43 0.652
# 44 0.684
# 45 0.677
# 46 0.666
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'log_loss', 'n_estimators': 75, 'min_samples_split': 2, 'max_depth': 10, 'ccp_alpha': 0.001}", 5, 0.6686, 0.011056219968868212, 0.7459999999999999, 8.608559226989746)
# Elapsed time: 8.61s
#
# 42 0.605
# 43 0.609
# 44 0.63
# 45 0.63
# 46 0.627
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'log_loss', 'n_estimators': 75, 'min_samples_split': 4, 'max_depth': 2, 'ccp_alpha': 0}", 5, 0.6202, 0.010906878563548794, 0.6980000000000001, 2.087377643585205)
# Elapsed time: 2.09s
#
# 42 0.595
# 43 0.621
# 44 0.646
# 45 0.624
# 46 0.645
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'log_loss', 'n_estimators': 75, 'min_samples_split': 4, 'max_depth': 2, 'ccp_alpha': 0.001}", 5, 0.6262000000000001, 0.018712562625145722, 0.692, 2.08502311706543)
# Elapsed time: 2.09s
#
# 42 0.659
# 43 0.664
# 44 0.656
# 45 0.653
# 46 0.655
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'log_loss', 'n_estimators': 75, 'min_samples_split': 4, 'max_depth': 6, 'ccp_alpha': 0}", 5, 0.6574, 0.0038262252939418014, 0.73, 5.3969474792480465)
# Elapsed time: 5.40s
#
# 42 0.642
# 43 0.658
# 44 0.647
# 45 0.671
# 46 0.645
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'log_loss', 'n_estimators': 75, 'min_samples_split': 4, 'max_depth': 6, 'ccp_alpha': 0.001}", 5, 0.6526000000000001, 0.010669582934679322, 0.7370000000000001, 5.746396112442016)
# Elapsed time: 5.75s
#
# 42 0.654
# 43 0.683
# 44 0.685
# 45 0.667
# 46 0.665
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'log_loss', 'n_estimators': 75, 'min_samples_split': 4, 'max_depth': 10, 'ccp_alpha': 0}", 5, 0.6708000000000001, 0.011668761716651868, 0.744, 8.290201902389526)
# Elapsed time: 8.29s
#
# 42 0.662
# 43 0.695
# 44 0.683
# 45 0.676
# 46 0.656
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'log_loss', 'n_estimators': 75, 'min_samples_split': 4, 'max_depth': 10, 'ccp_alpha': 0.001}", 5, 0.6744000000000001, 0.014093970341958273, 0.7449999999999999, 8.17033896446228)
# Elapsed time: 8.17s
#
# 42 0.603
# 43 0.631
# 44 0.624
# 45 0.62
# 46 0.629
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'log_loss', 'n_estimators': 75, 'min_samples_split': 8, 'max_depth': 2, 'ccp_alpha': 0}", 5, 0.6214000000000001, 0.009971960689854335, 0.6849999999999999, 2.0203304290771484)
# Elapsed time: 2.02s
#
# 42 0.621
# 43 0.621
# 44 0.633
# 45 0.607
# 46 0.635
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'log_loss', 'n_estimators': 75, 'min_samples_split': 8, 'max_depth': 2, 'ccp_alpha': 0.001}", 5, 0.6234, 0.010071742649611345, 0.6980000000000001, 2.0382618427276613)
# Elapsed time: 2.04s
#
# 42 0.646
# 43 0.666
# 44 0.661
# 45 0.684
# 46 0.672
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'log_loss', 'n_estimators': 75, 'min_samples_split': 8, 'max_depth': 6, 'ccp_alpha': 0}", 5, 0.6658000000000001, 0.012528367810692673, 0.742, 5.355830478668213)
# Elapsed time: 5.36s
#
# 42 0.657
# 43 0.658
# 44 0.648
# 45 0.657
# 46 0.657
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'log_loss', 'n_estimators': 75, 'min_samples_split': 8, 'max_depth': 6, 'ccp_alpha': 0.001}", 5, 0.6554, 0.0037202150475476583, 0.7409999999999999, 5.32631025314331)
# Elapsed time: 5.33s
#
# 42 0.668
# 43 0.676
# 44 0.679
# 45 0.688
# 46 0.677
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'log_loss', 'n_estimators': 75, 'min_samples_split': 8, 'max_depth': 10, 'ccp_alpha': 0}", 5, 0.6776000000000001, 0.0064062469512187565, 0.75, 7.757653427124024)
# Elapsed time: 7.76s
#
# 42 0.662
# 43 0.665
# 44 0.673
# 45 0.678
# 46 0.678
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'log_loss', 'n_estimators': 75, 'min_samples_split': 8, 'max_depth': 10, 'ccp_alpha': 0.001}", 5, 0.6712, 0.006615134163416496, 0.7549999999999999, 7.814942979812622)
# Elapsed time: 7.81s
#
# 42 0.599
# 43 0.615
# 44 0.636
# 45 0.617
# 46 0.651
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'log_loss', 'n_estimators': 150, 'min_samples_split': 2, 'max_depth': 2, 'ccp_alpha': 0}", 5, 0.6236, 0.018039955654047507, 0.705, 3.775807094573975)
# Elapsed time: 3.78s
#
# 42 0.59
# 43 0.615
# 44 0.618
# 45 0.626
# 46 0.63
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'log_loss', 'n_estimators': 150, 'min_samples_split': 2, 'max_depth': 2, 'ccp_alpha': 0.001}", 5, 0.6157999999999999, 0.013977124167724932, 0.6789999999999999, 3.781119537353516)
# Elapsed time: 3.78s
#
# 42 0.66
# 43 0.671
# 44 0.666
# 45 0.654
# 46 0.657
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'log_loss', 'n_estimators': 150, 'min_samples_split': 2, 'max_depth': 6, 'ccp_alpha': 0}", 5, 0.6616, 0.006151422599691885, 0.739, 10.0122501373291)
# Elapsed time: 10.01s
#
# 42 0.668
# 43 0.673
# 44 0.662
# 45 0.652
# 46 0.647
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'log_loss', 'n_estimators': 150, 'min_samples_split': 2, 'max_depth': 6, 'ccp_alpha': 0.001}", 5, 0.6604000000000001, 0.009687104830649877, 0.7460000000000001, 9.903502702713013)
# Elapsed time: 9.90s
#
# 42 0.662
# 43 0.679
# 44 0.682
# 45 0.693
# 46 0.671
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'log_loss', 'n_estimators': 150, 'min_samples_split': 2, 'max_depth': 10, 'ccp_alpha': 0}", 5, 0.6774000000000001, 0.010442221985765266, 0.751, 15.061198282241822)
# Elapsed time: 15.06s
#
# 42 0.667
# 43 0.681
# 44 0.659
# 45 0.688
# 46 0.669
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'log_loss', 'n_estimators': 150, 'min_samples_split': 2, 'max_depth': 10, 'ccp_alpha': 0.001}", 5, 0.6728000000000001, 0.010361467077590872, 0.748, 15.466378116607666)
# Elapsed time: 15.47s
#
# 42 0.595
# 43 0.623
# 44 0.632
# 45 0.607
# 46 0.629
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'log_loss', 'n_estimators': 150, 'min_samples_split': 4, 'max_depth': 2, 'ccp_alpha': 0}", 5, 0.6172, 0.01406271666499757, 0.724, 3.931992530822754)
# Elapsed time: 3.93s
#
# 42 0.608
# 43 0.613
# 44 0.64
# 45 0.605
# 46 0.637
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'log_loss', 'n_estimators': 150, 'min_samples_split': 4, 'max_depth': 2, 'ccp_alpha': 0.001}", 5, 0.6206, 0.014867414032036654, 0.712, 4.063174152374268)
# Elapsed time: 4.06s
#
# 42 0.644
# 43 0.668
# 44 0.652
# 45 0.652
# 46 0.656
# ...
# 46 0.637
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'log_loss', 'n_estimators': 10, 'min_samples_split': 2, 'max_depth': 6, 'ccp_alpha': 0.001}", 6, 0.6328, 0.015587174214718984, 0.732, 0.6942646026611328)
# Elapsed time: 0.69s
#
# 42 0.627
# 43 0.663
# 44 0.646
# 45 0.659
# 46 0.626
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'log_loss', 'n_estimators': 10, 'min_samples_split': 2, 'max_depth': 10, 'ccp_alpha': 0}", 6, 0.6441999999999999, 0.015509996776273051, 0.725, 1.0859119892120361)
# Elapsed time: 1.09s
#
# 42 0.622
# 43 0.59
# 44 0.635
# 45 0.638
# 46 0.666
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'log_loss', 'n_estimators': 10, 'min_samples_split': 2, 'max_depth': 10, 'ccp_alpha': 0.001}", 6, 0.6302, 0.024693318934481064, 0.696, 1.0553229808807374)
# Elapsed time: 1.06s
#
# 42 0.589
# 43 0.629
# 44 0.603
# 45 0.54
# 46 0.626
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'log_loss', 'n_estimators': 10, 'min_samples_split': 4, 'max_depth': 2, 'ccp_alpha': 0}", 6, 0.5973999999999999, 0.03228993651278986, 0.663, 0.2868858814239502)
# Elapsed time: 0.29s
#
# 42 0.579
# 43 0.592
# 44 0.587
# 45 0.607
# 46 0.617
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'log_loss', 'n_estimators': 10, 'min_samples_split': 4, 'max_depth': 2, 'ccp_alpha': 0.001}", 6, 0.5963999999999999, 0.013763720427268214, 0.672, 0.28375992774963377)
# Elapsed time: 0.28s
#
# 42 0.637
# 43 0.669
# 44 0.645
# 45 0.65
# 46 0.633
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'log_loss', 'n_estimators': 10, 'min_samples_split': 4, 'max_depth': 6, 'ccp_alpha': 0}", 6, 0.6468, 0.012592060990957766, 0.7220000000000001, 0.6940854549407959)
# Elapsed time: 0.69s
#
# 42 0.644
# 43 0.648
# 44 0.655
# 45 0.628
# 46 0.629
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'log_loss', 'n_estimators': 10, 'min_samples_split': 4, 'max_depth': 6, 'ccp_alpha': 0.001}", 6, 0.6408, 0.010647065323364941, 0.7190000000000001, 0.7025134086608886)
# Elapsed time: 0.70s
#
# 42 0.657
# 43 0.644
# 44 0.644
# 45 0.671
# 46 0.664
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'log_loss', 'n_estimators': 10, 'min_samples_split': 4, 'max_depth': 10, 'ccp_alpha': 0}", 6, 0.6560000000000001, 0.010751744044572499, 0.7169999999999999, 1.0868730068206787)
# Elapsed time: 1.09s
#
# 42 0.646
# 43 0.671
# 44 0.658
# 45 0.648
# 46 0.658
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'log_loss', 'n_estimators': 10, 'min_samples_split': 4, 'max_depth': 10, 'ccp_alpha': 0.001}", 6, 0.6562, 0.008908422980528043, 0.733, 1.0714666843414307)
# Elapsed time: 1.07s
#
# 42 0.608
# 43 0.583
# 44 0.619
# 45 0.583
# 46 0.625
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'log_loss', 'n_estimators': 10, 'min_samples_split': 8, 'max_depth': 2, 'ccp_alpha': 0}", 6, 0.6035999999999999, 0.017681628884240293, 0.675, 0.28766298294067383)
# Elapsed time: 0.29s
#
# 42 0.575
# 43 0.595
# 44 0.594
# 45 0.601
# 46 0.567
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'log_loss', 'n_estimators': 10, 'min_samples_split': 8, 'max_depth': 2, 'ccp_alpha': 0.001}", 6, 0.5863999999999999, 0.013047605144240084, 0.664, 0.2911806106567383)
# Elapsed time: 0.29s
#
# 42 0.635
# 43 0.614
# 44 0.629
# 45 0.638
# 46 0.633
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'log_loss', 'n_estimators': 10, 'min_samples_split': 8, 'max_depth': 6, 'ccp_alpha': 0}", 6, 0.6298, 0.008423775875461084, 0.694, 0.7116930961608887)
# Elapsed time: 0.71s
#
# 42 0.611
# 43 0.631
# 44 0.665
# 45 0.609
# 46 0.633
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'log_loss', 'n_estimators': 10, 'min_samples_split': 8, 'max_depth': 6, 'ccp_alpha': 0.001}", 6, 0.6298, 0.0201831612984686, 0.6990000000000001, 0.6973205089569092)
# Elapsed time: 0.70s
#
# 42 0.631
# 43 0.652
# 44 0.639
# 45 0.638
# 46 0.648
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'log_loss', 'n_estimators': 10, 'min_samples_split': 8, 'max_depth': 10, 'ccp_alpha': 0}", 6, 0.6416000000000001, 0.007499333303701076, 0.7070000000000001, 1.0568840503692627)
# Elapsed time: 1.06s
#
# 42 0.662
# 43 0.611
# 44 0.669
# 45 0.612
# 46 0.679
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'log_loss', 'n_estimators': 10, 'min_samples_split': 8, 'max_depth': 10, 'ccp_alpha': 0.001}", 6, 0.6466000000000001, 0.029165733318399546, 0.732, 1.1037002086639405)
# Elapsed time: 1.10s
#
# 42 0.608
# 43 0.617
# 44 0.624
# 45 0.611
# 46 0.635
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'log_loss', 'n_estimators': 75, 'min_samples_split': 2, 'max_depth': 2, 'ccp_alpha': 0}", 6, 0.619, 0.009695359714832668, 0.6900000000000001, 1.9124995231628419)
# Elapsed time: 1.91s
#
# 42 0.589
# 43 0.628
# 44 0.619
# 45 0.613
# 46 0.631
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'log_loss', 'n_estimators': 75, 'min_samples_split': 2, 'max_depth': 2, 'ccp_alpha': 0.001}", 6, 0.616, 0.014939879517586492, 0.711, 1.9217173099517821)
# Elapsed time: 1.92s
#
# 42 0.668
# 43 0.674
# 44 0.676
# 45 0.665
# 46 0.67
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'log_loss', 'n_estimators': 75, 'min_samples_split': 2, 'max_depth': 6, 'ccp_alpha': 0}", 6, 0.6706000000000001, 0.003979949748426483, 0.738, 5.037485218048095)
# Elapsed time: 5.04s
#
# 42 0.662
# 43 0.678
# 44 0.685
# 45 0.687
# 46 0.665
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'log_loss', 'n_estimators': 75, 'min_samples_split': 2, 'max_depth': 6, 'ccp_alpha': 0.001}", 6, 0.6754000000000001, 0.010209799214480184, 0.749, 5.029543352127075)
# Elapsed time: 5.03s
#
# 42 0.677
# 43 0.7
# 44 0.714
# 45 0.689
# 46 0.671
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'log_loss', 'n_estimators': 75, 'min_samples_split': 2, 'max_depth': 10, 'ccp_alpha': 0}", 6, 0.6902000000000001, 0.015535765188750729, 0.758, 8.024090242385864)
# Elapsed time: 8.02s
#
# 42 0.68
# 43 0.686
# 44 0.707
# 45 0.689
# 46 0.687
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'log_loss', 'n_estimators': 75, 'min_samples_split': 2, 'max_depth': 10, 'ccp_alpha': 0.001}", 6, 0.6898, 0.009108238029388527, 0.772, 7.6460963726043705)
# Elapsed time: 7.65s
#
# 42 0.613
# 43 0.621
# 44 0.636
# 45 0.638
# 46 0.625
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'log_loss', 'n_estimators': 75, 'min_samples_split': 4, 'max_depth': 2, 'ccp_alpha': 0}", 6, 0.6266, 0.009350935782048776, 0.708, 1.8747128963470459)
# Elapsed time: 1.87s
#
# 42 0.593
# 43 0.602
# 44 0.643
# 45 0.635
# 46 0.649
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'log_loss', 'n_estimators': 75, 'min_samples_split': 4, 'max_depth': 2, 'ccp_alpha': 0.001}", 6, 0.6244, 0.02258849264559282, 0.702, 1.8866284847259522)
# Elapsed time: 1.89s
#
# 42 0.651
# 43 0.659
# 44 0.664
# 45 0.66
# 46 0.65
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'log_loss', 'n_estimators': 75, 'min_samples_split': 4, 'max_depth': 6, 'ccp_alpha': 0}", 6, 0.6568, 0.005418486873657632, 0.727, 5.038258504867554)
# Elapsed time: 5.04s
#
# 42 0.662
# 43 0.689
# 44 0.676
# 45 0.655
# 46 0.662
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'log_loss', 'n_estimators': 75, 'min_samples_split': 4, 'max_depth': 6, 'ccp_alpha': 0.001}", 6, 0.6688000000000001, 0.012188519188154046, 0.742, 4.980127954483033)
# Elapsed time: 4.98s
#
# 42 0.68
# 43 0.688
# 44 0.697
# 45 0.68
# 46 0.67
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'log_loss', 'n_estimators': 75, 'min_samples_split': 4, 'max_depth': 10, 'ccp_alpha': 0}", 6, 0.683, 0.009033271832508934, 0.7569999999999999, 7.692510795593262)
# Elapsed time: 7.69s
#
# 42 0.679
# 43 0.681
# 44 0.669
# 45 0.668
# 46 0.667
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'log_loss', 'n_estimators': 75, 'min_samples_split': 4, 'max_depth': 10, 'ccp_alpha': 0.001}", 6, 0.6728, 0.005946427498927407, 0.757, 7.8530761241912845)
# Elapsed time: 7.85s
#
# 42 0.608
# 43 0.611
# 44 0.645
# 45 0.609
# 46 0.622
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'log_loss', 'n_estimators': 75, 'min_samples_split': 8, 'max_depth': 2, 'ccp_alpha': 0}", 6, 0.619, 0.013928388277184131, 0.6990000000000001, 2.037566900253296)
# Elapsed time: 2.04s
#
# 42 0.602
# 43 0.618
# 44 0.641
# 45 0.643
# 46 0.65
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'log_loss', 'n_estimators': 75, 'min_samples_split': 8, 'max_depth': 2, 'ccp_alpha': 0.001}", 6, 0.6308, 0.017971087891388227, 0.696, 2.147958755493164)
# Elapsed time: 2.15s
#
# 42 0.644
# 43 0.678
# 44 0.669
# 45 0.67
# 46 0.663
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'log_loss', 'n_estimators': 75, 'min_samples_split': 8, 'max_depth': 6, 'ccp_alpha': 0}", 6, 0.6648, 0.011443775600735983, 0.734, 5.713162183761597)
# Elapsed time: 5.71s
#
# 42 0.663
# 43 0.683
# 44 0.666
# 45 0.671
# 46 0.66
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'log_loss', 'n_estimators': 75, 'min_samples_split': 8, 'max_depth': 6, 'ccp_alpha': 0.001}", 6, 0.6686, 0.008064738061462389, 0.7540000000000001, 5.7527491569519045)
# Elapsed time: 5.75s
#
# 42 0.679
# 43 0.694
# 44 0.702
# 45 0.701
# 46 0.68
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'log_loss', 'n_estimators': 75, 'min_samples_split': 8, 'max_depth': 10, 'ccp_alpha': 0}", 6, 0.6912, 0.009947864092356666, 0.753, 8.350435924530029)
# Elapsed time: 8.35s
#
# 42 0.665
# 43 0.693
# 44 0.688
# 45 0.699
# 46 0.672
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'log_loss', 'n_estimators': 75, 'min_samples_split': 8, 'max_depth': 10, 'ccp_alpha': 0.001}", 6, 0.6834, 0.01284678948220134, 0.748, 8.539186477661133)
# Elapsed time: 8.54s
#
# 42 0.608
# 43 0.608
# 44 0.639
# 45 0.614
# 46 0.644
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'log_loss', 'n_estimators': 150, 'min_samples_split': 2, 'max_depth': 2, 'ccp_alpha': 0}", 6, 0.6226, 0.015666524822052923, 0.6950000000000001, 4.1570604801177975)
# Elapsed time: 4.16s
#
# 42 0.598
# 43 0.626
# 44 0.638
# 45 0.628
# 46 0.633
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'log_loss', 'n_estimators': 150, 'min_samples_split': 2, 'max_depth': 2, 'ccp_alpha': 0.001}", 6, 0.6246, 0.013937001112147488, 0.72, 4.16585955619812)
# Elapsed time: 4.17s
#
# 42 0.663
# 43 0.683
# 44 0.664
# 45 0.661
# 46 0.657
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'log_loss', 'n_estimators': 150, 'min_samples_split': 2, 'max_depth': 6, 'ccp_alpha': 0}", 6, 0.6656000000000001, 0.00902441133814279, 0.748, 11.417340612411499)
# Elapsed time: 11.42s
#
# 42 0.649
# 43 0.665
# 44 0.675
# 45 0.687
# 46 0.662
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'log_loss', 'n_estimators': 150, 'min_samples_split': 2, 'max_depth': 6, 'ccp_alpha': 0.001}", 6, 0.6676, 0.012768711759609905, 0.745, 11.52056951522827)
# Elapsed time: 11.52s
#
# 42 0.659
# 43 0.683
# 44 0.704
# 45 0.679
# 46 0.68
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'log_loss', 'n_estimators': 150, 'min_samples_split': 2, 'max_depth': 10, 'ccp_alpha': 0}", 6, 0.6810000000000002, 0.01429685280052919, 0.767, 17.655462408065794)
# Elapsed time: 17.66s
#
# 42 0.683
# 43 0.699
# 44 0.708
# 45 0.679
# 46 0.681
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'log_loss', 'n_estimators': 150, 'min_samples_split': 2, 'max_depth': 10, 'ccp_alpha': 0.001}", 6, 0.6900000000000001, 0.01145425685062104, 0.752, 17.586731290817262)
# Elapsed time: 17.59s
#
# 42 0.6
# 43 0.619
# 44 0.633
# 45 0.628
# 46 0.634
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'log_loss', 'n_estimators': 150, 'min_samples_split': 4, 'max_depth': 2, 'ccp_alpha': 0}", 6, 0.6228, 0.012576167937810002, 0.712, 4.164608907699585)
# Elapsed time: 4.16s
#
# 42 0.62
# 43 0.634
# 44 0.626
# 45 0.629
# 46 0.633
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'log_loss', 'n_estimators': 150, 'min_samples_split': 4, 'max_depth': 2, 'ccp_alpha': 0.001}", 6, 0.6284, 0.005083306010855539, 0.704, 4.293874645233155)
# Elapsed time: 4.29s
#
# 42 0.651
# 43 0.667
# 44 0.668
# 45 0.673
# 46 0.662
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'log_loss', 'n_estimators': 150, 'min_samples_split': 4, 'max_depth': 6, 'ccp_alpha': 0}", 6, 0.6642, 0.007467261881037795, 0.735, 11.583659362792968)
# Elapsed time: 11.58s
#
# 42 0.649
# 43 0.672
# 44 0.666
# 45 0.663
# 46 0.669
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'log_loss', 'n_estimators': 150, 'min_samples_split': 4, 'max_depth': 6, 'ccp_alpha': 0.001}", 6, 0.6638000000000001, 0.00798498591107086, 0.747, 11.447414684295655)
# Elapsed time: 11.45s
#
# 42 0.68
# 43 0.683
# 44 0.715
# 45 0.702
# 46 0.682
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'log_loss', 'n_estimators': 150, 'min_samples_split': 4, 'max_depth': 10, 'ccp_alpha': 0}", 6, 0.6923999999999999, 0.013807244475274526, 0.75, 17.01528067588806)
# Elapsed time: 17.02s
#
# 42 0.683
# 43 0.695
# 44 0.681
# 45 0.699
# 46 0.677
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'log_loss', 'n_estimators': 150, 'min_samples_split': 4, 'max_depth': 10, 'ccp_alpha': 0.001}", 6, 0.687, 0.008485281374238525, 0.763, 16.46512875556946)
# Elapsed time: 16.47s
#
# 42 0.612
# 43 0.631
# 44 0.622
# 45 0.624
# 46 0.637
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'log_loss', 'n_estimators': 150, 'min_samples_split': 8, 'max_depth': 2, 'ccp_alpha': 0}", 6, 0.6252, 0.008471127433818955, 0.717, 4.241742420196533)
# Elapsed time: 4.24s
#
# 42 0.607
# 43 0.627
# 44 0.632
# 45 0.636
# 46 0.63
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'log_loss', 'n_estimators': 150, 'min_samples_split': 8, 'max_depth': 2, 'ccp_alpha': 0.001}", 6, 0.6264000000000001, 0.010131140113531162, 0.6950000000000001, 4.528793859481811)
# Elapsed time: 4.53s
#
# 42 0.66
# 43 0.681
# 44 0.691
# 45 0.67
# 46 0.666
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'log_loss', 'n_estimators': 150, 'min_samples_split': 8, 'max_depth': 6, 'ccp_alpha': 0}", 6, 0.6736, 0.011074294559925677, 0.7449999999999999, 11.177157926559449)
# Elapsed time: 11.18s
#
# 42 0.666
# 43 0.668
# 44 0.669
# 45 0.662
# 46 0.665
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'log_loss', 'n_estimators': 150, 'min_samples_split': 8, 'max_depth': 6, 'ccp_alpha': 0.001}", 6, 0.666, 0.0024494897427831805, 0.7549999999999999, 10.75524024963379)
# Elapsed time: 10.76s
#
# 42 0.673
# 43 0.702
# 44 0.706
# 45 0.701
# 46 0.682
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'log_loss', 'n_estimators': 150, 'min_samples_split': 8, 'max_depth': 10, 'ccp_alpha': 0}", 6, 0.6928, 0.012921300244170434, 0.76, 18.09835891723633)
# Elapsed time: 18.10s
#
# 42 0.688
# 43 0.708
# 44 0.685
# 45 0.692
# 46 0.684
# ('SelectFromModel', "{'threshold': -Infinity}", 'RandomForestClassifier', "{'criterion': 'log_loss', 'n_estimators': 150, 'min_samples_split': 8, 'max_depth': 10, 'ccp_alpha': 0.001}", 6, 0.6914, 0.008754427451295689, 0.767, 17.9971342086792)
# Elapsed time: 18.00s
