# %% [markdown]
# # Convergence for all datasets and all splits
#
# The results are imported from a `.json` from previously run experiments.

# %%
import json
import pandas as pd
import numpy as np

# %%
from utils.plots import plot_figures_for_cv

# %%
with open('results/l_vals.json', 'r') as file:
    l_vals = json.load(file)

# %%
for key, value in l_vals.items():
    print(f"Dataset: {key}")
    l_iwls_vals_list = l_vals[key]['iwls']
    l_sgd_vals_list = l_vals[key]['sgd']
    l_adam_vals_list = l_vals[key]['adam']
    plot_figures_for_cv(l_iwls_vals_list, l_sgd_vals_list, l_adam_vals_list)
# Out:
# Dataset: booking
# Dataset: churn
# Dataset: diabetes
# Dataset: challenger
# Dataset: jungle
# Dataset: ionosphere
# Dataset: water
# Dataset: seeds
# Dataset: sonar
