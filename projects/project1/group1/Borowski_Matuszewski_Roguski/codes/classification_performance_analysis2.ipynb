# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

sns.set_theme(rc={'figure.figsize':(8,6)})

# %%
df = pd.read_csv('classification_performance.csv')

# %%
df
# Out:
#       dataset        method      time  accuracy  random_state  iters  product
# 0    banknote          IWLS  0.003713  0.867278           420     11     True
# 1    banknote           SGD  5.771048  0.862911           420    501     True
# 2    banknote          ADAM  0.414576  0.857995           420     24     True
# 3    banknote           LDA  0.000663  0.863996           420     -1     True
# 4    banknote           QDA  0.000284  0.869974           420     -1     True
# ..        ...           ...       ...       ...           ...    ...      ...
# 583       pc1          ADAM  0.177683  0.707504           777     12    False
# 584       pc1           LDA  0.000564  0.623983           777     -1    False
# 585       pc1           QDA  0.000236  0.651332           777     -1    False
# 586       pc1  DecisionTree  0.016959  0.578892           777     -1    False
# 587       pc1  RandomForest  0.336929  0.605470           777     -1    False
#
# [588 rows x 7 columns]

# %%
sns.set_theme(style="whitegrid")
sns.boxplot(data=df[df["product"] == True], x="dataset", y="accuracy", hue="method")
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.title("Classification performance on product datasets")
plt.show()

# %%
sns.set_theme(style="whitegrid")
sns.boxplot(data=df[df["product"] == False], x="dataset", y="accuracy", hue="method")
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.xticks(rotation=45)
# set title
plt.title("Classification accuracy for non-product datasets")
plt.show()

# %%
df_true = df[df["product"] == True]

# %%
df_true.groupby(["dataset", "method"]).agg({"accuracy": [("mean_accuracy", "mean"), ("std_accuracy", "std")]}).sort_values(by=["dataset", ("accuracy", "mean_accuracy")], ascending=[True, False])
# Out:
#                            accuracy
#                       mean_accuracy std_accuracy
# dataset  method
# banknote RandomForest      0.958030     0.005898
#          DecisionTree      0.943283     0.008817
#          QDA               0.871153     0.019954
#          LDA               0.865019     0.014824
#          IWLS              0.864164     0.010765
#          SGD               0.862918     0.011852
#          ADAM              0.862916     0.009650
# kin8nm   RandomForest      0.862052     0.007974
#          QDA               0.807280     0.009780
#          IWLS              0.795499     0.007684
#          SGD               0.795444     0.009266
#          LDA               0.788103     0.011262
#          DecisionTree      0.785958     0.010781
#          ADAM              0.778413     0.007293
# phoneme  RandomForest      0.871687     0.006799
#          DecisionTree      0.829678     0.012408
#          QDA               0.802470     0.005341
# ...

# %%
df_false = df[df["product"] == False]

# %%
# display all rows
pd.set_option('display.max_rows', None)

df_false.groupby(["dataset", "method"]).agg({"accuracy": [("mean_accuracy", "mean"), ("std_accuracy", "std")]}).sort_values(by=["dataset", ("accuracy", "mean_accuracy")], ascending=[True, False])
# Out:
#                                      accuracy
#                                 mean_accuracy std_accuracy
# dataset            method
# banknote           RandomForest      0.888972     0.015046
#                    DecisionTree      0.877964     0.014600
#                    LDA               0.866418     0.012465
#                    QDA               0.863998     0.012386
#                    ADAM              0.859889     0.008805
#                    IWLS              0.854741     0.008721
#                    SGD               0.854741     0.008721
# elevators          IWLS              0.679128     0.006585
#                    SGD               0.678922     0.006841
#                    ADAM              0.674969     0.007006
#                    RandomForest      0.671148     0.009159
#                    LDA               0.653548     0.003847
#                    QDA               0.651085     0.003783
#                    DecisionTree      0.634816     0.008870
# ...
