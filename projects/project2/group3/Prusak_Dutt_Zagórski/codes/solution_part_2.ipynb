# %% [markdown]
# # Imports And Consts

# %%
RESULTS_COLUMNS = [
    "score",
    "numberOfTruePositives",
    "accuracy",
    "precision",
    "numberOfFeatures",
    "model",
    "model_parameters",
    "feature_selector",
    "selector_parameters",
]

# %%
import functions
import numpy as np
import pandas as pd
import seaborn as sns
import pickle
from sklearn.feature_selection import f_classif, mutual_info_classif
import matplotlib.pyplot as plt
from sklearn.svm import SVC

# %% [markdown]
# # Load Data

# %% [markdown]
# load the training and test data in a format specified by task description

# %%
with open("./Dataset/x_test.txt") as file:
    X_test = [[float(digit) for digit in line.split()] for line in file]


with open("./Dataset/x_train.txt") as file:
    X_train = [[float(digit) for digit in line.split()] for line in file]


with open("./Dataset/y_train.txt") as file:
    y_train = [[float(digit) for digit in line.split()] for line in file]

# %% [markdown]
# In the X_test there are 500 features and 5000 observations, y_train contains 5000 values, X_train contains 500 features and 5000 observations

# %%
print("X_test datapoints:", len(X_test), " features:", len(X_test[0]))
print("X_train datapoints:", len(X_train), " features:", len(X_train[0]))
print("y_train datapoints:", len(y_train))
# Out:
# X_test datapoints: 5000  features: 500
# X_train datapoints: 5000  features: 500
# y_train datapoints: 5000

# %% [markdown]
# # Batch 16

# %%
# %%time
# Batch 16
## Consts
RESULTS_FILENAME = "./Results/Limited/results-16"
## Experiment
### Parameters
# HistGradientBoostingClassifier
learning_rate = [0.1, 0.01]
max_depth = [2, 3, 5, None]
random_state = [42]
max_features = [3, 5, 8, 1.0]
l2_regularization = [0, 0.5, 0.8]
histGradientBoostingParameters = functions.generateParameters(
    [learning_rate, max_depth, random_state, max_features, l2_regularization], globals()
)

# LDA
solver = ["svd", "lsqr"]
shrinkage = [None, "auto"]
n_components = [3, 5, 8, None]
ldaParameters = functions.generateParameters(
    [solver, shrinkage, n_components], globals()
)


# QDA
reg_param = [0, 0.3, 0.5, 0.8]
qdaParameters = functions.generateParameters([reg_param], globals())

# KNN
n_neighbors = [3, 5, 8]
weights = ["uniform", "distance"]
p = [1, 2]
leaf_size = [15, 30, 50]
knnParameters = functions.generateParameters(
    [n_neighbors, weights, p, leaf_size], globals()
)

# SVM
C = [0.5, 1.0, 1.5]
kernel = ["linear", "rbf", "sigmoid", "poly"]
svcParameters = functions.generateParameters([C, kernel], globals())

# GradientBoostingClassifier
loss = ["exponential"]
learning_rate = [ 0.001]
n_estimators = [800]
min_samples_split = [2]
min_samples_leaf = [5, 7]
subsample = [1.0]
max_depth = [5, 8 ]
min_impurity_decrease = [1]
random_state = [42]
max_features = [None]
ccp_alpha = [0]
gradientBoostingParameters = functions.generateParameters(
    [
        loss,
        learning_rate,
        n_estimators,
        subsample,
        max_depth,
        random_state,
        max_features,
        ccp_alpha,
        min_samples_split,
        min_samples_leaf,
        min_impurity_decrease,
    ],
    globals(),
)


# MLPClassifier

activation = ["relu", "tanh"]
solver = [ "adam"]
alpha = [ 0.01]
learning_rate = [ "adaptive"]
learning_rate_init = [0.01, 0.001]
hidden_layer_sizes = [(100,), (50,), (20,)]
max_iter = [1600]
random_state = [42]
mlpClassifierParameters = functions.generateParameters(
    [
        activation,
        solver,
        alpha,
        learning_rate,
        learning_rate_init,
        hidden_layer_sizes,
        max_iter,
        random_state,
    ],
    globals()
)
# Voting?
estimators = [
    [
        (
            "1",
            functions.GradientBoostingClassifier(
                loss="exponential",
                learning_rate=0.01,
                n_estimators=200,
                random_state=42,
            ),
        ),
        ("2", functions.MLPClassifier(max_iter=800, random_state=42)),
        ("3", functions.QuadraticDiscriminantAnalysis()),
    ]
]
voting = ["soft"]

votingParameters = functions.generateParameters([estimators, voting], globals())

# AdaBoost


estimator = [functions.DecisionTreeClassifier(), 
            functions.LinearDiscriminantAnalysis(),
            functions.QuadraticDiscriminantAnalysis(),
            ]
n_estimators = [50]
learning_rate = [0.1,0.01]
random_state = [42]

adaBoostParameters = functions.generateParameters(
    [estimator, n_estimators, learning_rate, random_state], globals()
)

models = [
    # {"model": functions.ModelType.LDA, "parameters": ldaParameters},
    # {"model": functions.ModelType.QDA, "parameters": qdaParameters},
    # {"model": functions.ModelType.KNN, "parameters": knnParameters},
    # {"model": functions.ModelType.SVC, "parameters": svcParameters},
    # {
      #  "model": functions.ModelType.GradientBoosting,
       #  "parameters": gradientBoostingParameters,
    # },
    # {
    #     "model": functions.ModelType.HistGradientBoosting,
    #     "parameters": histGradientBoostingParameters,
    # },
    {"model": functions.ModelType.MLPClassifier, "parameters": mlpClassifierParameters},
    {"model": functions.ModelType.ADABoost, "parameters": adaBoostParameters},
    # {"model": functions.ModelType.Voting, "parameters": votingParameters},
]
# KBest
k = [2, 3]
score_func = [mutual_info_classif]
kBestParameters = functions.generateParameters([score_func, k], globals())

# FPR

# mutual_info_classif seems to break for FPR but maybe try to run these without StandardScaler?
score_func = [f_classif]
alpha = [0.01]
fprParameters = functions.generateParameters([score_func, alpha], globals())


# RFE
estimator = [SVC(kernel="linear")]
n_features_to_select = [2, 3]
step = [0.9]
rfeParameters = functions.generateParameters(
    [estimator, n_features_to_select, step], globals()
)


featureSelectors = [
    {"model": functions.FeatureSelectorType.KBest, "parameters": kBestParameters},
    #{"model": functions.FeatureSelectorType.FPR, "parameters": fprParameters},
    #{"model": functions.FeatureSelectorType.RFE, "parameters": rfeParameters},
]
scalers = [
    # {"model": functions.Scaler.NoScaling, "parameters": [{}]},
    # {"model": functions.Scaler.Standard, "parameters": [{}]},
    {"model": functions.Scaler.Robust, "parameters": [{}]},
]

degree = [2]

polynomialParameters = functions.generateParameters([degree], globals())

featureGenerators = [
    {"model": functions.FeatureGenerator.NoFeatureGeneration, "parameters": [{}]},
    {
        "model": functions.FeatureGenerator.Polynomial,
        "parameters": polynomialParameters,
    },
]
### Conducting the experiment
y_train_ravel = np.ravel(y_train, order="C")
y_train_ravel = y_train_ravel.astype(int)
results = functions.conductExperimentsWithScalersAndGenerators(
    models=models,
    featureSelectors=featureSelectors,
    X_orig=X_train,
    y_orig=y_train_ravel,
    scalers=scalers,
    featureGenerators=featureGenerators,
    getLimitedScore=True,
    limit=0.45,

)
with open(RESULTS_FILENAME, "wb") as f:
    pickle.dump(results, f)
## Results
with open(RESULTS_FILENAME, "rb") as input_file:
    results = pickle.load(input_file)
resultsDf = pd.DataFrame(
    results,
    columns=functions.RESULTS_COLUMNS,
)
### Detailed Results
processedResultsDf, parameters = functions.extractParameterResultsArr(
    resultsDf,
    [models, featureSelectors, scalers, featureGenerators],
    [
        "model_parameters",
        "selector_parameters",
        "scaler_parameters",
        "feature_generator_parameters",
    ],
)
functions.drawParameterResultsBarplot(processedResultsDf, parameters)
### Score/Accuracy by number of features
functions.drawResultsPerNumberOfFeatures(processedResultsDf)
### Final Results for Feature Selectors
plt.title("Final comparison of feature selectors")
sns.boxplot(data=processedResultsDf, x="feature_selector", y="score")

plt.tight_layout()
plt.show()
sns.boxplot(data=processedResultsDf,x="model",y="score",hue="feature_generator")
sns.boxplot(data=processedResultsDf,x="model",y="score",hue="scaler")
### Final Results for Models
plt.title("Final comparison of models")
sns.boxplot(data=processedResultsDf, x="model", y="score")
plt.tight_layout()
plt.show()
### Final Results
filteredDf = functions.filterDataframeByBestResults(processedResultsDf)
processedResultsDf[processedResultsDf["scaler"]==functions.Scaler.NoScaling.name].sort_values(by="score",ascending=False).head(5)
filteredDf['scaler']
filteredDf['model_parameters'].to_numpy()
filteredDf['feature_generator']
filteredDf


filteredDf = functions.filterDataframeByBestResults(processedResultsDf)
processedResultsDf[processedResultsDf["scaler"]==functions.Scaler.NoScaling.name].sort_values(by="score",ascending=False).head(5)
filteredDf['scaler']
filteredDf['model_parameters'].to_numpy()
filteredDf['feature_generator']
filteredDf
# Out:
# Performed Experiment 1/72(approx) took (s): model: 0.94 selector 10.11 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002C072FC5760>, 'k': 2} ModelType.MLPClassifier {'activation': 'relu', 'solver': 'adam', 'alpha': 0.01, 'learning_rate': 'adaptive', 'learning_rate_init': 0.01, 'hidden_layer_sizes': (100,), 'max_iter': 1600, 'random_state': 42} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {}
# Performed Experiment 2/72(approx) took (s): model: 0.6 selector 10.11 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002C072FC5760>, 'k': 2} ModelType.MLPClassifier {'activation': 'relu', 'solver': 'adam', 'alpha': 0.01, 'learning_rate': 'adaptive', 'learning_rate_init': 0.01, 'hidden_layer_sizes': (50,), 'max_iter': 1600, 'random_state': 42} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {}
# Performed Experiment 3/72(approx) took (s): model: 0.1 selector 10.11 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002C072FC5760>, 'k': 2} ModelType.MLPClassifier {'activation': 'relu', 'solver': 'adam', 'alpha': 0.01, 'learning_rate': 'adaptive', 'learning_rate_init': 0.01, 'hidden_layer_sizes': (20,), 'max_iter': 1600, 'random_state': 42} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {}
# Performed Experiment 4/72(approx) took (s): model: 0.88 selector 10.11 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002C072FC5760>, 'k': 2} ModelType.MLPClassifier {'activation': 'relu', 'solver': 'adam', 'alpha': 0.01, 'learning_rate': 'adaptive', 'learning_rate_init': 0.001, 'hidden_layer_sizes': (100,), 'max_iter': 1600, 'random_state': 42} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {}
# Performed Experiment 5/72(approx) took (s): model: 0.46 selector 10.11 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002C072FC5760>, 'k': 2} ModelType.MLPClassifier {'activation': 'relu', 'solver': 'adam', 'alpha': 0.01, 'learning_rate': 'adaptive', 'learning_rate_init': 0.001, 'hidden_layer_sizes': (50,), 'max_iter': 1600, 'random_state': 42} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {}
# Performed Experiment 6/72(approx) took (s): model: 0.17 selector 10.11 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002C072FC5760>, 'k': 2} ModelType.MLPClassifier {'activation': 'relu', 'solver': 'adam', 'alpha': 0.01, 'learning_rate': 'adaptive', 'learning_rate_init': 0.001, 'hidden_layer_sizes': (20,), 'max_iter': 1600, 'random_state': 42} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {}
# Performed Experiment 7/72(approx) took (s): model: 0.8 selector 10.11 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002C072FC5760>, 'k': 2} ModelType.MLPClassifier {'activation': 'tanh', 'solver': 'adam', 'alpha': 0.01, 'learning_rate': 'adaptive', 'learning_rate_init': 0.01, 'hidden_layer_sizes': (100,), 'max_iter': 1600, 'random_state': 42} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {}
# Performed Experiment 8/72(approx) took (s): model: 0.65 selector 10.11 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002C072FC5760>, 'k': 2} ModelType.MLPClassifier {'activation': 'tanh', 'solver': 'adam', 'alpha': 0.01, 'learning_rate': 'adaptive', 'learning_rate_init': 0.01, 'hidden_layer_sizes': (50,), 'max_iter': 1600, 'random_state': 42} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {}
# Performed Experiment 9/72(approx) took (s): model: 0.13 selector 10.11 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002C072FC5760>, 'k': 2} ModelType.MLPClassifier {'activation': 'tanh', 'solver': 'adam', 'alpha': 0.01, 'learning_rate': 'adaptive', 'learning_rate_init': 0.01, 'hidden_layer_sizes': (20,), 'max_iter': 1600, 'random_state': 42} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {}
# Performed Experiment 10/72(approx) took (s): model: 3.43 selector 10.11 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002C072FC5760>, 'k': 2} ModelType.MLPClassifier {'activation': 'tanh', 'solver': 'adam', 'alpha': 0.01, 'learning_rate': 'adaptive', 'learning_rate_init': 0.001, 'hidden_layer_sizes': (100,), 'max_iter': 1600, 'random_state': 42} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {}
# Performed Experiment 11/72(approx) took (s): model: 1.88 selector 10.11 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002C072FC5760>, 'k': 2} ModelType.MLPClassifier {'activation': 'tanh', 'solver': 'adam', 'alpha': 0.01, 'learning_rate': 'adaptive', 'learning_rate_init': 0.001, 'hidden_layer_sizes': (50,), 'max_iter': 1600, 'random_state': 42} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {}
# Performed Experiment 12/72(approx) took (s): model: 0.38 selector 10.11 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002C072FC5760>, 'k': 2} ModelType.MLPClassifier {'activation': 'tanh', 'solver': 'adam', 'alpha': 0.01, 'learning_rate': 'adaptive', 'learning_rate_init': 0.001, 'hidden_layer_sizes': (20,), 'max_iter': 1600, 'random_state': 42} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {}
# Performed Experiment 13/72(approx) took (s): model: 0.03 selector 10.11 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002C072FC5760>, 'k': 2} ModelType.ADABoost {'estimator': DecisionTreeClassifier(), 'n_estimators': 50, 'learning_rate': 0.1, 'random_state': 42} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {}
# Performed Experiment 14/72(approx) took (s): model: 0.03 selector 10.11 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002C072FC5760>, 'k': 2} ModelType.ADABoost {'estimator': DecisionTreeClassifier(), 'n_estimators': 50, 'learning_rate': 0.01, 'random_state': 42} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {}
# !!!Experiment failed for: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002C072FC5760>, 'k': 2} ModelType.ADABoost {'estimator': LinearDiscriminantAnalysis(), 'n_estimators': 50, 'learning_rate': 0.1, 'random_state': 42} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {} LinearDiscriminantAnalysis doesn't support sample_weight.
# !!!Experiment failed for: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002C072FC5760>, 'k': 2} ModelType.ADABoost {'estimator': LinearDiscriminantAnalysis(), 'n_estimators': 50, 'learning_rate': 0.01, 'random_state': 42} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {} LinearDiscriminantAnalysis doesn't support sample_weight.
# !!!Experiment failed for: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002C072FC5760>, 'k': 2} ModelType.ADABoost {'estimator': QuadraticDiscriminantAnalysis(), 'n_estimators': 50, 'learning_rate': 0.1, 'random_state': 42} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {} QuadraticDiscriminantAnalysis doesn't support sample_weight.
# !!!Experiment failed for: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002C072FC5760>, 'k': 2} ModelType.ADABoost {'estimator': QuadraticDiscriminantAnalysis(), 'n_estimators': 50, 'learning_rate': 0.01, 'random_state': 42} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {} QuadraticDiscriminantAnalysis doesn't support sample_weight.
# c:\Users\prusak.patryk\Projects\Uni\advml-proj-2\.venv\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\prusak.patryk\Projects\Uni\advml-proj-2\.venv\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\prusak.patryk\Projects\Uni\advml-proj-2\.venv\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\prusak.patryk\Projects\Uni\advml-proj-2\.venv\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\prusak.patryk\Projects\Uni\advml-proj-2\.venv\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\prusak.patryk\Projects\Uni\advml-proj-2\.venv\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# Performed Experiment 15/72(approx) took (s): model: 1.13 selector 10.11 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002C072FC5760>, 'k': 2} ModelType.MLPClassifier {'activation': 'relu', 'solver': 'adam', 'alpha': 0.01, 'learning_rate': 'adaptive', 'learning_rate_init': 0.01, 'hidden_layer_sizes': (100,), 'max_iter': 1600, 'random_state': 42} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2}
# Performed Experiment 16/72(approx) took (s): model: 0.83 selector 10.11 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002C072FC5760>, 'k': 2} ModelType.MLPClassifier {'activation': 'relu', 'solver': 'adam', 'alpha': 0.01, 'learning_rate': 'adaptive', 'learning_rate_init': 0.01, 'hidden_layer_sizes': (50,), 'max_iter': 1600, 'random_state': 42} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2}
# Performed Experiment 17/72(approx) took (s): model: 0.17 selector 10.11 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002C072FC5760>, 'k': 2} ModelType.MLPClassifier {'activation': 'relu', 'solver': 'adam', 'alpha': 0.01, 'learning_rate': 'adaptive', 'learning_rate_init': 0.01, 'hidden_layer_sizes': (20,), 'max_iter': 1600, 'random_state': 42} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2}
# Performed Experiment 18/72(approx) took (s): model: 2.79 selector 10.11 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002C072FC5760>, 'k': 2} ModelType.MLPClassifier {'activation': 'relu', 'solver': 'adam', 'alpha': 0.01, 'learning_rate': 'adaptive', 'learning_rate_init': 0.001, 'hidden_layer_sizes': (100,), 'max_iter': 1600, 'random_state': 42} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2}
# Performed Experiment 19/72(approx) took (s): model: 0.69 selector 10.11 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002C072FC5760>, 'k': 2} ModelType.MLPClassifier {'activation': 'relu', 'solver': 'adam', 'alpha': 0.01, 'learning_rate': 'adaptive', 'learning_rate_init': 0.001, 'hidden_layer_sizes': (50,), 'max_iter': 1600, 'random_state': 42} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2}
# Performed Experiment 20/72(approx) took (s): model: 0.3 selector 10.11 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002C072FC5760>, 'k': 2} ModelType.MLPClassifier {'activation': 'relu', 'solver': 'adam', 'alpha': 0.01, 'learning_rate': 'adaptive', 'learning_rate_init': 0.001, 'hidden_layer_sizes': (20,), 'max_iter': 1600, 'random_state': 42} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2}
# Performed Experiment 21/72(approx) took (s): model: 0.73 selector 10.11 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002C072FC5760>, 'k': 2} ModelType.MLPClassifier {'activation': 'tanh', 'solver': 'adam', 'alpha': 0.01, 'learning_rate': 'adaptive', 'learning_rate_init': 0.01, 'hidden_layer_sizes': (100,), 'max_iter': 1600, 'random_state': 42} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2}
# Performed Experiment 22/72(approx) took (s): model: 0.57 selector 10.11 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002C072FC5760>, 'k': 2} ModelType.MLPClassifier {'activation': 'tanh', 'solver': 'adam', 'alpha': 0.01, 'learning_rate': 'adaptive', 'learning_rate_init': 0.01, 'hidden_layer_sizes': (50,), 'max_iter': 1600, 'random_state': 42} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2}
# Performed Experiment 23/72(approx) took (s): model: 0.13 selector 10.11 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002C072FC5760>, 'k': 2} ModelType.MLPClassifier {'activation': 'tanh', 'solver': 'adam', 'alpha': 0.01, 'learning_rate': 'adaptive', 'learning_rate_init': 0.01, 'hidden_layer_sizes': (20,), 'max_iter': 1600, 'random_state': 42} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2}
# Performed Experiment 24/72(approx) took (s): model: 0.61 selector 10.11 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002C072FC5760>, 'k': 2} ModelType.MLPClassifier {'activation': 'tanh', 'solver': 'adam', 'alpha': 0.01, 'learning_rate': 'adaptive', 'learning_rate_init': 0.001, 'hidden_layer_sizes': (100,), 'max_iter': 1600, 'random_state': 42} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2}
# Performed Experiment 25/72(approx) took (s): model: 0.67 selector 10.11 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002C072FC5760>, 'k': 2} ModelType.MLPClassifier {'activation': 'tanh', 'solver': 'adam', 'alpha': 0.01, 'learning_rate': 'adaptive', 'learning_rate_init': 0.001, 'hidden_layer_sizes': (50,), 'max_iter': 1600, 'random_state': 42} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2}
# Performed Experiment 26/72(approx) took (s): model: 0.1 selector 10.11 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002C072FC5760>, 'k': 2} ModelType.MLPClassifier {'activation': 'tanh', 'solver': 'adam', 'alpha': 0.01, 'learning_rate': 'adaptive', 'learning_rate_init': 0.001, 'hidden_layer_sizes': (20,), 'max_iter': 1600, 'random_state': 42} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2}
# Performed Experiment 27/72(approx) took (s): model: 0.05 selector 10.11 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002C072FC5760>, 'k': 2} ModelType.ADABoost {'estimator': DecisionTreeClassifier(), 'n_estimators': 50, 'learning_rate': 0.1, 'random_state': 42} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2}
# Performed Experiment 28/72(approx) took (s): model: 0.03 selector 10.11 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002C072FC5760>, 'k': 2} ModelType.ADABoost {'estimator': DecisionTreeClassifier(), 'n_estimators': 50, 'learning_rate': 0.01, 'random_state': 42} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2}
# !!!Experiment failed for: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002C072FC5760>, 'k': 2} ModelType.ADABoost {'estimator': LinearDiscriminantAnalysis(), 'n_estimators': 50, 'learning_rate': 0.1, 'random_state': 42} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2} LinearDiscriminantAnalysis doesn't support sample_weight.
# !!!Experiment failed for: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002C072FC5760>, 'k': 2} ModelType.ADABoost {'estimator': LinearDiscriminantAnalysis(), 'n_estimators': 50, 'learning_rate': 0.01, 'random_state': 42} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2} LinearDiscriminantAnalysis doesn't support sample_weight.
# !!!Experiment failed for: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002C072FC5760>, 'k': 2} ModelType.ADABoost {'estimator': QuadraticDiscriminantAnalysis(), 'n_estimators': 50, 'learning_rate': 0.1, 'random_state': 42} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2} QuadraticDiscriminantAnalysis doesn't support sample_weight.
# !!!Experiment failed for: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002C072FC5760>, 'k': 2} ModelType.ADABoost {'estimator': QuadraticDiscriminantAnalysis(), 'n_estimators': 50, 'learning_rate': 0.01, 'random_state': 42} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2} QuadraticDiscriminantAnalysis doesn't support sample_weight.
# c:\Users\prusak.patryk\Projects\Uni\advml-proj-2\.venv\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\prusak.patryk\Projects\Uni\advml-proj-2\.venv\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\prusak.patryk\Projects\Uni\advml-proj-2\.venv\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\prusak.patryk\Projects\Uni\advml-proj-2\.venv\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\prusak.patryk\Projects\Uni\advml-proj-2\.venv\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\prusak.patryk\Projects\Uni\advml-proj-2\.venv\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# Performed Experiment 29/72(approx) took (s): model: 1.03 selector 8.6 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002C072FC5760>, 'k': 3} ModelType.MLPClassifier {'activation': 'relu', 'solver': 'adam', 'alpha': 0.01, 'learning_rate': 'adaptive', 'learning_rate_init': 0.01, 'hidden_layer_sizes': (100,), 'max_iter': 1600, 'random_state': 42} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {}
# Performed Experiment 30/72(approx) took (s): model: 0.65 selector 8.6 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002C072FC5760>, 'k': 3} ModelType.MLPClassifier {'activation': 'relu', 'solver': 'adam', 'alpha': 0.01, 'learning_rate': 'adaptive', 'learning_rate_init': 0.01, 'hidden_layer_sizes': (50,), 'max_iter': 1600, 'random_state': 42} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {}
# Performed Experiment 31/72(approx) took (s): model: 0.13 selector 8.6 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002C072FC5760>, 'k': 3} ModelType.MLPClassifier {'activation': 'relu', 'solver': 'adam', 'alpha': 0.01, 'learning_rate': 'adaptive', 'learning_rate_init': 0.01, 'hidden_layer_sizes': (20,), 'max_iter': 1600, 'random_state': 42} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {}
# Performed Experiment 32/72(approx) took (s): model: 2.0 selector 8.6 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002C072FC5760>, 'k': 3} ModelType.MLPClassifier {'activation': 'relu', 'solver': 'adam', 'alpha': 0.01, 'learning_rate': 'adaptive', 'learning_rate_init': 0.001, 'hidden_layer_sizes': (100,), 'max_iter': 1600, 'random_state': 42} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {}
# Performed Experiment 33/72(approx) took (s): model: 1.02 selector 8.6 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002C072FC5760>, 'k': 3} ModelType.MLPClassifier {'activation': 'relu', 'solver': 'adam', 'alpha': 0.01, 'learning_rate': 'adaptive', 'learning_rate_init': 0.001, 'hidden_layer_sizes': (50,), 'max_iter': 1600, 'random_state': 42} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {}
# Performed Experiment 34/72(approx) took (s): model: 0.29 selector 8.6 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002C072FC5760>, 'k': 3} ModelType.MLPClassifier {'activation': 'relu', 'solver': 'adam', 'alpha': 0.01, 'learning_rate': 'adaptive', 'learning_rate_init': 0.001, 'hidden_layer_sizes': (20,), 'max_iter': 1600, 'random_state': 42} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {}
# Performed Experiment 35/72(approx) took (s): model: 0.81 selector 8.6 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002C072FC5760>, 'k': 3} ModelType.MLPClassifier {'activation': 'tanh', 'solver': 'adam', 'alpha': 0.01, 'learning_rate': 'adaptive', 'learning_rate_init': 0.01, 'hidden_layer_sizes': (100,), 'max_iter': 1600, 'random_state': 42} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {}
# Performed Experiment 36/72(approx) took (s): model: 0.91 selector 8.6 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002C072FC5760>, 'k': 3} ModelType.MLPClassifier {'activation': 'tanh', 'solver': 'adam', 'alpha': 0.01, 'learning_rate': 'adaptive', 'learning_rate_init': 0.01, 'hidden_layer_sizes': (50,), 'max_iter': 1600, 'random_state': 42} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {}
# Performed Experiment 37/72(approx) took (s): model: 0.15 selector 8.6 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002C072FC5760>, 'k': 3} ModelType.MLPClassifier {'activation': 'tanh', 'solver': 'adam', 'alpha': 0.01, 'learning_rate': 'adaptive', 'learning_rate_init': 0.01, 'hidden_layer_sizes': (20,), 'max_iter': 1600, 'random_state': 42} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {}
# Performed Experiment 38/72(approx) took (s): model: 3.61 selector 8.6 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002C072FC5760>, 'k': 3} ModelType.MLPClassifier {'activation': 'tanh', 'solver': 'adam', 'alpha': 0.01, 'learning_rate': 'adaptive', 'learning_rate_init': 0.001, 'hidden_layer_sizes': (100,), 'max_iter': 1600, 'random_state': 42} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {}
# Performed Experiment 39/72(approx) took (s): model: 2.38 selector 8.6 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002C072FC5760>, 'k': 3} ModelType.MLPClassifier {'activation': 'tanh', 'solver': 'adam', 'alpha': 0.01, 'learning_rate': 'adaptive', 'learning_rate_init': 0.001, 'hidden_layer_sizes': (50,), 'max_iter': 1600, 'random_state': 42} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {}
# Performed Experiment 40/72(approx) took (s): model: 0.77 selector 8.6 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002C072FC5760>, 'k': 3} ModelType.MLPClassifier {'activation': 'tanh', 'solver': 'adam', 'alpha': 0.01, 'learning_rate': 'adaptive', 'learning_rate_init': 0.001, 'hidden_layer_sizes': (20,), 'max_iter': 1600, 'random_state': 42} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {}
# Performed Experiment 41/72(approx) took (s): model: 0.07 selector 8.6 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002C072FC5760>, 'k': 3} ModelType.ADABoost {'estimator': DecisionTreeClassifier(), 'n_estimators': 50, 'learning_rate': 0.1, 'random_state': 42} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {}
# Performed Experiment 42/72(approx) took (s): model: 0.07 selector 8.6 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002C072FC5760>, 'k': 3} ModelType.ADABoost {'estimator': DecisionTreeClassifier(), 'n_estimators': 50, 'learning_rate': 0.01, 'random_state': 42} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {}
# !!!Experiment failed for: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002C072FC5760>, 'k': 3} ModelType.ADABoost {'estimator': LinearDiscriminantAnalysis(), 'n_estimators': 50, 'learning_rate': 0.1, 'random_state': 42} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {} LinearDiscriminantAnalysis doesn't support sample_weight.
# !!!Experiment failed for: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002C072FC5760>, 'k': 3} ModelType.ADABoost {'estimator': LinearDiscriminantAnalysis(), 'n_estimators': 50, 'learning_rate': 0.01, 'random_state': 42} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {} LinearDiscriminantAnalysis doesn't support sample_weight.
# !!!Experiment failed for: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002C072FC5760>, 'k': 3} ModelType.ADABoost {'estimator': QuadraticDiscriminantAnalysis(), 'n_estimators': 50, 'learning_rate': 0.1, 'random_state': 42} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {} QuadraticDiscriminantAnalysis doesn't support sample_weight.
# !!!Experiment failed for: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002C072FC5760>, 'k': 3} ModelType.ADABoost {'estimator': QuadraticDiscriminantAnalysis(), 'n_estimators': 50, 'learning_rate': 0.01, 'random_state': 42} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {} QuadraticDiscriminantAnalysis doesn't support sample_weight.
# c:\Users\prusak.patryk\Projects\Uni\advml-proj-2\.venv\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\prusak.patryk\Projects\Uni\advml-proj-2\.venv\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\prusak.patryk\Projects\Uni\advml-proj-2\.venv\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\prusak.patryk\Projects\Uni\advml-proj-2\.venv\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\prusak.patryk\Projects\Uni\advml-proj-2\.venv\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\prusak.patryk\Projects\Uni\advml-proj-2\.venv\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# Performed Experiment 43/72(approx) took (s): model: 1.44 selector 8.6 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002C072FC5760>, 'k': 3} ModelType.MLPClassifier {'activation': 'relu', 'solver': 'adam', 'alpha': 0.01, 'learning_rate': 'adaptive', 'learning_rate_init': 0.01, 'hidden_layer_sizes': (100,), 'max_iter': 1600, 'random_state': 42} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2}
# Performed Experiment 44/72(approx) took (s): model: 1.33 selector 8.6 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002C072FC5760>, 'k': 3} ModelType.MLPClassifier {'activation': 'relu', 'solver': 'adam', 'alpha': 0.01, 'learning_rate': 'adaptive', 'learning_rate_init': 0.01, 'hidden_layer_sizes': (50,), 'max_iter': 1600, 'random_state': 42} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2}
# Performed Experiment 45/72(approx) took (s): model: 0.12 selector 8.6 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002C072FC5760>, 'k': 3} ModelType.MLPClassifier {'activation': 'relu', 'solver': 'adam', 'alpha': 0.01, 'learning_rate': 'adaptive', 'learning_rate_init': 0.01, 'hidden_layer_sizes': (20,), 'max_iter': 1600, 'random_state': 42} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2}
# Performed Experiment 46/72(approx) took (s): model: 5.11 selector 8.6 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002C072FC5760>, 'k': 3} ModelType.MLPClassifier {'activation': 'relu', 'solver': 'adam', 'alpha': 0.01, 'learning_rate': 'adaptive', 'learning_rate_init': 0.001, 'hidden_layer_sizes': (100,), 'max_iter': 1600, 'random_state': 42} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2}
# Performed Experiment 47/72(approx) took (s): model: 3.32 selector 8.6 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002C072FC5760>, 'k': 3} ModelType.MLPClassifier {'activation': 'relu', 'solver': 'adam', 'alpha': 0.01, 'learning_rate': 'adaptive', 'learning_rate_init': 0.001, 'hidden_layer_sizes': (50,), 'max_iter': 1600, 'random_state': 42} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2}
# Performed Experiment 48/72(approx) took (s): model: 0.69 selector 8.6 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002C072FC5760>, 'k': 3} ModelType.MLPClassifier {'activation': 'relu', 'solver': 'adam', 'alpha': 0.01, 'learning_rate': 'adaptive', 'learning_rate_init': 0.001, 'hidden_layer_sizes': (20,), 'max_iter': 1600, 'random_state': 42} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2}
# Performed Experiment 49/72(approx) took (s): model: 2.25 selector 8.6 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002C072FC5760>, 'k': 3} ModelType.MLPClassifier {'activation': 'tanh', 'solver': 'adam', 'alpha': 0.01, 'learning_rate': 'adaptive', 'learning_rate_init': 0.01, 'hidden_layer_sizes': (100,), 'max_iter': 1600, 'random_state': 42} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2}
# Performed Experiment 50/72(approx) took (s): model: 2.16 selector 8.6 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002C072FC5760>, 'k': 3} ModelType.MLPClassifier {'activation': 'tanh', 'solver': 'adam', 'alpha': 0.01, 'learning_rate': 'adaptive', 'learning_rate_init': 0.01, 'hidden_layer_sizes': (50,), 'max_iter': 1600, 'random_state': 42} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2}
# Performed Experiment 51/72(approx) took (s): model: 1.88 selector 8.6 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002C072FC5760>, 'k': 3} ModelType.MLPClassifier {'activation': 'tanh', 'solver': 'adam', 'alpha': 0.01, 'learning_rate': 'adaptive', 'learning_rate_init': 0.01, 'hidden_layer_sizes': (20,), 'max_iter': 1600, 'random_state': 42} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2}
# Performed Experiment 52/72(approx) took (s): model: 1.28 selector 8.6 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002C072FC5760>, 'k': 3} ModelType.MLPClassifier {'activation': 'tanh', 'solver': 'adam', 'alpha': 0.01, 'learning_rate': 'adaptive', 'learning_rate_init': 0.001, 'hidden_layer_sizes': (100,), 'max_iter': 1600, 'random_state': 42} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2}
# Performed Experiment 53/72(approx) took (s): model: 1.09 selector 8.6 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002C072FC5760>, 'k': 3} ModelType.MLPClassifier {'activation': 'tanh', 'solver': 'adam', 'alpha': 0.01, 'learning_rate': 'adaptive', 'learning_rate_init': 0.001, 'hidden_layer_sizes': (50,), 'max_iter': 1600, 'random_state': 42} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2}
# Performed Experiment 54/72(approx) took (s): model: 0.86 selector 8.6 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002C072FC5760>, 'k': 3} ModelType.MLPClassifier {'activation': 'tanh', 'solver': 'adam', 'alpha': 0.01, 'learning_rate': 'adaptive', 'learning_rate_init': 0.001, 'hidden_layer_sizes': (20,), 'max_iter': 1600, 'random_state': 42} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2}
# c:\Users\prusak.patryk\Projects\Uni\advml-proj-2\.venv\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# Performed Experiment 55/72(approx) took (s): model: 0.21 selector 8.6 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002C072FC5760>, 'k': 3} ModelType.ADABoost {'estimator': DecisionTreeClassifier(), 'n_estimators': 50, 'learning_rate': 0.1, 'random_state': 42} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2}
# c:\Users\prusak.patryk\Projects\Uni\advml-proj-2\.venv\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# Performed Experiment 56/72(approx) took (s): model: 0.31 selector 8.6 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002C072FC5760>, 'k': 3} ModelType.ADABoost {'estimator': DecisionTreeClassifier(), 'n_estimators': 50, 'learning_rate': 0.01, 'random_state': 42} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2}
# !!!Experiment failed for: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002C072FC5760>, 'k': 3} ModelType.ADABoost {'estimator': LinearDiscriminantAnalysis(), 'n_estimators': 50, 'learning_rate': 0.1, 'random_state': 42} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2} LinearDiscriminantAnalysis doesn't support sample_weight.
# !!!Experiment failed for: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002C072FC5760>, 'k': 3} ModelType.ADABoost {'estimator': LinearDiscriminantAnalysis(), 'n_estimators': 50, 'learning_rate': 0.01, 'random_state': 42} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2} LinearDiscriminantAnalysis doesn't support sample_weight.
# !!!Experiment failed for: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002C072FC5760>, 'k': 3} ModelType.ADABoost {'estimator': QuadraticDiscriminantAnalysis(), 'n_estimators': 50, 'learning_rate': 0.1, 'random_state': 42} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2} QuadraticDiscriminantAnalysis doesn't support sample_weight.
# !!!Experiment failed for: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002C072FC5760>, 'k': 3} ModelType.ADABoost {'estimator': QuadraticDiscriminantAnalysis(), 'n_estimators': 50, 'learning_rate': 0.01, 'random_state': 42} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2} QuadraticDiscriminantAnalysis doesn't support sample_weight.
# c:\Users\prusak.patryk\Projects\Uni\advml-proj-2\.venv\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\prusak.patryk\Projects\Uni\advml-proj-2\.venv\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\prusak.patryk\Projects\Uni\advml-proj-2\.venv\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\prusak.patryk\Projects\Uni\advml-proj-2\.venv\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File <timed exec>:226
#
# File c:\Users\prusak.patryk\Projects\Uni\advml-proj-2\functions.py:913, in drawParameterResultsBarplot(resultsDf, parameters)
#     908 if (
#     909     parameter["parameterColumnName"]
#     910     == RESULTS_COLUMNS[len(RESULTS_COLUMNS) - 1]
#     911 ):
#     912     plt.title("Score for parameter " + parameter["parameterName"])
# --> 913     sns.barplot(
#     914         data=resultsDf,
#     915         x="model",
#     916         y="score",
#     917         hue=resultsDf[
#     918             [
#     919                 "feature_selector",
#     920                 getParameterName(
#     921                     parameter["parameterColumnName"], parameter["parameterName"]
#     922                 ),
#     923             ]
#     924         ].apply(tuple, axis=1),
#     925     )
#     927     plt.tight_layout()
#     928     plt.show()
#
# File c:\Users\prusak.patryk\Projects\Uni\advml-proj-2\.venv\Lib\site-packages\seaborn\categorical.py:2380, in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, seed, units, weights, orient, color, palette, saturation, fill, hue_norm, width, dodge, gap, log_scale, native_scale, formatter, legend, capsize, err_kws, ci, errcolor, errwidth, ax, **kwargs)
#    2377 # Deprecations to remove in v0.15.0.
#    2378 err_kws, capsize = p._err_kws_backcompat(err_kws, errcolor, errwidth, capsize)
# -> 2380 p.plot_bars(
#    2381     aggregator=aggregator,
#    2382     dodge=dodge,
#    2383     width=width,
#    2384     gap=gap,
#    2385     color=color,
#    2386     fill=fill,
#    2387     capsize=capsize,
#    2388     err_kws=err_kws,
#    2389     plot_kws=kwargs,
#    2390 )
#    2392 p._add_axis_labels(ax)
#    2393 p._adjust_cat_axis(ax, axis=p.orient)
#
# File c:\Users\prusak.patryk\Projects\Uni\advml-proj-2\.venv\Lib\site-packages\seaborn\categorical.py:1288, in _CategoricalPlotter.plot_bars(self, aggregator, dodge, gap, width, fill, color, capsize, err_kws, plot_kws)
#    1286 agg_data["width"] = width * self._native_width
#    1287 if dodge:
# -> 1288     self._dodge(sub_vars, agg_data)
#    1289 if gap:
#    1290     agg_data["width"] *= 1 - gap
#
# File c:\Users\prusak.patryk\Projects\Uni\advml-proj-2\.venv\Lib\site-packages\seaborn\categorical.py:401, in _CategoricalPlotter._dodge(self, keys, data)
#     396 if "hue" not in self.variables:
#     397     # Short-circuit if hue variable was not assigned
#     398     # We could potentially warn when hue=None, dodge=True, user may be confused
#     399     # But I think it's fine to just treat it as a no-op.
#     400     return
# --> 401 hue_idx = self._hue_map.levels.index(keys["hue"])
#     402 n = len(self._hue_map.levels)
#     403 data["width"] /= n
#
# File missing.pyx:392, in pandas._libs.missing.NAType.__bool__()
#
# TypeError: boolean value of NA is ambiguous

# %%
from sklearn.decomposition import PCA

# %%
y_train_ravel = np.ravel(y_train, order="C")
y_train_ravel = y_train_ravel.astype(int)
from sklearn.model_selection import train_test_split

# selector = functions.SelectKBest(score_func=mutual_info_classif,k=2)
selector = functions.PCA(n_components=5, random_state=42)

X_new = selector.fit_transform(X_train, y_train_ravel)
X_new = functions.RobustScaler().fit_transform(X_new, y_train_ravel)
X_t, X_te, y_t, y_te = train_test_split(
    X_new, y_train_ravel, random_state=42, test_size=0.33
)

# %%
activation = ["relu"]
solver = ["adam"]
alpha = [0.01]
learning_rate = ["adaptive"]
learning_rate_init = [0.001]
hidden_layer_sizes = [(100,)]
max_iter = [1600]
random_state = [42]
mlpClassifierParameters = functions.generateParameters(
    [
        activation,
        solver,
        alpha,
        learning_rate,
        learning_rate_init,
        hidden_layer_sizes,
        max_iter,
        random_state,
    ],
    globals(),
)
clf = functions.MLPClassifier(**mlpClassifierParameters[0])
# clf = functions.LinearDiscriminantAnalysis()
clf.fit(X_t, y_t)
ypred = clf.predict_proba(X_te)
functions.getScoreLimited(y_te, ypred, len(X_new[0]), 0.45)
# Out:
# (195, 0.290519877675841)

# %% [markdown]
# # Batch 17

# %%
# %%time
# Batch 16
## Consts
RESULTS_FILENAME = "./Results/Limited/results-16"
## Experiment
### Parameters
# HistGradientBoostingClassifier
learning_rate = [0.1, 0.01]
max_depth = [2, 3, 5, None]
random_state = [42]
max_features = [3, 5, 8, 1.0]
l2_regularization = [0, 0.5, 0.8]
histGradientBoostingParameters = functions.generateParameters(
    [learning_rate, max_depth, random_state, max_features, l2_regularization], globals()
)

# LDA
solver = ["svd", "lsqr"]
shrinkage = [None, "auto"]
n_components = [3, 5, 8, None]
ldaParameters = functions.generateParameters(
    [solver, shrinkage, n_components], globals()
)


# QDA
reg_param = [0, 0.3, 0.5, 0.8]
qdaParameters = functions.generateParameters([reg_param], globals())

# KNN
n_neighbors = [3, 5, 8]
weights = ["uniform", "distance"]
p = [1, 2]
leaf_size = [15, 30, 50]
knnParameters = functions.generateParameters(
    [n_neighbors, weights, p, leaf_size], globals()
)

# SVM
C = [0.5, 1.0, 1.5]
kernel = ["linear", "rbf", "sigmoid", "poly"]
svcParameters = functions.generateParameters([C, kernel], globals())

# GradientBoostingClassifier
loss = ["exponential"]
learning_rate = [ 0.001]
n_estimators = [800]
min_samples_split = [2]
min_samples_leaf = [5, 7]
subsample = [1.0]
max_depth = [5, 8 ]
min_impurity_decrease = [1]
random_state = [42]
max_features = [None]
ccp_alpha = [0]
gradientBoostingParameters = functions.generateParameters(
    [
        loss,
        learning_rate,
        n_estimators,
        subsample,
        max_depth,
        random_state,
        max_features,
        ccp_alpha,
        min_samples_split,
        min_samples_leaf,
        min_impurity_decrease,
    ],
    globals(),
)


# MLPClassifier

activation = ["relu", "tanh"]
solver = [ "adam"]
alpha = [ 0.01]
learning_rate = [ "adaptive"]
learning_rate_init = [0.01, 0.001]
hidden_layer_sizes = [(100,), (50,), (20,)]
max_iter = [1600]
random_state = [42]
mlpClassifierParameters = functions.generateParameters(
    [
        activation,
        solver,
        alpha,
        learning_rate,
        learning_rate_init,
        hidden_layer_sizes,
        max_iter,
        random_state,
    ],
    globals()
)
# Voting?
estimators = [
    [
        (
            "1",
            functions.GradientBoostingClassifier(
                loss="exponential",
                learning_rate=0.01,
                n_estimators=200,
                random_state=42,
            ),
        ),
        ("2", functions.MLPClassifier(max_iter=800, random_state=42)),
        ("3", functions.QuadraticDiscriminantAnalysis()),
    ]
]
voting = ["soft"]

votingParameters = functions.generateParameters([estimators, voting], globals())

# AdaBoost


estimator = [functions.DecisionTreeClassifier(), 
            functions.LinearDiscriminantAnalysis(),
            functions.QuadraticDiscriminantAnalysis(),
            ]
n_estimators = [50]
learning_rate = [0.1,0.01]
random_state = [42]

adaBoostParameters = functions.generateParameters(
    [estimator, n_estimators, learning_rate, random_state], globals()
)

models = [
    {"model": functions.ModelType.LDA, "parameters": ldaParameters},
    {"model": functions.ModelType.QDA, "parameters": qdaParameters},
    # {"model": functions.ModelType.KNN, "parameters": knnParameters},
    # {"model": functions.ModelType.SVC, "parameters": svcParameters},
    # {
      #  "model": functions.ModelType.GradientBoosting,
       #  "parameters": gradientBoostingParameters,
    # },
    # {
    #     "model": functions.ModelType.HistGradientBoosting,
    #     "parameters": histGradientBoostingParameters,
    # },
    {"model": functions.ModelType.MLPClassifier, "parameters": mlpClassifierParameters},
    {"model": functions.ModelType.ADABoost, "parameters": adaBoostParameters},
    # {"model": functions.ModelType.Voting, "parameters": votingParameters},
]
# KBest
k = [2, 3]
score_func = [mutual_info_classif]
kBestParameters = functions.generateParameters([score_func, k], globals())

# FPR

# mutual_info_classif seems to break for FPR but maybe try to run these without StandardScaler?
score_func = [f_classif]
alpha = [0.01]
fprParameters = functions.generateParameters([score_func, alpha], globals())


# RFE
estimator = [SVC(kernel="linear")]
n_features_to_select = [2, 3]
step = [0.9]
rfeParameters = functions.generateParameters(
    [estimator, n_features_to_select, step], globals()
)

# PCA
n_components=[2,3]
random_state=[42]

pcaParams = functions.generateParameters(
    [n_components, random_state], globals()
)



featureSelectors = [
    {"model": functions.FeatureSelectorType.KBest, "parameters": kBestParameters},
    #{"model": functions.FeatureSelectorType.FPR, "parameters": fprParameters},
    #{"model": functions.FeatureSelectorType.RFE, "parameters": rfeParameters},
    {"model": functions.FeatureSelectorType.PCA, "parameters": pcaParams},
]
scalers = [
    # {"model": functions.Scaler.NoScaling, "parameters": [{}]},
    # {"model": functions.Scaler.Standard, "parameters": [{}]},
    {"model": functions.Scaler.Robust, "parameters": [{}]},
]

degree = [2]

polynomialParameters = functions.generateParameters([degree], globals())

featureGenerators = [
    {"model": functions.FeatureGenerator.NoFeatureGeneration, "parameters": [{}]},
    {
        "model": functions.FeatureGenerator.Polynomial,
        "parameters": polynomialParameters,
    },
]
### Conducting the experiment
y_train_ravel = np.ravel(y_train, order="C")
y_train_ravel = y_train_ravel.astype(int)
results = functions.conductExperimentsWithScalersAndGenerators(
    models=models,
    featureSelectors=featureSelectors,
    X_orig=X_train,
    y_orig=y_train_ravel,
    scalers=scalers,
    featureGenerators=featureGenerators,
    getLimitedScore=True,
    limit=0.45,

)
with open(RESULTS_FILENAME, "wb") as f:
    pickle.dump(results, f)
## Results
with open(RESULTS_FILENAME, "rb") as input_file:
    results = pickle.load(input_file)
resultsDf = pd.DataFrame(
    results,
    columns=functions.RESULTS_COLUMNS,
)
### Detailed Results
processedResultsDf, parameters = functions.extractParameterResultsArr(
    resultsDf,
    [models, featureSelectors, scalers, featureGenerators],
    [
        "model_parameters",
        "selector_parameters",
        "scaler_parameters",
        "feature_generator_parameters",
    ],
)
functions.drawParameterResultsBarplot(processedResultsDf, parameters)
### Score/Accuracy by number of features
functions.drawResultsPerNumberOfFeatures(processedResultsDf)
### Final Results for Feature Selectors
plt.title("Final comparison of feature selectors")
sns.boxplot(data=processedResultsDf, x="feature_selector", y="score")

plt.tight_layout()
plt.show()
sns.boxplot(data=processedResultsDf,x="model",y="score",hue="feature_generator")
sns.boxplot(data=processedResultsDf,x="model",y="score",hue="scaler")
### Final Results for Models
plt.title("Final comparison of models")
sns.boxplot(data=processedResultsDf, x="model", y="score")
plt.tight_layout()
plt.show()
### Final Results
filteredDf = functions.filterDataframeByBestResults(processedResultsDf)
processedResultsDf[processedResultsDf["scaler"]==functions.Scaler.NoScaling.name].sort_values(by="score",ascending=False).head(5)
filteredDf['scaler']
filteredDf['model_parameters'].to_numpy()
filteredDf['feature_generator']
print(filteredDf)


filteredDf = functions.filterDataframeByBestResults(processedResultsDf)
processedResultsDf[processedResultsDf["scaler"]==functions.Scaler.NoScaling.name].sort_values(by="score",ascending=False).head(5)
filteredDf['scaler']
filteredDf['model_parameters'].to_numpy()
filteredDf['feature_generator']
print(filteredDf)
# Out:
# !!!Experiment failed for: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 2} ModelType.LDA {'solver': 'svd', 'shrinkage': None, 'n_components': 3} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {} n_components cannot be larger than min(n_features, n_classes - 1).
# !!!Experiment failed for: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 2} ModelType.LDA {'solver': 'svd', 'shrinkage': None, 'n_components': 5} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {} n_components cannot be larger than min(n_features, n_classes - 1).
# !!!Experiment failed for: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 2} ModelType.LDA {'solver': 'svd', 'shrinkage': None, 'n_components': 8} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {} n_components cannot be larger than min(n_features, n_classes - 1).
# Performed Experiment 1/304(approx) took (s): model: 0.0 selector 7.36 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 2} ModelType.LDA {'solver': 'svd', 'shrinkage': None, 'n_components': None} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {}
# !!!Experiment failed for: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 2} ModelType.LDA {'solver': 'svd', 'shrinkage': 'auto', 'n_components': 3} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {} n_components cannot be larger than min(n_features, n_classes - 1).
# !!!Experiment failed for: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 2} ModelType.LDA {'solver': 'svd', 'shrinkage': 'auto', 'n_components': 5} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {} n_components cannot be larger than min(n_features, n_classes - 1).
# !!!Experiment failed for: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 2} ModelType.LDA {'solver': 'svd', 'shrinkage': 'auto', 'n_components': 8} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {} n_components cannot be larger than min(n_features, n_classes - 1).
# !!!Experiment failed for: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 2} ModelType.LDA {'solver': 'svd', 'shrinkage': 'auto', 'n_components': None} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {} shrinkage not supported with 'svd' solver.
# !!!Experiment failed for: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 2} ModelType.LDA {'solver': 'lsqr', 'shrinkage': None, 'n_components': 3} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {} n_components cannot be larger than min(n_features, n_classes - 1).
# !!!Experiment failed for: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 2} ModelType.LDA {'solver': 'lsqr', 'shrinkage': None, 'n_components': 5} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {} n_components cannot be larger than min(n_features, n_classes - 1).
# !!!Experiment failed for: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 2} ModelType.LDA {'solver': 'lsqr', 'shrinkage': None, 'n_components': 8} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {} n_components cannot be larger than min(n_features, n_classes - 1).
# Performed Experiment 2/304(approx) took (s): model: 0.01 selector 7.36 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 2} ModelType.LDA {'solver': 'lsqr', 'shrinkage': None, 'n_components': None} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {}
# !!!Experiment failed for: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 2} ModelType.LDA {'solver': 'lsqr', 'shrinkage': 'auto', 'n_components': 3} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {} n_components cannot be larger than min(n_features, n_classes - 1).
# !!!Experiment failed for: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 2} ModelType.LDA {'solver': 'lsqr', 'shrinkage': 'auto', 'n_components': 5} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {} n_components cannot be larger than min(n_features, n_classes - 1).
# !!!Experiment failed for: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 2} ModelType.LDA {'solver': 'lsqr', 'shrinkage': 'auto', 'n_components': 8} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {} n_components cannot be larger than min(n_features, n_classes - 1).
# Performed Experiment 3/304(approx) took (s): model: 0.0 selector 7.36 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 2} ModelType.LDA {'solver': 'lsqr', 'shrinkage': 'auto', 'n_components': None} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {}
# Performed Experiment 4/304(approx) took (s): model: 0.01 selector 7.36 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 2} ModelType.QDA {'reg_param': 0} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {}
# Performed Experiment 5/304(approx) took (s): model: 0.0 selector 7.36 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 2} ModelType.QDA {'reg_param': 0.3} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {}
# Performed Experiment 6/304(approx) took (s): model: 0.01 selector 7.36 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 2} ModelType.QDA {'reg_param': 0.5} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {}
# Performed Experiment 7/304(approx) took (s): model: 0.0 selector 7.36 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 2} ModelType.QDA {'reg_param': 0.8} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {}
# Performed Experiment 8/304(approx) took (s): model: 1.03 selector 7.36 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 2} ModelType.MLPClassifier {'activation': 'relu', 'solver': 'adam', 'alpha': 0.01, 'learning_rate': 'adaptive', 'learning_rate_init': 0.01, 'hidden_layer_sizes': (100,), 'max_iter': 1600, 'random_state': 42} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {}
# Performed Experiment 9/304(approx) took (s): model: 0.75 selector 7.36 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 2} ModelType.MLPClassifier {'activation': 'relu', 'solver': 'adam', 'alpha': 0.01, 'learning_rate': 'adaptive', 'learning_rate_init': 0.01, 'hidden_layer_sizes': (50,), 'max_iter': 1600, 'random_state': 42} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {}
# Performed Experiment 10/304(approx) took (s): model: 0.13 selector 7.36 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 2} ModelType.MLPClassifier {'activation': 'relu', 'solver': 'adam', 'alpha': 0.01, 'learning_rate': 'adaptive', 'learning_rate_init': 0.01, 'hidden_layer_sizes': (20,), 'max_iter': 1600, 'random_state': 42} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {}
# Performed Experiment 11/304(approx) took (s): model: 1.13 selector 7.36 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 2} ModelType.MLPClassifier {'activation': 'relu', 'solver': 'adam', 'alpha': 0.01, 'learning_rate': 'adaptive', 'learning_rate_init': 0.001, 'hidden_layer_sizes': (100,), 'max_iter': 1600, 'random_state': 42} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {}
# Performed Experiment 12/304(approx) took (s): model: 0.6 selector 7.36 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 2} ModelType.MLPClassifier {'activation': 'relu', 'solver': 'adam', 'alpha': 0.01, 'learning_rate': 'adaptive', 'learning_rate_init': 0.001, 'hidden_layer_sizes': (50,), 'max_iter': 1600, 'random_state': 42} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {}
# Performed Experiment 13/304(approx) took (s): model: 0.19 selector 7.36 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 2} ModelType.MLPClassifier {'activation': 'relu', 'solver': 'adam', 'alpha': 0.01, 'learning_rate': 'adaptive', 'learning_rate_init': 0.001, 'hidden_layer_sizes': (20,), 'max_iter': 1600, 'random_state': 42} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {}
# Performed Experiment 14/304(approx) took (s): model: 0.94 selector 7.36 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 2} ModelType.MLPClassifier {'activation': 'tanh', 'solver': 'adam', 'alpha': 0.01, 'learning_rate': 'adaptive', 'learning_rate_init': 0.01, 'hidden_layer_sizes': (100,), 'max_iter': 1600, 'random_state': 42} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {}
# Performed Experiment 15/304(approx) took (s): model: 0.9 selector 7.36 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 2} ModelType.MLPClassifier {'activation': 'tanh', 'solver': 'adam', 'alpha': 0.01, 'learning_rate': 'adaptive', 'learning_rate_init': 0.01, 'hidden_layer_sizes': (50,), 'max_iter': 1600, 'random_state': 42} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {}
# Performed Experiment 16/304(approx) took (s): model: 0.11 selector 7.36 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 2} ModelType.MLPClassifier {'activation': 'tanh', 'solver': 'adam', 'alpha': 0.01, 'learning_rate': 'adaptive', 'learning_rate_init': 0.01, 'hidden_layer_sizes': (20,), 'max_iter': 1600, 'random_state': 42} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {}
# Performed Experiment 17/304(approx) took (s): model: 5.09 selector 7.36 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 2} ModelType.MLPClassifier {'activation': 'tanh', 'solver': 'adam', 'alpha': 0.01, 'learning_rate': 'adaptive', 'learning_rate_init': 0.001, 'hidden_layer_sizes': (100,), 'max_iter': 1600, 'random_state': 42} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {}
# Performed Experiment 18/304(approx) took (s): model: 2.98 selector 7.36 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 2} ModelType.MLPClassifier {'activation': 'tanh', 'solver': 'adam', 'alpha': 0.01, 'learning_rate': 'adaptive', 'learning_rate_init': 0.001, 'hidden_layer_sizes': (50,), 'max_iter': 1600, 'random_state': 42} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {}
# Performed Experiment 19/304(approx) took (s): model: 0.57 selector 7.36 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 2} ModelType.MLPClassifier {'activation': 'tanh', 'solver': 'adam', 'alpha': 0.01, 'learning_rate': 'adaptive', 'learning_rate_init': 0.001, 'hidden_layer_sizes': (20,), 'max_iter': 1600, 'random_state': 42} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {}
# Performed Experiment 20/304(approx) took (s): model: 0.06 selector 7.36 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 2} ModelType.ADABoost {'estimator': DecisionTreeClassifier(), 'n_estimators': 50, 'learning_rate': 0.1, 'random_state': 42} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {}
# Performed Experiment 21/304(approx) took (s): model: 0.03 selector 7.36 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 2} ModelType.ADABoost {'estimator': DecisionTreeClassifier(), 'n_estimators': 50, 'learning_rate': 0.01, 'random_state': 42} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {}
# !!!Experiment failed for: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 2} ModelType.ADABoost {'estimator': LinearDiscriminantAnalysis(), 'n_estimators': 50, 'learning_rate': 0.1, 'random_state': 42} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {} LinearDiscriminantAnalysis doesn't support sample_weight.
# !!!Experiment failed for: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 2} ModelType.ADABoost {'estimator': LinearDiscriminantAnalysis(), 'n_estimators': 50, 'learning_rate': 0.01, 'random_state': 42} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {} LinearDiscriminantAnalysis doesn't support sample_weight.
# !!!Experiment failed for: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 2} ModelType.ADABoost {'estimator': QuadraticDiscriminantAnalysis(), 'n_estimators': 50, 'learning_rate': 0.1, 'random_state': 42} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {} QuadraticDiscriminantAnalysis doesn't support sample_weight.
# !!!Experiment failed for: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 2} ModelType.ADABoost {'estimator': QuadraticDiscriminantAnalysis(), 'n_estimators': 50, 'learning_rate': 0.01, 'random_state': 42} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {} QuadraticDiscriminantAnalysis doesn't support sample_weight.
# !!!Experiment failed for: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 2} ModelType.LDA {'solver': 'svd', 'shrinkage': None, 'n_components': 3} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2} n_components cannot be larger than min(n_features, n_classes - 1).
# !!!Experiment failed for: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 2} ModelType.LDA {'solver': 'svd', 'shrinkage': None, 'n_components': 5} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2} n_components cannot be larger than min(n_features, n_classes - 1).
# !!!Experiment failed for: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 2} ModelType.LDA {'solver': 'svd', 'shrinkage': None, 'n_components': 8} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2} n_components cannot be larger than min(n_features, n_classes - 1).
# Performed Experiment 22/304(approx) took (s): model: 0.01 selector 7.36 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 2} ModelType.LDA {'solver': 'svd', 'shrinkage': None, 'n_components': None} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2}
# !!!Experiment failed for: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 2} ModelType.LDA {'solver': 'svd', 'shrinkage': 'auto', 'n_components': 3} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2} n_components cannot be larger than min(n_features, n_classes - 1).
# !!!Experiment failed for: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 2} ModelType.LDA {'solver': 'svd', 'shrinkage': 'auto', 'n_components': 5} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2} n_components cannot be larger than min(n_features, n_classes - 1).
# !!!Experiment failed for: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 2} ModelType.LDA {'solver': 'svd', 'shrinkage': 'auto', 'n_components': 8} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2} n_components cannot be larger than min(n_features, n_classes - 1).
# !!!Experiment failed for: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 2} ModelType.LDA {'solver': 'svd', 'shrinkage': 'auto', 'n_components': None} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2} shrinkage not supported with 'svd' solver.
# !!!Experiment failed for: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 2} ModelType.LDA {'solver': 'lsqr', 'shrinkage': None, 'n_components': 3} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2} n_components cannot be larger than min(n_features, n_classes - 1).
# !!!Experiment failed for: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 2} ModelType.LDA {'solver': 'lsqr', 'shrinkage': None, 'n_components': 5} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2} n_components cannot be larger than min(n_features, n_classes - 1).
# !!!Experiment failed for: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 2} ModelType.LDA {'solver': 'lsqr', 'shrinkage': None, 'n_components': 8} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2} n_components cannot be larger than min(n_features, n_classes - 1).
# Performed Experiment 23/304(approx) took (s): model: 0.01 selector 7.36 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 2} ModelType.LDA {'solver': 'lsqr', 'shrinkage': None, 'n_components': None} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2}
# !!!Experiment failed for: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 2} ModelType.LDA {'solver': 'lsqr', 'shrinkage': 'auto', 'n_components': 3} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2} n_components cannot be larger than min(n_features, n_classes - 1).
# !!!Experiment failed for: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 2} ModelType.LDA {'solver': 'lsqr', 'shrinkage': 'auto', 'n_components': 5} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2} n_components cannot be larger than min(n_features, n_classes - 1).
# !!!Experiment failed for: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 2} ModelType.LDA {'solver': 'lsqr', 'shrinkage': 'auto', 'n_components': 8} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2} n_components cannot be larger than min(n_features, n_classes - 1).
# Performed Experiment 24/304(approx) took (s): model: 0.01 selector 7.36 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 2} ModelType.LDA {'solver': 'lsqr', 'shrinkage': 'auto', 'n_components': None} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2}
# Performed Experiment 25/304(approx) took (s): model: 0.07 selector 7.36 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 2} ModelType.QDA {'reg_param': 0} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2}
# Performed Experiment 26/304(approx) took (s): model: 0.01 selector 7.36 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 2} ModelType.QDA {'reg_param': 0.3} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2}
# Performed Experiment 27/304(approx) took (s): model: 0.01 selector 7.36 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 2} ModelType.QDA {'reg_param': 0.5} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2}
# c:\Users\prusak.patryk\Projects\Uni\advml-proj-2\.venv\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\prusak.patryk\Projects\Uni\advml-proj-2\.venv\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\prusak.patryk\Projects\Uni\advml-proj-2\.venv\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\prusak.patryk\Projects\Uni\advml-proj-2\.venv\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\prusak.patryk\Projects\Uni\advml-proj-2\.venv\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\prusak.patryk\Projects\Uni\advml-proj-2\.venv\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\prusak.patryk\Projects\Uni\advml-proj-2\.venv\Lib\site-packages\sklearn\discriminant_analysis.py:935: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# c:\Users\prusak.patryk\Projects\Uni\advml-proj-2\.venv\Lib\site-packages\sklearn\discriminant_analysis.py:960: RuntimeWarning: divide by zero encountered in power
#   X2 = np.dot(Xm, R * (S ** (-0.5)))
# c:\Users\prusak.patryk\Projects\Uni\advml-proj-2\.venv\Lib\site-packages\sklearn\discriminant_analysis.py:960: RuntimeWarning: invalid value encountered in multiply
#   X2 = np.dot(Xm, R * (S ** (-0.5)))
# c:\Users\prusak.patryk\Projects\Uni\advml-proj-2\.venv\Lib\site-packages\sklearn\discriminant_analysis.py:963: RuntimeWarning: divide by zero encountered in log
#   u = np.asarray([np.sum(np.log(s)) for s in self.scalings_])
# c:\Users\prusak.patryk\Projects\Uni\advml-proj-2\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\prusak.patryk\Projects\Uni\advml-proj-2\.venv\Lib\site-packages\sklearn\discriminant_analysis.py:935: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# c:\Users\prusak.patryk\Projects\Uni\advml-proj-2\.venv\Lib\site-packages\sklearn\discriminant_analysis.py:935: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# c:\Users\prusak.patryk\Projects\Uni\advml-proj-2\.venv\Lib\site-packages\sklearn\discriminant_analysis.py:935: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# Performed Experiment 28/304(approx) took (s): model: 0.01 selector 7.36 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 2} ModelType.QDA {'reg_param': 0.8} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2}
# Performed Experiment 29/304(approx) took (s): model: 1.55 selector 7.36 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 2} ModelType.MLPClassifier {'activation': 'relu', 'solver': 'adam', 'alpha': 0.01, 'learning_rate': 'adaptive', 'learning_rate_init': 0.01, 'hidden_layer_sizes': (100,), 'max_iter': 1600, 'random_state': 42} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2}
# Performed Experiment 30/304(approx) took (s): model: 1.02 selector 7.36 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 2} ModelType.MLPClassifier {'activation': 'relu', 'solver': 'adam', 'alpha': 0.01, 'learning_rate': 'adaptive', 'learning_rate_init': 0.01, 'hidden_layer_sizes': (50,), 'max_iter': 1600, 'random_state': 42} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2}
# Performed Experiment 31/304(approx) took (s): model: 0.18 selector 7.36 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 2} ModelType.MLPClassifier {'activation': 'relu', 'solver': 'adam', 'alpha': 0.01, 'learning_rate': 'adaptive', 'learning_rate_init': 0.01, 'hidden_layer_sizes': (20,), 'max_iter': 1600, 'random_state': 42} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2}
# Performed Experiment 32/304(approx) took (s): model: 3.5 selector 7.36 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 2} ModelType.MLPClassifier {'activation': 'relu', 'solver': 'adam', 'alpha': 0.01, 'learning_rate': 'adaptive', 'learning_rate_init': 0.001, 'hidden_layer_sizes': (100,), 'max_iter': 1600, 'random_state': 42} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2}
# Performed Experiment 33/304(approx) took (s): model: 0.58 selector 7.36 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 2} ModelType.MLPClassifier {'activation': 'relu', 'solver': 'adam', 'alpha': 0.01, 'learning_rate': 'adaptive', 'learning_rate_init': 0.001, 'hidden_layer_sizes': (50,), 'max_iter': 1600, 'random_state': 42} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2}
# Performed Experiment 34/304(approx) took (s): model: 0.22 selector 7.36 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 2} ModelType.MLPClassifier {'activation': 'relu', 'solver': 'adam', 'alpha': 0.01, 'learning_rate': 'adaptive', 'learning_rate_init': 0.001, 'hidden_layer_sizes': (20,), 'max_iter': 1600, 'random_state': 42} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2}
# Performed Experiment 35/304(approx) took (s): model: 0.8 selector 7.36 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 2} ModelType.MLPClassifier {'activation': 'tanh', 'solver': 'adam', 'alpha': 0.01, 'learning_rate': 'adaptive', 'learning_rate_init': 0.01, 'hidden_layer_sizes': (100,), 'max_iter': 1600, 'random_state': 42} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2}
# Performed Experiment 36/304(approx) took (s): model: 0.75 selector 7.36 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 2} ModelType.MLPClassifier {'activation': 'tanh', 'solver': 'adam', 'alpha': 0.01, 'learning_rate': 'adaptive', 'learning_rate_init': 0.01, 'hidden_layer_sizes': (50,), 'max_iter': 1600, 'random_state': 42} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2}
# Performed Experiment 37/304(approx) took (s): model: 0.15 selector 7.36 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 2} ModelType.MLPClassifier {'activation': 'tanh', 'solver': 'adam', 'alpha': 0.01, 'learning_rate': 'adaptive', 'learning_rate_init': 0.01, 'hidden_layer_sizes': (20,), 'max_iter': 1600, 'random_state': 42} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2}
# Performed Experiment 38/304(approx) took (s): model: 0.82 selector 7.36 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 2} ModelType.MLPClassifier {'activation': 'tanh', 'solver': 'adam', 'alpha': 0.01, 'learning_rate': 'adaptive', 'learning_rate_init': 0.001, 'hidden_layer_sizes': (100,), 'max_iter': 1600, 'random_state': 42} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2}
# Performed Experiment 39/304(approx) took (s): model: 0.72 selector 7.36 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 2} ModelType.MLPClassifier {'activation': 'tanh', 'solver': 'adam', 'alpha': 0.01, 'learning_rate': 'adaptive', 'learning_rate_init': 0.001, 'hidden_layer_sizes': (50,), 'max_iter': 1600, 'random_state': 42} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2}
# Performed Experiment 40/304(approx) took (s): model: 0.11 selector 7.36 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 2} ModelType.MLPClassifier {'activation': 'tanh', 'solver': 'adam', 'alpha': 0.01, 'learning_rate': 'adaptive', 'learning_rate_init': 0.001, 'hidden_layer_sizes': (20,), 'max_iter': 1600, 'random_state': 42} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2}
# Performed Experiment 41/304(approx) took (s): model: 0.03 selector 7.36 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 2} ModelType.ADABoost {'estimator': DecisionTreeClassifier(), 'n_estimators': 50, 'learning_rate': 0.1, 'random_state': 42} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2}
# Performed Experiment 42/304(approx) took (s): model: 0.06 selector 7.36 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 2} ModelType.ADABoost {'estimator': DecisionTreeClassifier(), 'n_estimators': 50, 'learning_rate': 0.01, 'random_state': 42} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2}
# !!!Experiment failed for: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 2} ModelType.ADABoost {'estimator': LinearDiscriminantAnalysis(), 'n_estimators': 50, 'learning_rate': 0.1, 'random_state': 42} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2} LinearDiscriminantAnalysis doesn't support sample_weight.
# c:\Users\prusak.patryk\Projects\Uni\advml-proj-2\.venv\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\prusak.patryk\Projects\Uni\advml-proj-2\.venv\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\prusak.patryk\Projects\Uni\advml-proj-2\.venv\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\prusak.patryk\Projects\Uni\advml-proj-2\.venv\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\prusak.patryk\Projects\Uni\advml-proj-2\.venv\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\prusak.patryk\Projects\Uni\advml-proj-2\.venv\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# !!!Experiment failed for: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 2} ModelType.ADABoost {'estimator': LinearDiscriminantAnalysis(), 'n_estimators': 50, 'learning_rate': 0.01, 'random_state': 42} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2} LinearDiscriminantAnalysis doesn't support sample_weight.
# !!!Experiment failed for: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 2} ModelType.ADABoost {'estimator': QuadraticDiscriminantAnalysis(), 'n_estimators': 50, 'learning_rate': 0.1, 'random_state': 42} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2} QuadraticDiscriminantAnalysis doesn't support sample_weight.
# !!!Experiment failed for: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 2} ModelType.ADABoost {'estimator': QuadraticDiscriminantAnalysis(), 'n_estimators': 50, 'learning_rate': 0.01, 'random_state': 42} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2} QuadraticDiscriminantAnalysis doesn't support sample_weight.
# !!!Experiment failed for: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 3} ModelType.LDA {'solver': 'svd', 'shrinkage': None, 'n_components': 3} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {} n_components cannot be larger than min(n_features, n_classes - 1).
# !!!Experiment failed for: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 3} ModelType.LDA {'solver': 'svd', 'shrinkage': None, 'n_components': 5} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {} n_components cannot be larger than min(n_features, n_classes - 1).
# !!!Experiment failed for: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 3} ModelType.LDA {'solver': 'svd', 'shrinkage': None, 'n_components': 8} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {} n_components cannot be larger than min(n_features, n_classes - 1).
# Performed Experiment 43/304(approx) took (s): model: 0.0 selector 10.01 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 3} ModelType.LDA {'solver': 'svd', 'shrinkage': None, 'n_components': None} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {}
# !!!Experiment failed for: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 3} ModelType.LDA {'solver': 'svd', 'shrinkage': 'auto', 'n_components': 3} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {} n_components cannot be larger than min(n_features, n_classes - 1).
# !!!Experiment failed for: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 3} ModelType.LDA {'solver': 'svd', 'shrinkage': 'auto', 'n_components': 5} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {} n_components cannot be larger than min(n_features, n_classes - 1).
# !!!Experiment failed for: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 3} ModelType.LDA {'solver': 'svd', 'shrinkage': 'auto', 'n_components': 8} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {} n_components cannot be larger than min(n_features, n_classes - 1).
# !!!Experiment failed for: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 3} ModelType.LDA {'solver': 'svd', 'shrinkage': 'auto', 'n_components': None} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {} shrinkage not supported with 'svd' solver.
# !!!Experiment failed for: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 3} ModelType.LDA {'solver': 'lsqr', 'shrinkage': None, 'n_components': 3} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {} n_components cannot be larger than min(n_features, n_classes - 1).
# !!!Experiment failed for: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 3} ModelType.LDA {'solver': 'lsqr', 'shrinkage': None, 'n_components': 5} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {} n_components cannot be larger than min(n_features, n_classes - 1).
# !!!Experiment failed for: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 3} ModelType.LDA {'solver': 'lsqr', 'shrinkage': None, 'n_components': 8} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {} n_components cannot be larger than min(n_features, n_classes - 1).
# Performed Experiment 44/304(approx) took (s): model: 0.01 selector 10.01 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 3} ModelType.LDA {'solver': 'lsqr', 'shrinkage': None, 'n_components': None} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {}
# !!!Experiment failed for: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 3} ModelType.LDA {'solver': 'lsqr', 'shrinkage': 'auto', 'n_components': 3} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {} n_components cannot be larger than min(n_features, n_classes - 1).
# !!!Experiment failed for: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 3} ModelType.LDA {'solver': 'lsqr', 'shrinkage': 'auto', 'n_components': 5} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {} n_components cannot be larger than min(n_features, n_classes - 1).
# !!!Experiment failed for: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 3} ModelType.LDA {'solver': 'lsqr', 'shrinkage': 'auto', 'n_components': 8} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {} n_components cannot be larger than min(n_features, n_classes - 1).
# Performed Experiment 45/304(approx) took (s): model: 0.0 selector 10.01 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 3} ModelType.LDA {'solver': 'lsqr', 'shrinkage': 'auto', 'n_components': None} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {}
# Performed Experiment 46/304(approx) took (s): model: 0.0 selector 10.01 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 3} ModelType.QDA {'reg_param': 0} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {}
# Performed Experiment 47/304(approx) took (s): model: 0.0 selector 10.01 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 3} ModelType.QDA {'reg_param': 0.3} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {}
# Performed Experiment 48/304(approx) took (s): model: 0.0 selector 10.01 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 3} ModelType.QDA {'reg_param': 0.5} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {}
# Performed Experiment 49/304(approx) took (s): model: 0.02 selector 10.01 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 3} ModelType.QDA {'reg_param': 0.8} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {}
# Performed Experiment 50/304(approx) took (s): model: 1.05 selector 10.01 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 3} ModelType.MLPClassifier {'activation': 'relu', 'solver': 'adam', 'alpha': 0.01, 'learning_rate': 'adaptive', 'learning_rate_init': 0.01, 'hidden_layer_sizes': (100,), 'max_iter': 1600, 'random_state': 42} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {}
# Performed Experiment 51/304(approx) took (s): model: 0.53 selector 10.01 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 3} ModelType.MLPClassifier {'activation': 'relu', 'solver': 'adam', 'alpha': 0.01, 'learning_rate': 'adaptive', 'learning_rate_init': 0.01, 'hidden_layer_sizes': (50,), 'max_iter': 1600, 'random_state': 42} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {}
# Performed Experiment 52/304(approx) took (s): model: 0.11 selector 10.01 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 3} ModelType.MLPClassifier {'activation': 'relu', 'solver': 'adam', 'alpha': 0.01, 'learning_rate': 'adaptive', 'learning_rate_init': 0.01, 'hidden_layer_sizes': (20,), 'max_iter': 1600, 'random_state': 42} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {}
# Performed Experiment 53/304(approx) took (s): model: 1.84 selector 10.01 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 3} ModelType.MLPClassifier {'activation': 'relu', 'solver': 'adam', 'alpha': 0.01, 'learning_rate': 'adaptive', 'learning_rate_init': 0.001, 'hidden_layer_sizes': (100,), 'max_iter': 1600, 'random_state': 42} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {}
# Performed Experiment 54/304(approx) took (s): model: 0.65 selector 10.01 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 3} ModelType.MLPClassifier {'activation': 'relu', 'solver': 'adam', 'alpha': 0.01, 'learning_rate': 'adaptive', 'learning_rate_init': 0.001, 'hidden_layer_sizes': (50,), 'max_iter': 1600, 'random_state': 42} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {}
# Performed Experiment 55/304(approx) took (s): model: 0.17 selector 10.01 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 3} ModelType.MLPClassifier {'activation': 'relu', 'solver': 'adam', 'alpha': 0.01, 'learning_rate': 'adaptive', 'learning_rate_init': 0.001, 'hidden_layer_sizes': (20,), 'max_iter': 1600, 'random_state': 42} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {}
# Performed Experiment 56/304(approx) took (s): model: 0.71 selector 10.01 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 3} ModelType.MLPClassifier {'activation': 'tanh', 'solver': 'adam', 'alpha': 0.01, 'learning_rate': 'adaptive', 'learning_rate_init': 0.01, 'hidden_layer_sizes': (100,), 'max_iter': 1600, 'random_state': 42} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {}
# Performed Experiment 57/304(approx) took (s): model: 0.68 selector 10.01 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 3} ModelType.MLPClassifier {'activation': 'tanh', 'solver': 'adam', 'alpha': 0.01, 'learning_rate': 'adaptive', 'learning_rate_init': 0.01, 'hidden_layer_sizes': (50,), 'max_iter': 1600, 'random_state': 42} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {}
# Performed Experiment 58/304(approx) took (s): model: 0.11 selector 10.01 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 3} ModelType.MLPClassifier {'activation': 'tanh', 'solver': 'adam', 'alpha': 0.01, 'learning_rate': 'adaptive', 'learning_rate_init': 0.01, 'hidden_layer_sizes': (20,), 'max_iter': 1600, 'random_state': 42} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {}
# Performed Experiment 59/304(approx) took (s): model: 2.76 selector 10.01 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 3} ModelType.MLPClassifier {'activation': 'tanh', 'solver': 'adam', 'alpha': 0.01, 'learning_rate': 'adaptive', 'learning_rate_init': 0.001, 'hidden_layer_sizes': (100,), 'max_iter': 1600, 'random_state': 42} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {}
# Performed Experiment 60/304(approx) took (s): model: 1.47 selector 10.01 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 3} ModelType.MLPClassifier {'activation': 'tanh', 'solver': 'adam', 'alpha': 0.01, 'learning_rate': 'adaptive', 'learning_rate_init': 0.001, 'hidden_layer_sizes': (50,), 'max_iter': 1600, 'random_state': 42} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {}
# Performed Experiment 61/304(approx) took (s): model: 0.35 selector 10.01 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 3} ModelType.MLPClassifier {'activation': 'tanh', 'solver': 'adam', 'alpha': 0.01, 'learning_rate': 'adaptive', 'learning_rate_init': 0.001, 'hidden_layer_sizes': (20,), 'max_iter': 1600, 'random_state': 42} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {}
# Performed Experiment 62/304(approx) took (s): model: 0.03 selector 10.01 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 3} ModelType.ADABoost {'estimator': DecisionTreeClassifier(), 'n_estimators': 50, 'learning_rate': 0.1, 'random_state': 42} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {}
# Performed Experiment 63/304(approx) took (s): model: 0.02 selector 10.01 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 3} ModelType.ADABoost {'estimator': DecisionTreeClassifier(), 'n_estimators': 50, 'learning_rate': 0.01, 'random_state': 42} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {}
# !!!Experiment failed for: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 3} ModelType.ADABoost {'estimator': LinearDiscriminantAnalysis(), 'n_estimators': 50, 'learning_rate': 0.1, 'random_state': 42} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {} LinearDiscriminantAnalysis doesn't support sample_weight.
# !!!Experiment failed for: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 3} ModelType.ADABoost {'estimator': LinearDiscriminantAnalysis(), 'n_estimators': 50, 'learning_rate': 0.01, 'random_state': 42} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {} LinearDiscriminantAnalysis doesn't support sample_weight.
# !!!Experiment failed for: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 3} ModelType.ADABoost {'estimator': QuadraticDiscriminantAnalysis(), 'n_estimators': 50, 'learning_rate': 0.1, 'random_state': 42} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {} QuadraticDiscriminantAnalysis doesn't support sample_weight.
# !!!Experiment failed for: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 3} ModelType.ADABoost {'estimator': QuadraticDiscriminantAnalysis(), 'n_estimators': 50, 'learning_rate': 0.01, 'random_state': 42} Scaler.Robust {} FeatureGenerator.NoFeatureGeneration {} QuadraticDiscriminantAnalysis doesn't support sample_weight.
# !!!Experiment failed for: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 3} ModelType.LDA {'solver': 'svd', 'shrinkage': None, 'n_components': 3} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2} n_components cannot be larger than min(n_features, n_classes - 1).
# !!!Experiment failed for: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 3} ModelType.LDA {'solver': 'svd', 'shrinkage': None, 'n_components': 5} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2} n_components cannot be larger than min(n_features, n_classes - 1).
# !!!Experiment failed for: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 3} ModelType.LDA {'solver': 'svd', 'shrinkage': None, 'n_components': 8} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2} n_components cannot be larger than min(n_features, n_classes - 1).
# Performed Experiment 64/304(approx) took (s): model: 0.02 selector 10.01 with: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 3} ModelType.LDA {'solver': 'svd', 'shrinkage': None, 'n_components': None} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2}
# !!!Experiment failed for: FeatureSelectorType.KBest {'score_func': <function mutual_info_classif at 0x000002204A5CCE00>, 'k': 3} ModelType.LDA {'solver': 'svd', 'shrinkage': 'auto', 'n_components': 3} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2} n_components cannot be larger than min(n_features, n_classes - 1).
# ...
# Performed Experiment 150/304(approx) took (s): model: 0.0 selector 0.2 with: FeatureSelectorType.PCA {'n_components': 3, 'random_state': 42} ModelType.LDA {'solver': 'lsqr', 'shrinkage': 'auto', 'n_components': None} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2}
# Performed Experiment 151/304(approx) took (s): model: 0.0 selector 0.2 with: FeatureSelectorType.PCA {'n_components': 3, 'random_state': 42} ModelType.QDA {'reg_param': 0} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2}
# Performed Experiment 152/304(approx) took (s): model: 0.02 selector 0.2 with: FeatureSelectorType.PCA {'n_components': 3, 'random_state': 42} ModelType.QDA {'reg_param': 0.3} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2}
# Performed Experiment 153/304(approx) took (s): model: 0.0 selector 0.2 with: FeatureSelectorType.PCA {'n_components': 3, 'random_state': 42} ModelType.QDA {'reg_param': 0.5} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2}
# Performed Experiment 154/304(approx) took (s): model: 0.0 selector 0.2 with: FeatureSelectorType.PCA {'n_components': 3, 'random_state': 42} ModelType.QDA {'reg_param': 0.8} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2}
# c:\Users\prusak.patryk\Projects\Uni\advml-proj-2\.venv\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\prusak.patryk\Projects\Uni\advml-proj-2\.venv\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\prusak.patryk\Projects\Uni\advml-proj-2\.venv\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\prusak.patryk\Projects\Uni\advml-proj-2\.venv\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\prusak.patryk\Projects\Uni\advml-proj-2\.venv\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\prusak.patryk\Projects\Uni\advml-proj-2\.venv\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\prusak.patryk\Projects\Uni\advml-proj-2\.venv\Lib\site-packages\sklearn\discriminant_analysis.py:935: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# c:\Users\prusak.patryk\Projects\Uni\advml-proj-2\.venv\Lib\site-packages\sklearn\discriminant_analysis.py:960: RuntimeWarning: divide by zero encountered in power
#   X2 = np.dot(Xm, R * (S ** (-0.5)))
# c:\Users\prusak.patryk\Projects\Uni\advml-proj-2\.venv\Lib\site-packages\sklearn\discriminant_analysis.py:960: RuntimeWarning: invalid value encountered in multiply
#   X2 = np.dot(Xm, R * (S ** (-0.5)))
# c:\Users\prusak.patryk\Projects\Uni\advml-proj-2\.venv\Lib\site-packages\sklearn\discriminant_analysis.py:963: RuntimeWarning: divide by zero encountered in log
#   u = np.asarray([np.sum(np.log(s)) for s in self.scalings_])
# c:\Users\prusak.patryk\Projects\Uni\advml-proj-2\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\prusak.patryk\Projects\Uni\advml-proj-2\.venv\Lib\site-packages\sklearn\discriminant_analysis.py:935: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# c:\Users\prusak.patryk\Projects\Uni\advml-proj-2\.venv\Lib\site-packages\sklearn\discriminant_analysis.py:935: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# c:\Users\prusak.patryk\Projects\Uni\advml-proj-2\.venv\Lib\site-packages\sklearn\discriminant_analysis.py:935: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# Performed Experiment 155/304(approx) took (s): model: 2.05 selector 0.2 with: FeatureSelectorType.PCA {'n_components': 3, 'random_state': 42} ModelType.MLPClassifier {'activation': 'relu', 'solver': 'adam', 'alpha': 0.01, 'learning_rate': 'adaptive', 'learning_rate_init': 0.01, 'hidden_layer_sizes': (100,), 'max_iter': 1600, 'random_state': 42} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2}
# Performed Experiment 156/304(approx) took (s): model: 1.72 selector 0.2 with: FeatureSelectorType.PCA {'n_components': 3, 'random_state': 42} ModelType.MLPClassifier {'activation': 'relu', 'solver': 'adam', 'alpha': 0.01, 'learning_rate': 'adaptive', 'learning_rate_init': 0.01, 'hidden_layer_sizes': (50,), 'max_iter': 1600, 'random_state': 42} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2}
# Performed Experiment 157/304(approx) took (s): model: 0.19 selector 0.2 with: FeatureSelectorType.PCA {'n_components': 3, 'random_state': 42} ModelType.MLPClassifier {'activation': 'relu', 'solver': 'adam', 'alpha': 0.01, 'learning_rate': 'adaptive', 'learning_rate_init': 0.01, 'hidden_layer_sizes': (20,), 'max_iter': 1600, 'random_state': 42} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2}
# Performed Experiment 158/304(approx) took (s): model: 3.55 selector 0.2 with: FeatureSelectorType.PCA {'n_components': 3, 'random_state': 42} ModelType.MLPClassifier {'activation': 'relu', 'solver': 'adam', 'alpha': 0.01, 'learning_rate': 'adaptive', 'learning_rate_init': 0.001, 'hidden_layer_sizes': (100,), 'max_iter': 1600, 'random_state': 42} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2}
# Performed Experiment 159/304(approx) took (s): model: 2.92 selector 0.2 with: FeatureSelectorType.PCA {'n_components': 3, 'random_state': 42} ModelType.MLPClassifier {'activation': 'relu', 'solver': 'adam', 'alpha': 0.01, 'learning_rate': 'adaptive', 'learning_rate_init': 0.001, 'hidden_layer_sizes': (50,), 'max_iter': 1600, 'random_state': 42} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2}
# Performed Experiment 160/304(approx) took (s): model: 0.25 selector 0.2 with: FeatureSelectorType.PCA {'n_components': 3, 'random_state': 42} ModelType.MLPClassifier {'activation': 'relu', 'solver': 'adam', 'alpha': 0.01, 'learning_rate': 'adaptive', 'learning_rate_init': 0.001, 'hidden_layer_sizes': (20,), 'max_iter': 1600, 'random_state': 42} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2}
# Performed Experiment 161/304(approx) took (s): model: 1.12 selector 0.2 with: FeatureSelectorType.PCA {'n_components': 3, 'random_state': 42} ModelType.MLPClassifier {'activation': 'tanh', 'solver': 'adam', 'alpha': 0.01, 'learning_rate': 'adaptive', 'learning_rate_init': 0.01, 'hidden_layer_sizes': (100,), 'max_iter': 1600, 'random_state': 42} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2}
# Performed Experiment 162/304(approx) took (s): model: 0.44 selector 0.2 with: FeatureSelectorType.PCA {'n_components': 3, 'random_state': 42} ModelType.MLPClassifier {'activation': 'tanh', 'solver': 'adam', 'alpha': 0.01, 'learning_rate': 'adaptive', 'learning_rate_init': 0.01, 'hidden_layer_sizes': (50,), 'max_iter': 1600, 'random_state': 42} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2}
# Performed Experiment 163/304(approx) took (s): model: 0.18 selector 0.2 with: FeatureSelectorType.PCA {'n_components': 3, 'random_state': 42} ModelType.MLPClassifier {'activation': 'tanh', 'solver': 'adam', 'alpha': 0.01, 'learning_rate': 'adaptive', 'learning_rate_init': 0.01, 'hidden_layer_sizes': (20,), 'max_iter': 1600, 'random_state': 42} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2}
# Performed Experiment 164/304(approx) took (s): model: 1.02 selector 0.2 with: FeatureSelectorType.PCA {'n_components': 3, 'random_state': 42} ModelType.MLPClassifier {'activation': 'tanh', 'solver': 'adam', 'alpha': 0.01, 'learning_rate': 'adaptive', 'learning_rate_init': 0.001, 'hidden_layer_sizes': (100,), 'max_iter': 1600, 'random_state': 42} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2}
# Performed Experiment 165/304(approx) took (s): model: 1.63 selector 0.2 with: FeatureSelectorType.PCA {'n_components': 3, 'random_state': 42} ModelType.MLPClassifier {'activation': 'tanh', 'solver': 'adam', 'alpha': 0.01, 'learning_rate': 'adaptive', 'learning_rate_init': 0.001, 'hidden_layer_sizes': (50,), 'max_iter': 1600, 'random_state': 42} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2}
# Performed Experiment 166/304(approx) took (s): model: 0.2 selector 0.2 with: FeatureSelectorType.PCA {'n_components': 3, 'random_state': 42} ModelType.MLPClassifier {'activation': 'tanh', 'solver': 'adam', 'alpha': 0.01, 'learning_rate': 'adaptive', 'learning_rate_init': 0.001, 'hidden_layer_sizes': (20,), 'max_iter': 1600, 'random_state': 42} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2}
# Performed Experiment 167/304(approx) took (s): model: 0.06 selector 0.2 with: FeatureSelectorType.PCA {'n_components': 3, 'random_state': 42} ModelType.ADABoost {'estimator': DecisionTreeClassifier(), 'n_estimators': 50, 'learning_rate': 0.1, 'random_state': 42} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2}
# Performed Experiment 168/304(approx) took (s): model: 0.08 selector 0.2 with: FeatureSelectorType.PCA {'n_components': 3, 'random_state': 42} ModelType.ADABoost {'estimator': DecisionTreeClassifier(), 'n_estimators': 50, 'learning_rate': 0.01, 'random_state': 42} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2}
# !!!Experiment failed for: FeatureSelectorType.PCA {'n_components': 3, 'random_state': 42} ModelType.ADABoost {'estimator': LinearDiscriminantAnalysis(), 'n_estimators': 50, 'learning_rate': 0.1, 'random_state': 42} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2} LinearDiscriminantAnalysis doesn't support sample_weight.
# !!!Experiment failed for: FeatureSelectorType.PCA {'n_components': 3, 'random_state': 42} ModelType.ADABoost {'estimator': LinearDiscriminantAnalysis(), 'n_estimators': 50, 'learning_rate': 0.01, 'random_state': 42} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2} LinearDiscriminantAnalysis doesn't support sample_weight.
# !!!Experiment failed for: FeatureSelectorType.PCA {'n_components': 3, 'random_state': 42} ModelType.ADABoost {'estimator': QuadraticDiscriminantAnalysis(), 'n_estimators': 50, 'learning_rate': 0.1, 'random_state': 42} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2} QuadraticDiscriminantAnalysis doesn't support sample_weight.
# !!!Experiment failed for: FeatureSelectorType.PCA {'n_components': 3, 'random_state': 42} ModelType.ADABoost {'estimator': QuadraticDiscriminantAnalysis(), 'n_estimators': 50, 'learning_rate': 0.01, 'random_state': 42} Scaler.Robust {} FeatureGenerator.Polynomial {'degree': 2} QuadraticDiscriminantAnalysis doesn't support sample_weight.
# c:\Users\prusak.patryk\Projects\Uni\advml-proj-2\.venv\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\prusak.patryk\Projects\Uni\advml-proj-2\.venv\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\prusak.patryk\Projects\Uni\advml-proj-2\.venv\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\prusak.patryk\Projects\Uni\advml-proj-2\.venv\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\prusak.patryk\Projects\Uni\advml-proj-2\.venv\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\prusak.patryk\Projects\Uni\advml-proj-2\.venv\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File <timed exec>:236
#
# File c:\Users\prusak.patryk\Projects\Uni\advml-proj-2\functions.py:1010, in drawParameterResultsBarplot(resultsDf, parameters)
#    1008 else:
#    1009     plt.title("Score for parameter " + parameter["parameterName"])
# -> 1010     sns.barplot(
#    1011         data=resultsDf,
#    1012         x="feature_selector",
#    1013         y="score",
#    1014         hue=resultsDf[
#    1015             [
#    1016                 "model",
#    1017                 getParameterName(
#    1018                     parameter["parameterColumnName"], parameter["parameterName"]
#    1019                 ),
#    1020             ]
#    1021         ].apply(tuple, axis=1),
#    1022     )
#    1024     plt.tight_layout()
#    1025     plt.show()
#
# File c:\Users\prusak.patryk\Projects\Uni\advml-proj-2\.venv\Lib\site-packages\seaborn\categorical.py:2380, in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, seed, units, weights, orient, color, palette, saturation, fill, hue_norm, width, dodge, gap, log_scale, native_scale, formatter, legend, capsize, err_kws, ci, errcolor, errwidth, ax, **kwargs)
#    2377 # Deprecations to remove in v0.15.0.
#    2378 err_kws, capsize = p._err_kws_backcompat(err_kws, errcolor, errwidth, capsize)
# -> 2380 p.plot_bars(
#    2381     aggregator=aggregator,
#    2382     dodge=dodge,
#    2383     width=width,
#    2384     gap=gap,
#    2385     color=color,
#    2386     fill=fill,
#    2387     capsize=capsize,
#    2388     err_kws=err_kws,
#    2389     plot_kws=kwargs,
#    2390 )
#    2392 p._add_axis_labels(ax)
#    2393 p._adjust_cat_axis(ax, axis=p.orient)
#
# File c:\Users\prusak.patryk\Projects\Uni\advml-proj-2\.venv\Lib\site-packages\seaborn\categorical.py:1288, in _CategoricalPlotter.plot_bars(self, aggregator, dodge, gap, width, fill, color, capsize, err_kws, plot_kws)
#    1286 agg_data["width"] = width * self._native_width
#    1287 if dodge:
# -> 1288     self._dodge(sub_vars, agg_data)
#    1289 if gap:
#    1290     agg_data["width"] *= 1 - gap
#
# File c:\Users\prusak.patryk\Projects\Uni\advml-proj-2\.venv\Lib\site-packages\seaborn\categorical.py:401, in _CategoricalPlotter._dodge(self, keys, data)
#     396 if "hue" not in self.variables:
#     397     # Short-circuit if hue variable was not assigned
#     398     # We could potentially warn when hue=None, dodge=True, user may be confused
#     399     # But I think it's fine to just treat it as a no-op.
#     400     return
# --> 401 hue_idx = self._hue_map.levels.index(keys["hue"])
#     402 n = len(self._hue_map.levels)
#     403 data["width"] /= n
#
# File missing.pyx:392, in pandas._libs.missing.NAType.__bool__()
#
# TypeError: boolean value of NA is ambiguous

# %%
plt.title("Final comparison of feature selectors")
sns.boxplot(data=processedResultsDf, x="feature_selector", y="score")
# Out:
# <Axes: title={'center': 'Final comparison of feature selectors'}, xlabel='feature_selector', ylabel='score'>
