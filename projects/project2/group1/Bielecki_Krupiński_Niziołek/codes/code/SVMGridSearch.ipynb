# %%
import time

import numpy as np
import pandas as pd
from sklearn.discriminant_analysis import (
    LinearDiscriminantAnalysis,
    QuadraticDiscriminantAnalysis,
)
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier
from sklearn.feature_selection import (
    RFE,
    SelectFromModel,
    SelectKBest,
    SequentialFeatureSelector,
    f_classif,
    mutual_info_classif,
)
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from utils import (
    experiment,
    get_data,
    get_param_combinations,
    get_params_json,
    save_results,
)

from xgboost import XGBClassifier
X, y = get_data()

# %%
import json
import time
from itertools import product

import numpy as np
import pandas as pd
from sklearn.discriminant_analysis import StandardScaler
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split


def get_data():
    X = pd.read_csv("../data/x_train.txt", sep=" ", header=None)
    y = pd.read_csv("../data/y_train.txt", header=None)
    scaler = StandardScaler()

    X = scaler.fit_transform(X)
    y = y.values.ravel()

    return X, y


def get_param_combinations(param_dict):
    value_prod = list(product(*param_dict.values()))
    keys = param_dict.keys()
    return [dict(zip(keys, values)) for values in value_prod]


def param_json_to_str(param_json):
    if type(param_json).__name__ == "function":
        return param_json.__name__
    return param_json


def get_params_json(params):
    params_mapped = {k: param_json_to_str(v) for k, v in params.items()}
    return json.dumps(params_mapped).replace('"', "'")


def save_results(results, filename):
    df = pd.DataFrame(
        results,
        columns=[
            "feature_selector",
            "feature_selector_params",
            "classifier",
            "classifier_params",
            "n_features",
            "accuracy",
            "accuracy_std",
            "accuracy_top_20pc",
            "elapsed_time",
        ],
    )
    df.to_csv(f"../results/{filename}.csv", index=False)


def experiment(
    X,
    y,
    fs_cls,
    fs_kwargs,
    clf_cls,
    clf_kwargs,
    n_features,
    k_param_name,
    requires_estimator,
    train_test_seeds,
):
    # Run experiment
    start = time.time()
    accs, accs_top_20pc = _experiment_internal(
        X,
        y,
        fs_cls,
        fs_kwargs,
        clf_cls,
        clf_kwargs,
        n_features,
        k_param_name,
        requires_estimator,
        train_test_seeds,
    )
    elapsed = time.time() - start
    elapsed = elapsed / len(train_test_seeds)

    acc = accs.mean()
    acc_std = accs.std()
    acc_top_20pc = accs_top_20pc.mean()

    result = (
        fs_cls.__name__,
        get_params_json(fs_kwargs),
        clf_cls.__name__,
        get_params_json(clf_kwargs),
        n_features,
        acc,
        acc_std,
        acc_top_20pc,
        elapsed,
    )

    return result


def _experiment_internal(
    X,
    y,
    fs_cls,
    fs_kwargs,
    clf_cls,
    clf_kwargs,
    n_features,
    k_param_name,
    requires_estimator,
    train_test_seeds,
):
    clf = clf_cls(**clf_kwargs)

    fs_kwargs = {
        k_param_name: n_features,
        **fs_kwargs,
    }
    if requires_estimator:
        feature_selector = fs_cls(estimator=clf, **fs_kwargs)
    else:
        feature_selector = fs_cls(**fs_kwargs)

    accs = []
    accs_top_20pc = []

    for seed in train_test_seeds:
        X_train, X_test, y_train, y_test = train_test_split(
            X,
            y,
            test_size=0.2,
            stratify=y,
            random_state=seed,
        )

        # Feature selection
        cols = [105,100,101,102,103,104,8,113,2,391]

        X_train = X_train[:, cols[:n_features]]
        X_test = X_test[:, cols[:n_features]]

        # Training
        clf.fit(X_train, y_train)

        # Prediction
        pred = clf.predict(X_test)

        proba_1 = clf.predict_proba(X_test)[:, 1]
        proba_1 = np.array([proba_1, y_test]).T
        proba_1 = proba_1[proba_1[:, 0].argsort()][::-1]

        # Evaluation
        acc = accuracy_score(y_test, pred)
        top_20pc = proba_1[: int(len(proba_1) * 0.2)]
        acc_top_20pc = accuracy_score(top_20pc[:, 1], np.round(top_20pc[:, 0]))

        print(seed, acc)

        accs.append(acc)
        accs_top_20pc.append(acc_top_20pc)

    return np.array(accs), np.array(accs_top_20pc)

# %%
def run_experiment(feature_selectors, classifiers, ks, results, train_test_seeds=[42]):
    for fs in feature_selectors:
        for clf in classifiers:
            for k in ks:
                # Generate parameter combinations
                fs_cls, fs_params, k_param_name, requires_estimator = fs
                clf_cls, clf_params = clf

                fs_param_combinations = get_param_combinations(fs_params)
                clf_param_combinations = get_param_combinations(clf_params)

                for fs_params in fs_param_combinations:
                    for clf_params in clf_param_combinations:
                        result = experiment(
                            X,
                            y,
                            fs_cls,
                            fs_params,
                            clf_cls,
                            clf_params,
                            k,
                            k_param_name,
                            requires_estimator,
                            train_test_seeds,
                        )

                        print(result)
                        print(f"Elapsed time: {result[-1]:.2f}s\n")
                        results.append(result)
                        save_results(results, filename)

# %%
results = []

filename = "svm_grid_search"

feature_selectors = [
     (SelectFromModel, {"threshold": [-np.inf]}, "max_features", True)
]

classifiers = [
    (
        SVC,
        {"kernel" : ['linear', 'poly', 'rbf', 'sigmoid'],
         "degree" : [3,4,5],
         'gamma' : ['scale', 'auto'],
         'coef0' : [0, 1/8, 1/4, 1/2, 1],
         'probability' : [True]
        },
    )
]

ks = np.arange(1, 7, 1)
train_test_seeds = list(range(42, 47))

run_experiment(feature_selectors, classifiers, ks, results, train_test_seeds)
# Out:
# 42 0.509
# 43 0.522
# 44 0.54
# 45 0.528
# 46 0.514
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'linear', 'degree': 3, 'gamma': 'scale', 'coef0': 0, 'probability': true}", 1, 0.5226000000000001, 0.010873821775254557, 0.5589999999999999, 1.6629682540893556)
# Elapsed time: 1.66s
#
# 42 0.509
# 43 0.522
# 44 0.54
# 45 0.528
# 46 0.514
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'linear', 'degree': 3, 'gamma': 'scale', 'coef0': 0.125, 'probability': true}", 1, 0.5226000000000001, 0.010873821775254557, 0.5650000000000001, 1.7007025241851808)
# Elapsed time: 1.70s
#
# 42 0.509
# 43 0.522
# 44 0.54
# 45 0.528
# 46 0.514
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'linear', 'degree': 3, 'gamma': 'scale', 'coef0': 0.25, 'probability': true}", 1, 0.5226000000000001, 0.010873821775254557, 0.556, 1.7879930973052978)
# Elapsed time: 1.79s
#
# 42 0.509
# 43 0.522
# 44 0.54
# 45 0.528
# 46 0.514
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'linear', 'degree': 3, 'gamma': 'scale', 'coef0': 0.5, 'probability': true}", 1, 0.5226000000000001, 0.010873821775254557, 0.5690000000000001, 1.6196101188659668)
# Elapsed time: 1.62s
#
# 42 0.509
# 43 0.522
# 44 0.54
# 45 0.528
# 46 0.514
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'linear', 'degree': 3, 'gamma': 'scale', 'coef0': 1, 'probability': true}", 1, 0.5226000000000001, 0.010873821775254557, 0.5549999999999999, 1.5614083766937257)
# Elapsed time: 1.56s
#
# 42 0.509
# 43 0.522
# 44 0.54
# 45 0.528
# 46 0.514
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'linear', 'degree': 3, 'gamma': 'auto', 'coef0': 0, 'probability': true}", 1, 0.5226000000000001, 0.010873821775254557, 0.534, 1.7519497871398926)
# Elapsed time: 1.75s
#
# 42 0.509
# 43 0.522
# 44 0.54
# 45 0.528
# 46 0.514
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'linear', 'degree': 3, 'gamma': 'auto', 'coef0': 0.125, 'probability': true}", 1, 0.5226000000000001, 0.010873821775254557, 0.57, 1.6876375198364257)
# Elapsed time: 1.69s
#
# 42 0.509
# 43 0.522
# 44 0.54
# 45 0.528
# 46 0.514
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'linear', 'degree': 3, 'gamma': 'auto', 'coef0': 0.25, 'probability': true}", 1, 0.5226000000000001, 0.010873821775254557, 0.582, 1.6472747802734375)
# Elapsed time: 1.65s
#
# 42 0.509
# 43 0.522
# 44 0.54
# 45 0.528
# 46 0.514
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'linear', 'degree': 3, 'gamma': 'auto', 'coef0': 0.5, 'probability': true}", 1, 0.5226000000000001, 0.010873821775254557, 0.576, 1.5858388423919678)
# Elapsed time: 1.59s
#
# 42 0.509
# 43 0.522
# 44 0.54
# 45 0.528
# 46 0.514
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'linear', 'degree': 3, 'gamma': 'auto', 'coef0': 1, 'probability': true}", 1, 0.5226000000000001, 0.010873821775254557, 0.563, 1.5960894107818604)
# Elapsed time: 1.60s
#
# 42 0.509
# 43 0.522
# 44 0.54
# 45 0.528
# 46 0.514
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'linear', 'degree': 4, 'gamma': 'scale', 'coef0': 0, 'probability': true}", 1, 0.5226000000000001, 0.010873821775254557, 0.5730000000000001, 1.5530795097351073)
# Elapsed time: 1.55s
#
# 42 0.509
# 43 0.522
# 44 0.54
# 45 0.528
# 46 0.514
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'linear', 'degree': 4, 'gamma': 'scale', 'coef0': 0.125, 'probability': true}", 1, 0.5226000000000001, 0.010873821775254557, 0.5619999999999999, 1.5241209983825683)
# Elapsed time: 1.52s
#
# 42 0.509
# 43 0.522
# 44 0.54
# 45 0.528
# 46 0.514
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'linear', 'degree': 4, 'gamma': 'scale', 'coef0': 0.25, 'probability': true}", 1, 0.5226000000000001, 0.010873821775254557, 0.567, 1.5467962265014648)
# Elapsed time: 1.55s
#
# 42 0.509
# 43 0.522
# 44 0.54
# 45 0.528
# 46 0.514
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'linear', 'degree': 4, 'gamma': 'scale', 'coef0': 0.5, 'probability': true}", 1, 0.5226000000000001, 0.010873821775254557, 0.548, 1.6501530647277831)
# Elapsed time: 1.65s
#
# 42 0.509
# 43 0.522
# 44 0.54
# 45 0.528
# 46 0.514
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'linear', 'degree': 4, 'gamma': 'scale', 'coef0': 1, 'probability': true}", 1, 0.5226000000000001, 0.010873821775254557, 0.57, 1.8011302471160888)
# Elapsed time: 1.80s
#
# 42 0.509
# 43 0.522
# 44 0.54
# 45 0.528
# 46 0.514
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'linear', 'degree': 4, 'gamma': 'auto', 'coef0': 0, 'probability': true}", 1, 0.5226000000000001, 0.010873821775254557, 0.576, 1.6068707942962646)
# Elapsed time: 1.61s
#
# 42 0.509
# 43 0.522
# 44 0.54
# 45 0.528
# 46 0.514
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'linear', 'degree': 4, 'gamma': 'auto', 'coef0': 0.125, 'probability': true}", 1, 0.5226000000000001, 0.010873821775254557, 0.562, 1.5848415851593018)
# Elapsed time: 1.58s
#
# 42 0.509
# 43 0.522
# 44 0.54
# 45 0.528
# 46 0.514
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'linear', 'degree': 4, 'gamma': 'auto', 'coef0': 0.25, 'probability': true}", 1, 0.5226000000000001, 0.010873821775254557, 0.577, 1.5972745895385743)
# Elapsed time: 1.60s
#
# 42 0.509
# 43 0.522
# 44 0.54
# 45 0.528
# 46 0.514
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'linear', 'degree': 4, 'gamma': 'auto', 'coef0': 0.5, 'probability': true}", 1, 0.5226000000000001, 0.010873821775254557, 0.582, 1.5298007488250733)
# Elapsed time: 1.53s
#
# 42 0.509
# 43 0.522
# 44 0.54
# 45 0.528
# 46 0.514
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'linear', 'degree': 4, 'gamma': 'auto', 'coef0': 1, 'probability': true}", 1, 0.5226000000000001, 0.010873821775254557, 0.579, 1.5432458877563477)
# Elapsed time: 1.54s
#
# 42 0.509
# 43 0.522
# 44 0.54
# 45 0.528
# 46 0.514
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'linear', 'degree': 5, 'gamma': 'scale', 'coef0': 0, 'probability': true}", 1, 0.5226000000000001, 0.010873821775254557, 0.5609999999999999, 1.5492910861968994)
# Elapsed time: 1.55s
#
# 42 0.509
# 43 0.522
# 44 0.54
# 45 0.528
# 46 0.514
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'linear', 'degree': 5, 'gamma': 'scale', 'coef0': 0.125, 'probability': true}", 1, 0.5226000000000001, 0.010873821775254557, 0.5469999999999999, 1.580846405029297)
# Elapsed time: 1.58s
#
# 42 0.509
# 43 0.522
# 44 0.54
# 45 0.528
# 46 0.514
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'linear', 'degree': 5, 'gamma': 'scale', 'coef0': 0.25, 'probability': true}", 1, 0.5226000000000001, 0.010873821775254557, 0.576, 1.597165584564209)
# Elapsed time: 1.60s
#
# 42 0.509
# 43 0.522
# 44 0.54
# 45 0.528
# 46 0.514
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'linear', 'degree': 5, 'gamma': 'scale', 'coef0': 0.5, 'probability': true}", 1, 0.5226000000000001, 0.010873821775254557, 0.577, 1.5344823360443116)
# Elapsed time: 1.53s
#
# 42 0.509
# 43 0.522
# 44 0.54
# 45 0.528
# 46 0.514
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'linear', 'degree': 5, 'gamma': 'scale', 'coef0': 1, 'probability': true}", 1, 0.5226000000000001, 0.010873821775254557, 0.571, 1.5531147480010987)
# Elapsed time: 1.55s
#
# 42 0.509
# 43 0.522
# 44 0.54
# 45 0.528
# 46 0.514
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'linear', 'degree': 5, 'gamma': 'auto', 'coef0': 0, 'probability': true}", 1, 0.5226000000000001, 0.010873821775254557, 0.5509999999999999, 1.592506217956543)
# Elapsed time: 1.59s
#
# 42 0.509
# 43 0.522
# 44 0.54
# 45 0.528
# 46 0.514
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'linear', 'degree': 5, 'gamma': 'auto', 'coef0': 0.125, 'probability': true}", 1, 0.5226000000000001, 0.010873821775254557, 0.5730000000000001, 1.5554224967956543)
# Elapsed time: 1.56s
#
# 42 0.509
# 43 0.522
# 44 0.54
# 45 0.528
# 46 0.514
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'linear', 'degree': 5, 'gamma': 'auto', 'coef0': 0.25, 'probability': true}", 1, 0.5226000000000001, 0.010873821775254557, 0.5710000000000001, 1.5421350955963136)
# Elapsed time: 1.54s
#
# 42 0.509
# 43 0.522
# 44 0.54
# 45 0.528
# 46 0.514
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'linear', 'degree': 5, 'gamma': 'auto', 'coef0': 0.5, 'probability': true}", 1, 0.5226000000000001, 0.010873821775254557, 0.548, 1.5417170524597168)
# Elapsed time: 1.54s
#
# 42 0.509
# 43 0.522
# 44 0.54
# 45 0.528
# 46 0.514
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'linear', 'degree': 5, 'gamma': 'auto', 'coef0': 1, 'probability': true}", 1, 0.5226000000000001, 0.010873821775254557, 0.5549999999999999, 1.5916592121124267)
# Elapsed time: 1.59s
#
# 42 0.511
# 43 0.514
# 44 0.506
# 45 0.505
# 46 0.51
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'poly', 'degree': 3, 'gamma': 'scale', 'coef0': 0, 'probability': true}", 1, 0.5092000000000001, 0.003310589071449373, 0.5439999999999999, 2.902553749084473)
# Elapsed time: 2.90s
#
# 42 0.563
# 43 0.551
# 44 0.562
# 45 0.569
# 46 0.562
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'poly', 'degree': 3, 'gamma': 'scale', 'coef0': 0.125, 'probability': true}", 1, 0.5614000000000001, 0.005817215828899565, 0.647, 2.662513828277588)
# Elapsed time: 2.66s
#
# 42 0.56
# 43 0.549
# 44 0.563
# 45 0.568
# 46 0.562
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'poly', 'degree': 3, 'gamma': 'scale', 'coef0': 0.25, 'probability': true}", 1, 0.5603999999999999, 0.0062801273872430015, 0.6460000000000001, 2.5416619777679443)
# Elapsed time: 2.54s
#
# 42 0.563
# 43 0.549
# 44 0.563
# 45 0.567
# 46 0.562
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'poly', 'degree': 3, 'gamma': 'scale', 'coef0': 0.5, 'probability': true}", 1, 0.5608000000000001, 0.006144916598294854, 0.6460000000000001, 2.408059024810791)
# Elapsed time: 2.41s
#
# 42 0.563
# 43 0.549
# 44 0.563
# 45 0.567
# 46 0.562
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'poly', 'degree': 3, 'gamma': 'scale', 'coef0': 1, 'probability': true}", 1, 0.5608000000000001, 0.006144916598294854, 0.6460000000000001, 2.560343074798584)
# Elapsed time: 2.56s
#
# 42 0.511
# 43 0.514
# 44 0.506
# 45 0.505
# 46 0.51
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'poly', 'degree': 3, 'gamma': 'auto', 'coef0': 0, 'probability': true}", 1, 0.5092000000000001, 0.003310589071449373, 0.556, 3.0293508052825926)
# Elapsed time: 3.03s
#
# 42 0.563
# 43 0.551
# 44 0.562
# 45 0.569
# 46 0.562
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'poly', 'degree': 3, 'gamma': 'auto', 'coef0': 0.125, 'probability': true}", 1, 0.5614000000000001, 0.005817215828899565, 0.647, 2.643949031829834)
# Elapsed time: 2.64s
#
# 42 0.56
# 43 0.549
# 44 0.563
# 45 0.568
# 46 0.562
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'poly', 'degree': 3, 'gamma': 'auto', 'coef0': 0.25, 'probability': true}", 1, 0.5603999999999999, 0.0062801273872430015, 0.6460000000000001, 2.6280231952667235)
# Elapsed time: 2.63s
#
# 42 0.563
# 43 0.549
# 44 0.563
# 45 0.567
# 46 0.562
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'poly', 'degree': 3, 'gamma': 'auto', 'coef0': 0.5, 'probability': true}", 1, 0.5608000000000001, 0.006144916598294854, 0.6460000000000001, 2.4099730014801026)
# Elapsed time: 2.41s
#
# 42 0.563
# 43 0.549
# 44 0.563
# 45 0.567
# 46 0.562
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'poly', 'degree': 3, 'gamma': 'auto', 'coef0': 1, 'probability': true}", 1, 0.5608000000000001, 0.006144916598294854, 0.6460000000000001, 2.5394177436828613)
# Elapsed time: 2.54s
#
# 42 0.547
# 43 0.539
# 44 0.53
# 45 0.534
# 46 0.536
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'poly', 'degree': 4, 'gamma': 'scale', 'coef0': 0, 'probability': true}", 1, 0.5372000000000001, 0.005706137047074847, 0.618, 4.677971410751343)
# Elapsed time: 4.68s
#
# 42 0.567
# 43 0.56
# 44 0.562
# 45 0.563
# 46 0.561
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'poly', 'degree': 4, 'gamma': 'scale', 'coef0': 0.125, 'probability': true}", 1, 0.5626, 0.0024166091947188727, 0.645, 3.5716340065002443)
# Elapsed time: 3.57s
#
# 42 0.562
# 43 0.56
# 44 0.562
# 45 0.56
# 46 0.559
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'poly', 'degree': 4, 'gamma': 'scale', 'coef0': 0.25, 'probability': true}", 1, 0.5606000000000001, 0.001200000000000001, 0.6450000000000001, 3.5857162952423094)
# Elapsed time: 3.59s
#
# 42 0.562
# 43 0.56
# 44 0.562
# 45 0.56
# 46 0.559
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'poly', 'degree': 4, 'gamma': 'scale', 'coef0': 0.5, 'probability': true}", 1, 0.5606000000000001, 0.001200000000000001, 0.6450000000000001, 3.9906447887420655)
# Elapsed time: 3.99s
#
# 42 0.562
# 43 0.56
# 44 0.562
# 45 0.56
# 46 0.559
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'poly', 'degree': 4, 'gamma': 'scale', 'coef0': 1, 'probability': true}", 1, 0.5606000000000001, 0.001200000000000001, 0.6450000000000001, 5.056215047836304)
# Elapsed time: 5.06s
#
# 42 0.547
# 43 0.539
# 44 0.53
# 45 0.534
# 46 0.536
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'poly', 'degree': 4, 'gamma': 'auto', 'coef0': 0, 'probability': true}", 1, 0.5372000000000001, 0.005706137047074847, 0.615, 5.211779975891114)
# Elapsed time: 5.21s
#
# 42 0.567
# 43 0.56
# 44 0.562
# 45 0.563
# 46 0.561
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'poly', 'degree': 4, 'gamma': 'auto', 'coef0': 0.125, 'probability': true}", 1, 0.5626, 0.0024166091947188727, 0.645, 3.502748489379883)
# Elapsed time: 3.50s
#
# 42 0.562
# 43 0.56
# 44 0.562
# 45 0.56
# 46 0.559
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'poly', 'degree': 4, 'gamma': 'auto', 'coef0': 0.25, 'probability': true}", 1, 0.5606000000000001, 0.001200000000000001, 0.6450000000000001, 4.098249769210815)
# Elapsed time: 4.10s
#
# 42 0.562
# 43 0.56
# 44 0.562
# 45 0.56
# 46 0.559
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'poly', 'degree': 4, 'gamma': 'auto', 'coef0': 0.5, 'probability': true}", 1, 0.5606000000000001, 0.001200000000000001, 0.6450000000000001, 3.8752206802368163)
# Elapsed time: 3.88s
#
# 42 0.562
# 43 0.56
# 44 0.562
# 45 0.56
# 46 0.559
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'poly', 'degree': 4, 'gamma': 'auto', 'coef0': 1, 'probability': true}", 1, 0.5606000000000001, 0.001200000000000001, 0.6450000000000001, 5.599429607391357)
# Elapsed time: 5.60s
#
# 42 0.502
# 43 0.502
# 44 0.503
# 45 0.502
# 46 0.5
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'poly', 'degree': 5, 'gamma': 'scale', 'coef0': 0, 'probability': true}", 1, 0.5018, 0.000979795897113272, 0.5439999999999999, 176.6268291950226)
# Elapsed time: 176.63s
#
# 42 0.566
# 43 0.554
# 44 0.565
# 45 0.565
# 46 0.562
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'poly', 'degree': 5, 'gamma': 'scale', 'coef0': 0.125, 'probability': true}", 1, 0.5624, 0.00440908153700968, 0.643, 18.665101194381712)
# Elapsed time: 18.67s
#
# 42 0.565
# 43 0.556
# 44 0.558
# 45 0.562
# 46 0.558
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'poly', 'degree': 5, 'gamma': 'scale', 'coef0': 0.25, 'probability': true}", 1, 0.5598000000000001, 0.0032496153618543516, 0.6439999999999999, 19.243312692642213)
# Elapsed time: 19.24s
#
# 42 0.566
# 43 0.559
# 44 0.561
# 45 0.564
# 46 0.562
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'poly', 'degree': 5, 'gamma': 'scale', 'coef0': 0.5, 'probability': true}", 1, 0.5624, 0.0024166091947188688, 0.647, 26.236846590042113)
# Elapsed time: 26.24s
#
# 42 0.564
# 43 0.56
# 44 0.563
# 45 0.563
# 46 0.561
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'poly', 'degree': 5, 'gamma': 'scale', 'coef0': 1, 'probability': true}", 1, 0.5622, 0.0014696938456698568, 0.648, 28.929815006256103)
# Elapsed time: 28.93s
#
# 42 0.502
# 43 0.502
# 44 0.503
# 45 0.502
# 46 0.5
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'poly', 'degree': 5, 'gamma': 'auto', 'coef0': 0, 'probability': true}", 1, 0.5018, 0.000979795897113272, 0.533, 119.0070297241211)
# Elapsed time: 119.01s
#
# 42 0.566
# 43 0.554
# 44 0.563
# 45 0.565
# 46 0.563
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'poly', 'degree': 5, 'gamma': 'auto', 'coef0': 0.125, 'probability': true}", 1, 0.5622, 0.004261455150532465, 0.643, 19.163247299194335)
# Elapsed time: 19.16s
#
# 42 0.565
# 43 0.556
# 44 0.559
# 45 0.562
# 46 0.558
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'poly', 'degree': 5, 'gamma': 'auto', 'coef0': 0.25, 'probability': true}", 1, 0.5599999999999999, 0.003162277660168347, 0.6439999999999999, 19.068750619888306)
# Elapsed time: 19.07s
#
# 42 0.566
# 43 0.559
# 44 0.561
# 45 0.564
# 46 0.563
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'poly', 'degree': 5, 'gamma': 'auto', 'coef0': 0.5, 'probability': true}", 1, 0.5626, 0.0024166091947188688, 0.649, 26.294993829727172)
# Elapsed time: 26.29s
#
# 42 0.564
# 43 0.559
# 44 0.562
# 45 0.563
# 46 0.561
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'poly', 'degree': 5, 'gamma': 'auto', 'coef0': 1, 'probability': true}", 1, 0.5618000000000001, 0.001720465053408483, 0.648, 29.459464645385744)
# Elapsed time: 29.46s
#
# 42 0.566
# 43 0.56
# 44 0.565
# 45 0.571
# 46 0.564
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'rbf', 'degree': 3, 'gamma': 'scale', 'coef0': 0, 'probability': true}", 1, 0.5651999999999999, 0.0035440090293338404, 0.646, 3.815250873565674)
# Elapsed time: 3.82s
#
# 42 0.566
# 43 0.56
# 44 0.565
# 45 0.571
# 46 0.564
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'rbf', 'degree': 3, 'gamma': 'scale', 'coef0': 0.125, 'probability': true}", 1, 0.5651999999999999, 0.0035440090293338404, 0.646, 4.08672571182251)
# Elapsed time: 4.09s
#
# 42 0.566
# 43 0.56
# 44 0.565
# 45 0.571
# 46 0.564
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'rbf', 'degree': 3, 'gamma': 'scale', 'coef0': 0.25, 'probability': true}", 1, 0.5651999999999999, 0.0035440090293338404, 0.646, 3.79984769821167)
# Elapsed time: 3.80s
#
# 42 0.566
# 43 0.56
# 44 0.565
# 45 0.571
# 46 0.564
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'rbf', 'degree': 3, 'gamma': 'scale', 'coef0': 0.5, 'probability': true}", 1, 0.5651999999999999, 0.0035440090293338404, 0.646, 3.916542387008667)
# Elapsed time: 3.92s
#
# 42 0.566
# 43 0.56
# 44 0.565
# 45 0.571
# 46 0.564
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'rbf', 'degree': 3, 'gamma': 'scale', 'coef0': 1, 'probability': true}", 1, 0.5651999999999999, 0.0035440090293338404, 0.646, 4.508523178100586)
# Elapsed time: 4.51s
#
# 42 0.566
# 43 0.561
# 44 0.565
# 45 0.571
# 46 0.563
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'rbf', 'degree': 3, 'gamma': 'auto', 'coef0': 0, 'probability': true}", 1, 0.5651999999999999, 0.003370459909270519, 0.646, 4.187100982666015)
# Elapsed time: 4.19s
#
# 42 0.566
# 43 0.561
# 44 0.565
# 45 0.571
# 46 0.563
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'rbf', 'degree': 3, 'gamma': 'auto', 'coef0': 0.125, 'probability': true}", 1, 0.5651999999999999, 0.003370459909270519, 0.646, 3.8695656299591064)
# Elapsed time: 3.87s
#
# 42 0.566
# 43 0.561
# 44 0.565
# 45 0.571
# 46 0.563
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'rbf', 'degree': 3, 'gamma': 'auto', 'coef0': 0.25, 'probability': true}", 1, 0.5651999999999999, 0.003370459909270519, 0.646, 3.938925838470459)
# Elapsed time: 3.94s
#
# 42 0.566
# 43 0.561
# 44 0.565
# 45 0.571
# 46 0.563
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'rbf', 'degree': 3, 'gamma': 'auto', 'coef0': 0.5, 'probability': true}", 1, 0.5651999999999999, 0.003370459909270519, 0.646, 3.8709339141845702)
# Elapsed time: 3.87s
#
# 42 0.566
# 43 0.561
# 44 0.565
# 45 0.571
# 46 0.563
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'rbf', 'degree': 3, 'gamma': 'auto', 'coef0': 1, 'probability': true}", 1, 0.5651999999999999, 0.003370459909270519, 0.646, 4.114491128921509)
# Elapsed time: 4.11s
#
# 42 0.566
# 43 0.56
# 44 0.565
# 45 0.571
# 46 0.564
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'rbf', 'degree': 4, 'gamma': 'scale', 'coef0': 0, 'probability': true}", 1, 0.5651999999999999, 0.0035440090293338404, 0.646, 4.276445770263672)
# Elapsed time: 4.28s
#
# 42 0.566
# 43 0.56
# 44 0.565
# 45 0.571
# 46 0.564
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'rbf', 'degree': 4, 'gamma': 'scale', 'coef0': 0.125, 'probability': true}", 1, 0.5651999999999999, 0.0035440090293338404, 0.646, 3.845178174972534)
# Elapsed time: 3.85s
#
# 42 0.566
# 43 0.56
# 44 0.565
# 45 0.571
# 46 0.564
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'rbf', 'degree': 4, 'gamma': 'scale', 'coef0': 0.25, 'probability': true}", 1, 0.5651999999999999, 0.0035440090293338404, 0.646, 3.8607160568237306)
# Elapsed time: 3.86s
#
# 42 0.566
# 43 0.56
# 44 0.565
# 45 0.571
# 46 0.564
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'rbf', 'degree': 4, 'gamma': 'scale', 'coef0': 0.5, 'probability': true}", 1, 0.5651999999999999, 0.0035440090293338404, 0.646, 3.7751769065856933)
# Elapsed time: 3.78s
#
# 42 0.566
# 43 0.56
# 44 0.565
# 45 0.571
# 46 0.564
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'rbf', 'degree': 4, 'gamma': 'scale', 'coef0': 1, 'probability': true}", 1, 0.5651999999999999, 0.0035440090293338404, 0.646, 3.8851127147674562)
# Elapsed time: 3.89s
#
# 42 0.566
# 43 0.561
# 44 0.565
# 45 0.571
# 46 0.563
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'rbf', 'degree': 4, 'gamma': 'auto', 'coef0': 0, 'probability': true}", 1, 0.5651999999999999, 0.003370459909270519, 0.646, 3.798516321182251)
# Elapsed time: 3.80s
#
# 42 0.566
# 43 0.561
# 44 0.565
# 45 0.571
# 46 0.563
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'rbf', 'degree': 4, 'gamma': 'auto', 'coef0': 0.125, 'probability': true}", 1, 0.5651999999999999, 0.003370459909270519, 0.646, 3.8125685691833495)
# Elapsed time: 3.81s
#
# 42 0.566
# 43 0.561
# 44 0.565
# 45 0.571
# 46 0.563
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'rbf', 'degree': 4, 'gamma': 'auto', 'coef0': 0.25, 'probability': true}", 1, 0.5651999999999999, 0.003370459909270519, 0.646, 3.842027521133423)
# Elapsed time: 3.84s
#
# 42 0.566
# 43 0.561
# 44 0.565
# 45 0.571
# 46 0.563
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'rbf', 'degree': 4, 'gamma': 'auto', 'coef0': 0.5, 'probability': true}", 1, 0.5651999999999999, 0.003370459909270519, 0.646, 3.780652093887329)
# Elapsed time: 3.78s
#
# 42 0.566
# 43 0.561
# 44 0.565
# 45 0.571
# 46 0.563
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'rbf', 'degree': 4, 'gamma': 'auto', 'coef0': 1, 'probability': true}", 1, 0.5651999999999999, 0.003370459909270519, 0.646, 3.8116806030273436)
# Elapsed time: 3.81s
#
# 42 0.566
# 43 0.56
# 44 0.565
# 45 0.571
# 46 0.564
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'rbf', 'degree': 5, 'gamma': 'scale', 'coef0': 0, 'probability': true}", 1, 0.5651999999999999, 0.0035440090293338404, 0.646, 3.755988073348999)
# Elapsed time: 3.76s
#
# 42 0.566
# 43 0.56
# 44 0.565
# 45 0.571
# 46 0.564
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'rbf', 'degree': 5, 'gamma': 'scale', 'coef0': 0.125, 'probability': true}", 1, 0.5651999999999999, 0.0035440090293338404, 0.646, 3.865932083129883)
# Elapsed time: 3.87s
#
# 42 0.566
# 43 0.56
# 44 0.565
# 45 0.571
# 46 0.564
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'rbf', 'degree': 5, 'gamma': 'scale', 'coef0': 0.25, 'probability': true}", 1, 0.5651999999999999, 0.0035440090293338404, 0.646, 3.8094308853149412)
# Elapsed time: 3.81s
#
# 42 0.566
# 43 0.56
# 44 0.565
# 45 0.571
# 46 0.564
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'rbf', 'degree': 5, 'gamma': 'scale', 'coef0': 0.5, 'probability': true}", 1, 0.5651999999999999, 0.0035440090293338404, 0.646, 3.7758481979370115)
# Elapsed time: 3.78s
#
# 42 0.566
# 43 0.56
# 44 0.565
# 45 0.571
# 46 0.564
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'rbf', 'degree': 5, 'gamma': 'scale', 'coef0': 1, 'probability': true}", 1, 0.5651999999999999, 0.0035440090293338404, 0.646, 3.9062222480773925)
# Elapsed time: 3.91s
#
# 42 0.566
# 43 0.561
# 44 0.565
# 45 0.571
# 46 0.563
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'rbf', 'degree': 5, 'gamma': 'auto', 'coef0': 0, 'probability': true}", 1, 0.5651999999999999, 0.003370459909270519, 0.646, 3.866765928268433)
# Elapsed time: 3.87s
#
# 42 0.566
# 43 0.561
# 44 0.565
# 45 0.571
# 46 0.563
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'rbf', 'degree': 5, 'gamma': 'auto', 'coef0': 0.125, 'probability': true}", 1, 0.5651999999999999, 0.003370459909270519, 0.646, 3.834297227859497)
# Elapsed time: 3.83s
#
# 42 0.566
# 43 0.561
# 44 0.565
# 45 0.571
# 46 0.563
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'rbf', 'degree': 5, 'gamma': 'auto', 'coef0': 0.25, 'probability': true}", 1, 0.5651999999999999, 0.003370459909270519, 0.646, 3.802607774734497)
# Elapsed time: 3.80s
#
# 42 0.566
# 43 0.561
# 44 0.565
# 45 0.571
# 46 0.563
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'rbf', 'degree': 5, 'gamma': 'auto', 'coef0': 0.5, 'probability': true}", 1, 0.5651999999999999, 0.003370459909270519, 0.646, 4.011919212341309)
# Elapsed time: 4.01s
#
# 42 0.566
# 43 0.561
# 44 0.565
# 45 0.571
# 46 0.563
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'rbf', 'degree': 5, 'gamma': 'auto', 'coef0': 1, 'probability': true}", 1, 0.5651999999999999, 0.003370459909270519, 0.646, 4.302530193328858)
# Elapsed time: 4.30s
#
# 42 0.489
# 43 0.507
# 44 0.489
# 45 0.502
# 46 0.503
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'sigmoid', 'degree': 3, 'gamma': 'scale', 'coef0': 0, 'probability': true}", 1, 0.49799999999999994, 0.007536577472566717, 0.54, 1.5012019634246827)
# Elapsed time: 1.50s
#
# 42 0.486
# 43 0.503
# 44 0.495
# 45 0.503
# 46 0.502
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'sigmoid', 'degree': 3, 'gamma': 'scale', 'coef0': 0.125, 'probability': true}", 1, 0.49779999999999996, 0.006615134163416496, 0.55, 1.4686611652374268)
# Elapsed time: 1.47s
#
# 42 0.482
# 43 0.487
# 44 0.499
# 45 0.492
# 46 0.498
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'sigmoid', 'degree': 3, 'gamma': 'scale', 'coef0': 0.25, 'probability': true}", 1, 0.49160000000000004, 0.006468384651518498, 0.5589999999999999, 1.5425245761871338)
# Elapsed time: 1.54s
#
# 42 0.44
# 43 0.437
# 44 0.441
# 45 0.436
# 46 0.437
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'sigmoid', 'degree': 3, 'gamma': 'scale', 'coef0': 0.5, 'probability': true}", 1, 0.4382, 0.0019390719429665333, 0.619, 2.2293148040771484)
# Elapsed time: 2.23s
#
# 42 0.44
# 43 0.558
# 44 0.441
# 45 0.554
# 46 0.44
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'sigmoid', 'degree': 3, 'gamma': 'scale', 'coef0': 1, 'probability': true}", 1, 0.48660000000000003, 0.056680155257373833, 0.5640000000000001, 1.8502042770385743)
# Elapsed time: 1.85s
#
# 42 0.489
# 43 0.509
# 44 0.489
# 45 0.502
# 46 0.502
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'sigmoid', 'degree': 3, 'gamma': 'auto', 'coef0': 0, 'probability': true}", 1, 0.49820000000000003, 0.007934733769950957, 0.5439999999999999, 1.5509117603302003)
# Elapsed time: 1.55s
#
# 42 0.487
# 43 0.503
# 44 0.495
# 45 0.503
# 46 0.5
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'sigmoid', 'degree': 3, 'gamma': 'auto', 'coef0': 0.125, 'probability': true}", 1, 0.4976, 0.006053098380168627, 0.5469999999999999, 1.4588633060455323)
# Elapsed time: 1.46s
#
# 42 0.481
# 43 0.489
# 44 0.498
# 45 0.492
# 46 0.496
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'sigmoid', 'degree': 3, 'gamma': 'auto', 'coef0': 0.25, 'probability': true}", 1, 0.49119999999999997, 0.0059799665550904265, 0.5599999999999999, 1.4722474575042725)
# Elapsed time: 1.47s
#
# 42 0.44
# 43 0.437
# 44 0.441
# 45 0.436
# 46 0.437
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'sigmoid', 'degree': 3, 'gamma': 'auto', 'coef0': 0.5, 'probability': true}", 1, 0.4382, 0.0019390719429665333, 0.615, 2.1227625370025636)
# Elapsed time: 2.12s
#
# 42 0.44
# 43 0.558
# 44 0.441
# 45 0.554
# 46 0.44
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'sigmoid', 'degree': 3, 'gamma': 'auto', 'coef0': 1, 'probability': true}", 1, 0.48660000000000003, 0.056680155257373833, 0.522, 1.8626864910125733)
# Elapsed time: 1.86s
#
# 42 0.489
# 43 0.507
# 44 0.489
# 45 0.502
# 46 0.503
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'sigmoid', 'degree': 4, 'gamma': 'scale', 'coef0': 0, 'probability': true}", 1, 0.49799999999999994, 0.007536577472566717, 0.5170000000000001, 1.4940459728240967)
# Elapsed time: 1.49s
#
# 42 0.486
# 43 0.503
# 44 0.495
# 45 0.503
# 46 0.502
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'sigmoid', 'degree': 4, 'gamma': 'scale', 'coef0': 0.125, 'probability': true}", 1, 0.49779999999999996, 0.006615134163416496, 0.5519999999999999, 1.4890593051910401)
# Elapsed time: 1.49s
#
# 42 0.482
# 43 0.487
# 44 0.499
# 45 0.492
# 46 0.498
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'sigmoid', 'degree': 4, 'gamma': 'scale', 'coef0': 0.25, 'probability': true}", 1, 0.49160000000000004, 0.006468384651518498, 0.5589999999999999, 1.490851354598999)
# Elapsed time: 1.49s
#
# 42 0.44
# 43 0.437
# 44 0.441
# 45 0.436
# 46 0.437
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'sigmoid', 'degree': 4, 'gamma': 'scale', 'coef0': 0.5, 'probability': true}", 1, 0.4382, 0.0019390719429665333, 0.619, 2.2013801097869874)
# Elapsed time: 2.20s
#
# 42 0.44
# 43 0.558
# 44 0.441
# 45 0.554
# 46 0.44
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'sigmoid', 'degree': 4, 'gamma': 'scale', 'coef0': 1, 'probability': true}", 1, 0.48660000000000003, 0.056680155257373833, 0.481, 1.832357358932495)
# Elapsed time: 1.83s
#
# 42 0.489
# 43 0.509
# 44 0.489
# 45 0.502
# 46 0.502
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'sigmoid', 'degree': 4, 'gamma': 'auto', 'coef0': 0, 'probability': true}", 1, 0.49820000000000003, 0.007934733769950957, 0.558, 1.5007744789123536)
# Elapsed time: 1.50s
#
# 42 0.487
# 43 0.503
# 44 0.495
# 45 0.503
# 46 0.5
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'sigmoid', 'degree': 4, 'gamma': 'auto', 'coef0': 0.125, 'probability': true}", 1, 0.4976, 0.006053098380168627, 0.5359999999999999, 1.4722325801849365)
# Elapsed time: 1.47s
#
# 42 0.481
# 43 0.489
# 44 0.498
# 45 0.492
# 46 0.496
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'sigmoid', 'degree': 4, 'gamma': 'auto', 'coef0': 0.25, 'probability': true}", 1, 0.49119999999999997, 0.0059799665550904265, 0.5559999999999999, 1.4879014015197753)
# Elapsed time: 1.49s
#
# 42 0.44
# 43 0.437
# 44 0.441
# 45 0.436
# 46 0.437
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'sigmoid', 'degree': 4, 'gamma': 'auto', 'coef0': 0.5, 'probability': true}", 1, 0.4382, 0.0019390719429665333, 0.615, 2.133597707748413)
# Elapsed time: 2.13s
#
# 42 0.44
# 43 0.558
# 44 0.441
# 45 0.554
# 46 0.44
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'sigmoid', 'degree': 4, 'gamma': 'auto', 'coef0': 1, 'probability': true}", 1, 0.48660000000000003, 0.056680155257373833, 0.557, 1.8646526336669922)
# Elapsed time: 1.86s
#
# 42 0.489
# 43 0.507
# 44 0.489
# 45 0.502
# 46 0.503
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'sigmoid', 'degree': 5, 'gamma': 'scale', 'coef0': 0, 'probability': true}", 1, 0.49799999999999994, 0.007536577472566717, 0.5650000000000001, 1.5291029930114746)
# Elapsed time: 1.53s
#
# 42 0.486
# 43 0.503
# 44 0.495
# 45 0.503
# 46 0.502
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'sigmoid', 'degree': 5, 'gamma': 'scale', 'coef0': 0.125, 'probability': true}", 1, 0.49779999999999996, 0.006615134163416496, 0.529, 1.4652632236480714)
# Elapsed time: 1.47s
#
# 42 0.482
# 43 0.487
# 44 0.499
# 45 0.492
# 46 0.498
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'sigmoid', 'degree': 5, 'gamma': 'scale', 'coef0': 0.25, 'probability': true}", 1, 0.49160000000000004, 0.006468384651518498, 0.542, 1.48746018409729)
# Elapsed time: 1.49s
#
# 42 0.44
# 43 0.437
# 44 0.441
# 45 0.436
# 46 0.437
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'sigmoid', 'degree': 5, 'gamma': 'scale', 'coef0': 0.5, 'probability': true}", 1, 0.4382, 0.0019390719429665333, 0.619, 2.164131784439087)
# Elapsed time: 2.16s
#
# 42 0.44
# 43 0.558
# 44 0.441
# 45 0.554
# 46 0.44
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'sigmoid', 'degree': 5, 'gamma': 'scale', 'coef0': 1, 'probability': true}", 1, 0.48660000000000003, 0.056680155257373833, 0.561, 1.8783041000366212)
# Elapsed time: 1.88s
#
# 42 0.489
# 43 0.509
# 44 0.489
# 45 0.502
# 46 0.502
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'sigmoid', 'degree': 5, 'gamma': 'auto', 'coef0': 0, 'probability': true}", 1, 0.49820000000000003, 0.007934733769950957, 0.541, 1.5153611183166504)
# Elapsed time: 1.52s
#
# 42 0.487
# 43 0.503
# 44 0.495
# 45 0.503
# 46 0.5
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'sigmoid', 'degree': 5, 'gamma': 'auto', 'coef0': 0.125, 'probability': true}", 1, 0.4976, 0.006053098380168627, 0.5269999999999999, 1.4682297706604004)
# Elapsed time: 1.47s
#
# 42 0.481
# 43 0.489
# 44 0.498
# 45 0.492
# 46 0.496
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'sigmoid', 'degree': 5, 'gamma': 'auto', 'coef0': 0.25, 'probability': true}", 1, 0.49119999999999997, 0.0059799665550904265, 0.56, 1.5009842395782471)
# Elapsed time: 1.50s
#
# 42 0.44
# 43 0.437
# 44 0.441
# 45 0.436
# 46 0.437
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'sigmoid', 'degree': 5, 'gamma': 'auto', 'coef0': 0.5, 'probability': true}", 1, 0.4382, 0.0019390719429665333, 0.615, 2.1561124324798584)
# Elapsed time: 2.16s
#
# 42 0.44
# 43 0.558
# 44 0.441
# 45 0.554
# 46 0.44
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'sigmoid', 'degree': 5, 'gamma': 'auto', 'coef0': 1, 'probability': true}", 1, 0.48660000000000003, 0.056680155257373833, 0.442, 1.8253178596496582)
# Elapsed time: 1.83s
#
# 42 0.502
# 43 0.512
# 44 0.532
# 45 0.531
# 46 0.514
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'linear', 'degree': 3, 'gamma': 'scale', 'coef0': 0, 'probability': true}", 2, 0.5182, 0.011600000000000011, 0.562, 1.5635030746459961)
# Elapsed time: 1.56s
#
# 42 0.502
# 43 0.512
# 44 0.532
# 45 0.531
# 46 0.514
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'linear', 'degree': 3, 'gamma': 'scale', 'coef0': 0.125, 'probability': true}", 2, 0.5182, 0.011600000000000011, 0.5690000000000001, 1.5564762115478517)
# Elapsed time: 1.56s
#
# 42 0.502
# 43 0.512
# 44 0.532
# 45 0.531
# 46 0.514
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'linear', 'degree': 3, 'gamma': 'scale', 'coef0': 0.25, 'probability': true}", 2, 0.5182, 0.011600000000000011, 0.579, 1.5454537391662597)
# Elapsed time: 1.55s
#
# 42 0.502
# 43 0.512
# 44 0.532
# 45 0.531
# 46 0.514
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'linear', 'degree': 3, 'gamma': 'scale', 'coef0': 0.5, 'probability': true}", 2, 0.5182, 0.011600000000000011, 0.562, 1.6764357089996338)
# Elapsed time: 1.68s
#
# 42 0.502
# 43 0.512
# 44 0.532
# 45 0.531
# 46 0.514
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'linear', 'degree': 3, 'gamma': 'scale', 'coef0': 1, 'probability': true}", 2, 0.5182, 0.011600000000000011, 0.58, 1.5753270626068114)
# Elapsed time: 1.58s
#
# 42 0.502
# 43 0.512
# 44 0.532
# 45 0.531
# 46 0.514
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'linear', 'degree': 3, 'gamma': 'auto', 'coef0': 0, 'probability': true}", 2, 0.5182, 0.011600000000000011, 0.554, 1.7571110725402832)
# Elapsed time: 1.76s
#
# 42 0.502
# 43 0.512
# 44 0.532
# 45 0.531
# 46 0.514
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'linear', 'degree': 3, 'gamma': 'auto', 'coef0': 0.125, 'probability': true}", 2, 0.5182, 0.011600000000000011, 0.5599999999999999, 1.5410427570343017)
# Elapsed time: 1.54s
#
# 42 0.502
# 43 0.512
# 44 0.532
# 45 0.531
# 46 0.514
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'linear', 'degree': 3, 'gamma': 'auto', 'coef0': 0.25, 'probability': true}", 2, 0.5182, 0.011600000000000011, 0.5509999999999999, 1.5546052932739258)
# Elapsed time: 1.55s
#
# 42 0.502
# 43 0.512
# 44 0.532
# 45 0.531
# 46 0.514
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'linear', 'degree': 3, 'gamma': 'auto', 'coef0': 0.5, 'probability': true}", 2, 0.5182, 0.011600000000000011, 0.5820000000000001, 1.6285436153411865)
# Elapsed time: 1.63s
#
# 42 0.502
# 43 0.512
# 44 0.532
# 45 0.531
# 46 0.514
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'linear', 'degree': 3, 'gamma': 'auto', 'coef0': 1, 'probability': true}", 2, 0.5182, 0.011600000000000011, 0.563, 1.5990085124969482)
# Elapsed time: 1.60s
#
# 42 0.502
# 43 0.512
# 44 0.532
# 45 0.531
# 46 0.514
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'linear', 'degree': 4, 'gamma': 'scale', 'coef0': 0, 'probability': true}", 2, 0.5182, 0.011600000000000011, 0.568, 1.5810608863830566)
# Elapsed time: 1.58s
#
# 42 0.502
# 43 0.512
# 44 0.532
# 45 0.531
# 46 0.514
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'linear', 'degree': 4, 'gamma': 'scale', 'coef0': 0.125, 'probability': true}", 2, 0.5182, 0.011600000000000011, 0.55, 1.5428122520446776)
# Elapsed time: 1.54s
#
# 42 0.502
# 43 0.512
# 44 0.532
# 45 0.531
# 46 0.514
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'linear', 'degree': 4, 'gamma': 'scale', 'coef0': 0.25, 'probability': true}", 2, 0.5182, 0.011600000000000011, 0.5740000000000001, 1.6033661365509033)
# Elapsed time: 1.60s
#
# 42 0.502
# 43 0.512
# 44 0.532
# 45 0.531
# 46 0.514
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'linear', 'degree': 4, 'gamma': 'scale', 'coef0': 0.5, 'probability': true}", 2, 0.5182, 0.011600000000000011, 0.5660000000000001, 1.5505030155181885)
# Elapsed time: 1.55s
#
# 42 0.502
# 43 0.512
# 44 0.532
# 45 0.531
# 46 0.514
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'linear', 'degree': 4, 'gamma': 'scale', 'coef0': 1, 'probability': true}", 2, 0.5182, 0.011600000000000011, 0.5529999999999999, 1.6307799339294433)
# Elapsed time: 1.63s
#
# 42 0.502
# 43 0.512
# 44 0.532
# 45 0.531
# 46 0.514
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'linear', 'degree': 4, 'gamma': 'auto', 'coef0': 0, 'probability': true}", 2, 0.5182, 0.011600000000000011, 0.567, 1.5819898128509522)
# Elapsed time: 1.58s
#
# 42 0.502
# 43 0.512
# 44 0.532
# 45 0.531
# 46 0.514
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'linear', 'degree': 4, 'gamma': 'auto', 'coef0': 0.125, 'probability': true}", 2, 0.5182, 0.011600000000000011, 0.563, 1.539940357208252)
# Elapsed time: 1.54s
#
# 42 0.502
# 43 0.512
# 44 0.532
# 45 0.531
# 46 0.514
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'linear', 'degree': 4, 'gamma': 'auto', 'coef0': 0.25, 'probability': true}", 2, 0.5182, 0.011600000000000011, 0.5650000000000001, 1.4946736812591552)
# Elapsed time: 1.49s
#
# 42 0.502
# 43 0.512
# 44 0.532
# 45 0.531
# 46 0.514
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'linear', 'degree': 4, 'gamma': 'auto', 'coef0': 0.5, 'probability': true}", 2, 0.5182, 0.011600000000000011, 0.557, 1.508327341079712)
# Elapsed time: 1.51s
#
# 42 0.502
# 43 0.512
# 44 0.532
# 45 0.531
# 46 0.514
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'linear', 'degree': 4, 'gamma': 'auto', 'coef0': 1, 'probability': true}", 2, 0.5182, 0.011600000000000011, 0.575, 1.5536794662475586)
# Elapsed time: 1.55s
#
# 42 0.502
# 43 0.512
# 44 0.532
# 45 0.531
# 46 0.514
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'linear', 'degree': 5, 'gamma': 'scale', 'coef0': 0, 'probability': true}", 2, 0.5182, 0.011600000000000011, 0.5700000000000001, 1.6174670219421388)
# Elapsed time: 1.62s
#
# 42 0.502
# 43 0.512
# 44 0.532
# 45 0.531
# 46 0.514
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'linear', 'degree': 5, 'gamma': 'scale', 'coef0': 0.125, 'probability': true}", 2, 0.5182, 0.011600000000000011, 0.5619999999999999, 1.5364060401916504)
# Elapsed time: 1.54s
#
# 42 0.502
# 43 0.512
# 44 0.532
# 45 0.531
# 46 0.514
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'linear', 'degree': 5, 'gamma': 'scale', 'coef0': 0.25, 'probability': true}", 2, 0.5182, 0.011600000000000011, 0.5619999999999999, 1.643216037750244)
# Elapsed time: 1.64s
#
# 42 0.502
# 43 0.512
# 44 0.532
# 45 0.531
# 46 0.514
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'linear', 'degree': 5, 'gamma': 'scale', 'coef0': 0.5, 'probability': true}", 2, 0.5182, 0.011600000000000011, 0.5579999999999999, 1.5847607135772706)
# Elapsed time: 1.58s
#
# 42 0.502
# 43 0.512
# 44 0.532
# 45 0.531
# 46 0.514
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'linear', 'degree': 5, 'gamma': 'scale', 'coef0': 1, 'probability': true}", 2, 0.5182, 0.011600000000000011, 0.5660000000000001, 1.5555107116699218)
# Elapsed time: 1.56s
#
# 42 0.502
# 43 0.512
# 44 0.532
# 45 0.531
# 46 0.514
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'linear', 'degree': 5, 'gamma': 'auto', 'coef0': 0, 'probability': true}", 2, 0.5182, 0.011600000000000011, 0.582, 1.5875365734100342)
# Elapsed time: 1.59s
#
# 42 0.502
# 43 0.512
# 44 0.532
# 45 0.531
# 46 0.514
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'linear', 'degree': 5, 'gamma': 'auto', 'coef0': 0.125, 'probability': true}", 2, 0.5182, 0.011600000000000011, 0.577, 1.5957817077636718)
# Elapsed time: 1.60s
#
# 42 0.502
# 43 0.512
# 44 0.532
# 45 0.531
# 46 0.514
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'linear', 'degree': 5, 'gamma': 'auto', 'coef0': 0.25, 'probability': true}", 2, 0.5182, 0.011600000000000011, 0.5579999999999999, 1.6157673358917237)
# Elapsed time: 1.62s
#
# 42 0.502
# 43 0.512
# 44 0.532
# 45 0.531
# 46 0.514
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'linear', 'degree': 5, 'gamma': 'auto', 'coef0': 0.5, 'probability': true}", 2, 0.5182, 0.011600000000000011, 0.57, 1.6088587284088134)
# Elapsed time: 1.61s
#
# 42 0.502
# 43 0.512
# 44 0.532
# 45 0.531
# 46 0.514
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'linear', 'degree': 5, 'gamma': 'auto', 'coef0': 1, 'probability': true}", 2, 0.5182, 0.011600000000000011, 0.557, 1.5439026832580567)
# Elapsed time: 1.54s
#
# 42 0.523
# 43 0.51
# 44 0.515
# 45 0.517
# 46 0.524
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'poly', 'degree': 3, 'gamma': 'scale', 'coef0': 0, 'probability': true}", 2, 0.5178, 0.005192301994298872, 0.604, 2.475845384597778)
# Elapsed time: 2.48s
#
# 42 0.602
# 43 0.597
# 44 0.598
# 45 0.603
# 46 0.622
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'poly', 'degree': 3, 'gamma': 'scale', 'coef0': 0.125, 'probability': true}", 2, 0.6043999999999998, 0.009090654541890817, 0.69, 2.0219867706298826)
# Elapsed time: 2.02s
#
# 42 0.6
# 43 0.599
# 44 0.596
# 45 0.603
# 46 0.62
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'poly', 'degree': 3, 'gamma': 'scale', 'coef0': 0.25, 'probability': true}", 2, 0.6035999999999999, 0.00849941174435032, 0.69, 2.0824435234069822)
# Elapsed time: 2.08s
#
# 42 0.602
# 43 0.599
# 44 0.596
# 45 0.602
# 46 0.619
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'poly', 'degree': 3, 'gamma': 'scale', 'coef0': 0.5, 'probability': true}", 2, 0.6035999999999999, 0.008014985963805558, 0.689, 2.0192020893096925)
# Elapsed time: 2.02s
#
# 42 0.602
# 43 0.599
# 44 0.596
# 45 0.602
# 46 0.619
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'poly', 'degree': 3, 'gamma': 'scale', 'coef0': 1, 'probability': true}", 2, 0.6035999999999999, 0.008014985963805558, 0.689, 2.075714349746704)
# Elapsed time: 2.08s
#
# 42 0.523
# 43 0.51
# 44 0.515
# 45 0.517
# 46 0.524
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'poly', 'degree': 3, 'gamma': 'auto', 'coef0': 0, 'probability': true}", 2, 0.5178, 0.005192301994298872, 0.6050000000000001, 2.3210336208343505)
# Elapsed time: 2.32s
#
# 42 0.602
# 43 0.597
# 44 0.598
# 45 0.603
# 46 0.622
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'poly', 'degree': 3, 'gamma': 'auto', 'coef0': 0.125, 'probability': true}", 2, 0.6043999999999998, 0.009090654541890817, 0.69, 1.9832276344299316)
# Elapsed time: 1.98s
#
# 42 0.6
# 43 0.599
# 44 0.597
# 45 0.603
# 46 0.62
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'poly', 'degree': 3, 'gamma': 'auto', 'coef0': 0.25, 'probability': true}", 2, 0.6038, 0.008328265125462813, 0.69, 2.061524820327759)
# Elapsed time: 2.06s
#
# 42 0.601
# 43 0.599
# 44 0.596
# 45 0.602
# 46 0.619
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'poly', 'degree': 3, 'gamma': 'auto', 'coef0': 0.5, 'probability': true}", 2, 0.6033999999999999, 0.008064738061462389, 0.69, 2.1900210857391356)
# Elapsed time: 2.19s
#
# 42 0.602
# 43 0.599
# 44 0.596
# 45 0.602
# 46 0.619
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'poly', 'degree': 3, 'gamma': 'auto', 'coef0': 1, 'probability': true}", 2, 0.6035999999999999, 0.008014985963805558, 0.69, 2.169681167602539)
# Elapsed time: 2.17s
#
# 42 0.571
# 43 0.57
# 44 0.57
# 45 0.564
# 46 0.582
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'poly', 'degree': 4, 'gamma': 'scale', 'coef0': 0, 'probability': true}", 2, 0.5713999999999999, 0.005851495535331123, 0.6990000000000001, 2.3404837131500242)
# Elapsed time: 2.34s
#
# 42 0.609
# 43 0.6
# 44 0.602
# 45 0.602
# 46 0.626
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'poly', 'degree': 4, 'gamma': 'scale', 'coef0': 0.125, 'probability': true}", 2, 0.6077999999999999, 0.009600000000000008, 0.6980000000000001, 2.77168664932251)
# Elapsed time: 2.77s
#
# 42 0.601
# 43 0.597
# 44 0.606
# 45 0.606
# 46 0.626
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'poly', 'degree': 4, 'gamma': 'scale', 'coef0': 0.25, 'probability': true}", 2, 0.6072, 0.009987992791347027, 0.697, 2.927604341506958)
# Elapsed time: 2.93s
#
# 42 0.603
# 43 0.599
# 44 0.606
# 45 0.605
# 46 0.624
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'poly', 'degree': 4, 'gamma': 'scale', 'coef0': 0.5, 'probability': true}", 2, 0.6073999999999999, 0.008639444426582078, 0.696, 3.3173676490783692)
# Elapsed time: 3.32s
#
# 42 0.601
# 43 0.6
# 44 0.606
# 45 0.605
# 46 0.624
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'poly', 'degree': 4, 'gamma': 'scale', 'coef0': 1, 'probability': true}", 2, 0.6072, 0.008704022058795585, 0.697, 3.898929166793823)
# Elapsed time: 3.90s
#
# 42 0.571
# 43 0.57
# 44 0.57
# 45 0.564
# 46 0.582
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'poly', 'degree': 4, 'gamma': 'auto', 'coef0': 0, 'probability': true}", 2, 0.5713999999999999, 0.005851495535331123, 0.6990000000000001, 2.2722893714904786)
# Elapsed time: 2.27s
#
# 42 0.609
# 43 0.6
# 44 0.603
# 45 0.601
# 46 0.626
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'poly', 'degree': 4, 'gamma': 'auto', 'coef0': 0.125, 'probability': true}", 2, 0.6078, 0.009620810776644563, 0.6980000000000001, 2.8147539138793944)
# Elapsed time: 2.81s
#
# 42 0.601
# 43 0.597
# 44 0.606
# 45 0.606
# 46 0.626
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'poly', 'degree': 4, 'gamma': 'auto', 'coef0': 0.25, 'probability': true}", 2, 0.6072, 0.009987992791347027, 0.697, 2.9314431667327883)
# Elapsed time: 2.93s
#
# 42 0.603
# 43 0.599
# 44 0.606
# 45 0.605
# 46 0.624
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'poly', 'degree': 4, 'gamma': 'auto', 'coef0': 0.5, 'probability': true}", 2, 0.6073999999999999, 0.008639444426582078, 0.696, 3.171750068664551)
# Elapsed time: 3.17s
#
# 42 0.601
# 43 0.599
# 44 0.606
# 45 0.605
# 46 0.624
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'poly', 'degree': 4, 'gamma': 'auto', 'coef0': 1, 'probability': true}", 2, 0.607, 0.008876936408468867, 0.697, 3.900813341140747)
# Elapsed time: 3.90s
#
# 42 0.504
# 43 0.509
# 44 0.503
# 45 0.505
# 46 0.507
# ...
# Elapsed time: 3.17s
#
# 42 0.692
# 43 0.703
# 44 0.709
# 45 0.723
# 46 0.698
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'rbf', 'degree': 3, 'gamma': 'scale', 'coef0': 0.25, 'probability': true}", 6, 0.705, 0.010601886624558866, 0.767, 3.224201774597168)
# Elapsed time: 3.22s
#
# 42 0.692
# 43 0.703
# 44 0.709
# 45 0.723
# 46 0.698
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'rbf', 'degree': 3, 'gamma': 'scale', 'coef0': 0.5, 'probability': true}", 6, 0.705, 0.010601886624558866, 0.767, 3.1701449394226073)
# Elapsed time: 3.17s
#
# 42 0.692
# 43 0.703
# 44 0.709
# 45 0.723
# 46 0.698
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'rbf', 'degree': 3, 'gamma': 'scale', 'coef0': 1, 'probability': true}", 6, 0.705, 0.010601886624558866, 0.767, 3.2280625343322753)
# Elapsed time: 3.23s
#
# 42 0.692
# 43 0.703
# 44 0.708
# 45 0.723
# 46 0.698
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'rbf', 'degree': 3, 'gamma': 'auto', 'coef0': 0, 'probability': true}", 6, 0.7047999999999999, 0.010533755265810962, 0.766, 3.2075440883636475)
# Elapsed time: 3.21s
#
# 42 0.692
# 43 0.703
# 44 0.708
# 45 0.723
# 46 0.698
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'rbf', 'degree': 3, 'gamma': 'auto', 'coef0': 0.125, 'probability': true}", 6, 0.7047999999999999, 0.010533755265810962, 0.766, 3.208999824523926)
# Elapsed time: 3.21s
#
# 42 0.692
# 43 0.703
# 44 0.708
# 45 0.723
# 46 0.698
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'rbf', 'degree': 3, 'gamma': 'auto', 'coef0': 0.25, 'probability': true}", 6, 0.7047999999999999, 0.010533755265810962, 0.766, 3.1599629402160643)
# Elapsed time: 3.16s
#
# 42 0.692
# 43 0.703
# 44 0.708
# 45 0.723
# 46 0.698
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'rbf', 'degree': 3, 'gamma': 'auto', 'coef0': 0.5, 'probability': true}", 6, 0.7047999999999999, 0.010533755265810962, 0.766, 3.270678234100342)
# Elapsed time: 3.27s
#
# 42 0.692
# 43 0.703
# 44 0.708
# 45 0.723
# 46 0.698
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'rbf', 'degree': 3, 'gamma': 'auto', 'coef0': 1, 'probability': true}", 6, 0.7047999999999999, 0.010533755265810962, 0.766, 3.1844246864318846)
# Elapsed time: 3.18s
#
# 42 0.692
# 43 0.703
# 44 0.709
# 45 0.723
# 46 0.698
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'rbf', 'degree': 4, 'gamma': 'scale', 'coef0': 0, 'probability': true}", 6, 0.705, 0.010601886624558866, 0.767, 3.2354318618774416)
# Elapsed time: 3.24s
#
# 42 0.692
# 43 0.703
# 44 0.709
# 45 0.723
# 46 0.698
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'rbf', 'degree': 4, 'gamma': 'scale', 'coef0': 0.125, 'probability': true}", 6, 0.705, 0.010601886624558866, 0.767, 3.2520527839660645)
# Elapsed time: 3.25s
#
# 42 0.692
# 43 0.703
# 44 0.709
# 45 0.723
# 46 0.698
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'rbf', 'degree': 4, 'gamma': 'scale', 'coef0': 0.25, 'probability': true}", 6, 0.705, 0.010601886624558866, 0.767, 3.2841214179992675)
# Elapsed time: 3.28s
#
# 42 0.692
# 43 0.703
# 44 0.709
# 45 0.723
# 46 0.698
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'rbf', 'degree': 4, 'gamma': 'scale', 'coef0': 0.5, 'probability': true}", 6, 0.705, 0.010601886624558866, 0.767, 3.2227087020874023)
# Elapsed time: 3.22s
#
# 42 0.692
# 43 0.703
# 44 0.709
# 45 0.723
# 46 0.698
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'rbf', 'degree': 4, 'gamma': 'scale', 'coef0': 1, 'probability': true}", 6, 0.705, 0.010601886624558866, 0.767, 3.2696162700653075)
# Elapsed time: 3.27s
#
# 42 0.692
# 43 0.703
# 44 0.708
# 45 0.723
# 46 0.698
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'rbf', 'degree': 4, 'gamma': 'auto', 'coef0': 0, 'probability': true}", 6, 0.7047999999999999, 0.010533755265810962, 0.766, 3.2195606231689453)
# Elapsed time: 3.22s
#
# 42 0.692
# 43 0.703
# 44 0.708
# 45 0.723
# 46 0.698
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'rbf', 'degree': 4, 'gamma': 'auto', 'coef0': 0.125, 'probability': true}", 6, 0.7047999999999999, 0.010533755265810962, 0.766, 3.2728261947631836)
# Elapsed time: 3.27s
#
# 42 0.692
# 43 0.703
# 44 0.708
# 45 0.723
# 46 0.698
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'rbf', 'degree': 4, 'gamma': 'auto', 'coef0': 0.25, 'probability': true}", 6, 0.7047999999999999, 0.010533755265810962, 0.766, 3.234637641906738)
# Elapsed time: 3.23s
#
# 42 0.692
# 43 0.703
# 44 0.708
# 45 0.723
# 46 0.698
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'rbf', 'degree': 4, 'gamma': 'auto', 'coef0': 0.5, 'probability': true}", 6, 0.7047999999999999, 0.010533755265810962, 0.766, 3.2118265628814697)
# Elapsed time: 3.21s
#
# 42 0.692
# 43 0.703
# 44 0.708
# 45 0.723
# 46 0.698
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'rbf', 'degree': 4, 'gamma': 'auto', 'coef0': 1, 'probability': true}", 6, 0.7047999999999999, 0.010533755265810962, 0.766, 3.2151774406433105)
# Elapsed time: 3.22s
#
# 42 0.692
# 43 0.703
# 44 0.709
# 45 0.723
# 46 0.698
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'rbf', 'degree': 5, 'gamma': 'scale', 'coef0': 0, 'probability': true}", 6, 0.705, 0.010601886624558866, 0.767, 3.249026823043823)
# Elapsed time: 3.25s
#
# 42 0.692
# 43 0.703
# 44 0.709
# 45 0.723
# 46 0.698
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'rbf', 'degree': 5, 'gamma': 'scale', 'coef0': 0.125, 'probability': true}", 6, 0.705, 0.010601886624558866, 0.767, 3.1041547775268556)
# Elapsed time: 3.10s
#
# 42 0.692
# 43 0.703
# 44 0.709
# 45 0.723
# 46 0.698
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'rbf', 'degree': 5, 'gamma': 'scale', 'coef0': 0.25, 'probability': true}", 6, 0.705, 0.010601886624558866, 0.767, 3.101729679107666)
# Elapsed time: 3.10s
#
# 42 0.692
# 43 0.703
# 44 0.709
# 45 0.723
# 46 0.698
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'rbf', 'degree': 5, 'gamma': 'scale', 'coef0': 0.5, 'probability': true}", 6, 0.705, 0.010601886624558866, 0.767, 3.071893548965454)
# Elapsed time: 3.07s
#
# 42 0.692
# 43 0.703
# 44 0.709
# 45 0.723
# 46 0.698
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'rbf', 'degree': 5, 'gamma': 'scale', 'coef0': 1, 'probability': true}", 6, 0.705, 0.010601886624558866, 0.767, 3.1066685199737547)
# Elapsed time: 3.11s
#
# 42 0.692
# 43 0.703
# 44 0.708
# 45 0.723
# 46 0.698
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'rbf', 'degree': 5, 'gamma': 'auto', 'coef0': 0, 'probability': true}", 6, 0.7047999999999999, 0.010533755265810962, 0.766, 3.120488500595093)
# Elapsed time: 3.12s
#
# 42 0.692
# 43 0.703
# 44 0.708
# 45 0.723
# 46 0.698
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'rbf', 'degree': 5, 'gamma': 'auto', 'coef0': 0.125, 'probability': true}", 6, 0.7047999999999999, 0.010533755265810962, 0.766, 3.1204421043396)
# Elapsed time: 3.12s
#
# 42 0.692
# 43 0.703
# 44 0.708
# 45 0.723
# 46 0.698
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'rbf', 'degree': 5, 'gamma': 'auto', 'coef0': 0.25, 'probability': true}", 6, 0.7047999999999999, 0.010533755265810962, 0.766, 3.0893105030059815)
# Elapsed time: 3.09s
#
# 42 0.692
# 43 0.703
# 44 0.708
# 45 0.723
# 46 0.698
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'rbf', 'degree': 5, 'gamma': 'auto', 'coef0': 0.5, 'probability': true}", 6, 0.7047999999999999, 0.010533755265810962, 0.766, 3.1350374698638914)
# Elapsed time: 3.14s
#
# 42 0.692
# 43 0.703
# 44 0.708
# 45 0.723
# 46 0.698
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'rbf', 'degree': 5, 'gamma': 'auto', 'coef0': 1, 'probability': true}", 6, 0.7047999999999999, 0.010533755265810962, 0.766, 3.4595601081848146)
# Elapsed time: 3.46s
#
# 42 0.516
# 43 0.493
# 44 0.508
# 45 0.521
# 46 0.488
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'sigmoid', 'degree': 3, 'gamma': 'scale', 'coef0': 0, 'probability': true}", 6, 0.5052, 0.012796874618437124, 0.618, 2.4889422416687013)
# Elapsed time: 2.49s
#
# 42 0.401
# 43 0.366
# 44 0.403
# 45 0.363
# 46 0.369
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'sigmoid', 'degree': 3, 'gamma': 'scale', 'coef0': 0.125, 'probability': true}", 6, 0.38039999999999996, 0.017749366185867047, 0.735, 2.365102434158325)
# Elapsed time: 2.37s
#
# 42 0.344
# 43 0.354
# 44 0.35
# 45 0.337
# 46 0.327
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'sigmoid', 'degree': 3, 'gamma': 'scale', 'coef0': 0.25, 'probability': true}", 6, 0.3424, 0.00960416576283436, 0.756, 2.0975191593170166)
# Elapsed time: 2.10s
#
# 42 0.339
# 43 0.321
# 44 0.331
# 45 0.321
# 46 0.313
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'sigmoid', 'degree': 3, 'gamma': 'scale', 'coef0': 0.5, 'probability': true}", 6, 0.325, 0.009033271832508979, 0.774, 2.0447396755218508)
# Elapsed time: 2.04s
#
# 42 0.305
# 43 0.287
# 44 0.297
# 45 0.278
# 46 0.292
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'sigmoid', 'degree': 3, 'gamma': 'scale', 'coef0': 1, 'probability': true}", 6, 0.2918, 0.009108238029388552, 0.777, 2.419193983078003)
# Elapsed time: 2.42s
#
# 42 0.487
# 43 0.508
# 44 0.533
# 45 0.481
# 46 0.506
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'sigmoid', 'degree': 3, 'gamma': 'auto', 'coef0': 0, 'probability': true}", 6, 0.5029999999999999, 0.018297540818372305, 0.604, 2.357517671585083)
# Elapsed time: 2.36s
#
# 42 0.403
# 43 0.381
# 44 0.399
# 45 0.373
# 46 0.374
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'sigmoid', 'degree': 3, 'gamma': 'auto', 'coef0': 0.125, 'probability': true}", 6, 0.386, 0.012617448236470015, 0.728, 2.3992642879486086)
# Elapsed time: 2.40s
#
# 42 0.346
# 43 0.34
# 44 0.35
# 45 0.34
# 46 0.32
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'sigmoid', 'degree': 3, 'gamma': 'auto', 'coef0': 0.25, 'probability': true}", 6, 0.33920000000000006, 0.010322790320451141, 0.757, 2.0837046623229982)
# Elapsed time: 2.08s
#
# 42 0.344
# 43 0.319
# 44 0.336
# 45 0.331
# 46 0.317
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'sigmoid', 'degree': 3, 'gamma': 'auto', 'coef0': 0.5, 'probability': true}", 6, 0.3294, 0.010209799214480168, 0.766, 2.0040334701538085)
# Elapsed time: 2.00s
#
# 42 0.306
# 43 0.287
# 44 0.297
# 45 0.277
# 46 0.292
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'sigmoid', 'degree': 3, 'gamma': 'auto', 'coef0': 1, 'probability': true}", 6, 0.29179999999999995, 0.009703607576566554, 0.7790000000000001, 2.456810140609741)
# Elapsed time: 2.46s
#
# 42 0.516
# 43 0.493
# 44 0.508
# 45 0.521
# 46 0.488
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'sigmoid', 'degree': 4, 'gamma': 'scale', 'coef0': 0, 'probability': true}", 6, 0.5052, 0.012796874618437124, 0.636, 2.3347957134246826)
# Elapsed time: 2.33s
#
# 42 0.401
# 43 0.366
# 44 0.403
# 45 0.363
# 46 0.369
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'sigmoid', 'degree': 4, 'gamma': 'scale', 'coef0': 0.125, 'probability': true}", 6, 0.38039999999999996, 0.017749366185867047, 0.735, 2.3853600025177)
# Elapsed time: 2.39s
#
# 42 0.344
# 43 0.354
# 44 0.35
# 45 0.337
# 46 0.327
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'sigmoid', 'degree': 4, 'gamma': 'scale', 'coef0': 0.25, 'probability': true}", 6, 0.3424, 0.00960416576283436, 0.756, 2.096047115325928)
# Elapsed time: 2.10s
#
# 42 0.339
# 43 0.321
# 44 0.331
# 45 0.321
# 46 0.313
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'sigmoid', 'degree': 4, 'gamma': 'scale', 'coef0': 0.5, 'probability': true}", 6, 0.325, 0.009033271832508979, 0.774, 2.0060563564300535)
# Elapsed time: 2.01s
#
# 42 0.305
# 43 0.287
# 44 0.297
# 45 0.278
# 46 0.292
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'sigmoid', 'degree': 4, 'gamma': 'scale', 'coef0': 1, 'probability': true}", 6, 0.2918, 0.009108238029388552, 0.777, 2.4240582466125487)
# Elapsed time: 2.42s
#
# 42 0.487
# 43 0.508
# 44 0.533
# 45 0.481
# 46 0.506
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'sigmoid', 'degree': 4, 'gamma': 'auto', 'coef0': 0, 'probability': true}", 6, 0.5029999999999999, 0.018297540818372305, 0.6140000000000001, 2.344611406326294)
# Elapsed time: 2.34s
#
# 42 0.403
# 43 0.381
# 44 0.399
# 45 0.373
# 46 0.374
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'sigmoid', 'degree': 4, 'gamma': 'auto', 'coef0': 0.125, 'probability': true}", 6, 0.386, 0.012617448236470015, 0.729, 2.407870388031006)
# Elapsed time: 2.41s
#
# 42 0.346
# 43 0.34
# 44 0.35
# 45 0.34
# 46 0.32
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'sigmoid', 'degree': 4, 'gamma': 'auto', 'coef0': 0.25, 'probability': true}", 6, 0.33920000000000006, 0.010322790320451141, 0.757, 2.147471284866333)
# Elapsed time: 2.15s
#
# 42 0.344
# 43 0.319
# 44 0.336
# 45 0.331
# 46 0.317
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'sigmoid', 'degree': 4, 'gamma': 'auto', 'coef0': 0.5, 'probability': true}", 6, 0.3294, 0.010209799214480168, 0.766, 2.0159865379333497)
# Elapsed time: 2.02s
#
# 42 0.306
# 43 0.287
# 44 0.297
# 45 0.277
# 46 0.292
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'sigmoid', 'degree': 4, 'gamma': 'auto', 'coef0': 1, 'probability': true}", 6, 0.29179999999999995, 0.009703607576566554, 0.7790000000000001, 2.437188911437988)
# Elapsed time: 2.44s
#
# 42 0.516
# 43 0.493
# 44 0.508
# 45 0.521
# 46 0.488
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'sigmoid', 'degree': 5, 'gamma': 'scale', 'coef0': 0, 'probability': true}", 6, 0.5052, 0.012796874618437124, 0.645, 2.3761735916137696)
# Elapsed time: 2.38s
#
# 42 0.401
# 43 0.366
# 44 0.403
# 45 0.363
# 46 0.369
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'sigmoid', 'degree': 5, 'gamma': 'scale', 'coef0': 0.125, 'probability': true}", 6, 0.38039999999999996, 0.017749366185867047, 0.735, 2.3679253578186037)
# Elapsed time: 2.37s
#
# 42 0.344
# 43 0.354
# 44 0.35
# 45 0.337
# 46 0.327
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'sigmoid', 'degree': 5, 'gamma': 'scale', 'coef0': 0.25, 'probability': true}", 6, 0.3424, 0.00960416576283436, 0.756, 2.14277606010437)
# Elapsed time: 2.14s
#
# 42 0.339
# 43 0.321
# 44 0.331
# 45 0.321
# 46 0.313
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'sigmoid', 'degree': 5, 'gamma': 'scale', 'coef0': 0.5, 'probability': true}", 6, 0.325, 0.009033271832508979, 0.774, 2.083121681213379)
# Elapsed time: 2.08s
#
# 42 0.305
# 43 0.287
# 44 0.297
# 45 0.278
# 46 0.292
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'sigmoid', 'degree': 5, 'gamma': 'scale', 'coef0': 1, 'probability': true}", 6, 0.2918, 0.009108238029388552, 0.777, 2.4339507579803468)
# Elapsed time: 2.43s
#
# 42 0.487
# 43 0.508
# 44 0.533
# 45 0.481
# 46 0.506
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'sigmoid', 'degree': 5, 'gamma': 'auto', 'coef0': 0, 'probability': true}", 6, 0.5029999999999999, 0.018297540818372305, 0.5900000000000001, 2.305885744094849)
# Elapsed time: 2.31s
#
# 42 0.403
# 43 0.381
# 44 0.399
# 45 0.373
# 46 0.374
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'sigmoid', 'degree': 5, 'gamma': 'auto', 'coef0': 0.125, 'probability': true}", 6, 0.386, 0.012617448236470015, 0.729, 2.36385293006897)
# Elapsed time: 2.36s
#
# 42 0.346
# 43 0.34
# 44 0.35
# 45 0.34
# 46 0.32
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'sigmoid', 'degree': 5, 'gamma': 'auto', 'coef0': 0.25, 'probability': true}", 6, 0.33920000000000006, 0.010322790320451141, 0.757, 2.102394771575928)
# Elapsed time: 2.10s
#
# 42 0.344
# 43 0.319
# 44 0.336
# 45 0.331
# 46 0.317
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'sigmoid', 'degree': 5, 'gamma': 'auto', 'coef0': 0.5, 'probability': true}", 6, 0.3294, 0.010209799214480168, 0.766, 2.1189912796020507)
# Elapsed time: 2.12s
#
# 42 0.306
# 43 0.287
# 44 0.297
# 45 0.277
# 46 0.292
# ('SelectFromModel', "{'threshold': -Infinity}", 'SVC', "{'kernel': 'sigmoid', 'degree': 5, 'gamma': 'auto', 'coef0': 1, 'probability': true}", 6, 0.29179999999999995, 0.009703607576566554, 0.7790000000000001, 2.4287181377410887)
# Elapsed time: 2.43s
