# %%
import numpy as np
from models import SGD
import datasets.read as data
import seaborn as sns
import pandas as pd
from matplotlib import pyplot as plt

# %%
X, y = data.read_Rice_Cammeo_Osmancik("datasets/")
# Out:
# /home/klimek/sem8_v2/aml/aml_projects/Project1/datasets/read.py:14: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Class'] = df['Class'].replace('Osmancik', 0)

# %%
X.shape
# Out:
# (3810, 7)

# %%
np.isnan(X).sum()
# Out:
# 0

# %%
X[:5,:]
# Out:
# array([[1.52310000e+04, 5.25578979e+02, 2.29749878e+02, 8.50937881e+01,
#         9.28882003e-01, 1.56170000e+04, 5.72895527e-01],
#        [1.46560000e+04, 4.94311005e+02, 2.06020065e+02, 9.17309723e+01,
#         8.95404994e-01, 1.50720000e+04, 6.15436316e-01],
#        [1.46340000e+04, 5.01122009e+02, 2.14106781e+02, 8.77682877e+01,
#         9.12118077e-01, 1.49540000e+04, 6.93258822e-01],
#        [1.31760000e+04, 4.58342987e+02, 1.93337387e+02, 8.74483948e+01,
#         8.91860902e-01, 1.33680000e+04, 6.40669048e-01],
#        [1.46880000e+04, 5.07166992e+02, 2.11743378e+02, 8.93124542e+01,
#         9.06690896e-01, 1.52620000e+04, 6.46023929e-01]])

# %%
y.shape
# Out:
# (3810,)

# %%
np.isnan(y).sum()
# Out:
# 0

# %%
y[:5]
# Out:
# array([1, 1, 1, 1, 1])

# %% [markdown]
# ## SGD test

# %%
m = SGD(iter_limit=500, rate=1E-5)
m.fit(X, y)
m.get_params()['coefficients']
# Out:
# Debug: 0.33556194352203467
# Debug: 0.3328679525348681
# Debug: 0.3139007468050119
# Debug: 0.3106703413492369
# Debug: 0.30385480874127957
# Debug: 0.3226971518275503
# Debug: 0.2890471216433781
# Debug: 0.3119180134740729
# Debug: 0.2776961442343513
# Debug: 0.26478393172374837
# Debug: 0.2690928762328504
# Debug: 0.2552917510114341
# Debug: 0.4517448137748161
# Debug: 0.2463511983858595
# Debug: 0.2472073464066611
# Debug: 0.24488519290688515
# Debug: 0.23690345568866178
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 2
#       1 m = SGD(iter_limit=500, rate=1E-5)
# ----> 2 m.fit(X, y)
#       3 m.get_params()['coefficients']
#
# File ~/sem8_v2/aml/aml_projects/Project1/models/sgd.py:105, in SGD.fit(self, X, y, interactions)
#     103 while True:
#     104     try:
# --> 105         self._iteration(X_copy, y_copy)
#     106     except StopIteration:
#     107         break
#
# File ~/sem8_v2/aml/aml_projects/Project1/models/sgd.py:64, in SGD._iteration(self, X, y)
#      61 self._rng.shuffle(combined_data)
#      63 beta = np.copy(self._beta)
# ---> 64 np.apply_along_axis(lambda r: self._update_beta(r[:-1], r[-1]), 1, combined_data)
#      66 if self._n_iter % 10 == 0:
#      67     print("Debug:", np.linalg.norm(self._beta - beta, ord=np.inf))
#
# File ~/sem8_v2/aml/aml_projects/Project1/venv/lib/python3.10/site-packages/numpy/lib/shape_base.py:402, in apply_along_axis(func1d, axis, arr, *args, **kwargs)
#     400 buff[ind0] = res
#     401 for ind in inds:
# --> 402     buff[ind] = asanyarray(func1d(inarr_view[ind], *args, **kwargs))
#     404 if not isinstance(res, matrix):
#     405     # wrap the array, to preserve subclasses
#     406     buff = res.__array_wrap__(buff)
#
# File ~/sem8_v2/aml/aml_projects/Project1/models/sgd.py:64, in SGD._iteration.<locals>.<lambda>(r)
#      61 self._rng.shuffle(combined_data)
#      63 beta = np.copy(self._beta)
# ---> 64 np.apply_along_axis(lambda r: self._update_beta(r[:-1], r[-1]), 1, combined_data)
#      66 if self._n_iter % 10 == 0:
#      67     print("Debug:", np.linalg.norm(self._beta - beta, ord=np.inf))
#
# File ~/sem8_v2/aml/aml_projects/Project1/models/sgd.py:48, in SGD._update_beta(self, x_sample, y_sample)
#      47 def _update_beta(self, x_sample, y_sample):
# ---> 48     grad = self._gradient3(x_sample, y_sample)
#      49     self._beta -= self._learning_rate * grad
#
# File ~/sem8_v2/aml/aml_projects/Project1/models/sgd.py:43, in SGD._gradient3(self, x_sample, y_sample)
#      42 def _gradient3(self, x_sample, y_sample):
# ---> 43     pred = (_sigmoid(np.dot(x_sample, self._beta)) * 2) - 1
#      45     return -y_sample*x_sample / (np.exp(pred * y_sample) + 1)
#
# KeyboardInterrupt:

# %%
y0 = y==0
y1 = y==1

p0 = m.predict_proba(X[y0])
p1 = m.predict_proba(X[y1])

fig, ax = plt.subplots(1, 2)
ax[0].set_title('Class = 0')
sns.histplot(x=p0, ax=ax[0], binwidth=0.025)
ax[1].set_title('Class = 1')
sns.histplot(x=p1, ax=ax[1], binwidth=0.025)
# Out:
# <Axes: title={'center': 'Class = 1'}, ylabel='Count'>

# %%
y_pred = m.predict(X)
1 - np.abs(y_pred - y).mean()
# Out:
# 0.8178477690288714

# %%
yyy = m.predict_proba(X)
df = pd.DataFrame.from_dict({'prob': yyy, 'color': y})
sns.boxplot(data=df, x='color', y='prob')

(yyy[y1] > 0.99).mean()
perfect_coefs = m.get_params()['coefficients']
perfect_coefs
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 5
#       2 df = pd.DataFrame.from_dict({'prob': yyy, 'color': y})
#       3 sns.boxplot(data=df, x='color', y='prob')
# ----> 5 (yyy[y1] > 0.99).mean()
#       6 perfect_coefs = m.get_params()['coefficients']
#       7 perfect_coefs
#
# NameError: name 'y1' is not defined

# %%
np.all(m.get_params()['weights'] == np.diag(np.ones(X.shape[0])))

# %%
m.get_params()
